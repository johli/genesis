# %%
import keras
from keras.models import Sequential, Model, load_model

from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, LSTM, ConvLSTM2D, GRU, BatchNormalization, LocallyConnected2D, Permute
from keras.layers import Concatenate, Reshape, Softmax, Conv2DTranspose, Embedding, Multiply
from keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from keras import regularizers
from keras import backend as K
from keras.utils.generic_utils import Progbar
from keras.layers.merge import _Merge
import keras.losses

from functools import partial

from collections import defaultdict

import tensorflow as tf
from tensorflow.python.framework import ops

import isolearn.keras as iso

import numpy as np

import tensorflow as tf
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)

import pandas as pd

import os
import pickle
import numpy as np

import scipy.sparse as sp
import scipy.io as spio

import matplotlib.pyplot as plt

import isolearn.io as isoio
import isolearn.keras as isol

from genesis.visualization import *


def iso_normalizer(t) :
    iso = 0.0
    if np.sum(t) > 0.0 :
        iso = np.sum(t[80: 80+25]) / np.sum(t)
    
    return iso

def cut_normalizer(t) :
    cuts = np.concatenate([np.zeros(205), np.array([1.0])])
    if np.sum(t) > 0.0 :
        cuts = t / np.sum(t)
    
    return cuts

def plot_gan_logo(pwm, score, sequence_template=None, figsize=(12, 3), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=164) :

    #Slice according to seq trim index
    pwm = pwm[plot_start: plot_end, :]
    sequence_template = sequence_template[plot_start: plot_end]

    pwm += 0.0001
    for j in range(0, pwm.shape[0]) :
        pwm[j, :] /= np.sum(pwm[j, :])

    entropy = np.zeros(pwm.shape)
    entropy[pwm > 0] = pwm[pwm > 0] * -np.log2(pwm[pwm > 0])
    entropy = np.sum(entropy, axis=1)
    conservation = 2 - entropy

    fig = plt.figure(figsize=figsize)

    gs = gridspec.GridSpec(1, 2, width_ratios=[width_ratios[0], width_ratios[-1]])

    ax2 = plt.subplot(gs[0])
    ax3 = plt.subplot(gs[1])

    plt.sca(ax2)
    plt.axis('off')


    annot_text = '\nScore = ' + str(round(score, 4))

    ax2.text(0.99, 0.5, annot_text, horizontalalignment='right', verticalalignment='center', transform=ax2.transAxes, color='black', fontsize=12, weight="bold")

    height_base = (1.0 - logo_height) / 2.

    for j in range(0, pwm.shape[0]) :
        sort_index = np.argsort(pwm[j, :])

        for ii in range(0, 4) :
            i = sort_index[ii]

            nt_prob = pwm[j, i] * conservation[j]

            nt = ''
            if i == 0 :
                nt = 'A'
            elif i == 1 :
                nt = 'C'
            elif i == 2 :
                nt = 'G'
            elif i == 3 :
                nt = 'T'

            color = None
            if sequence_template[j] != 'N' :
                color = 'black'

            if ii == 0 :
                letterAt(nt, j + 0.5, height_base, nt_prob * logo_height, ax3, color=color)
            else :
                prev_prob = np.sum(pwm[j, sort_index[:ii]] * conservation[j]) * logo_height
                letterAt(nt, j + 0.5, height_base + prev_prob, nt_prob * logo_height, ax3, color=color)

    plt.sca(ax3)

    plt.xlim((0, plot_end - plot_start))
    plt.ylim((0, 2))
    plt.xticks([], [])
    plt.yticks([], [])
    plt.axis('off')
    ax3.axhline(y=0.01 + height_base, color='black', linestyle='-', linewidth=2)


    for axis in fig.axes :
        axis.get_xaxis().set_visible(False)
        axis.get_yaxis().set_visible(False)

    plt.tight_layout()

    plt.show()

from keras.backend.tensorflow_backend import set_session

def contain_tf_gpu_mem_usage() :
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
    set_session(sess)

contain_tf_gpu_mem_usage()
# Out:
# Using TensorFlow backend.

# %%
#Load APA plasmid data (random mpra)
file_path = '../../../../aparent/data/prepared_data/apa_plasmid_data/'
data_version = ''

#plasmid_dict = isoio.load(file_path + 'apa_plasmid_data' + data_version)
plasmid_dict = pickle.load(open('../../../../aparent/apa_plasmid_data.pickle', 'rb'))

plasmid_df = plasmid_dict['plasmid_df']
plasmid_cuts = plasmid_dict['plasmid_cuts']

print("len(plasmid_df) = " + str(len(plasmid_df)))
# Out:
# len(plasmid_df) = 3810974

# %%
#Filter data
kept_libraries = [20]

min_count = 6
min_usage = 0.0
max_usage = 0.15

keep_index = np.nonzero(plasmid_df.sublibrary == "doubledope_5prime_0")[0]
plasmid_df = plasmid_df.iloc[keep_index].copy()
plasmid_cuts = plasmid_cuts[keep_index, :]

keep_index = np.nonzero(plasmid_df.seq.str.slice(70, 76).isin(['ATTAAA', 'AATAAA']))[0]
plasmid_df = plasmid_df.iloc[keep_index].copy()
plasmid_cuts = plasmid_cuts[keep_index, :]

keep_index = np.nonzero(~plasmid_df.seq.str.slice(155, 161).isin(['ATTAAA', 'AATAAA']))[0]
plasmid_df = plasmid_df.iloc[keep_index].copy()
plasmid_cuts = plasmid_cuts[keep_index, :]

if kept_libraries is not None :
    keep_index = np.nonzero(plasmid_df.library_index.isin(kept_libraries))[0]
    plasmid_df = plasmid_df.iloc[keep_index].copy()
    plasmid_cuts = plasmid_cuts[keep_index, :]

if min_count is not None :
    
    keep_index = np.nonzero(plasmid_df.total_count >= min_count)[0]
    
    #total_c = np.ravel(plasmid_cuts[:, 180+70+6:180+70+6+35].sum(axis=-1)) + np.ravel(plasmid_cuts[:, -1].todense())
    #keep_index = np.nonzero(total_c >= min_count)[0]
    
    plasmid_df = plasmid_df.iloc[keep_index].copy()
    plasmid_cuts = plasmid_cuts[keep_index, :]

if min_usage is not None and max_usage is not None :
    
    #prox_c = np.ravel(plasmid_cuts[:, 180+70+6:180+70+6+35].sum(axis=-1))
    #total_c = np.ravel(plasmid_cuts[:, 180:180+205].sum(axis=-1)) + np.ravel(plasmid_cuts[:, -1].todense())
    
    prox_c = np.ravel(plasmid_df.proximal_count)
    total_c = np.ravel(plasmid_df.total_count)
    
    #prox_c = np.ravel(plasmid_cuts[:, 180+70+6:180+70+6+35].sum(axis=-1))
    #total_c = np.ravel(plasmid_cuts[:, 180+70+6:180+70+6+35].sum(axis=-1)) + np.ravel(plasmid_cuts[:, -1].todense())
    
    
    keep_index = np.nonzero((prox_c / total_c >= min_usage) & (prox_c / total_c <= max_usage))[0]
    #keep_index = np.nonzero(plasmid_df.proximal_count / plasmid_df.total_count >= min_usage)[0]
    plasmid_df = plasmid_df.iloc[keep_index].copy()
    plasmid_cuts = plasmid_cuts[keep_index, :]

print("len(plasmid_df) = " + str(len(plasmid_df)) + " (filtered)")
# Out:
# len(plasmid_df) = 11055 (filtered)

# %%
#Store cached filtered dataframe
#pickle.dump({'plasmid_df' : plasmid_df, 'plasmid_cuts' : plasmid_cuts}, open('apa_doubledope_cached_set_weak_short_cano_pas.pickle', 'wb'))

#Load cached dataframe
cached_dict = pickle.load(open('apa_doubledope_cached_set_weak_short_cano_pas.pickle', 'rb'))
plasmid_df = cached_dict['plasmid_df']
plasmid_cuts = cached_dict['plasmid_cuts']

print("len(plasmid_df) = " + str(len(plasmid_df)) + " (loaded)")
# Out:
# len(plasmid_df) = 11278 (loaded)

# %%
#Make generators

valid_set_size = 0.05
test_set_size = 0.05

batch_size = 32

#Generate training and test set indexes
plasmid_index = np.arange(len(plasmid_df), dtype=np.int)

plasmid_train_index = plasmid_index[:-int(len(plasmid_df) * (valid_set_size + test_set_size))]
plasmid_valid_index = plasmid_index[plasmid_train_index.shape[0]:-int(len(plasmid_df) * test_set_size)]
plasmid_test_index = plasmid_index[plasmid_train_index.shape[0] + plasmid_valid_index.shape[0]:]

print('Training set size = ' + str(plasmid_train_index.shape[0]))
print('Validation set size = ' + str(plasmid_valid_index.shape[0]))
print('Test set size = ' + str(plasmid_test_index.shape[0]))


data_gens = {
    gen_id : iso.DataGenerator(
        idx,
        {'df' : plasmid_df},
        batch_size=batch_size,
        inputs = [
            {
                'id' : 'seq',
                'source_type' : 'dataframe',
                'source' : 'df',
                'extractor' : lambda row, index: row['padded_seq'][180 + 40: 180 + 40 + 81] + "G" * (128-81),
                'encoder' : iso.OneHotEncoder(seq_length=128),
                'dim' : (1, 128, 4),
                'sparsify' : False
            }
        ],
        outputs = [
            {
                'id' : 'dummy_output',
                'source_type' : 'zeros',
                'dim' : (1,),
                'sparsify' : False
            }
        ],
        randomizers = [],
        shuffle = True if gen_id == 'train' else False
    ) for gen_id, idx in [('all', plasmid_index), ('train', plasmid_train_index), ('valid', plasmid_valid_index), ('test', plasmid_test_index)]
}
# Out:
# Training set size = 10151
# Validation set size = 564
# Test set size = 563

# %%
x_train = np.concatenate([data_gens['train'][i][0][0] for i in range(len(data_gens['train']))], axis=0)
x_test = np.concatenate([data_gens['test'][i][0][0] for i in range(len(data_gens['test']))], axis=0)

print(x_train.shape)
print(x_test.shape)
# Out:
# (10144, 1, 128, 4)
# (544, 1, 128, 4)

# %%
def load_decoder_network_deconv(batch_size, seq_length=205) :

    #Generator network parameters
    latent_size = 100

    #Policy network definition
    policy_dense_0 = Dense(16 * 384, activation='linear', kernel_initializer='glorot_uniform', name='policy_generator_dense_0')

    policy_dense_0_reshape = Reshape((1, 16, 384))

    policy_deconv_0 = Conv2DTranspose(256, (1, 7), strides=(1, 2), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_deconv_0')

    policy_deconv_1 = Conv2DTranspose(192, (1, 8), strides=(1, 2), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_deconv_1')

    policy_deconv_2 = Conv2DTranspose(128, (1, 7), strides=(1, 2), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_deconv_2')

    policy_conv_3 = Conv2D(4, (1, 7), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_deconv_3')

    batch_norm_dense_0 = BatchNormalization(axis=-1, name='policy_generator_batch_norm_dense_0')
    relu_dense_0 = Lambda(lambda x: K.relu(x))

    batch_norm_0 = BatchNormalization(axis=-1, name='policy_generator_batch_norm_0')
    relu_0 = Lambda(lambda x: K.relu(x))
    
    batch_norm_1 = BatchNormalization(axis=-1, name='policy_generator_batch_norm_1')
    relu_1 = Lambda(lambda x: K.relu(x))
    
    batch_norm_2 = BatchNormalization(axis=-1, name='policy_generator_batch_norm_2')
    relu_2 = Lambda(lambda x: K.relu(x))
    
    def _generator_func(seed_input) :
        relu_dense_0_out = relu_dense_0(batch_norm_dense_0(policy_dense_0_reshape(policy_dense_0(seed_input))))
        
        policy_relu_0_out = relu_0(batch_norm_0(policy_deconv_0(relu_dense_0_out)))
        policy_relu_1_out = relu_1(batch_norm_1(policy_deconv_1(policy_relu_0_out)))
        policy_relu_2_out = relu_2(batch_norm_2(policy_deconv_2(policy_relu_1_out)))

        policy_conv_3_out = policy_conv_3(policy_relu_2_out)
        
        return policy_conv_3_out

    return _generator_func

# %%
#Encoder Model definition
def load_encoder_network_conv(batch_size, seq_length=205, latent_size=100) :

    #Discriminator network definition
    policy_conv_0 = Conv2D(64, (1, 8), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_conv_0')
    policy_batchnorm_0 = BatchNormalization(axis=-1, name='policy_discriminator_batch_norm_0')
    relu_0 = Lambda(lambda x: K.relu(x))
    
    policy_conv_1 = Conv2D(96, (1, 8), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_conv_1')
    policy_batchnorm_1 = BatchNormalization(axis=-1, name='policy_discriminator_batch_norm_1')
    relu_1 = Lambda(lambda x: K.relu(x))
    
    policy_conv_2 = Conv2D(128, (1, 8), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_conv_2')
    policy_batchnorm_2 = BatchNormalization(axis=-1, name='policy_discriminator_batch_norm_2')
    relu_2 = Lambda(lambda x: K.relu(x))
    
    final_flatten = Flatten()
    
    #final_dense = Dense(128, activation='relu', kernel_initializer='glorot_normal', name='policy_discriminator_dense_final')
    #final_drop = Dropout(0.25)
    
    z_mean = Dense(latent_size, name='policy_discriminator_z_mean')
    z_log_var = Dense(latent_size, name='policy_discriminator_z_log_var')
    
    def _encoder_func(sequence_input) :
        relu_0_out = relu_0(policy_batchnorm_0(policy_conv_0(sequence_input)))
        relu_1_out = relu_1(policy_batchnorm_1(policy_conv_1(relu_0_out)))
        relu_2_out = relu_2(policy_batchnorm_2(policy_conv_2(relu_1_out)))

        #Final dense out
        final_dense_out = final_flatten(relu_2_out)#final_drop(final_dense(final_flatten(relu_2_out)))
        
        #Z mean and log variance
        z_mean_out = z_mean(final_dense_out)
        z_log_var_out = z_log_var(final_dense_out)

        return z_mean_out, z_log_var_out

    return _encoder_func

# %%
from tensorflow.python.framework import ops

#Stochastic Binarized Neuron helper functions (Tensorflow)
#ST Estimator code adopted from https://r2rt.com/beyond-binary-ternary-and-one-hot-neurons.html
#See Github https://github.com/spitis/

def st_sampled_softmax(logits):
    with ops.name_scope("STSampledSoftmax") as namescope :
        nt_probs = tf.nn.softmax(logits)
        onehot_dim = logits.get_shape().as_list()[1]
        sampled_onehot = tf.one_hot(tf.squeeze(tf.multinomial(logits, 1), 1), onehot_dim, 1.0, 0.0)
        with tf.get_default_graph().gradient_override_map({'Ceil': 'Identity', 'Mul': 'STMul'}):
            return tf.ceil(sampled_onehot * nt_probs)

def st_hardmax_softmax(logits):
    with ops.name_scope("STHardmaxSoftmax") as namescope :
        nt_probs = tf.nn.softmax(logits)
        onehot_dim = logits.get_shape().as_list()[1]
        sampled_onehot = tf.one_hot(tf.argmax(nt_probs, 1), onehot_dim, 1.0, 0.0)
        with tf.get_default_graph().gradient_override_map({'Ceil': 'Identity', 'Mul': 'STMul'}):
            return tf.ceil(sampled_onehot * nt_probs)

@ops.RegisterGradient("STMul")
def st_mul(op, grad):
    return [grad, grad]

# %%
#PWM Masking and Sampling helper functions

def mask_pwm(inputs) :
    pwm, onehot_template, onehot_mask = inputs

    return pwm * onehot_mask + onehot_template

def sample_pwm_only(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = st_sampled_softmax(flat_pwm)

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))

def sample_pwm(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = sampled_pwm = K.switch(K.learning_phase(), st_sampled_softmax(flat_pwm), st_hardmax_softmax(flat_pwm))

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))

def max_pwm(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = sampled_pwm = st_hardmax_softmax(flat_pwm)

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))


#Generator helper functions
def initialize_sequence_templates(generator, sequence_templates) :

    embedding_templates = []
    embedding_masks = []

    for k in range(len(sequence_templates)) :
        sequence_template = sequence_templates[k]
        onehot_template = iso.OneHotEncoder(seq_length=len(sequence_template))(sequence_template).reshape((1, len(sequence_template), 4))

        for j in range(len(sequence_template)) :
            if sequence_template[j] not in ['N', 'X'] :
                nt_ix = np.argmax(onehot_template[0, j, :])
                onehot_template[:, j, :] = -4.0
                onehot_template[:, j, nt_ix] = 10.0
            elif sequence_template[j] == 'X' :
                onehot_template[:, j, :] = -1.0

        onehot_mask = np.zeros((1, len(sequence_template), 4))
        for j in range(len(sequence_template)) :
            if sequence_template[j] == 'N' :
                onehot_mask[:, j, :] = 1.0

        embedding_templates.append(onehot_template.reshape(1, -1))
        embedding_masks.append(onehot_mask.reshape(1, -1))

    embedding_templates = np.concatenate(embedding_templates, axis=0)
    embedding_masks = np.concatenate(embedding_masks, axis=0)

    generator.get_layer('template_dense').set_weights([embedding_templates])
    generator.get_layer('template_dense').trainable = False

    generator.get_layer('mask_dense').set_weights([embedding_masks])
    generator.get_layer('mask_dense').trainable = False


#Generator construction function
def build_sampler(batch_size, seq_length, n_classes=1, n_samples=None, validation_sample_mode='max') :

    use_samples = True
    if n_samples is None :
        use_samples = False
        n_samples = 1

    
    #Initialize Reshape layer
    reshape_layer = Reshape((1, seq_length, 4))

    #Initialize template and mask matrices
    onehot_template_dense = Embedding(n_classes, seq_length * 4, embeddings_initializer='zeros', name='template_dense')
    onehot_mask_dense = Embedding(n_classes, seq_length * 4, embeddings_initializer='ones', name='mask_dense')

    #Initialize Templating and Masking Lambda layer
    masking_layer = Lambda(mask_pwm, output_shape = (1, seq_length, 4), name='masking_layer')
    
    #Initialize PWM normalization layer
    pwm_layer = Softmax(axis=-1, name='pwm')
    
    #Initialize sampling layers
    sample_func = sample_pwm
    if validation_sample_mode == 'sample' :
        sample_func = sample_pwm_only
    
    upsampling_layer = Lambda(lambda x: K.tile(x, [n_samples, 1, 1, 1]), name='upsampling_layer')
    sampling_layer = Lambda(sample_func, name='pwm_sampler')
    permute_layer = Lambda(lambda x: K.permute_dimensions(K.reshape(x, (n_samples, batch_size, 1, seq_length, 4)), (1, 0, 2, 3, 4)), name='permute_layer')
    
    
    def _sampler_func(class_input, raw_logits) :
        
        #Get Template and Mask
        onehot_template = reshape_layer(onehot_template_dense(class_input))
        onehot_mask = reshape_layer(onehot_mask_dense(class_input))
        
        #Add Template and Multiply Mask
        pwm_logits = masking_layer([raw_logits, onehot_template, onehot_mask])
        
        #Compute PWM (Nucleotide-wise Softmax)
        pwm = pwm_layer(pwm_logits)
        
        sampled_pwm = None
        
        #Optionally tile each PWM to sample from and create sample axis
        if use_samples :
            pwm_logits_upsampled = upsampling_layer(pwm_logits)
            sampled_pwm = sampling_layer(pwm_logits_upsampled)
            sampled_pwm = permute_layer(sampled_pwm)
        else :
            sampled_pwm = sampling_layer(pwm_logits)
        
        
        return pwm_logits, pwm, sampled_pwm
    
    return _sampler_func

# %%
def get_pwm_cross_entropy(pwm_start, pwm_end) :

    def _pwm_cross_entropy(inputs) :
        pwm_true, pwm_pred = inputs
        
        pwm_pred = K.clip(pwm_pred, K.epsilon(), 1. - K.epsilon())

        ce = - K.sum(pwm_true[:, 0, pwm_start:pwm_end, :] * K.log(pwm_pred[:, 0, pwm_start:pwm_end, :]), axis=-1)
        
        return K.expand_dims(K.mean(ce, axis=-1), axis=-1)
    
    return _pwm_cross_entropy

def min_pred(y_true, y_pred) :
    return y_pred

def get_weighted_loss(loss_coeff=1.) :
    
    def _min_pred(y_true, y_pred) :
        return loss_coeff * y_pred
    
    return _min_pred

def get_z_sample(z_inputs):
    
    z_mean, z_log_var = z_inputs
    
    batch_size = K.shape(z_mean)[0]
    latent_dim = K.int_shape(z_mean)[1]
    
    epsilon = K.random_normal(shape=(batch_size, latent_dim))
    
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

def get_z_kl_loss(anneal_coeff) :
    
    def _z_kl_loss(inputs, anneal_coeff=anneal_coeff) :
        z_mean, z_log_var = inputs
        
        kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
        kl_loss = K.mean(kl_loss, axis=-1)
        kl_loss *= -0.5
        
        return anneal_coeff * K.expand_dims(kl_loss, axis=-1)
    
    return _z_kl_loss

# %%
#Simple Library

sequence_templates = [
    'ATCCANNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNCAGCC' + 'G' * (128 - 81)
]

# %%
#Initialize Encoder and Decoder networks
batch_size = 32
seq_length = 128
n_samples = None
latent_size = 100

#Load Encoder
encoder = load_encoder_network_conv(batch_size, seq_length=seq_length, latent_size=latent_size)

#Load Decoder
decoder = load_decoder_network_deconv(batch_size, seq_length=seq_length)

#Load Sampler
sampler = build_sampler(batch_size, seq_length, n_classes=1, n_samples=n_samples, validation_sample_mode='sample')

# %%
#Build Encoder Model
encoder_input = Input(shape=(1, seq_length, 4), name='encoder_input')

z_mean, z_log_var = encoder(encoder_input)

z_sampling_layer = Lambda(get_z_sample, output_shape=(latent_size,), name='z_sampler')
z = z_sampling_layer([z_mean, z_log_var])

# instantiate encoder model
encoder_model = Model(encoder_input, [z_mean, z_log_var, z])
encoder_model.compile(
    optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
    loss=min_pred
)

#Build Decoder Model
decoder_class = Input(shape=(1,), name='decoder_class')
decoder_input = Input(shape=(latent_size,), name='decoder_input')

pwm_logits, pwm, sampled_pwm = sampler(decoder_class, decoder(decoder_input))

decoder_model = Model([decoder_class, decoder_input], [pwm_logits, pwm, sampled_pwm])

#Initialize Sequence Templates and Masks
initialize_sequence_templates(decoder_model, sequence_templates)

decoder_model.compile(
    optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
    loss=min_pred
)

# %%
#Build VAE Pipeline

vae_decoder_class = Input(shape=(1,), name='vae_decoder_class')
vae_encoder_input = Input(shape=(1, seq_length, 4), name='vae_encoder_input')

encoded_z_mean, encoded_z_log_var = encoder(vae_encoder_input)
encoded_z = z_sampling_layer([encoded_z_mean, encoded_z_log_var])
decoded_logits, decoded_pwm, decoded_sample = sampler(vae_decoder_class, decoder(encoded_z))

reconstruction_loss = Lambda(get_pwm_cross_entropy(pwm_start=5, pwm_end=81-5), name='reconstruction')([vae_encoder_input, decoded_pwm])

anneal_coeff = K.variable(0.0)

kl_loss = Lambda(get_z_kl_loss(anneal_coeff), name='kl')([encoded_z_mean, encoded_z_log_var])

vae_model = Model(
    [vae_decoder_class, vae_encoder_input],
    [reconstruction_loss, kl_loss]#, entropy_loss]
)

#Initialize Sequence Templates and Masks
initialize_sequence_templates(vae_model, sequence_templates)

vae_model.compile(
    optimizer=keras.optimizers.Adam(lr=0.0001, beta_1=0.5, beta_2=0.9),
    #optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
    loss={
        'reconstruction' : get_weighted_loss(loss_coeff=1.),
        'kl' : get_weighted_loss(loss_coeff=1.0)#0.5#0.35#0.15#0.05#, #0.000001
        #'entropy' : get_weighted_loss(loss_coeff=0.0)
    }
)

# %%
encoder_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 1, 128, 4)    0
# __________________________________________________________________________________________________
# policy_discriminator_conv_0 (Co (None, 1, 128, 64)   2112        encoder_input[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_batch_norm (None, 1, 128, 64)   256         policy_discriminator_conv_0[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 128, 64)   0           policy_discriminator_batch_norm_0
# __________________________________________________________________________________________________
# policy_discriminator_conv_1 (Co (None, 1, 128, 96)   49248       lambda_1[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_batch_norm (None, 1, 128, 96)   384         policy_discriminator_conv_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1, 128, 96)   0           policy_discriminator_batch_norm_1
# __________________________________________________________________________________________________
# policy_discriminator_conv_2 (Co (None, 1, 128, 128)  98432       lambda_2[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_batch_norm (None, 1, 128, 128)  512         policy_discriminator_conv_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1, 128, 128)  0           policy_discriminator_batch_norm_2
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 16384)        0           lambda_3[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_z_mean (De (None, 100)          1638500     flatten_1[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_z_log_var  (None, 100)          1638500     flatten_1[0][0]
# __________________________________________________________________________________________________
# z_sampler (Lambda)              (None, 100)          0           policy_discriminator_z_mean[0][0]
#                                                                  policy_discriminator_z_log_var[0]
# ==================================================================================================
# Total params: 3,427,944
# Trainable params: 3,427,368
# Non-trainable params: 576
# __________________________________________________________________________________________________

# %%
decoder_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# decoder_input (InputLayer)      (None, 100)          0
# __________________________________________________________________________________________________
# policy_generator_dense_0 (Dense (None, 6144)         620544      decoder_input[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 16, 384)   0           policy_generator_dense_0[0][0]
# __________________________________________________________________________________________________
# policy_generator_batch_norm_den (None, 1, 16, 384)   1536        reshape_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 16, 384)   0           policy_generator_batch_norm_dense
# __________________________________________________________________________________________________
# policy_generator_deconv_0 (Conv (None, 1, 32, 256)   688384      lambda_4[0][0]
# __________________________________________________________________________________________________
# policy_generator_batch_norm_0 ( (None, 1, 32, 256)   1024        policy_generator_deconv_0[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 32, 256)   0           policy_generator_batch_norm_0[0][
# __________________________________________________________________________________________________
# policy_generator_deconv_1 (Conv (None, 1, 64, 192)   393408      lambda_5[0][0]
# __________________________________________________________________________________________________
# policy_generator_batch_norm_1 ( (None, 1, 64, 192)   768         policy_generator_deconv_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1, 64, 192)   0           policy_generator_batch_norm_1[0][
# __________________________________________________________________________________________________
# policy_generator_deconv_2 (Conv (None, 1, 128, 128)  172160      lambda_6[0][0]
# __________________________________________________________________________________________________
# policy_generator_batch_norm_2 ( (None, 1, 128, 128)  512         policy_generator_deconv_2[0][0]
# __________________________________________________________________________________________________
# decoder_class (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1, 128, 128)  0           policy_generator_batch_norm_2[0][
# __________________________________________________________________________________________________
# template_dense (Embedding)      (None, 1, 512)       512         decoder_class[0][0]
# __________________________________________________________________________________________________
# mask_dense (Embedding)          (None, 1, 512)       512         decoder_class[0][0]
# __________________________________________________________________________________________________
# policy_generator_deconv_3 (Conv (None, 1, 128, 4)    3588        lambda_7[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 128, 4)    0           template_dense[0][0]
#                                                                  mask_dense[0][0]
# __________________________________________________________________________________________________
# masking_layer (Lambda)          (None, 1, 128, 4)    0           policy_generator_deconv_3[0][0]
#                                                                  reshape_2[0][0]
#                                                                  reshape_2[1][0]
# __________________________________________________________________________________________________
# pwm (Softmax)                   (None, 1, 128, 4)    0           masking_layer[0][0]
# __________________________________________________________________________________________________
# pwm_sampler (Lambda)            (None, 1, None, 4)   0           masking_layer[0][0]
# ==================================================================================================
# Total params: 1,882,948
# Trainable params: 1,880,004
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
n_epochs = 100

def _anneal_func(val, epoch, n_epochs=n_epochs) :
    if epoch <= 0 :
        return 0.0
    elif epoch <= 3 :
        return 0.1
    elif epoch <= 6 :
        return 0.2
    elif epoch <= 9 :
        return 0.4
    elif epoch <= 12 :
        return 0.6
    elif epoch <= 15 :
        return 0.8
    elif epoch > 15 :
        return 1.0
    return 1.0

# %%
class EpochVariableCallback(Callback):
    def __init__(self, my_variable, my_func):
        self.my_variable = my_variable       
        self.my_func = my_func
    def on_epoch_end(self, epoch, logs={}):
        K.set_value(self.my_variable, self.my_func(K.get_value(self.my_variable), epoch))

s_train = np.zeros((x_train.shape[0], 1))
s_test = np.zeros((x_test.shape[0], 1))

dummy_target_train = np.zeros((x_train.shape[0], 1))
dummy_target_test = np.zeros((x_test.shape[0], 1))

model_name = "vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed"

callbacks =[
    #EarlyStopping(monitor='val_loss', min_delta=0.002, patience=10, verbose=0, mode='auto'),
    ModelCheckpoint("model_checkpoints/" + model_name + "_epoch_{epoch:02d}.hdf5", monitor='val_loss', mode='min', save_weights_only=True),
    EpochVariableCallback(anneal_coeff, _anneal_func)
]

# train the autoencoder
train_history = vae_model.fit(
    [s_train, x_train],
    [dummy_target_train, dummy_target_train],#, dummy_target_train],
    shuffle=True,
    epochs=n_epochs,
    batch_size=batch_size,
    validation_data=(
        [s_test, x_test],
        [dummy_target_test, dummy_target_test]#, dummy_target_test]
    ),
    callbacks=callbacks
)
# Out:
# Train on 10144 samples, validate on 544 samples
# Epoch 1/100
# 10144/10144 [==============================] - 14s 1ms/step - loss: 0.9745 - reconstruction_loss: 0.9745 - kl_loss: 0.0000e+00 - val_loss: 0.9657 - val_reconstruction_loss: 0.9657 - val_kl_loss: 0.0000e+00
# Epoch 2/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.5317 - reconstruction_loss: 0.5317 - kl_loss: 0.0000e+00 - val_loss: 0.5758 - val_reconstruction_loss: 0.5758 - val_kl_loss: 0.0000e+00
# Epoch 3/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.6246 - reconstruction_loss: 0.4079 - kl_loss: 0.2167 - val_loss: 0.5507 - val_reconstruction_loss: 0.3346 - val_kl_loss: 0.2161
# Epoch 4/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.4211 - reconstruction_loss: 0.2311 - kl_loss: 0.1901 - val_loss: 0.4360 - val_reconstruction_loss: 0.2342 - val_kl_loss: 0.2019
# Epoch 5/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.3516 - reconstruction_loss: 0.1630 - kl_loss: 0.1886 - val_loss: 0.3922 - val_reconstruction_loss: 0.1957 - val_kl_loss: 0.1964
# Epoch 6/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.4937 - reconstruction_loss: 0.1804 - kl_loss: 0.3133 - val_loss: 0.5223 - val_reconstruction_loss: 0.2029 - val_kl_loss: 0.3194
# Epoch 7/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.4736 - reconstruction_loss: 0.1651 - kl_loss: 0.3085 - val_loss: 0.5249 - val_reconstruction_loss: 0.2089 - val_kl_loss: 0.3160
# Epoch 8/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.4618 - reconstruction_loss: 0.1543 - kl_loss: 0.3075 - val_loss: 0.5038 - val_reconstruction_loss: 0.1988 - val_kl_loss: 0.3050
# Epoch 9/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.7243 - reconstruction_loss: 0.2219 - kl_loss: 0.5023 - val_loss: 0.7412 - val_reconstruction_loss: 0.2443 - val_kl_loss: 0.4969
# Epoch 10/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.7103 - reconstruction_loss: 0.2207 - kl_loss: 0.4896 - val_loss: 0.7680 - val_reconstruction_loss: 0.2669 - val_kl_loss: 0.5011
# Epoch 11/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.7012 - reconstruction_loss: 0.2164 - kl_loss: 0.4848 - val_loss: 0.7685 - val_reconstruction_loss: 0.2920 - val_kl_loss: 0.4765
# Epoch 12/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.9133 - reconstruction_loss: 0.2902 - kl_loss: 0.6231 - val_loss: 0.9691 - val_reconstruction_loss: 0.3459 - val_kl_loss: 0.6232
# Epoch 13/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.9012 - reconstruction_loss: 0.2983 - kl_loss: 0.6029 - val_loss: 0.9601 - val_reconstruction_loss: 0.3758 - val_kl_loss: 0.5844
# Epoch 14/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.8940 - reconstruction_loss: 0.2970 - kl_loss: 0.5970 - val_loss: 0.9561 - val_reconstruction_loss: 0.3606 - val_kl_loss: 0.5956
# Epoch 15/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0677 - reconstruction_loss: 0.3914 - kl_loss: 0.6763 - val_loss: 1.1054 - val_reconstruction_loss: 0.4430 - val_kl_loss: 0.6624
# Epoch 16/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0584 - reconstruction_loss: 0.4057 - kl_loss: 0.6527 - val_loss: 1.0972 - val_reconstruction_loss: 0.4298 - val_kl_loss: 0.6674
# Epoch 17/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0503 - reconstruction_loss: 0.4025 - kl_loss: 0.6478 - val_loss: 1.1495 - val_reconstruction_loss: 0.4674 - val_kl_loss: 0.6821
# Epoch 18/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1886 - reconstruction_loss: 0.5311 - kl_loss: 0.6574 - val_loss: 1.2386 - val_reconstruction_loss: 0.5912 - val_kl_loss: 0.6474
# Epoch 19/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1804 - reconstruction_loss: 0.5565 - kl_loss: 0.6238 - val_loss: 1.2077 - val_reconstruction_loss: 0.5811 - val_kl_loss: 0.6266
# Epoch 20/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1744 - reconstruction_loss: 0.5561 - kl_loss: 0.6184 - val_loss: 1.2197 - val_reconstruction_loss: 0.5958 - val_kl_loss: 0.6239
# Epoch 21/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1693 - reconstruction_loss: 0.5522 - kl_loss: 0.6171 - val_loss: 1.2282 - val_reconstruction_loss: 0.5701 - val_kl_loss: 0.6581
# Epoch 22/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1646 - reconstruction_loss: 0.5476 - kl_loss: 0.6171 - val_loss: 1.2235 - val_reconstruction_loss: 0.5883 - val_kl_loss: 0.6352
# Epoch 23/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1612 - reconstruction_loss: 0.5443 - kl_loss: 0.6170 - val_loss: 1.2198 - val_reconstruction_loss: 0.6234 - val_kl_loss: 0.5964
# Epoch 24/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1558 - reconstruction_loss: 0.5392 - kl_loss: 0.6165 - val_loss: 1.2077 - val_reconstruction_loss: 0.5660 - val_kl_loss: 0.6417
# Epoch 25/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1502 - reconstruction_loss: 0.5344 - kl_loss: 0.6159 - val_loss: 1.2168 - val_reconstruction_loss: 0.6052 - val_kl_loss: 0.6116
# Epoch 26/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1479 - reconstruction_loss: 0.5315 - kl_loss: 0.6164 - val_loss: 1.2128 - val_reconstruction_loss: 0.5943 - val_kl_loss: 0.6185
# Epoch 27/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1441 - reconstruction_loss: 0.5267 - kl_loss: 0.6174 - val_loss: 1.2068 - val_reconstruction_loss: 0.5882 - val_kl_loss: 0.6186
# Epoch 28/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1398 - reconstruction_loss: 0.5220 - kl_loss: 0.6178 - val_loss: 1.2075 - val_reconstruction_loss: 0.5634 - val_kl_loss: 0.6441
# Epoch 29/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1365 - reconstruction_loss: 0.5188 - kl_loss: 0.6178 - val_loss: 1.2126 - val_reconstruction_loss: 0.5879 - val_kl_loss: 0.6247
# Epoch 30/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1329 - reconstruction_loss: 0.5147 - kl_loss: 0.6181 - val_loss: 1.2062 - val_reconstruction_loss: 0.5970 - val_kl_loss: 0.6092
# Epoch 31/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1301 - reconstruction_loss: 0.5104 - kl_loss: 0.6198 - val_loss: 1.2068 - val_reconstruction_loss: 0.5756 - val_kl_loss: 0.6313
# Epoch 32/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1252 - reconstruction_loss: 0.5052 - kl_loss: 0.6199 - val_loss: 1.2136 - val_reconstruction_loss: 0.6110 - val_kl_loss: 0.6026
# Epoch 33/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1237 - reconstruction_loss: 0.5013 - kl_loss: 0.6224 - val_loss: 1.2083 - val_reconstruction_loss: 0.5982 - val_kl_loss: 0.6102
# Epoch 34/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1192 - reconstruction_loss: 0.4959 - kl_loss: 0.6232 - val_loss: 1.2150 - val_reconstruction_loss: 0.6136 - val_kl_loss: 0.6014
# Epoch 35/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1165 - reconstruction_loss: 0.4932 - kl_loss: 0.6233 - val_loss: 1.1943 - val_reconstruction_loss: 0.5730 - val_kl_loss: 0.6213
# Epoch 36/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1141 - reconstruction_loss: 0.4899 - kl_loss: 0.6242 - val_loss: 1.2050 - val_reconstruction_loss: 0.5746 - val_kl_loss: 0.6304
# Epoch 37/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1087 - reconstruction_loss: 0.4841 - kl_loss: 0.6246 - val_loss: 1.1996 - val_reconstruction_loss: 0.5987 - val_kl_loss: 0.6009
# Epoch 38/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1079 - reconstruction_loss: 0.4822 - kl_loss: 0.6257 - val_loss: 1.2068 - val_reconstruction_loss: 0.5719 - val_kl_loss: 0.6349
# Epoch 39/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1039 - reconstruction_loss: 0.4794 - kl_loss: 0.6244 - val_loss: 1.2042 - val_reconstruction_loss: 0.5426 - val_kl_loss: 0.6616
# Epoch 40/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1010 - reconstruction_loss: 0.4730 - kl_loss: 0.6280 - val_loss: 1.2012 - val_reconstruction_loss: 0.5811 - val_kl_loss: 0.6201
# Epoch 41/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0997 - reconstruction_loss: 0.4696 - kl_loss: 0.6301 - val_loss: 1.2030 - val_reconstruction_loss: 0.6066 - val_kl_loss: 0.5964
# Epoch 42/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0973 - reconstruction_loss: 0.4675 - kl_loss: 0.6298 - val_loss: 1.2048 - val_reconstruction_loss: 0.5695 - val_kl_loss: 0.6353
# Epoch 43/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0941 - reconstruction_loss: 0.4644 - kl_loss: 0.6297 - val_loss: 1.2071 - val_reconstruction_loss: 0.5558 - val_kl_loss: 0.6512
# Epoch 44/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0915 - reconstruction_loss: 0.4594 - kl_loss: 0.6321 - val_loss: 1.2059 - val_reconstruction_loss: 0.5505 - val_kl_loss: 0.6553
# Epoch 45/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0895 - reconstruction_loss: 0.4579 - kl_loss: 0.6317 - val_loss: 1.2103 - val_reconstruction_loss: 0.5960 - val_kl_loss: 0.6143
# Epoch 46/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0856 - reconstruction_loss: 0.4533 - kl_loss: 0.6323 - val_loss: 1.2104 - val_reconstruction_loss: 0.5708 - val_kl_loss: 0.6396
# Epoch 47/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0856 - reconstruction_loss: 0.4500 - kl_loss: 0.6356 - val_loss: 1.2126 - val_reconstruction_loss: 0.5945 - val_kl_loss: 0.6181
# Epoch 48/100
# 10144/10144 [==============================] - 10s 997us/step - loss: 1.0816 - reconstruction_loss: 0.4471 - kl_loss: 0.6345 - val_loss: 1.2217 - val_reconstruction_loss: 0.6369 - val_kl_loss: 0.5848
# Epoch 49/100
# 10144/10144 [==============================] - 10s 997us/step - loss: 1.0810 - reconstruction_loss: 0.4432 - kl_loss: 0.6378 - val_loss: 1.2085 - val_reconstruction_loss: 0.5444 - val_kl_loss: 0.6641
# Epoch 50/100
# 10144/10144 [==============================] - 10s 998us/step - loss: 1.0786 - reconstruction_loss: 0.4401 - kl_loss: 0.6385 - val_loss: 1.2101 - val_reconstruction_loss: 0.5539 - val_kl_loss: 0.6562
# Epoch 51/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0756 - reconstruction_loss: 0.4373 - kl_loss: 0.6383 - val_loss: 1.2175 - val_reconstruction_loss: 0.5745 - val_kl_loss: 0.6429
# Epoch 52/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0735 - reconstruction_loss: 0.4342 - kl_loss: 0.6392 - val_loss: 1.2104 - val_reconstruction_loss: 0.5781 - val_kl_loss: 0.6323
# Epoch 53/100
# 10144/10144 [==============================] - 10s 998us/step - loss: 1.0726 - reconstruction_loss: 0.4309 - kl_loss: 0.6417 - val_loss: 1.2287 - val_reconstruction_loss: 0.6447 - val_kl_loss: 0.5840
# Epoch 54/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0697 - reconstruction_loss: 0.4273 - kl_loss: 0.6424 - val_loss: 1.2177 - val_reconstruction_loss: 0.5727 - val_kl_loss: 0.6450
# Epoch 55/100
# 10144/10144 [==============================] - 10s 998us/step - loss: 1.0676 - reconstruction_loss: 0.4264 - kl_loss: 0.6412 - val_loss: 1.2215 - val_reconstruction_loss: 0.6082 - val_kl_loss: 0.6133
# Epoch 56/100
# 10144/10144 [==============================] - 10s 998us/step - loss: 1.0655 - reconstruction_loss: 0.4224 - kl_loss: 0.6432 - val_loss: 1.2132 - val_reconstruction_loss: 0.5476 - val_kl_loss: 0.6656
# Epoch 57/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0637 - reconstruction_loss: 0.4204 - kl_loss: 0.6433 - val_loss: 1.2146 - val_reconstruction_loss: 0.5508 - val_kl_loss: 0.6638
# Epoch 58/100
# 10144/10144 [==============================] - 10s 997us/step - loss: 1.0627 - reconstruction_loss: 0.4170 - kl_loss: 0.6456 - val_loss: 1.2113 - val_reconstruction_loss: 0.5710 - val_kl_loss: 0.6403
# Epoch 59/100
# 10144/10144 [==============================] - 10s 1000us/step - loss: 1.0603 - reconstruction_loss: 0.4157 - kl_loss: 0.6446 - val_loss: 1.2255 - val_reconstruction_loss: 0.5045 - val_kl_loss: 0.7211
# Epoch 60/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0589 - reconstruction_loss: 0.4128 - kl_loss: 0.6461 - val_loss: 1.2141 - val_reconstruction_loss: 0.5722 - val_kl_loss: 0.6419
# Epoch 61/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0576 - reconstruction_loss: 0.4103 - kl_loss: 0.6473 - val_loss: 1.2210 - val_reconstruction_loss: 0.5741 - val_kl_loss: 0.6469
# Epoch 62/100
# 10144/10144 [==============================] - 10s 998us/step - loss: 1.0558 - reconstruction_loss: 0.4071 - kl_loss: 0.6487 - val_loss: 1.2261 - val_reconstruction_loss: 0.5618 - val_kl_loss: 0.6643
# Epoch 63/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0532 - reconstruction_loss: 0.4048 - kl_loss: 0.6484 - val_loss: 1.2163 - val_reconstruction_loss: 0.5744 - val_kl_loss: 0.6419
# Epoch 64/100
# 10144/10144 [==============================] - 10s 998us/step - loss: 1.0522 - reconstruction_loss: 0.4030 - kl_loss: 0.6492 - val_loss: 1.2404 - val_reconstruction_loss: 0.6398 - val_kl_loss: 0.6006
# Epoch 65/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0508 - reconstruction_loss: 0.4008 - kl_loss: 0.6500 - val_loss: 1.2221 - val_reconstruction_loss: 0.5756 - val_kl_loss: 0.6465
# Epoch 66/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0503 - reconstruction_loss: 0.3987 - kl_loss: 0.6516 - val_loss: 1.2232 - val_reconstruction_loss: 0.5461 - val_kl_loss: 0.6771
# Epoch 67/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0469 - reconstruction_loss: 0.3956 - kl_loss: 0.6514 - val_loss: 1.2205 - val_reconstruction_loss: 0.5577 - val_kl_loss: 0.6628
# Epoch 68/100
# 10144/10144 [==============================] - 10s 998us/step - loss: 1.0481 - reconstruction_loss: 0.3955 - kl_loss: 0.6526 - val_loss: 1.2268 - val_reconstruction_loss: 0.5562 - val_kl_loss: 0.6706
# Epoch 69/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0443 - reconstruction_loss: 0.3918 - kl_loss: 0.6525 - val_loss: 1.2368 - val_reconstruction_loss: 0.6264 - val_kl_loss: 0.6103
# Epoch 70/100
# 10144/10144 [==============================] - 10s 996us/step - loss: 1.0431 - reconstruction_loss: 0.3909 - kl_loss: 0.6522 - val_loss: 1.2308 - val_reconstruction_loss: 0.5665 - val_kl_loss: 0.6644
# Epoch 71/100
# 10144/10144 [==============================] - 10s 997us/step - loss: 1.0442 - reconstruction_loss: 0.3887 - kl_loss: 0.6555 - val_loss: 1.2376 - val_reconstruction_loss: 0.5613 - val_kl_loss: 0.6762
# Epoch 72/100
# 10144/10144 [==============================] - 10s 997us/step - loss: 1.0415 - reconstruction_loss: 0.3860 - kl_loss: 0.6556 - val_loss: 1.2686 - val_reconstruction_loss: 0.6951 - val_kl_loss: 0.5734
# Epoch 73/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0400 - reconstruction_loss: 0.3837 - kl_loss: 0.6564 - val_loss: 1.2371 - val_reconstruction_loss: 0.5373 - val_kl_loss: 0.6998
# Epoch 74/100
# 10144/10144 [==============================] - 10s 997us/step - loss: 1.0393 - reconstruction_loss: 0.3808 - kl_loss: 0.6585 - val_loss: 1.2374 - val_reconstruction_loss: 0.6074 - val_kl_loss: 0.6300
# Epoch 75/100
# 10144/10144 [==============================] - 10s 1000us/step - loss: 1.0376 - reconstruction_loss: 0.3797 - kl_loss: 0.6580 - val_loss: 1.2588 - val_reconstruction_loss: 0.6772 - val_kl_loss: 0.5816
# Epoch 76/100
# 10144/10144 [==============================] - 10s 990us/step - loss: 1.0347 - reconstruction_loss: 0.3778 - kl_loss: 0.6569 - val_loss: 1.2498 - val_reconstruction_loss: 0.6492 - val_kl_loss: 0.6007
# Epoch 77/100
# 10144/10144 [==============================] - 10s 990us/step - loss: 1.0355 - reconstruction_loss: 0.3767 - kl_loss: 0.6588 - val_loss: 1.2456 - val_reconstruction_loss: 0.5705 - val_kl_loss: 0.6751
# Epoch 78/100
# 10144/10144 [==============================] - 10s 994us/step - loss: 1.0350 - reconstruction_loss: 0.3738 - kl_loss: 0.6612 - val_loss: 1.2470 - val_reconstruction_loss: 0.5219 - val_kl_loss: 0.7251
# Epoch 79/100
# 10144/10144 [==============================] - 10s 991us/step - loss: 1.0328 - reconstruction_loss: 0.3732 - kl_loss: 0.6597 - val_loss: 1.2400 - val_reconstruction_loss: 0.5710 - val_kl_loss: 0.6691
# Epoch 80/100
# 10144/10144 [==============================] - 10s 995us/step - loss: 1.0325 - reconstruction_loss: 0.3719 - kl_loss: 0.6606 - val_loss: 1.2508 - val_reconstruction_loss: 0.6379 - val_kl_loss: 0.6130
# Epoch 81/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0294 - reconstruction_loss: 0.3685 - kl_loss: 0.6610 - val_loss: 1.2722 - val_reconstruction_loss: 0.6795 - val_kl_loss: 0.5926
# Epoch 82/100
# 10144/10144 [==============================] - 10s 996us/step - loss: 1.0285 - reconstruction_loss: 0.3678 - kl_loss: 0.6607 - val_loss: 1.2450 - val_reconstruction_loss: 0.5722 - val_kl_loss: 0.6729
# Epoch 83/100
# 10144/10144 [==============================] - 10s 996us/step - loss: 1.0276 - reconstruction_loss: 0.3664 - kl_loss: 0.6612 - val_loss: 1.2499 - val_reconstruction_loss: 0.5953 - val_kl_loss: 0.6546
# Epoch 84/100
# 10144/10144 [==============================] - 10s 994us/step - loss: 1.0260 - reconstruction_loss: 0.3642 - kl_loss: 0.6618 - val_loss: 1.2413 - val_reconstruction_loss: 0.5881 - val_kl_loss: 0.6531
# Epoch 85/100
# 10144/10144 [==============================] - 10s 996us/step - loss: 1.0245 - reconstruction_loss: 0.3622 - kl_loss: 0.6622 - val_loss: 1.2579 - val_reconstruction_loss: 0.5095 - val_kl_loss: 0.7484
# Epoch 86/100
# 10144/10144 [==============================] - 10s 995us/step - loss: 1.0252 - reconstruction_loss: 0.3613 - kl_loss: 0.6639 - val_loss: 1.2666 - val_reconstruction_loss: 0.6707 - val_kl_loss: 0.5959
# Epoch 87/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0229 - reconstruction_loss: 0.3596 - kl_loss: 0.6633 - val_loss: 1.2629 - val_reconstruction_loss: 0.6448 - val_kl_loss: 0.6181
# Epoch 88/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0236 - reconstruction_loss: 0.3588 - kl_loss: 0.6647 - val_loss: 1.3201 - val_reconstruction_loss: 0.7879 - val_kl_loss: 0.5322
# Epoch 89/100
# 10144/10144 [==============================] - 10s 998us/step - loss: 1.0208 - reconstruction_loss: 0.3572 - kl_loss: 0.6637 - val_loss: 1.2681 - val_reconstruction_loss: 0.6562 - val_kl_loss: 0.6120
# Epoch 90/100
# 10144/10144 [==============================] - 10s 996us/step - loss: 1.0212 - reconstruction_loss: 0.3565 - kl_loss: 0.6647 - val_loss: 1.2606 - val_reconstruction_loss: 0.6320 - val_kl_loss: 0.6286
# Epoch 91/100
# 10144/10144 [==============================] - 10s 996us/step - loss: 1.0202 - reconstruction_loss: 0.3551 - kl_loss: 0.6651 - val_loss: 1.2606 - val_reconstruction_loss: 0.5225 - val_kl_loss: 0.7381
# Epoch 92/100
# 10144/10144 [==============================] - 10s 995us/step - loss: 1.0188 - reconstruction_loss: 0.3543 - kl_loss: 0.6646 - val_loss: 1.2708 - val_reconstruction_loss: 0.5074 - val_kl_loss: 0.7634
# Epoch 93/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0183 - reconstruction_loss: 0.3518 - kl_loss: 0.6665 - val_loss: 1.2818 - val_reconstruction_loss: 0.6610 - val_kl_loss: 0.6209
# Epoch 94/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0166 - reconstruction_loss: 0.3519 - kl_loss: 0.6647 - val_loss: 1.2936 - val_reconstruction_loss: 0.4729 - val_kl_loss: 0.8207
# Epoch 95/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0158 - reconstruction_loss: 0.3511 - kl_loss: 0.6647 - val_loss: 1.2658 - val_reconstruction_loss: 0.5487 - val_kl_loss: 0.7171
# Epoch 96/100
# 10144/10144 [==============================] - 10s 999us/step - loss: 1.0152 - reconstruction_loss: 0.3483 - kl_loss: 0.6669 - val_loss: 1.2714 - val_reconstruction_loss: 0.6160 - val_kl_loss: 0.6554
# Epoch 97/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0130 - reconstruction_loss: 0.3472 - kl_loss: 0.6659 - val_loss: 1.2765 - val_reconstruction_loss: 0.6507 - val_kl_loss: 0.6257
# Epoch 98/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0116 - reconstruction_loss: 0.3470 - kl_loss: 0.6647 - val_loss: 1.2780 - val_reconstruction_loss: 0.4920 - val_kl_loss: 0.7860
# Epoch 99/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0130 - reconstruction_loss: 0.3462 - kl_loss: 0.6668 - val_loss: 1.2676 - val_reconstruction_loss: 0.5586 - val_kl_loss: 0.7090
# Epoch 100/100
# 10144/10144 [==============================] - 10s 1000us/step - loss: 1.0108 - reconstruction_loss: 0.3442 - kl_loss: 0.6666 - val_loss: 1.2868 - val_reconstruction_loss: 0.6822 - val_kl_loss: 0.6045

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(4.5 * 2, 4))

n_epochs_actual = len(train_history.history['reconstruction_loss'])

ax1.plot(np.arange(1, n_epochs_actual + 1), train_history.history['reconstruction_loss'], linewidth=3, color='green')
ax1.plot(np.arange(1, n_epochs_actual + 1), train_history.history['val_reconstruction_loss'], linewidth=3, color='orange')

plt.sca(ax1)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Reconstruction Loss", fontsize=14)
plt.xlim(1, n_epochs_actual)
plt.xticks([1, n_epochs_actual], [1, n_epochs], fontsize=12)
plt.yticks(fontsize=12)

ax2.plot(np.arange(1, n_epochs_actual + 1), train_history.history['kl_loss'], linewidth=3, color='green')
ax2.plot(np.arange(1, n_epochs_actual + 1), train_history.history['val_kl_loss'], linewidth=3, color='orange')

plt.sca(ax2)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("KL Divergence", fontsize=14)
plt.xlim(1, n_epochs_actual)
plt.xticks([1, n_epochs_actual], [1, n_epochs], fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()

plt.show()

# %%
# Save model and weights
save_dir = 'saved_models'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_encoder.h5'
model_path = os.path.join(save_dir, model_name)
encoder_model.save(model_path)
print('Saved trained model at %s ' % model_path)

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_decoder.h5'
model_path = os.path.join(save_dir, model_name)
decoder_model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at saved_models/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_encoder.h5
# Saved trained model at saved_models/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_decoder.h5

# %%
#Load models
save_dir = 'saved_models'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_encoder.h5'
model_path = os.path.join(save_dir, model_name)
encoder_model = load_model(model_path, custom_objects={'st_sampled_softmax':st_sampled_softmax, 'st_hardmax_softmax':st_hardmax_softmax, 'min_pred':min_pred})

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_decoder.h5'
model_path = os.path.join(save_dir, model_name)
decoder_model = load_model(model_path, custom_objects={'st_sampled_softmax':st_sampled_softmax, 'st_hardmax_softmax':st_hardmax_softmax, 'min_pred':min_pred})

# %%
encoder_model.load_weights("model_checkpoints/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_epoch_50.hdf5", by_name=True)
decoder_model.load_weights("model_checkpoints/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_epoch_50.hdf5", by_name=True)

# %%
# Save model and weights
save_dir = 'saved_models'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_encoder_epoch_50.h5'
model_path = os.path.join(save_dir, model_name)
encoder_model.save(model_path)
print('Saved trained model at %s ' % model_path)

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_decoder_epoch_50.h5'
model_path = os.path.join(save_dir, model_name)
decoder_model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at saved_models/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_encoder_epoch_50.h5
# Saved trained model at saved_models/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_very_high_kl_convnet_no_drop_annealed_decoder_epoch_50.h5

# %%
#Visualize a few fake and real sequence patterns

s_test = np.zeros((x_test.shape[0], 1))

z_mean_test, z_log_var_test, z_test = encoder_model.predict([x_test], batch_size=32, verbose=True)

fake_pwm_test_batch = decoder_model.predict([s_test, z_test], batch_size=32, verbose=True)

for plot_i in range(5) :
    print("Test sequence " + str(plot_i) + ":")
    plot_gan_logo(x_test[plot_i, 0, :, :], 0, sequence_template=('N' * 128), figsize=(12, 0.75), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=81)
    plot_gan_logo(fake_pwm_test_batch[1][plot_i, 0, :, :], 0, sequence_template=('N' * 128), figsize=(12, 0.75), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=81)
# Out:
# 544/544 [==============================] - 0s 132us/step
# 544/544 [==============================] - 0s 271us/step
# Test sequence 0:
# Test sequence 1:
# Test sequence 2:
# Test sequence 3:
# Test sequence 4:

# %%
#Sample new patterns

z_test_new = np.random.normal(loc=0.0, scale=1.0, size=(32, 100))

fake_pwm_test_batch = decoder_model.predict_on_batch([s_test[:32], z_test_new[:32]])

print("- Fake PWMs (Randomly Generated) -")

for plot_i in range(32) :
    plot_gan_logo(fake_pwm_test_batch[1][plot_i, 0, :, :], 0, sequence_template=('N' * 128), figsize=(12, 0.55), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=128)
# Out:
# - Fake PWMs (Randomly Generated) -
