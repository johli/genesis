# %%
import keras
from keras.models import Sequential, Model, load_model

from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Conv1D, MaxPooling1D, LSTM, ConvLSTM2D, GRU, BatchNormalization, LocallyConnected2D, Permute
from keras.layers import Concatenate, Reshape, Softmax, Conv2DTranspose, Embedding, Multiply
from keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from keras import regularizers
from keras import backend as K
from keras.utils.generic_utils import Progbar
from keras.layers.merge import _Merge
import keras.losses

from functools import partial

from collections import defaultdict

import tensorflow as tf
from tensorflow.python.framework import ops

import isolearn.keras as iso

import numpy as np

import tensorflow as tf
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)

import pandas as pd

import os
import pickle
import numpy as np

import scipy.sparse as sp
import scipy.io as spio

import matplotlib.pyplot as plt

import isolearn.io as isoio
import isolearn.keras as isol

from genesis.visualization import *


def iso_normalizer(t) :
    iso = 0.0
    if np.sum(t) > 0.0 :
        iso = np.sum(t[80: 80+25]) / np.sum(t)
    
    return iso

def cut_normalizer(t) :
    cuts = np.concatenate([np.zeros(205), np.array([1.0])])
    if np.sum(t) > 0.0 :
        cuts = t / np.sum(t)
    
    return cuts

def plot_gan_logo(pwm, score, sequence_template=None, figsize=(12, 3), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=164) :

    #Slice according to seq trim index
    pwm = pwm[plot_start: plot_end, :]
    sequence_template = sequence_template[plot_start: plot_end]

    pwm += 0.0001
    for j in range(0, pwm.shape[0]) :
        pwm[j, :] /= np.sum(pwm[j, :])

    entropy = np.zeros(pwm.shape)
    entropy[pwm > 0] = pwm[pwm > 0] * -np.log2(pwm[pwm > 0])
    entropy = np.sum(entropy, axis=1)
    conservation = 2 - entropy

    fig = plt.figure(figsize=figsize)

    gs = gridspec.GridSpec(1, 2, width_ratios=[width_ratios[0], width_ratios[-1]])

    ax2 = plt.subplot(gs[0])
    ax3 = plt.subplot(gs[1])

    plt.sca(ax2)
    plt.axis('off')


    annot_text = '\nScore = ' + str(round(score, 4))

    ax2.text(0.99, 0.5, annot_text, horizontalalignment='right', verticalalignment='center', transform=ax2.transAxes, color='black', fontsize=12, weight="bold")

    height_base = (1.0 - logo_height) / 2.

    for j in range(0, pwm.shape[0]) :
        sort_index = np.argsort(pwm[j, :])

        for ii in range(0, 4) :
            i = sort_index[ii]

            nt_prob = pwm[j, i] * conservation[j]

            nt = ''
            if i == 0 :
                nt = 'A'
            elif i == 1 :
                nt = 'C'
            elif i == 2 :
                nt = 'G'
            elif i == 3 :
                nt = 'T'

            color = None
            if sequence_template[j] != 'N' :
                color = 'black'

            if ii == 0 :
                letterAt(nt, j + 0.5, height_base, nt_prob * logo_height, ax3, color=color)
            else :
                prev_prob = np.sum(pwm[j, sort_index[:ii]] * conservation[j]) * logo_height
                letterAt(nt, j + 0.5, height_base + prev_prob, nt_prob * logo_height, ax3, color=color)

    plt.sca(ax3)

    plt.xlim((0, plot_end - plot_start))
    plt.ylim((0, 2))
    plt.xticks([], [])
    plt.yticks([], [])
    plt.axis('off')
    ax3.axhline(y=0.01 + height_base, color='black', linestyle='-', linewidth=2)


    for axis in fig.axes :
        axis.get_xaxis().set_visible(False)
        axis.get_yaxis().set_visible(False)

    plt.tight_layout()

    plt.show()

from keras.backend.tensorflow_backend import set_session

def contain_tf_gpu_mem_usage() :
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
    set_session(sess)

contain_tf_gpu_mem_usage()
# Out:
# Using TensorFlow backend.

# %%
#Load APA native data (APADB)

plasmid_df = pd.read_csv('../leslie_apadb_data_wider_v2.csv', sep=',')

print("len(plasmid_df) = " + str(len(plasmid_df)))

#Filter data

plasmid_df = plasmid_df.loc[plasmid_df['site_type'].isin(['UTR3', 'Extension'])].copy().reset_index(drop=True)

#plasmid_df = plasmid_df.query("pas != -1").copy().reset_index(drop=True)
plasmid_df = plasmid_df.loc[plasmid_df['pas'].isin([0, 1, 2])].copy().reset_index(drop=True)

print("len(plasmid_df) = " + str(len(plasmid_df)) + " (filtered)")
# Out:
# len(plasmid_df) = 59731
# len(plasmid_df) = 31060 (filtered)

# %%
#Make generators

valid_set_size = 0.05
test_set_size = 0.05

batch_size = 32

#Generate training and test set indexes
plasmid_index = np.arange(len(plasmid_df), dtype=np.int)

plasmid_train_index = plasmid_index[:-int(len(plasmid_df) * (valid_set_size + test_set_size))]
plasmid_valid_index = plasmid_index[plasmid_train_index.shape[0]:-int(len(plasmid_df) * test_set_size)]
plasmid_test_index = plasmid_index[plasmid_train_index.shape[0] + plasmid_valid_index.shape[0]:]

print('Training set size = ' + str(plasmid_train_index.shape[0]))
print('Validation set size = ' + str(plasmid_valid_index.shape[0]))
print('Test set size = ' + str(plasmid_test_index.shape[0]))


data_gens = {
    gen_id : iso.DataGenerator(
        idx,
        {'df' : plasmid_df},
        batch_size=batch_size,
        inputs = [
            {
                'id' : 'seq',
                'source_type' : 'dataframe',
                'source' : 'df',
                'extractor' : iso.SequenceExtractor('wide_seq_ext', start_pos=175 - 62, end_pos=175 - 62 + 160),
                'encoder' : iso.OneHotEncoder(seq_length=160),
                'dim' : (1, 160, 4),
                'sparsify' : False
            }
        ],
        outputs = [
            {
                'id' : 'dummy_output',
                'source_type' : 'zeros',
                'dim' : (1,),
                'sparsify' : False
            }
        ],
        randomizers = [],
        shuffle = True if gen_id == 'train' else False
    ) for gen_id, idx in [('all', plasmid_index), ('train', plasmid_train_index), ('valid', plasmid_valid_index), ('test', plasmid_test_index)]
}
# Out:
# Training set size = 27954
# Validation set size = 1553
# Test set size = 1553

# %%
x_train = np.concatenate([data_gens['train'][i][0][0] for i in range(len(data_gens['train']))], axis=0)
x_test = np.concatenate([data_gens['test'][i][0][0] for i in range(len(data_gens['test']))], axis=0)

print(x_train.shape)
print(x_test.shape)
# Out:
# (27936, 1, 160, 4)
# (1536, 1, 160, 4)

# %%
def make_gen_resblock(n_channels=64, window_size=3, stride=1, dilation=1, group_ix=0, layer_ix=0) :

    #Initialize res block layers
    batch_norm_0 = BatchNormalization(name='policy_generator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_batch_norm_0')

    relu_0 = Lambda(lambda x: K.relu(x))
    
    deconv_0 = Conv2DTranspose(n_channels, (1, window_size), strides=(1, stride), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_deconv_0')

    batch_norm_1 = BatchNormalization(name='policy_generator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_batch_norm_1')

    relu_1 = Lambda(lambda x: K.relu(x))

    conv_1 = Conv2D(n_channels, (1, window_size), dilation_rate=(1, dilation), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_conv_1')

    skip_deconv_0 = Conv2DTranspose(n_channels, (1, 1), strides=(1, stride), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_skip_deconv_0')
    
    skip_1 = Lambda(lambda x: x[0] + x[1], name='policy_generator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_skip_1')

    #Execute res block
    def _resblock_func(input_tensor) :
        
        batch_norm_0_out = batch_norm_0(input_tensor)
        relu_0_out = relu_0(batch_norm_0_out)
        deconv_0_out = deconv_0(relu_0_out)

        batch_norm_1_out = batch_norm_1(deconv_0_out)
        relu_1_out = relu_1(batch_norm_1_out)
        conv_1_out = conv_1(relu_1_out)
        
        skip_deconv_0_out = skip_deconv_0(input_tensor)

        skip_1_out = skip_1([conv_1_out, skip_deconv_0_out])
        
        return skip_1_out

    return _resblock_func

#Decoder Model definition
def load_decoder_resnet(seq_length=160, latent_size=100) :

    #Generator network parameters
    window_size = 3
    
    strides = [2, 2, 2, 2, 2, 1]
    dilations = [1, 1, 1, 1, 1, 1]
    channels = [512, 256, 128, 64, 32, 32]
    initial_length = 5
    n_resblocks = len(strides)

    #Policy network definition
    policy_dense_0 = Dense(initial_length * channels[0], activation='linear', kernel_initializer='glorot_normal', name='policy_generator_dense_0')
    policy_dense_0_reshape = Reshape((1, initial_length, channels[0]))
    
    curr_length = initial_length
    
    resblocks = []
    for layer_ix in range(n_resblocks) :
        resblocks.append(make_gen_resblock(n_channels=channels[layer_ix], window_size=window_size, stride=strides[layer_ix], dilation=dilations[layer_ix], group_ix=0, layer_ix=layer_ix))
    
    final_conv = Conv2D(4, (1, 1), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_final_conv')
    
    def _generator_func(seed_input) :
        
        policy_dense_0_out = policy_dense_0_reshape(policy_dense_0(seed_input))
        
        #Connect group of res blocks
        output_tensor = policy_dense_0_out

        #Res block group 0
        for layer_ix in range(n_resblocks) :
            output_tensor = resblocks[layer_ix](output_tensor)

        #Final conv out
        final_conv_out = final_conv(output_tensor)
        
        return final_conv_out

    return _generator_func

# %%
from keras.layers.pooling import _GlobalPooling2D

class GlobalSumPooling2D(_GlobalPooling2D):
    def call(self, inputs):
        if self.data_format == 'channels_last':
            return K.sum(inputs, axis=[1, 2])
        else:
            return K.sum(inputs, axis=[2, 3])


def make_disc_resblock_pooled(n_channels=64, window_size=3, dilation=1, drop_rate=0.0, group_ix=0, layer_ix=0) :

    #Initialize res block layers
    batch_norm_0 = BatchNormalization(name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_batch_norm_0')
    
    relu_0 = Lambda(lambda x: K.relu(x))

    conv_0 = Conv2D(n_channels, (1, window_size), dilation_rate=(1, dilation), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_conv_0')

    batch_norm_1 = BatchNormalization(name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_batch_norm_1')
    
    relu_1 = Lambda(lambda x: K.relu(x))

    conv_1 = Conv2D(n_channels, (1, window_size), dilation_rate=(1, dilation), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_conv_1')
    
    pool_1 = AveragePooling2D(pool_size=(1, 2))
    
    drop_1 = Dropout(drop_rate, name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_drop_1')
    
    skip_conv_0 = Conv2D(n_channels, (1, 1), dilation_rate=(1, 1), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_skip_conv_0')
    
    skip_pool_0 = AveragePooling2D(pool_size=(1, 2))

    skip_1 = Lambda(lambda x: x[0] + x[1], name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_skip_1')
    
    #Execute res block
    def _resblock_func(input_tensor) :
        
        batch_norm_0_out = batch_norm_0(input_tensor)
        relu_0_out = relu_0(batch_norm_0_out)
        conv_0_out = conv_0(relu_0_out)

        batch_norm_1_out = batch_norm_1(conv_0_out)
        relu_1_out = relu_1(batch_norm_1_out)
        conv_1_out = conv_1(relu_1_out)
        pool_1_out = pool_1(conv_1_out)
        
        skip_conv_0_out = skip_conv_0(input_tensor)
        skip_pool_0_out = skip_pool_0(skip_conv_0_out)

        skip_1_out = skip_1([pool_1_out, skip_pool_0_out])
        
        if drop_rate > 0.0 :
            skip_1_out = drop_1(skip_1_out)
        
        return skip_1_out

    return _resblock_func

def make_disc_resblock(n_channels=64, window_size=3, dilation=1, drop_rate=0.0, group_ix=0, layer_ix=0) :

    #Initialize res block layers
    batch_norm_0 = BatchNormalization(name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_batch_norm_0')
    
    relu_0 = Lambda(lambda x: K.relu(x, alpha=0.0))

    conv_0 = Conv2D(n_channels, (1, window_size), dilation_rate=(1, dilation), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_conv_0')

    batch_norm_1 = BatchNormalization(name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_batch_norm_1')
    
    relu_1 = Lambda(lambda x: K.relu(x, alpha=0.0))

    conv_1 = Conv2D(n_channels, (1, window_size), dilation_rate=(1, dilation), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_conv_1')
    
    drop_1 = Dropout(drop_rate, name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_drop_1')
    
    skip_conv_0 = Conv2D(n_channels, (1, 1), dilation_rate=(1, 1), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_skip_conv_0')
    
    skip_1 = Lambda(lambda x: x[0] + x[1], name='policy_discriminator_resblock_' + str(group_ix) + '_' + str(layer_ix) + '_skip_1')
    
    #Execute res block
    def _resblock_func(input_tensor) :
        
        batch_norm_0_out = batch_norm_0(input_tensor)
        relu_0_out = relu_0(batch_norm_0_out)
        conv_0_out = conv_0(relu_0_out)

        batch_norm_1_out = batch_norm_1(conv_0_out)
        relu_1_out = relu_1(batch_norm_1_out)
        conv_1_out = conv_1(relu_1_out)
        
        skip_conv_0_out = skip_conv_0(input_tensor)

        skip_1_out = skip_1([conv_1_out, skip_conv_0_out])
        
        if drop_rate > 0.0 :
            skip_1_out = drop_1(skip_1_out)
        
        return skip_1_out

    return _resblock_func

#GAN Discriminator Model definition
def load_encoder_resnet(seq_length=160, latent_size=100) :

    downsamples = [False, False, True, True]
    dilations = [1, 1, 1, 1]
    channels = [32, 32, 64, 128]
    window_sizes = [7, 7, 3, 3]
    drop_outs = [0.0, 0.0, 0.0, 0.0]
    
    n_resblocks = len(dilations)

    policy_conv_0 = Conv2D(channels[0], (1, 1), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_conv_0')
    
    resblocks = []
    for layer_ix in range(n_resblocks) :
        if downsamples[layer_ix] :
            resblocks.append(make_disc_resblock_pooled(n_channels=channels[layer_ix], window_size=window_sizes[layer_ix], dilation=dilations[layer_ix], drop_rate=drop_outs[layer_ix], group_ix=0, layer_ix=layer_ix))
        else :
            resblocks.append(make_disc_resblock(n_channels=channels[layer_ix], window_size=window_sizes[layer_ix], dilation=dilations[layer_ix], drop_rate=drop_outs[layer_ix], group_ix=0, layer_ix=layer_ix))
    
    last_block_conv = Conv2D(channels[-1], (1, 1), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_last_block_conv')
    
    global_pool = Flatten()#GlobalSumPooling2D()#
    
    z_mean = Dense(latent_size, name='policy_discriminator_z_mean')
    z_log_var = Dense(latent_size, name='policy_discriminator_z_log_var')
    
    def _discriminator_func(seq_input) :
        
        policy_conv_0_out = policy_conv_0(seq_input)
        
        #Connect group of res blocks
        output_tensor = policy_conv_0_out

        #Res block group 0
        for layer_ix in range(n_resblocks) :
            output_tensor = resblocks[layer_ix](output_tensor)
        
        #Last res block extr conv
        last_block_conv_out = last_block_conv(output_tensor)
        
        global_pool_out = global_pool(last_block_conv_out)

        #Z mean and log variance
        z_mean_out = z_mean(global_pool_out)
        z_log_var_out = z_log_var(global_pool_out)

        return z_mean_out, z_log_var_out

    return _discriminator_func

# %%
from tensorflow.python.framework import ops

#Stochastic Binarized Neuron helper functions (Tensorflow)
#ST Estimator code adopted from https://r2rt.com/beyond-binary-ternary-and-one-hot-neurons.html
#See Github https://github.com/spitis/

def st_sampled_softmax(logits):
    with ops.name_scope("STSampledSoftmax") as namescope :
        nt_probs = tf.nn.softmax(logits)
        onehot_dim = logits.get_shape().as_list()[1]
        sampled_onehot = tf.one_hot(tf.squeeze(tf.multinomial(logits, 1), 1), onehot_dim, 1.0, 0.0)
        with tf.get_default_graph().gradient_override_map({'Ceil': 'Identity', 'Mul': 'STMul'}):
            return tf.ceil(sampled_onehot * nt_probs)

def st_hardmax_softmax(logits):
    with ops.name_scope("STHardmaxSoftmax") as namescope :
        nt_probs = tf.nn.softmax(logits)
        onehot_dim = logits.get_shape().as_list()[1]
        sampled_onehot = tf.one_hot(tf.argmax(nt_probs, 1), onehot_dim, 1.0, 0.0)
        with tf.get_default_graph().gradient_override_map({'Ceil': 'Identity', 'Mul': 'STMul'}):
            return tf.ceil(sampled_onehot * nt_probs)

@ops.RegisterGradient("STMul")
def st_mul(op, grad):
    return [grad, grad]

# %%
#PWM Masking and Sampling helper functions

def mask_pwm(inputs) :
    pwm, onehot_template, onehot_mask = inputs

    return pwm * onehot_mask + onehot_template

def sample_pwm_only(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = st_sampled_softmax(flat_pwm)

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))

def sample_pwm(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = sampled_pwm = K.switch(K.learning_phase(), st_sampled_softmax(flat_pwm), st_hardmax_softmax(flat_pwm))

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))

def max_pwm(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = sampled_pwm = st_hardmax_softmax(flat_pwm)

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))


#Generator helper functions
def initialize_sequence_templates(generator, sequence_templates) :

    embedding_templates = []
    embedding_masks = []

    for k in range(len(sequence_templates)) :
        sequence_template = sequence_templates[k]
        onehot_template = iso.OneHotEncoder(seq_length=len(sequence_template))(sequence_template).reshape((1, len(sequence_template), 4))

        for j in range(len(sequence_template)) :
            if sequence_template[j] not in ['N', 'X'] :
                nt_ix = np.argmax(onehot_template[0, j, :])
                onehot_template[:, j, :] = -4.0
                onehot_template[:, j, nt_ix] = 10.0
            elif sequence_template[j] == 'X' :
                onehot_template[:, j, :] = -1.0

        onehot_mask = np.zeros((1, len(sequence_template), 4))
        for j in range(len(sequence_template)) :
            if sequence_template[j] == 'N' :
                onehot_mask[:, j, :] = 1.0

        embedding_templates.append(onehot_template.reshape(1, -1))
        embedding_masks.append(onehot_mask.reshape(1, -1))

    embedding_templates = np.concatenate(embedding_templates, axis=0)
    embedding_masks = np.concatenate(embedding_masks, axis=0)

    generator.get_layer('template_dense').set_weights([embedding_templates])
    generator.get_layer('template_dense').trainable = False

    generator.get_layer('mask_dense').set_weights([embedding_masks])
    generator.get_layer('mask_dense').trainable = False


#Generator construction function
def build_sampler(batch_size, seq_length, n_classes=1, n_samples=None, validation_sample_mode='max') :

    use_samples = True
    if n_samples is None :
        use_samples = False
        n_samples = 1

    
    #Initialize Reshape layer
    reshape_layer = Reshape((1, seq_length, 4))

    #Initialize template and mask matrices
    onehot_template_dense = Embedding(n_classes, seq_length * 4, embeddings_initializer='zeros', name='template_dense')
    onehot_mask_dense = Embedding(n_classes, seq_length * 4, embeddings_initializer='ones', name='mask_dense')

    #Initialize Templating and Masking Lambda layer
    masking_layer = Lambda(mask_pwm, output_shape = (1, seq_length, 4), name='masking_layer')
    
    #Initialize PWM normalization layer
    pwm_layer = Softmax(axis=-1, name='pwm')
    
    #Initialize sampling layers
    sample_func = sample_pwm
    if validation_sample_mode == 'sample' :
        sample_func = sample_pwm_only
    
    upsampling_layer = Lambda(lambda x: K.tile(x, [n_samples, 1, 1, 1]), name='upsampling_layer')
    sampling_layer = Lambda(sample_func, name='pwm_sampler')
    permute_layer = Lambda(lambda x: K.permute_dimensions(K.reshape(x, (n_samples, batch_size, 1, seq_length, 4)), (1, 0, 2, 3, 4)), name='permute_layer')
    
    
    def _sampler_func(class_input, raw_logits) :
        
        #Get Template and Mask
        onehot_template = reshape_layer(onehot_template_dense(class_input))
        onehot_mask = reshape_layer(onehot_mask_dense(class_input))
        
        #Add Template and Multiply Mask
        pwm_logits = masking_layer([raw_logits, onehot_template, onehot_mask])
        
        #Compute PWM (Nucleotide-wise Softmax)
        pwm = pwm_layer(pwm_logits)
        
        sampled_pwm = None
        
        #Optionally tile each PWM to sample from and create sample axis
        if use_samples :
            pwm_logits_upsampled = upsampling_layer(pwm_logits)
            sampled_pwm = sampling_layer(pwm_logits_upsampled)
            sampled_pwm = permute_layer(sampled_pwm)
        else :
            sampled_pwm = sampling_layer(pwm_logits)
        
        
        return pwm_logits, pwm, sampled_pwm
    
    return _sampler_func

# %%
pwm_true = np.array([1., 0., 0., 0.])

p_ons = np.linspace(0.001, 0.999, 1000)

ces = []

for i in range(p_ons.shape[0]) :
    
    p_on = p_ons[i]
    p_off = 1. - p_on / 3.
    
    pwm_pred = np.array([p_on, p_off, p_off, p_off])
    
    ce = - np.sum(pwm_true * np.log(pwm_pred))
    ces.append(ce)

ces = np.array(ces)

f = plt.figure(figsize=(4, 3))

plt.plot(p_ons, ces, color='black', linewidth=2)

plt.scatter([0.25], [- np.sum(pwm_true * np.log(np.array([0.25, 0.25, 0.25, 0.25])))], c='darkblue', s=45)
plt.scatter([0.95], [- np.sum(pwm_true * np.log(np.array([0.95, 0.05/3., 0.05/3., 0.05/3.])))], c='darkorange', s=45)

plt.tight_layout()
plt.show()

# %%
def get_pwm_cross_entropy() :

    def _pwm_cross_entropy(inputs) :
        pwm_true, pwm_pred = inputs
        
        pwm_pred = K.clip(pwm_pred, K.epsilon(), 1. - K.epsilon())

        ce = - K.sum(pwm_true[:, 0, :, :] * K.log(pwm_pred[:, 0, :, :]), axis=-1)
        
        return K.expand_dims(K.mean(ce, axis=-1), axis=-1)
    
    return _pwm_cross_entropy

def min_pred(y_true, y_pred) :
    return y_pred

def get_weighted_loss(loss_coeff=1.) :
    
    def _min_pred(y_true, y_pred) :
        return loss_coeff * y_pred
    
    return _min_pred

def get_z_sample(z_inputs):
    
    z_mean, z_log_var = z_inputs
    
    batch_size = K.shape(z_mean)[0]
    latent_dim = K.int_shape(z_mean)[1]
    
    epsilon = K.random_normal(shape=(batch_size, latent_dim))
    
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

def get_z_kl_loss() :
    
    def _z_kl_loss(inputs) :
        z_mean, z_log_var = inputs
        
        kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
        kl_loss = K.mean(kl_loss, axis=-1)
        kl_loss *= -0.5
        
        return K.expand_dims(kl_loss, axis=-1)
    
    return _z_kl_loss

# %%
#Simple Library

sequence_templates = [
    'N' * 160
]

# %%
#Initialize Encoder and Decoder networks
batch_size = 32
seq_length = 160
n_samples = None
latent_size = 100

#Load Encoder
encoder = load_encoder_resnet(seq_length=seq_length, latent_size=latent_size)

#Load Decoder
decoder = load_decoder_resnet(seq_length=seq_length, latent_size=latent_size)

#Load Sampler
sampler = build_sampler(batch_size, seq_length, n_classes=1, n_samples=n_samples, validation_sample_mode='sample')

# %%
#Build Encoder Model
encoder_input = Input(shape=(1, seq_length, 4), name='encoder_input')

z_mean, z_log_var = encoder(encoder_input)

z_sampling_layer = Lambda(get_z_sample, output_shape=(latent_size,), name='z_sampler')
z = z_sampling_layer([z_mean, z_log_var])

# instantiate encoder model
encoder_model = Model(encoder_input, [z_mean, z_log_var, z])
encoder_model.compile(
    optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
    loss=min_pred
)

#Build Decoder Model
decoder_class = Input(shape=(1,), name='decoder_class')
decoder_input = Input(shape=(latent_size,), name='decoder_input')

pwm_logits, pwm, sampled_pwm = sampler(decoder_class, decoder(decoder_input))

decoder_model = Model([decoder_class, decoder_input], [pwm_logits, pwm, sampled_pwm])

#Initialize Sequence Templates and Masks
initialize_sequence_templates(decoder_model, sequence_templates)

decoder_model.compile(
    optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
    loss=min_pred
)

# %%
#Build VAE Pipeline

vae_decoder_class = Input(shape=(1,), name='vae_decoder_class')
vae_encoder_input = Input(shape=(1, seq_length, 4), name='vae_encoder_input')

encoded_z_mean, encoded_z_log_var = encoder(vae_encoder_input)
encoded_z = z_sampling_layer([encoded_z_mean, encoded_z_log_var])
decoded_logits, decoded_pwm, decoded_sample = sampler(vae_decoder_class, decoder(encoded_z))

reconstruction_loss = Lambda(get_pwm_cross_entropy(), name='reconstruction')([vae_encoder_input, decoded_pwm])

kl_loss = Lambda(get_z_kl_loss(), name='kl')([encoded_z_mean, encoded_z_log_var])

vae_model = Model(
    [vae_decoder_class, vae_encoder_input],
    [reconstruction_loss, kl_loss]#, entropy_loss]
)

#Initialize Sequence Templates and Masks
initialize_sequence_templates(vae_model, sequence_templates)

vae_model.compile(
    optimizer=keras.optimizers.Adam(lr=0.0001, beta_1=0.5, beta_2=0.9),
    #optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
    loss={
        'reconstruction' : get_weighted_loss(loss_coeff=1.),
        'kl' : get_weighted_loss(loss_coeff=0.15)#0.05#0.1#0.15#0.05#, #0.000001
        #'entropy' : get_weighted_loss(loss_coeff=0.0)
    }
)

# %%
encoder_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 1, 160, 4)    0
# __________________________________________________________________________________________________
# policy_discriminator_conv_0 (Co (None, 1, 160, 32)   160         encoder_input[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   128         policy_discriminator_conv_0[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 160, 32)   0           policy_discriminator_resblock_0_0
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   7200        lambda_1[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   128         policy_discriminator_resblock_0_0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1, 160, 32)   0           policy_discriminator_resblock_0_0
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   7200        lambda_2[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   1056        policy_discriminator_conv_0[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   0           policy_discriminator_resblock_0_0
#                                                                  policy_discriminator_resblock_0_0
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   128         policy_discriminator_resblock_0_0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1, 160, 32)   0           policy_discriminator_resblock_0_1
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   7200        lambda_3[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   128         policy_discriminator_resblock_0_1
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 160, 32)   0           policy_discriminator_resblock_0_1
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   7200        lambda_4[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   1056        policy_discriminator_resblock_0_0
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   0           policy_discriminator_resblock_0_1
#                                                                  policy_discriminator_resblock_0_1
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 32)   128         policy_discriminator_resblock_0_1
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 160, 32)   0           policy_discriminator_resblock_0_2
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 64)   6208        lambda_5[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 64)   256         policy_discriminator_resblock_0_2
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1, 160, 64)   0           policy_discriminator_resblock_0_2
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 64)   12352       lambda_6[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 160, 64)   2112        policy_discriminator_resblock_0_1
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 80, 64)    0           policy_discriminator_resblock_0_2
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 80, 64)    0           policy_discriminator_resblock_0_2
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 80, 64)    0           average_pooling2d_1[0][0]
#                                                                  average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 80, 64)    256         policy_discriminator_resblock_0_2
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1, 80, 64)    0           policy_discriminator_resblock_0_3
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 80, 128)   24704       lambda_7[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 80, 128)   512         policy_discriminator_resblock_0_3
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 1, 80, 128)   0           policy_discriminator_resblock_0_3
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 80, 128)   49280       lambda_8[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 80, 128)   8320        policy_discriminator_resblock_0_2
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 40, 128)   0           policy_discriminator_resblock_0_3
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 40, 128)   0           policy_discriminator_resblock_0_3
# __________________________________________________________________________________________________
# policy_discriminator_resblock_0 (None, 1, 40, 128)   0           average_pooling2d_3[0][0]
#                                                                  average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_last_block (None, 1, 40, 128)   16512       policy_discriminator_resblock_0_3
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 5120)         0           policy_discriminator_last_block_c
# __________________________________________________________________________________________________
# policy_discriminator_z_mean (De (None, 100)          512100      flatten_1[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_z_log_var  (None, 100)          512100      flatten_1[0][0]
# __________________________________________________________________________________________________
# z_sampler (Lambda)              (None, 100)          0           policy_discriminator_z_mean[0][0]
#                                                                  policy_discriminator_z_log_var[0]
# ==================================================================================================
# Total params: 1,176,424
# Trainable params: 1,175,592
# Non-trainable params: 832
# __________________________________________________________________________________________________

# %%
decoder_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# decoder_input (InputLayer)      (None, 100)          0
# __________________________________________________________________________________________________
# policy_generator_dense_0 (Dense (None, 2560)         258560      decoder_input[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 5, 512)    0           policy_generator_dense_0[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_0_b (None, 1, 5, 512)    2048        reshape_1[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 1, 5, 512)    0           policy_generator_resblock_0_0_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_0_d (None, 1, 10, 512)   786944      lambda_9[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_0_b (None, 1, 10, 512)   2048        policy_generator_resblock_0_0_dec
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 1, 10, 512)   0           policy_generator_resblock_0_0_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_0_c (None, 1, 10, 512)   786944      lambda_10[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_0_s (None, 1, 10, 512)   262656      reshape_1[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_0_s (None, 1, 10, 512)   0           policy_generator_resblock_0_0_con
#                                                                  policy_generator_resblock_0_0_ski
# __________________________________________________________________________________________________
# policy_generator_resblock_0_1_b (None, 1, 10, 512)   2048        policy_generator_resblock_0_0_ski
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 1, 10, 512)   0           policy_generator_resblock_0_1_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_1_d (None, 1, 20, 256)   393472      lambda_11[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_1_b (None, 1, 20, 256)   1024        policy_generator_resblock_0_1_dec
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 1, 20, 256)   0           policy_generator_resblock_0_1_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_1_c (None, 1, 20, 256)   196864      lambda_12[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_1_s (None, 1, 20, 256)   131328      policy_generator_resblock_0_0_ski
# __________________________________________________________________________________________________
# policy_generator_resblock_0_1_s (None, 1, 20, 256)   0           policy_generator_resblock_0_1_con
#                                                                  policy_generator_resblock_0_1_ski
# __________________________________________________________________________________________________
# policy_generator_resblock_0_2_b (None, 1, 20, 256)   1024        policy_generator_resblock_0_1_ski
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 1, 20, 256)   0           policy_generator_resblock_0_2_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_2_d (None, 1, 40, 128)   98432       lambda_13[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_2_b (None, 1, 40, 128)   512         policy_generator_resblock_0_2_dec
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 1, 40, 128)   0           policy_generator_resblock_0_2_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_2_c (None, 1, 40, 128)   49280       lambda_14[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_2_s (None, 1, 40, 128)   32896       policy_generator_resblock_0_1_ski
# __________________________________________________________________________________________________
# policy_generator_resblock_0_2_s (None, 1, 40, 128)   0           policy_generator_resblock_0_2_con
#                                                                  policy_generator_resblock_0_2_ski
# __________________________________________________________________________________________________
# policy_generator_resblock_0_3_b (None, 1, 40, 128)   512         policy_generator_resblock_0_2_ski
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 1, 40, 128)   0           policy_generator_resblock_0_3_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_3_d (None, 1, 80, 64)    24640       lambda_15[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_3_b (None, 1, 80, 64)    256         policy_generator_resblock_0_3_dec
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 1, 80, 64)    0           policy_generator_resblock_0_3_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_3_c (None, 1, 80, 64)    12352       lambda_16[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_3_s (None, 1, 80, 64)    8256        policy_generator_resblock_0_2_ski
# __________________________________________________________________________________________________
# policy_generator_resblock_0_3_s (None, 1, 80, 64)    0           policy_generator_resblock_0_3_con
#                                                                  policy_generator_resblock_0_3_ski
# __________________________________________________________________________________________________
# policy_generator_resblock_0_4_b (None, 1, 80, 64)    256         policy_generator_resblock_0_3_ski
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 1, 80, 64)    0           policy_generator_resblock_0_4_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_4_d (None, 1, 160, 32)   6176        lambda_17[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_4_b (None, 1, 160, 32)   128         policy_generator_resblock_0_4_dec
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 1, 160, 32)   0           policy_generator_resblock_0_4_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_4_c (None, 1, 160, 32)   3104        lambda_18[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_4_s (None, 1, 160, 32)   2080        policy_generator_resblock_0_3_ski
# __________________________________________________________________________________________________
# policy_generator_resblock_0_4_s (None, 1, 160, 32)   0           policy_generator_resblock_0_4_con
#                                                                  policy_generator_resblock_0_4_ski
# __________________________________________________________________________________________________
# policy_generator_resblock_0_5_b (None, 1, 160, 32)   128         policy_generator_resblock_0_4_ski
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 1, 160, 32)   0           policy_generator_resblock_0_5_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_5_d (None, 1, 160, 32)   3104        lambda_19[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_5_b (None, 1, 160, 32)   128         policy_generator_resblock_0_5_dec
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 1, 160, 32)   0           policy_generator_resblock_0_5_bat
# __________________________________________________________________________________________________
# policy_generator_resblock_0_5_c (None, 1, 160, 32)   3104        lambda_20[0][0]
# __________________________________________________________________________________________________
# policy_generator_resblock_0_5_s (None, 1, 160, 32)   1056        policy_generator_resblock_0_4_ski
# __________________________________________________________________________________________________
# decoder_class (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# policy_generator_resblock_0_5_s (None, 1, 160, 32)   0           policy_generator_resblock_0_5_con
#                                                                  policy_generator_resblock_0_5_ski
# __________________________________________________________________________________________________
# template_dense (Embedding)      (None, 1, 640)       640         decoder_class[0][0]
# __________________________________________________________________________________________________
# mask_dense (Embedding)          (None, 1, 640)       640         decoder_class[0][0]
# __________________________________________________________________________________________________
# policy_generator_final_conv (Co (None, 1, 160, 4)    132         policy_generator_resblock_0_5_ski
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 160, 4)    0           template_dense[0][0]
#                                                                  mask_dense[0][0]
# __________________________________________________________________________________________________
# masking_layer (Lambda)          (None, 1, 160, 4)    0           policy_generator_final_conv[0][0]
#                                                                  reshape_2[0][0]
#                                                                  reshape_2[1][0]
# __________________________________________________________________________________________________
# pwm (Softmax)                   (None, 1, 160, 4)    0           masking_layer[0][0]
# __________________________________________________________________________________________________
# pwm_sampler (Lambda)            (None, 1, None, 4)   0           masking_layer[0][0]
# ==================================================================================================
# Total params: 3,072,772
# Trainable params: 3,066,436
# Non-trainable params: 6,336
# __________________________________________________________________________________________________

# %%
n_epochs = 50#10

s_train = np.zeros((x_train.shape[0], 1))
s_test = np.zeros((x_test.shape[0], 1))

dummy_target_train = np.zeros((x_train.shape[0], 1))
dummy_target_test = np.zeros((x_test.shape[0], 1))

callbacks =[
    EarlyStopping(monitor='val_loss', min_delta=0.002, patience=10, verbose=0, mode='auto')
]

# train the autoencoder
train_history = vae_model.fit(
    [s_train, x_train],
    [dummy_target_train, dummy_target_train],#, dummy_target_train],
    shuffle=True,
    epochs=n_epochs,
    batch_size=batch_size,
    validation_data=(
        [s_test, x_test],
        [dummy_target_test, dummy_target_test]#, dummy_target_test]
    ),
    callbacks=callbacks
)
# Out:
# Train on 27936 samples, validate on 1536 samples
# Epoch 1/50
# 27936/27936 [==============================] - 58s 2ms/step - loss: 1.3392 - reconstruction_loss: 1.3021 - kl_loss: 0.0371 - val_loss: 1.2634 - val_reconstruction_loss: 1.2077 - val_kl_loss: 0.0557
# Epoch 2/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 1.1826 - reconstruction_loss: 1.0832 - kl_loss: 0.0993 - val_loss: 1.1172 - val_reconstruction_loss: 0.9799 - val_kl_loss: 0.1373
# Epoch 3/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 1.0533 - reconstruction_loss: 0.8863 - kl_loss: 0.1670 - val_loss: 0.9888 - val_reconstruction_loss: 0.7893 - val_kl_loss: 0.1995
# Epoch 4/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.9324 - reconstruction_loss: 0.7107 - kl_loss: 0.2218 - val_loss: 0.9069 - val_reconstruction_loss: 0.6629 - val_kl_loss: 0.2440
# Epoch 5/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.8605 - reconstruction_loss: 0.6102 - kl_loss: 0.2504 - val_loss: 0.8429 - val_reconstruction_loss: 0.5779 - val_kl_loss: 0.2650
# Epoch 6/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.8155 - reconstruction_loss: 0.5502 - kl_loss: 0.2653 - val_loss: 0.8181 - val_reconstruction_loss: 0.5450 - val_kl_loss: 0.2731
# Epoch 7/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.7873 - reconstruction_loss: 0.5115 - kl_loss: 0.2758 - val_loss: 0.7845 - val_reconstruction_loss: 0.5041 - val_kl_loss: 0.2804
# Epoch 8/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.7653 - reconstruction_loss: 0.4792 - kl_loss: 0.2861 - val_loss: 0.7930 - val_reconstruction_loss: 0.5033 - val_kl_loss: 0.2897
# Epoch 9/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.7450 - reconstruction_loss: 0.4488 - kl_loss: 0.2962 - val_loss: 0.7523 - val_reconstruction_loss: 0.4531 - val_kl_loss: 0.2992
# Epoch 10/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.7261 - reconstruction_loss: 0.4212 - kl_loss: 0.3049 - val_loss: 0.7504 - val_reconstruction_loss: 0.4383 - val_kl_loss: 0.3120
# Epoch 11/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.7108 - reconstruction_loss: 0.3984 - kl_loss: 0.3124 - val_loss: 0.7184 - val_reconstruction_loss: 0.3987 - val_kl_loss: 0.3197
# Epoch 12/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.6988 - reconstruction_loss: 0.3808 - kl_loss: 0.3180 - val_loss: 0.7101 - val_reconstruction_loss: 0.3844 - val_kl_loss: 0.3256
# Epoch 13/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.6873 - reconstruction_loss: 0.3646 - kl_loss: 0.3228 - val_loss: 0.6988 - val_reconstruction_loss: 0.3724 - val_kl_loss: 0.3264
# Epoch 14/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.6776 - reconstruction_loss: 0.3507 - kl_loss: 0.3268 - val_loss: 0.6992 - val_reconstruction_loss: 0.3625 - val_kl_loss: 0.3366
# Epoch 15/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.6700 - reconstruction_loss: 0.3396 - kl_loss: 0.3304 - val_loss: 0.6950 - val_reconstruction_loss: 0.3605 - val_kl_loss: 0.3346
# Epoch 16/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.6610 - reconstruction_loss: 0.3274 - kl_loss: 0.3336 - val_loss: 0.6430 - val_reconstruction_loss: 0.3014 - val_kl_loss: 0.3416
# Epoch 17/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.6539 - reconstruction_loss: 0.3172 - kl_loss: 0.3366 - val_loss: 0.6519 - val_reconstruction_loss: 0.3164 - val_kl_loss: 0.3355
# Epoch 18/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.6471 - reconstruction_loss: 0.3077 - kl_loss: 0.3394 - val_loss: 0.6256 - val_reconstruction_loss: 0.2864 - val_kl_loss: 0.3392
# Epoch 19/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.6423 - reconstruction_loss: 0.3002 - kl_loss: 0.3421 - val_loss: 0.6267 - val_reconstruction_loss: 0.2850 - val_kl_loss: 0.3417
# Epoch 20/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.6351 - reconstruction_loss: 0.2909 - kl_loss: 0.3442 - val_loss: 0.6389 - val_reconstruction_loss: 0.2957 - val_kl_loss: 0.3432
# Epoch 21/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.6309 - reconstruction_loss: 0.2843 - kl_loss: 0.3466 - val_loss: 0.6116 - val_reconstruction_loss: 0.2649 - val_kl_loss: 0.3467
# Epoch 22/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.6243 - reconstruction_loss: 0.2758 - kl_loss: 0.3485 - val_loss: 0.6103 - val_reconstruction_loss: 0.2586 - val_kl_loss: 0.3516
# Epoch 23/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.6194 - reconstruction_loss: 0.2687 - kl_loss: 0.3507 - val_loss: 0.6000 - val_reconstruction_loss: 0.2456 - val_kl_loss: 0.3545
# Epoch 24/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.6144 - reconstruction_loss: 0.2619 - kl_loss: 0.3525 - val_loss: 0.6664 - val_reconstruction_loss: 0.3053 - val_kl_loss: 0.3611
# Epoch 25/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.6095 - reconstruction_loss: 0.2548 - kl_loss: 0.3547 - val_loss: 0.6387 - val_reconstruction_loss: 0.2799 - val_kl_loss: 0.3588
# Epoch 26/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.6047 - reconstruction_loss: 0.2483 - kl_loss: 0.3563 - val_loss: 0.6018 - val_reconstruction_loss: 0.2523 - val_kl_loss: 0.3495
# Epoch 27/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5987 - reconstruction_loss: 0.2408 - kl_loss: 0.3579 - val_loss: 0.6056 - val_reconstruction_loss: 0.2433 - val_kl_loss: 0.3624
# Epoch 28/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5938 - reconstruction_loss: 0.2339 - kl_loss: 0.3599 - val_loss: 0.6130 - val_reconstruction_loss: 0.2544 - val_kl_loss: 0.3586
# Epoch 29/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5902 - reconstruction_loss: 0.2288 - kl_loss: 0.3615 - val_loss: 0.5831 - val_reconstruction_loss: 0.2137 - val_kl_loss: 0.3695
# Epoch 30/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5850 - reconstruction_loss: 0.2222 - kl_loss: 0.3628 - val_loss: 0.5884 - val_reconstruction_loss: 0.2233 - val_kl_loss: 0.3652
# Epoch 31/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.5806 - reconstruction_loss: 0.2163 - kl_loss: 0.3644 - val_loss: 0.5696 - val_reconstruction_loss: 0.2049 - val_kl_loss: 0.3647
# Epoch 32/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.5776 - reconstruction_loss: 0.2120 - kl_loss: 0.3657 - val_loss: 0.5916 - val_reconstruction_loss: 0.2227 - val_kl_loss: 0.3688
# Epoch 33/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.5725 - reconstruction_loss: 0.2058 - kl_loss: 0.3667 - val_loss: 0.5776 - val_reconstruction_loss: 0.2200 - val_kl_loss: 0.3576
# Epoch 34/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5668 - reconstruction_loss: 0.1988 - kl_loss: 0.3681 - val_loss: 0.5564 - val_reconstruction_loss: 0.1788 - val_kl_loss: 0.3776
# Epoch 35/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5642 - reconstruction_loss: 0.1948 - kl_loss: 0.3694 - val_loss: 0.5927 - val_reconstruction_loss: 0.2216 - val_kl_loss: 0.3710
# Epoch 36/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5596 - reconstruction_loss: 0.1895 - kl_loss: 0.3701 - val_loss: 0.5717 - val_reconstruction_loss: 0.2014 - val_kl_loss: 0.3703
# Epoch 37/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5568 - reconstruction_loss: 0.1856 - kl_loss: 0.3712 - val_loss: 0.5587 - val_reconstruction_loss: 0.1824 - val_kl_loss: 0.3763
# Epoch 38/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5523 - reconstruction_loss: 0.1801 - kl_loss: 0.3722 - val_loss: 0.5434 - val_reconstruction_loss: 0.1749 - val_kl_loss: 0.3685
# Epoch 39/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5491 - reconstruction_loss: 0.1759 - kl_loss: 0.3732 - val_loss: 0.5585 - val_reconstruction_loss: 0.1895 - val_kl_loss: 0.3690
# Epoch 40/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.5463 - reconstruction_loss: 0.1720 - kl_loss: 0.3743 - val_loss: 0.5350 - val_reconstruction_loss: 0.1540 - val_kl_loss: 0.3810
# Epoch 41/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.5423 - reconstruction_loss: 0.1675 - kl_loss: 0.3747 - val_loss: 0.5314 - val_reconstruction_loss: 0.1599 - val_kl_loss: 0.3715
# Epoch 42/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5401 - reconstruction_loss: 0.1645 - kl_loss: 0.3756 - val_loss: 0.5390 - val_reconstruction_loss: 0.1656 - val_kl_loss: 0.3734
# Epoch 43/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5374 - reconstruction_loss: 0.1611 - kl_loss: 0.3762 - val_loss: 0.5881 - val_reconstruction_loss: 0.2175 - val_kl_loss: 0.3705
# Epoch 44/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5342 - reconstruction_loss: 0.1574 - kl_loss: 0.3768 - val_loss: 0.6232 - val_reconstruction_loss: 0.2460 - val_kl_loss: 0.3773
# Epoch 45/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.5320 - reconstruction_loss: 0.1548 - kl_loss: 0.3773 - val_loss: 0.5525 - val_reconstruction_loss: 0.1842 - val_kl_loss: 0.3683
# Epoch 46/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5286 - reconstruction_loss: 0.1507 - kl_loss: 0.3778 - val_loss: 0.5262 - val_reconstruction_loss: 0.1506 - val_kl_loss: 0.3756
# Epoch 47/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.5265 - reconstruction_loss: 0.1483 - kl_loss: 0.3782 - val_loss: 0.5378 - val_reconstruction_loss: 0.1573 - val_kl_loss: 0.3805
# Epoch 48/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5249 - reconstruction_loss: 0.1461 - kl_loss: 0.3787 - val_loss: 0.5302 - val_reconstruction_loss: 0.1518 - val_kl_loss: 0.3784
# Epoch 49/50
# 27936/27936 [==============================] - 50s 2ms/step - loss: 0.5224 - reconstruction_loss: 0.1429 - kl_loss: 0.3794 - val_loss: 0.5168 - val_reconstruction_loss: 0.1399 - val_kl_loss: 0.3769
# Epoch 50/50
# 27936/27936 [==============================] - 49s 2ms/step - loss: 0.5202 - reconstruction_loss: 0.1405 - kl_loss: 0.3797 - val_loss: 0.5271 - val_reconstruction_loss: 0.1374 - val_kl_loss: 0.3898

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(4.5 * 2, 4))

n_epochs_actual = len(train_history.history['reconstruction_loss'])

ax1.plot(np.arange(1, n_epochs_actual + 1), train_history.history['reconstruction_loss'], linewidth=3, color='green')
ax1.plot(np.arange(1, n_epochs_actual + 1), train_history.history['val_reconstruction_loss'], linewidth=3, color='orange')

plt.sca(ax1)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Reconstruction Loss", fontsize=14)
plt.xlim(1, n_epochs_actual)
plt.xticks([1, n_epochs_actual], [1, n_epochs], fontsize=12)
plt.yticks(fontsize=12)

ax2.plot(np.arange(1, n_epochs_actual + 1), train_history.history['kl_loss'], linewidth=3, color='green')
ax2.plot(np.arange(1, n_epochs_actual + 1), train_history.history['val_kl_loss'], linewidth=3, color='orange')

plt.sca(ax2)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("KL Divergence", fontsize=14)
plt.xlim(1, n_epochs_actual)
plt.xticks([1, n_epochs_actual], [1, n_epochs], fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()

plt.show()

# %%
# Save model and weights
save_dir = 'saved_models'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_name = 'vae_apa_max_isoform_apadb_new_resnet_fixed_50_epochs_encoder_160_strided_encoder_strict_pas_only_retry.h5'
model_path = os.path.join(save_dir, model_name)
encoder_model.save(model_path)
print('Saved trained model at %s ' % model_path)

model_name = 'vae_apa_max_isoform_apadb_new_resnet_fixed_50_epochs_decoder_160_strided_encoder_strict_pas_only_retry.h5'
model_path = os.path.join(save_dir, model_name)
decoder_model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at saved_models/vae_apa_max_isoform_apadb_new_resnet_fixed_50_epochs_encoder_160_strided_encoder_strict_pas_only_retry.h5
# Saved trained model at saved_models/vae_apa_max_isoform_apadb_new_resnet_fixed_50_epochs_decoder_160_strided_encoder_strict_pas_only_retry.h5

# %%
#Load models
save_dir = 'saved_models'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_name = 'vae_apa_max_isoform_apadb_new_resnet_fixed_50_epochs_encoder_160_strided_encoder_strict_pas_only_retry.h5'
model_path = os.path.join(save_dir, model_name)
encoder_model = load_model(model_path, custom_objects={'st_sampled_softmax':st_sampled_softmax, 'st_hardmax_softmax':st_hardmax_softmax, 'min_pred':min_pred})

model_name = 'vae_apa_max_isoform_apadb_new_resnet_fixed_50_epochs_decoder_160_strided_encoder_strict_pas_only_retry.h5'
model_path = os.path.join(save_dir, model_name)
decoder_model = load_model(model_path, custom_objects={'st_sampled_softmax':st_sampled_softmax, 'st_hardmax_softmax':st_hardmax_softmax, 'min_pred':min_pred})

# %%
#Visualize a few fake and real sequence patterns

s_test = np.zeros((x_test.shape[0], 1))

z_mean_test, z_log_var_test, z_test = encoder_model.predict_on_batch([x_test[:32]])

fake_pwm_test_batch = decoder_model.predict_on_batch([s_test[:32], z_test[:32]])

for plot_i in range(5) :
    print("Test sequence " + str(plot_i) + ":")
    plot_gan_logo(x_test[plot_i, 0, :, :], 0, sequence_template=('N' * 160), figsize=(12, 0.55), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=62 + 6 + 62)
    plot_gan_logo(fake_pwm_test_batch[1][plot_i, 0, :, :], 0, sequence_template=('N' * 160), figsize=(12, 0.55), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=62 + 6 + 62)
# Out:
# Test sequence 0:
# Test sequence 1:
# Test sequence 2:
# Test sequence 3:
# Test sequence 4:

# %%
#Sample new patterns

z_test_new = np.random.normal(loc=0.0, scale=1.0, size=(32, 100))

fake_pwm_test_batch = decoder_model.predict_on_batch([s_test[:32], z_test_new[:32]])

print("- Fake PWMs (Randomly Generated) -")

for plot_i in range(32) :
    plot_gan_logo(fake_pwm_test_batch[1][plot_i, 0, :, :], 0, sequence_template=('N' * 160), figsize=(12, 0.55), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=62 + 6 + 62)
# Out:
# - Fake PWMs (Randomly Generated) -
