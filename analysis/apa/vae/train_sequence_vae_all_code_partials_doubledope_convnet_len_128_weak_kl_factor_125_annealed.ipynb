# %%
import keras
from keras.models import Sequential, Model, load_model

from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, LSTM, ConvLSTM2D, GRU, BatchNormalization, LocallyConnected2D, Permute
from keras.layers import Concatenate, Reshape, Softmax, Conv2DTranspose, Embedding, Multiply
from keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from keras import regularizers
from keras import backend as K
from keras.utils.generic_utils import Progbar
from keras.layers.merge import _Merge
import keras.losses

from functools import partial

from collections import defaultdict

import tensorflow as tf
from tensorflow.python.framework import ops

import isolearn.keras as iso

import numpy as np

import tensorflow as tf
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)

import pandas as pd

import os
import pickle
import numpy as np

import scipy.sparse as sp
import scipy.io as spio

import matplotlib.pyplot as plt

import isolearn.io as isoio
import isolearn.keras as isol

from genesis.visualization import *


def iso_normalizer(t) :
    iso = 0.0
    if np.sum(t) > 0.0 :
        iso = np.sum(t[80: 80+25]) / np.sum(t)
    
    return iso

def cut_normalizer(t) :
    cuts = np.concatenate([np.zeros(205), np.array([1.0])])
    if np.sum(t) > 0.0 :
        cuts = t / np.sum(t)
    
    return cuts

def plot_gan_logo(pwm, score, sequence_template=None, figsize=(12, 3), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=164) :

    #Slice according to seq trim index
    pwm = pwm[plot_start: plot_end, :]
    sequence_template = sequence_template[plot_start: plot_end]

    pwm += 0.0001
    for j in range(0, pwm.shape[0]) :
        pwm[j, :] /= np.sum(pwm[j, :])

    entropy = np.zeros(pwm.shape)
    entropy[pwm > 0] = pwm[pwm > 0] * -np.log2(pwm[pwm > 0])
    entropy = np.sum(entropy, axis=1)
    conservation = 2 - entropy

    fig = plt.figure(figsize=figsize)

    gs = gridspec.GridSpec(1, 2, width_ratios=[width_ratios[0], width_ratios[-1]])

    ax2 = plt.subplot(gs[0])
    ax3 = plt.subplot(gs[1])

    plt.sca(ax2)
    plt.axis('off')


    annot_text = '\nScore = ' + str(round(score, 4))

    ax2.text(0.99, 0.5, annot_text, horizontalalignment='right', verticalalignment='center', transform=ax2.transAxes, color='black', fontsize=12, weight="bold")

    height_base = (1.0 - logo_height) / 2.

    for j in range(0, pwm.shape[0]) :
        sort_index = np.argsort(pwm[j, :])

        for ii in range(0, 4) :
            i = sort_index[ii]

            nt_prob = pwm[j, i] * conservation[j]

            nt = ''
            if i == 0 :
                nt = 'A'
            elif i == 1 :
                nt = 'C'
            elif i == 2 :
                nt = 'G'
            elif i == 3 :
                nt = 'T'

            color = None
            if sequence_template[j] != 'N' :
                color = 'black'

            if ii == 0 :
                letterAt(nt, j + 0.5, height_base, nt_prob * logo_height, ax3, color=color)
            else :
                prev_prob = np.sum(pwm[j, sort_index[:ii]] * conservation[j]) * logo_height
                letterAt(nt, j + 0.5, height_base + prev_prob, nt_prob * logo_height, ax3, color=color)

    plt.sca(ax3)

    plt.xlim((0, plot_end - plot_start))
    plt.ylim((0, 2))
    plt.xticks([], [])
    plt.yticks([], [])
    plt.axis('off')
    ax3.axhline(y=0.01 + height_base, color='black', linestyle='-', linewidth=2)


    for axis in fig.axes :
        axis.get_xaxis().set_visible(False)
        axis.get_yaxis().set_visible(False)

    plt.tight_layout()

    plt.show()

from keras.backend.tensorflow_backend import set_session

def contain_tf_gpu_mem_usage() :
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
    set_session(sess)

contain_tf_gpu_mem_usage()
# Out:
# Using TensorFlow backend.

# %%
#Load APA plasmid data (random mpra)
file_path = '../../../../aparent/data/prepared_data/apa_plasmid_data/'
data_version = ''

#plasmid_dict = isoio.load(file_path + 'apa_plasmid_data' + data_version)
plasmid_dict = pickle.load(open('../../../../aparent/apa_plasmid_data.pickle', 'rb'))

plasmid_df = plasmid_dict['plasmid_df']
plasmid_cuts = plasmid_dict['plasmid_cuts']

print("len(plasmid_df) = " + str(len(plasmid_df)))
# Out:
# len(plasmid_df) = 3810974

# %%
#Filter data
kept_libraries = [20]

min_count = 6
min_usage = 0.0
max_usage = 0.15

keep_index = np.nonzero(plasmid_df.sublibrary == "doubledope_5prime_0")[0]
plasmid_df = plasmid_df.iloc[keep_index].copy()
plasmid_cuts = plasmid_cuts[keep_index, :]

keep_index = np.nonzero(plasmid_df.seq.str.slice(70, 76).isin(['ATTAAA', 'AATAAA']))[0]
plasmid_df = plasmid_df.iloc[keep_index].copy()
plasmid_cuts = plasmid_cuts[keep_index, :]

keep_index = np.nonzero(~plasmid_df.seq.str.slice(155, 161).isin(['ATTAAA', 'AATAAA']))[0]
plasmid_df = plasmid_df.iloc[keep_index].copy()
plasmid_cuts = plasmid_cuts[keep_index, :]

if kept_libraries is not None :
    keep_index = np.nonzero(plasmid_df.library_index.isin(kept_libraries))[0]
    plasmid_df = plasmid_df.iloc[keep_index].copy()
    plasmid_cuts = plasmid_cuts[keep_index, :]

if min_count is not None :
    
    keep_index = np.nonzero(plasmid_df.total_count >= min_count)[0]
    
    #total_c = np.ravel(plasmid_cuts[:, 180+70+6:180+70+6+35].sum(axis=-1)) + np.ravel(plasmid_cuts[:, -1].todense())
    #keep_index = np.nonzero(total_c >= min_count)[0]
    
    plasmid_df = plasmid_df.iloc[keep_index].copy()
    plasmid_cuts = plasmid_cuts[keep_index, :]

if min_usage is not None and max_usage is not None :
    
    #prox_c = np.ravel(plasmid_cuts[:, 180+70+6:180+70+6+35].sum(axis=-1))
    #total_c = np.ravel(plasmid_cuts[:, 180:180+205].sum(axis=-1)) + np.ravel(plasmid_cuts[:, -1].todense())
    
    prox_c = np.ravel(plasmid_df.proximal_count)
    total_c = np.ravel(plasmid_df.total_count)
    
    #prox_c = np.ravel(plasmid_cuts[:, 180+70+6:180+70+6+35].sum(axis=-1))
    #total_c = np.ravel(plasmid_cuts[:, 180+70+6:180+70+6+35].sum(axis=-1)) + np.ravel(plasmid_cuts[:, -1].todense())
    
    
    keep_index = np.nonzero((prox_c / total_c >= min_usage) & (prox_c / total_c <= max_usage))[0]
    #keep_index = np.nonzero(plasmid_df.proximal_count / plasmid_df.total_count >= min_usage)[0]
    plasmid_df = plasmid_df.iloc[keep_index].copy()
    plasmid_cuts = plasmid_cuts[keep_index, :]

print("len(plasmid_df) = " + str(len(plasmid_df)) + " (filtered)")
# Out:
# len(plasmid_df) = 11055 (filtered)

# %%
#Store cached filtered dataframe
#pickle.dump({'plasmid_df' : plasmid_df, 'plasmid_cuts' : plasmid_cuts}, open('apa_doubledope_cached_set_weak_short_cano_pas.pickle', 'wb'))

#Load cached dataframe
cached_dict = pickle.load(open('apa_doubledope_cached_set_weak_short_cano_pas.pickle', 'rb'))
plasmid_df = cached_dict['plasmid_df']
plasmid_cuts = cached_dict['plasmid_cuts']

print("len(plasmid_df) = " + str(len(plasmid_df)) + " (loaded)")
# Out:
# len(plasmid_df) = 11278 (loaded)

# %%
#Make generators

valid_set_size = 0.05
test_set_size = 0.05

batch_size = 32

#Generate training and test set indexes
plasmid_index = np.arange(len(plasmid_df), dtype=np.int)

plasmid_train_index = plasmid_index[:-int(len(plasmid_df) * (valid_set_size + test_set_size))]
plasmid_valid_index = plasmid_index[plasmid_train_index.shape[0]:-int(len(plasmid_df) * test_set_size)]
plasmid_test_index = plasmid_index[plasmid_train_index.shape[0] + plasmid_valid_index.shape[0]:]

print('Training set size = ' + str(plasmid_train_index.shape[0]))
print('Validation set size = ' + str(plasmid_valid_index.shape[0]))
print('Test set size = ' + str(plasmid_test_index.shape[0]))


data_gens = {
    gen_id : iso.DataGenerator(
        idx,
        {'df' : plasmid_df},
        batch_size=batch_size,
        inputs = [
            {
                'id' : 'seq',
                'source_type' : 'dataframe',
                'source' : 'df',
                'extractor' : lambda row, index: row['padded_seq'][180 + 40: 180 + 40 + 81] + "G" * (128-81),
                'encoder' : iso.OneHotEncoder(seq_length=128),
                'dim' : (1, 128, 4),
                'sparsify' : False
            }
        ],
        outputs = [
            {
                'id' : 'dummy_output',
                'source_type' : 'zeros',
                'dim' : (1,),
                'sparsify' : False
            }
        ],
        randomizers = [],
        shuffle = True if gen_id == 'train' else False
    ) for gen_id, idx in [('all', plasmid_index), ('train', plasmid_train_index), ('valid', plasmid_valid_index), ('test', plasmid_test_index)]
}
# Out:
# Training set size = 10151
# Validation set size = 564
# Test set size = 563

# %%
x_train = np.concatenate([data_gens['train'][i][0][0] for i in range(len(data_gens['train']))], axis=0)
x_test = np.concatenate([data_gens['test'][i][0][0] for i in range(len(data_gens['test']))], axis=0)

print(x_train.shape)
print(x_test.shape)
# Out:
# (10144, 1, 128, 4)
# (544, 1, 128, 4)

# %%
def load_decoder_network_deconv(batch_size, seq_length=205) :

    #Generator network parameters
    latent_size = 100

    #Policy network definition
    policy_dense_0 = Dense(16 * 384, activation='linear', kernel_initializer='glorot_uniform', name='policy_generator_dense_0')

    policy_dense_0_reshape = Reshape((1, 16, 384))

    policy_deconv_0 = Conv2DTranspose(256, (1, 7), strides=(1, 2), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_deconv_0')

    policy_deconv_1 = Conv2DTranspose(192, (1, 8), strides=(1, 2), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_deconv_1')

    policy_deconv_2 = Conv2DTranspose(128, (1, 7), strides=(1, 2), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_deconv_2')

    policy_conv_3 = Conv2D(4, (1, 7), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_generator_deconv_3')

    batch_norm_dense_0 = BatchNormalization(axis=-1, name='policy_generator_batch_norm_dense_0')
    relu_dense_0 = Lambda(lambda x: K.relu(x))

    batch_norm_0 = BatchNormalization(axis=-1, name='policy_generator_batch_norm_0')
    relu_0 = Lambda(lambda x: K.relu(x))
    
    batch_norm_1 = BatchNormalization(axis=-1, name='policy_generator_batch_norm_1')
    relu_1 = Lambda(lambda x: K.relu(x))
    
    batch_norm_2 = BatchNormalization(axis=-1, name='policy_generator_batch_norm_2')
    relu_2 = Lambda(lambda x: K.relu(x))
    
    def _generator_func(seed_input) :
        relu_dense_0_out = relu_dense_0(batch_norm_dense_0(policy_dense_0_reshape(policy_dense_0(seed_input))))
        
        policy_relu_0_out = relu_0(batch_norm_0(policy_deconv_0(relu_dense_0_out)))
        policy_relu_1_out = relu_1(batch_norm_1(policy_deconv_1(policy_relu_0_out)))
        policy_relu_2_out = relu_2(batch_norm_2(policy_deconv_2(policy_relu_1_out)))

        policy_conv_3_out = policy_conv_3(policy_relu_2_out)
        
        return policy_conv_3_out

    return _generator_func

# %%
#Encoder Model definition
def load_encoder_network_conv(batch_size, seq_length=205, latent_size=100) :

    #Discriminator network definition
    policy_conv_0 = Conv2D(64, (1, 8), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_conv_0')
    policy_batchnorm_0 = BatchNormalization(axis=-1, name='policy_discriminator_batch_norm_0')
    relu_0 = Lambda(lambda x: K.relu(x))
    
    policy_conv_1 = Conv2D(96, (1, 8), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_conv_1')
    policy_batchnorm_1 = BatchNormalization(axis=-1, name='policy_discriminator_batch_norm_1')
    relu_1 = Lambda(lambda x: K.relu(x))
    
    policy_conv_2 = Conv2D(128, (1, 8), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_discriminator_conv_2')
    policy_batchnorm_2 = BatchNormalization(axis=-1, name='policy_discriminator_batch_norm_2')
    relu_2 = Lambda(lambda x: K.relu(x))
    
    final_flatten = Flatten()
    
    #final_dense = Dense(128, activation='relu', kernel_initializer='glorot_normal', name='policy_discriminator_dense_final')
    #final_drop = Dropout(0.25)
    
    z_mean = Dense(latent_size, name='policy_discriminator_z_mean')
    z_log_var = Dense(latent_size, name='policy_discriminator_z_log_var')
    
    def _encoder_func(sequence_input) :
        relu_0_out = relu_0(policy_batchnorm_0(policy_conv_0(sequence_input)))
        relu_1_out = relu_1(policy_batchnorm_1(policy_conv_1(relu_0_out)))
        relu_2_out = relu_2(policy_batchnorm_2(policy_conv_2(relu_1_out)))

        #Final dense out
        final_dense_out = final_flatten(relu_2_out)#final_drop(final_dense(final_flatten(relu_2_out)))
        
        #Z mean and log variance
        z_mean_out = z_mean(final_dense_out)
        z_log_var_out = z_log_var(final_dense_out)

        return z_mean_out, z_log_var_out

    return _encoder_func

# %%
from tensorflow.python.framework import ops

#Stochastic Binarized Neuron helper functions (Tensorflow)
#ST Estimator code adopted from https://r2rt.com/beyond-binary-ternary-and-one-hot-neurons.html
#See Github https://github.com/spitis/

def st_sampled_softmax(logits):
    with ops.name_scope("STSampledSoftmax") as namescope :
        nt_probs = tf.nn.softmax(logits)
        onehot_dim = logits.get_shape().as_list()[1]
        sampled_onehot = tf.one_hot(tf.squeeze(tf.multinomial(logits, 1), 1), onehot_dim, 1.0, 0.0)
        with tf.get_default_graph().gradient_override_map({'Ceil': 'Identity', 'Mul': 'STMul'}):
            return tf.ceil(sampled_onehot * nt_probs)

def st_hardmax_softmax(logits):
    with ops.name_scope("STHardmaxSoftmax") as namescope :
        nt_probs = tf.nn.softmax(logits)
        onehot_dim = logits.get_shape().as_list()[1]
        sampled_onehot = tf.one_hot(tf.argmax(nt_probs, 1), onehot_dim, 1.0, 0.0)
        with tf.get_default_graph().gradient_override_map({'Ceil': 'Identity', 'Mul': 'STMul'}):
            return tf.ceil(sampled_onehot * nt_probs)

@ops.RegisterGradient("STMul")
def st_mul(op, grad):
    return [grad, grad]

# %%
#PWM Masking and Sampling helper functions

def mask_pwm(inputs) :
    pwm, onehot_template, onehot_mask = inputs

    return pwm * onehot_mask + onehot_template

def sample_pwm_only(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = st_sampled_softmax(flat_pwm)

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))

def sample_pwm(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = sampled_pwm = K.switch(K.learning_phase(), st_sampled_softmax(flat_pwm), st_hardmax_softmax(flat_pwm))

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))

def max_pwm(pwm_logits) :
    n_sequences = K.shape(pwm_logits)[0]
    seq_length = K.shape(pwm_logits)[2]

    flat_pwm = K.reshape(pwm_logits, (n_sequences * seq_length, 4))
    sampled_pwm = sampled_pwm = st_hardmax_softmax(flat_pwm)

    return K.reshape(sampled_pwm, (n_sequences, 1, seq_length, 4))


#Generator helper functions
def initialize_sequence_templates(generator, sequence_templates) :

    embedding_templates = []
    embedding_masks = []

    for k in range(len(sequence_templates)) :
        sequence_template = sequence_templates[k]
        onehot_template = iso.OneHotEncoder(seq_length=len(sequence_template))(sequence_template).reshape((1, len(sequence_template), 4))

        for j in range(len(sequence_template)) :
            if sequence_template[j] not in ['N', 'X'] :
                nt_ix = np.argmax(onehot_template[0, j, :])
                onehot_template[:, j, :] = -4.0
                onehot_template[:, j, nt_ix] = 10.0
            elif sequence_template[j] == 'X' :
                onehot_template[:, j, :] = -1.0

        onehot_mask = np.zeros((1, len(sequence_template), 4))
        for j in range(len(sequence_template)) :
            if sequence_template[j] == 'N' :
                onehot_mask[:, j, :] = 1.0

        embedding_templates.append(onehot_template.reshape(1, -1))
        embedding_masks.append(onehot_mask.reshape(1, -1))

    embedding_templates = np.concatenate(embedding_templates, axis=0)
    embedding_masks = np.concatenate(embedding_masks, axis=0)

    generator.get_layer('template_dense').set_weights([embedding_templates])
    generator.get_layer('template_dense').trainable = False

    generator.get_layer('mask_dense').set_weights([embedding_masks])
    generator.get_layer('mask_dense').trainable = False


#Generator construction function
def build_sampler(batch_size, seq_length, n_classes=1, n_samples=None, validation_sample_mode='max') :

    use_samples = True
    if n_samples is None :
        use_samples = False
        n_samples = 1

    
    #Initialize Reshape layer
    reshape_layer = Reshape((1, seq_length, 4))

    #Initialize template and mask matrices
    onehot_template_dense = Embedding(n_classes, seq_length * 4, embeddings_initializer='zeros', name='template_dense')
    onehot_mask_dense = Embedding(n_classes, seq_length * 4, embeddings_initializer='ones', name='mask_dense')

    #Initialize Templating and Masking Lambda layer
    masking_layer = Lambda(mask_pwm, output_shape = (1, seq_length, 4), name='masking_layer')
    
    #Initialize PWM normalization layer
    pwm_layer = Softmax(axis=-1, name='pwm')
    
    #Initialize sampling layers
    sample_func = sample_pwm
    if validation_sample_mode == 'sample' :
        sample_func = sample_pwm_only
    
    upsampling_layer = Lambda(lambda x: K.tile(x, [n_samples, 1, 1, 1]), name='upsampling_layer')
    sampling_layer = Lambda(sample_func, name='pwm_sampler')
    permute_layer = Lambda(lambda x: K.permute_dimensions(K.reshape(x, (n_samples, batch_size, 1, seq_length, 4)), (1, 0, 2, 3, 4)), name='permute_layer')
    
    
    def _sampler_func(class_input, raw_logits) :
        
        #Get Template and Mask
        onehot_template = reshape_layer(onehot_template_dense(class_input))
        onehot_mask = reshape_layer(onehot_mask_dense(class_input))
        
        #Add Template and Multiply Mask
        pwm_logits = masking_layer([raw_logits, onehot_template, onehot_mask])
        
        #Compute PWM (Nucleotide-wise Softmax)
        pwm = pwm_layer(pwm_logits)
        
        sampled_pwm = None
        
        #Optionally tile each PWM to sample from and create sample axis
        if use_samples :
            pwm_logits_upsampled = upsampling_layer(pwm_logits)
            sampled_pwm = sampling_layer(pwm_logits_upsampled)
            sampled_pwm = permute_layer(sampled_pwm)
        else :
            sampled_pwm = sampling_layer(pwm_logits)
        
        
        return pwm_logits, pwm, sampled_pwm
    
    return _sampler_func

# %%
def get_pwm_cross_entropy(pwm_start, pwm_end) :

    def _pwm_cross_entropy(inputs) :
        pwm_true, pwm_pred = inputs
        
        pwm_pred = K.clip(pwm_pred, K.epsilon(), 1. - K.epsilon())

        ce = - K.sum(pwm_true[:, 0, pwm_start:pwm_end, :] * K.log(pwm_pred[:, 0, pwm_start:pwm_end, :]), axis=-1)
        
        return K.expand_dims(K.mean(ce, axis=-1), axis=-1)
    
    return _pwm_cross_entropy

def min_pred(y_true, y_pred) :
    return y_pred

def get_weighted_loss(loss_coeff=1.) :
    
    def _min_pred(y_true, y_pred) :
        return loss_coeff * y_pred
    
    return _min_pred

def get_z_sample(z_inputs):
    
    z_mean, z_log_var = z_inputs
    
    batch_size = K.shape(z_mean)[0]
    latent_dim = K.int_shape(z_mean)[1]
    
    epsilon = K.random_normal(shape=(batch_size, latent_dim))
    
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

def get_z_kl_loss(anneal_coeff) :
    
    def _z_kl_loss(inputs, anneal_coeff=anneal_coeff) :
        z_mean, z_log_var = inputs
        
        kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
        kl_loss = K.mean(kl_loss, axis=-1)
        kl_loss *= -0.5
        
        return anneal_coeff * K.expand_dims(kl_loss, axis=-1)
    
    return _z_kl_loss

# %%
#Simple Library

sequence_templates = [
    'ATCCANNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNCAGCC' + 'G' * (128 - 81)
]

# %%
#Initialize Encoder and Decoder networks
batch_size = 32
seq_length = 128
n_samples = None
latent_size = 100

#Load Encoder
encoder = load_encoder_network_conv(batch_size, seq_length=seq_length, latent_size=latent_size)

#Load Decoder
decoder = load_decoder_network_deconv(batch_size, seq_length=seq_length)

#Load Sampler
sampler = build_sampler(batch_size, seq_length, n_classes=1, n_samples=n_samples, validation_sample_mode='sample')

# %%
#Build Encoder Model
encoder_input = Input(shape=(1, seq_length, 4), name='encoder_input')

z_mean, z_log_var = encoder(encoder_input)

z_sampling_layer = Lambda(get_z_sample, output_shape=(latent_size,), name='z_sampler')
z = z_sampling_layer([z_mean, z_log_var])

# instantiate encoder model
encoder_model = Model(encoder_input, [z_mean, z_log_var, z])
encoder_model.compile(
    optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
    loss=min_pred
)

#Build Decoder Model
decoder_class = Input(shape=(1,), name='decoder_class')
decoder_input = Input(shape=(latent_size,), name='decoder_input')

pwm_logits, pwm, sampled_pwm = sampler(decoder_class, decoder(decoder_input))

decoder_model = Model([decoder_class, decoder_input], [pwm_logits, pwm, sampled_pwm])

#Initialize Sequence Templates and Masks
initialize_sequence_templates(decoder_model, sequence_templates)

decoder_model.compile(
    optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
    loss=min_pred
)

# %%
#Build VAE Pipeline

vae_decoder_class = Input(shape=(1,), name='vae_decoder_class')
vae_encoder_input = Input(shape=(1, seq_length, 4), name='vae_encoder_input')

encoded_z_mean, encoded_z_log_var = encoder(vae_encoder_input)
encoded_z = z_sampling_layer([encoded_z_mean, encoded_z_log_var])
decoded_logits, decoded_pwm, decoded_sample = sampler(vae_decoder_class, decoder(encoded_z))

reconstruction_loss = Lambda(get_pwm_cross_entropy(pwm_start=5, pwm_end=81-5), name='reconstruction')([vae_encoder_input, decoded_pwm])

anneal_coeff = K.variable(0.0)

kl_loss = Lambda(get_z_kl_loss(anneal_coeff), name='kl')([encoded_z_mean, encoded_z_log_var])

vae_model = Model(
    [vae_decoder_class, vae_encoder_input],
    [reconstruction_loss, kl_loss]#, entropy_loss]
)

#Initialize Sequence Templates and Masks
initialize_sequence_templates(vae_model, sequence_templates)

vae_model.compile(
    optimizer=keras.optimizers.Adam(lr=0.0001, beta_1=0.5, beta_2=0.9),
    #optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
    loss={
        'reconstruction' : get_weighted_loss(loss_coeff=1.),
        'kl' : get_weighted_loss(loss_coeff=1.25)#0.5#0.35#0.15#0.05#, #0.000001
        #'entropy' : get_weighted_loss(loss_coeff=0.0)
    }
)

# %%
encoder_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 1, 128, 4)    0
# __________________________________________________________________________________________________
# policy_discriminator_conv_0 (Co (None, 1, 128, 64)   2112        encoder_input[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_batch_norm (None, 1, 128, 64)   256         policy_discriminator_conv_0[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 128, 64)   0           policy_discriminator_batch_norm_0
# __________________________________________________________________________________________________
# policy_discriminator_conv_1 (Co (None, 1, 128, 96)   49248       lambda_1[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_batch_norm (None, 1, 128, 96)   384         policy_discriminator_conv_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1, 128, 96)   0           policy_discriminator_batch_norm_1
# __________________________________________________________________________________________________
# policy_discriminator_conv_2 (Co (None, 1, 128, 128)  98432       lambda_2[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_batch_norm (None, 1, 128, 128)  512         policy_discriminator_conv_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1, 128, 128)  0           policy_discriminator_batch_norm_2
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 16384)        0           lambda_3[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_z_mean (De (None, 100)          1638500     flatten_1[0][0]
# __________________________________________________________________________________________________
# policy_discriminator_z_log_var  (None, 100)          1638500     flatten_1[0][0]
# __________________________________________________________________________________________________
# z_sampler (Lambda)              (None, 100)          0           policy_discriminator_z_mean[0][0]
#                                                                  policy_discriminator_z_log_var[0]
# ==================================================================================================
# Total params: 3,427,944
# Trainable params: 3,427,368
# Non-trainable params: 576
# __________________________________________________________________________________________________

# %%
decoder_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# decoder_input (InputLayer)      (None, 100)          0
# __________________________________________________________________________________________________
# policy_generator_dense_0 (Dense (None, 6144)         620544      decoder_input[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 16, 384)   0           policy_generator_dense_0[0][0]
# __________________________________________________________________________________________________
# policy_generator_batch_norm_den (None, 1, 16, 384)   1536        reshape_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 16, 384)   0           policy_generator_batch_norm_dense
# __________________________________________________________________________________________________
# policy_generator_deconv_0 (Conv (None, 1, 32, 256)   688384      lambda_4[0][0]
# __________________________________________________________________________________________________
# policy_generator_batch_norm_0 ( (None, 1, 32, 256)   1024        policy_generator_deconv_0[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 32, 256)   0           policy_generator_batch_norm_0[0][
# __________________________________________________________________________________________________
# policy_generator_deconv_1 (Conv (None, 1, 64, 192)   393408      lambda_5[0][0]
# __________________________________________________________________________________________________
# policy_generator_batch_norm_1 ( (None, 1, 64, 192)   768         policy_generator_deconv_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1, 64, 192)   0           policy_generator_batch_norm_1[0][
# __________________________________________________________________________________________________
# policy_generator_deconv_2 (Conv (None, 1, 128, 128)  172160      lambda_6[0][0]
# __________________________________________________________________________________________________
# policy_generator_batch_norm_2 ( (None, 1, 128, 128)  512         policy_generator_deconv_2[0][0]
# __________________________________________________________________________________________________
# decoder_class (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1, 128, 128)  0           policy_generator_batch_norm_2[0][
# __________________________________________________________________________________________________
# template_dense (Embedding)      (None, 1, 512)       512         decoder_class[0][0]
# __________________________________________________________________________________________________
# mask_dense (Embedding)          (None, 1, 512)       512         decoder_class[0][0]
# __________________________________________________________________________________________________
# policy_generator_deconv_3 (Conv (None, 1, 128, 4)    3588        lambda_7[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 128, 4)    0           template_dense[0][0]
#                                                                  mask_dense[0][0]
# __________________________________________________________________________________________________
# masking_layer (Lambda)          (None, 1, 128, 4)    0           policy_generator_deconv_3[0][0]
#                                                                  reshape_2[0][0]
#                                                                  reshape_2[1][0]
# __________________________________________________________________________________________________
# pwm (Softmax)                   (None, 1, 128, 4)    0           masking_layer[0][0]
# __________________________________________________________________________________________________
# pwm_sampler (Lambda)            (None, 1, None, 4)   0           masking_layer[0][0]
# ==================================================================================================
# Total params: 1,882,948
# Trainable params: 1,880,004
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
n_epochs = 100

def _anneal_func(val, epoch, n_epochs=n_epochs) :
    if epoch <= 0 :
        return 0.0
    elif epoch <= 3 :
        return 0.1
    elif epoch <= 6 :
        return 0.2
    elif epoch <= 9 :
        return 0.4
    elif epoch <= 12 :
        return 0.6
    elif epoch <= 15 :
        return 0.8
    elif epoch > 15 :
        return 1.0
    return 1.0

# %%
class EpochVariableCallback(Callback):
    def __init__(self, my_variable, my_func):
        self.my_variable = my_variable       
        self.my_func = my_func
    def on_epoch_end(self, epoch, logs={}):
        K.set_value(self.my_variable, self.my_func(K.get_value(self.my_variable), epoch))

s_train = np.zeros((x_train.shape[0], 1))
s_test = np.zeros((x_test.shape[0], 1))

dummy_target_train = np.zeros((x_train.shape[0], 1))
dummy_target_test = np.zeros((x_test.shape[0], 1))

model_name = "vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed"

callbacks =[
    #EarlyStopping(monitor='val_loss', min_delta=0.002, patience=10, verbose=0, mode='auto'),
    ModelCheckpoint("model_checkpoints/" + model_name + "_epoch_{epoch:02d}.hdf5", monitor='val_loss', mode='min', save_weights_only=True),
    EpochVariableCallback(anneal_coeff, _anneal_func)
]

# train the autoencoder
train_history = vae_model.fit(
    [s_train, x_train],
    [dummy_target_train, dummy_target_train],#, dummy_target_train],
    shuffle=True,
    epochs=n_epochs,
    batch_size=batch_size,
    validation_data=(
        [s_test, x_test],
        [dummy_target_test, dummy_target_test]#, dummy_target_test]
    ),
    callbacks=callbacks
)
# Out:
# Train on 10144 samples, validate on 544 samples
# Epoch 1/100
# 10144/10144 [==============================] - 14s 1ms/step - loss: 0.9787 - reconstruction_loss: 0.9787 - kl_loss: 0.0000e+00 - val_loss: 0.8863 - val_reconstruction_loss: 0.8863 - val_kl_loss: 0.0000e+00
# Epoch 2/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.4944 - reconstruction_loss: 0.4944 - kl_loss: 0.0000e+00 - val_loss: 0.5357 - val_reconstruction_loss: 0.5357 - val_kl_loss: 0.0000e+00
# Epoch 3/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.5849 - reconstruction_loss: 0.3231 - kl_loss: 0.2618 - val_loss: 0.5041 - val_reconstruction_loss: 0.2583 - val_kl_loss: 0.2457
# Epoch 4/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.4367 - reconstruction_loss: 0.2128 - kl_loss: 0.2239 - val_loss: 0.4431 - val_reconstruction_loss: 0.2219 - val_kl_loss: 0.2212
# Epoch 5/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.3937 - reconstruction_loss: 0.1731 - kl_loss: 0.2206 - val_loss: 0.4259 - val_reconstruction_loss: 0.2107 - val_kl_loss: 0.2152
# Epoch 6/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.5681 - reconstruction_loss: 0.2034 - kl_loss: 0.3647 - val_loss: 0.5893 - val_reconstruction_loss: 0.2167 - val_kl_loss: 0.3726
# Epoch 7/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.5485 - reconstruction_loss: 0.1900 - kl_loss: 0.3585 - val_loss: 0.6300 - val_reconstruction_loss: 0.2699 - val_kl_loss: 0.3601
# Epoch 8/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.5361 - reconstruction_loss: 0.1802 - kl_loss: 0.3559 - val_loss: 0.5857 - val_reconstruction_loss: 0.2230 - val_kl_loss: 0.3626
# Epoch 9/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.8389 - reconstruction_loss: 0.2661 - kl_loss: 0.5728 - val_loss: 0.8899 - val_reconstruction_loss: 0.3217 - val_kl_loss: 0.5682
# Epoch 10/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.8229 - reconstruction_loss: 0.2677 - kl_loss: 0.5553 - val_loss: 0.8731 - val_reconstruction_loss: 0.3209 - val_kl_loss: 0.5522
# Epoch 11/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 0.8128 - reconstruction_loss: 0.2636 - kl_loss: 0.5492 - val_loss: 0.8652 - val_reconstruction_loss: 0.3179 - val_kl_loss: 0.5473
# Epoch 12/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0523 - reconstruction_loss: 0.3763 - kl_loss: 0.6759 - val_loss: 1.1307 - val_reconstruction_loss: 0.5008 - val_kl_loss: 0.6300
# Epoch 13/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0373 - reconstruction_loss: 0.3914 - kl_loss: 0.6459 - val_loss: 1.0772 - val_reconstruction_loss: 0.4270 - val_kl_loss: 0.6503
# Epoch 14/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.0304 - reconstruction_loss: 0.3884 - kl_loss: 0.6421 - val_loss: 1.0768 - val_reconstruction_loss: 0.4484 - val_kl_loss: 0.6283
# Epoch 15/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2071 - reconstruction_loss: 0.5589 - kl_loss: 0.6481 - val_loss: 1.2280 - val_reconstruction_loss: 0.6019 - val_kl_loss: 0.6261
# Epoch 16/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1962 - reconstruction_loss: 0.5917 - kl_loss: 0.6044 - val_loss: 1.2356 - val_reconstruction_loss: 0.6016 - val_kl_loss: 0.6340
# Epoch 17/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1912 - reconstruction_loss: 0.5876 - kl_loss: 0.6036 - val_loss: 1.2194 - val_reconstruction_loss: 0.6411 - val_kl_loss: 0.5783
# Epoch 18/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.3003 - reconstruction_loss: 0.8427 - kl_loss: 0.4577 - val_loss: 1.3151 - val_reconstruction_loss: 0.9149 - val_kl_loss: 0.4002
# Epoch 19/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2889 - reconstruction_loss: 0.9069 - kl_loss: 0.3819 - val_loss: 1.2968 - val_reconstruction_loss: 0.9226 - val_kl_loss: 0.3741
# Epoch 20/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2812 - reconstruction_loss: 0.9152 - kl_loss: 0.3659 - val_loss: 1.2971 - val_reconstruction_loss: 0.9425 - val_kl_loss: 0.3546
# Epoch 21/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2769 - reconstruction_loss: 0.9126 - kl_loss: 0.3644 - val_loss: 1.2945 - val_reconstruction_loss: 0.9436 - val_kl_loss: 0.3510
# Epoch 22/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2745 - reconstruction_loss: 0.9142 - kl_loss: 0.3604 - val_loss: 1.3090 - val_reconstruction_loss: 0.9535 - val_kl_loss: 0.3555
# Epoch 23/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2704 - reconstruction_loss: 0.9087 - kl_loss: 0.3618 - val_loss: 1.2875 - val_reconstruction_loss: 0.9369 - val_kl_loss: 0.3506
# Epoch 24/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2684 - reconstruction_loss: 0.9016 - kl_loss: 0.3667 - val_loss: 1.3029 - val_reconstruction_loss: 0.9440 - val_kl_loss: 0.3589
# Epoch 25/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2650 - reconstruction_loss: 0.8944 - kl_loss: 0.3706 - val_loss: 1.3019 - val_reconstruction_loss: 0.9088 - val_kl_loss: 0.3931
# Epoch 26/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2649 - reconstruction_loss: 0.8901 - kl_loss: 0.3748 - val_loss: 1.2920 - val_reconstruction_loss: 0.9273 - val_kl_loss: 0.3648
# Epoch 27/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2597 - reconstruction_loss: 0.8828 - kl_loss: 0.3769 - val_loss: 1.2962 - val_reconstruction_loss: 0.9210 - val_kl_loss: 0.3752
# Epoch 28/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2576 - reconstruction_loss: 0.8728 - kl_loss: 0.3848 - val_loss: 1.2906 - val_reconstruction_loss: 0.9142 - val_kl_loss: 0.3765
# Epoch 29/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2587 - reconstruction_loss: 0.8738 - kl_loss: 0.3849 - val_loss: 1.2950 - val_reconstruction_loss: 0.9265 - val_kl_loss: 0.3685
# Epoch 30/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2547 - reconstruction_loss: 0.8682 - kl_loss: 0.3865 - val_loss: 1.2965 - val_reconstruction_loss: 0.9196 - val_kl_loss: 0.3768
# Epoch 31/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2515 - reconstruction_loss: 0.8555 - kl_loss: 0.3960 - val_loss: 1.2968 - val_reconstruction_loss: 0.9032 - val_kl_loss: 0.3936
# Epoch 32/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2504 - reconstruction_loss: 0.8495 - kl_loss: 0.4009 - val_loss: 1.2920 - val_reconstruction_loss: 0.9054 - val_kl_loss: 0.3866
# Epoch 33/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2472 - reconstruction_loss: 0.8446 - kl_loss: 0.4025 - val_loss: 1.2872 - val_reconstruction_loss: 0.8892 - val_kl_loss: 0.3980
# Epoch 34/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2454 - reconstruction_loss: 0.8355 - kl_loss: 0.4099 - val_loss: 1.2865 - val_reconstruction_loss: 0.8749 - val_kl_loss: 0.4116
# Epoch 35/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2442 - reconstruction_loss: 0.8352 - kl_loss: 0.4089 - val_loss: 1.2922 - val_reconstruction_loss: 0.8869 - val_kl_loss: 0.4052
# Epoch 36/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2430 - reconstruction_loss: 0.8296 - kl_loss: 0.4134 - val_loss: 1.2890 - val_reconstruction_loss: 0.8706 - val_kl_loss: 0.4184
# Epoch 37/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2417 - reconstruction_loss: 0.8224 - kl_loss: 0.4193 - val_loss: 1.2977 - val_reconstruction_loss: 0.8939 - val_kl_loss: 0.4038
# Epoch 38/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2394 - reconstruction_loss: 0.8179 - kl_loss: 0.4215 - val_loss: 1.2837 - val_reconstruction_loss: 0.8676 - val_kl_loss: 0.4161
# Epoch 39/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2368 - reconstruction_loss: 0.8113 - kl_loss: 0.4255 - val_loss: 1.2854 - val_reconstruction_loss: 0.8695 - val_kl_loss: 0.4160
# Epoch 40/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2356 - reconstruction_loss: 0.8045 - kl_loss: 0.4311 - val_loss: 1.2919 - val_reconstruction_loss: 0.8616 - val_kl_loss: 0.4304
# Epoch 41/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2343 - reconstruction_loss: 0.7990 - kl_loss: 0.4353 - val_loss: 1.2857 - val_reconstruction_loss: 0.8634 - val_kl_loss: 0.4223
# Epoch 42/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2314 - reconstruction_loss: 0.7942 - kl_loss: 0.4372 - val_loss: 1.2828 - val_reconstruction_loss: 0.8509 - val_kl_loss: 0.4318
# Epoch 43/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2312 - reconstruction_loss: 0.7867 - kl_loss: 0.4446 - val_loss: 1.2891 - val_reconstruction_loss: 0.8567 - val_kl_loss: 0.4325
# Epoch 44/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2291 - reconstruction_loss: 0.7830 - kl_loss: 0.4461 - val_loss: 1.2896 - val_reconstruction_loss: 0.8625 - val_kl_loss: 0.4271
# Epoch 45/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2280 - reconstruction_loss: 0.7772 - kl_loss: 0.4509 - val_loss: 1.2938 - val_reconstruction_loss: 0.8564 - val_kl_loss: 0.4375
# Epoch 46/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2263 - reconstruction_loss: 0.7719 - kl_loss: 0.4544 - val_loss: 1.2918 - val_reconstruction_loss: 0.8464 - val_kl_loss: 0.4454
# Epoch 47/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2252 - reconstruction_loss: 0.7669 - kl_loss: 0.4584 - val_loss: 1.2846 - val_reconstruction_loss: 0.8405 - val_kl_loss: 0.4441
# Epoch 48/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2241 - reconstruction_loss: 0.7614 - kl_loss: 0.4626 - val_loss: 1.2814 - val_reconstruction_loss: 0.8367 - val_kl_loss: 0.4447
# Epoch 49/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2225 - reconstruction_loss: 0.7561 - kl_loss: 0.4665 - val_loss: 1.2858 - val_reconstruction_loss: 0.8410 - val_kl_loss: 0.4448
# Epoch 50/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2220 - reconstruction_loss: 0.7523 - kl_loss: 0.4697 - val_loss: 1.2888 - val_reconstruction_loss: 0.8266 - val_kl_loss: 0.4621
# Epoch 51/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2213 - reconstruction_loss: 0.7484 - kl_loss: 0.4730 - val_loss: 1.2913 - val_reconstruction_loss: 0.8265 - val_kl_loss: 0.4648
# Epoch 52/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2183 - reconstruction_loss: 0.7416 - kl_loss: 0.4767 - val_loss: 1.2918 - val_reconstruction_loss: 0.8435 - val_kl_loss: 0.4483
# Epoch 53/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2168 - reconstruction_loss: 0.7364 - kl_loss: 0.4804 - val_loss: 1.2946 - val_reconstruction_loss: 0.8320 - val_kl_loss: 0.4626
# Epoch 54/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2166 - reconstruction_loss: 0.7320 - kl_loss: 0.4846 - val_loss: 1.2906 - val_reconstruction_loss: 0.8168 - val_kl_loss: 0.4738
# Epoch 55/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2151 - reconstruction_loss: 0.7301 - kl_loss: 0.4850 - val_loss: 1.2950 - val_reconstruction_loss: 0.8232 - val_kl_loss: 0.4718
# Epoch 56/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2148 - reconstruction_loss: 0.7233 - kl_loss: 0.4915 - val_loss: 1.2923 - val_reconstruction_loss: 0.8143 - val_kl_loss: 0.4780
# Epoch 57/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2110 - reconstruction_loss: 0.7181 - kl_loss: 0.4929 - val_loss: 1.3021 - val_reconstruction_loss: 0.8473 - val_kl_loss: 0.4548
# Epoch 58/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2106 - reconstruction_loss: 0.7131 - kl_loss: 0.4974 - val_loss: 1.2926 - val_reconstruction_loss: 0.8188 - val_kl_loss: 0.4738
# Epoch 59/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2111 - reconstruction_loss: 0.7125 - kl_loss: 0.4987 - val_loss: 1.2950 - val_reconstruction_loss: 0.8225 - val_kl_loss: 0.4725
# Epoch 60/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2098 - reconstruction_loss: 0.7081 - kl_loss: 0.5017 - val_loss: 1.2933 - val_reconstruction_loss: 0.8098 - val_kl_loss: 0.4834
# Epoch 61/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2088 - reconstruction_loss: 0.7044 - kl_loss: 0.5044 - val_loss: 1.2947 - val_reconstruction_loss: 0.8040 - val_kl_loss: 0.4908
# Epoch 62/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2067 - reconstruction_loss: 0.6978 - kl_loss: 0.5088 - val_loss: 1.3091 - val_reconstruction_loss: 0.8381 - val_kl_loss: 0.4710
# Epoch 63/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2062 - reconstruction_loss: 0.6948 - kl_loss: 0.5114 - val_loss: 1.2954 - val_reconstruction_loss: 0.7847 - val_kl_loss: 0.5107
# Epoch 64/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2060 - reconstruction_loss: 0.6915 - kl_loss: 0.5145 - val_loss: 1.3337 - val_reconstruction_loss: 0.8903 - val_kl_loss: 0.4434
# Epoch 65/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2031 - reconstruction_loss: 0.6893 - kl_loss: 0.5138 - val_loss: 1.3021 - val_reconstruction_loss: 0.8234 - val_kl_loss: 0.4787
# Epoch 66/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2029 - reconstruction_loss: 0.6832 - kl_loss: 0.5197 - val_loss: 1.3001 - val_reconstruction_loss: 0.7987 - val_kl_loss: 0.5014
# Epoch 67/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2028 - reconstruction_loss: 0.6820 - kl_loss: 0.5208 - val_loss: 1.3031 - val_reconstruction_loss: 0.7689 - val_kl_loss: 0.5342
# Epoch 68/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2005 - reconstruction_loss: 0.6789 - kl_loss: 0.5216 - val_loss: 1.3117 - val_reconstruction_loss: 0.7912 - val_kl_loss: 0.5204
# Epoch 69/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.2013 - reconstruction_loss: 0.6740 - kl_loss: 0.5274 - val_loss: 1.3052 - val_reconstruction_loss: 0.7927 - val_kl_loss: 0.5124
# Epoch 70/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1983 - reconstruction_loss: 0.6706 - kl_loss: 0.5277 - val_loss: 1.3171 - val_reconstruction_loss: 0.8525 - val_kl_loss: 0.4645
# Epoch 71/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1977 - reconstruction_loss: 0.6678 - kl_loss: 0.5299 - val_loss: 1.3042 - val_reconstruction_loss: 0.7770 - val_kl_loss: 0.5272
# Epoch 72/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1972 - reconstruction_loss: 0.6644 - kl_loss: 0.5328 - val_loss: 1.3260 - val_reconstruction_loss: 0.8710 - val_kl_loss: 0.4550
# Epoch 73/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1970 - reconstruction_loss: 0.6605 - kl_loss: 0.5365 - val_loss: 1.3220 - val_reconstruction_loss: 0.8323 - val_kl_loss: 0.4897
# Epoch 74/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1953 - reconstruction_loss: 0.6570 - kl_loss: 0.5383 - val_loss: 1.3159 - val_reconstruction_loss: 0.7211 - val_kl_loss: 0.5948
# Epoch 75/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1944 - reconstruction_loss: 0.6545 - kl_loss: 0.5399 - val_loss: 1.3150 - val_reconstruction_loss: 0.7225 - val_kl_loss: 0.5925
# Epoch 76/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1937 - reconstruction_loss: 0.6498 - kl_loss: 0.5440 - val_loss: 1.3141 - val_reconstruction_loss: 0.8131 - val_kl_loss: 0.5010
# Epoch 77/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1928 - reconstruction_loss: 0.6484 - kl_loss: 0.5444 - val_loss: 1.3087 - val_reconstruction_loss: 0.7755 - val_kl_loss: 0.5332
# Epoch 78/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1913 - reconstruction_loss: 0.6443 - kl_loss: 0.5470 - val_loss: 1.3176 - val_reconstruction_loss: 0.7765 - val_kl_loss: 0.5411
# Epoch 79/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1899 - reconstruction_loss: 0.6417 - kl_loss: 0.5481 - val_loss: 1.3139 - val_reconstruction_loss: 0.7950 - val_kl_loss: 0.5190
# Epoch 80/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1899 - reconstruction_loss: 0.6387 - kl_loss: 0.5512 - val_loss: 1.3158 - val_reconstruction_loss: 0.7838 - val_kl_loss: 0.5319
# Epoch 81/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1900 - reconstruction_loss: 0.6378 - kl_loss: 0.5522 - val_loss: 1.3297 - val_reconstruction_loss: 0.8313 - val_kl_loss: 0.4984
# Epoch 82/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1884 - reconstruction_loss: 0.6346 - kl_loss: 0.5538 - val_loss: 1.3180 - val_reconstruction_loss: 0.7709 - val_kl_loss: 0.5471
# Epoch 83/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1889 - reconstruction_loss: 0.6313 - kl_loss: 0.5575 - val_loss: 1.3341 - val_reconstruction_loss: 0.8491 - val_kl_loss: 0.4851
# Epoch 84/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1857 - reconstruction_loss: 0.6281 - kl_loss: 0.5576 - val_loss: 1.3200 - val_reconstruction_loss: 0.7378 - val_kl_loss: 0.5822
# Epoch 85/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1852 - reconstruction_loss: 0.6272 - kl_loss: 0.5581 - val_loss: 1.3152 - val_reconstruction_loss: 0.7474 - val_kl_loss: 0.5679
# Epoch 86/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1850 - reconstruction_loss: 0.6231 - kl_loss: 0.5619 - val_loss: 1.3494 - val_reconstruction_loss: 0.8823 - val_kl_loss: 0.4671
# Epoch 87/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1845 - reconstruction_loss: 0.6214 - kl_loss: 0.5631 - val_loss: 1.3624 - val_reconstruction_loss: 0.6682 - val_kl_loss: 0.6942
# Epoch 88/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1814 - reconstruction_loss: 0.6176 - kl_loss: 0.5638 - val_loss: 1.3231 - val_reconstruction_loss: 0.7865 - val_kl_loss: 0.5367
# Epoch 89/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1837 - reconstruction_loss: 0.6176 - kl_loss: 0.5661 - val_loss: 1.3231 - val_reconstruction_loss: 0.7990 - val_kl_loss: 0.5241
# Epoch 90/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1819 - reconstruction_loss: 0.6125 - kl_loss: 0.5694 - val_loss: 1.3522 - val_reconstruction_loss: 0.8805 - val_kl_loss: 0.4718
# Epoch 91/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1821 - reconstruction_loss: 0.6128 - kl_loss: 0.5693 - val_loss: 1.3250 - val_reconstruction_loss: 0.7914 - val_kl_loss: 0.5336
# Epoch 92/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1816 - reconstruction_loss: 0.6112 - kl_loss: 0.5705 - val_loss: 1.3358 - val_reconstruction_loss: 0.7123 - val_kl_loss: 0.6235
# Epoch 93/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1797 - reconstruction_loss: 0.6047 - kl_loss: 0.5750 - val_loss: 1.3280 - val_reconstruction_loss: 0.8164 - val_kl_loss: 0.5116
# Epoch 94/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1785 - reconstruction_loss: 0.6029 - kl_loss: 0.5756 - val_loss: 1.3513 - val_reconstruction_loss: 0.8596 - val_kl_loss: 0.4917
# Epoch 95/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1791 - reconstruction_loss: 0.6028 - kl_loss: 0.5763 - val_loss: 1.3305 - val_reconstruction_loss: 0.7620 - val_kl_loss: 0.5685
# Epoch 96/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1783 - reconstruction_loss: 0.5995 - kl_loss: 0.5788 - val_loss: 1.3780 - val_reconstruction_loss: 0.8986 - val_kl_loss: 0.4794
# Epoch 97/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1752 - reconstruction_loss: 0.5958 - kl_loss: 0.5794 - val_loss: 1.3650 - val_reconstruction_loss: 0.6686 - val_kl_loss: 0.6964
# Epoch 98/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1784 - reconstruction_loss: 0.5975 - kl_loss: 0.5809 - val_loss: 1.3347 - val_reconstruction_loss: 0.7315 - val_kl_loss: 0.6032
# Epoch 99/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1737 - reconstruction_loss: 0.5928 - kl_loss: 0.5810 - val_loss: 1.3431 - val_reconstruction_loss: 0.7568 - val_kl_loss: 0.5863
# Epoch 100/100
# 10144/10144 [==============================] - 10s 1ms/step - loss: 1.1755 - reconstruction_loss: 0.5906 - kl_loss: 0.5849 - val_loss: 1.3293 - val_reconstruction_loss: 0.7438 - val_kl_loss: 0.5855

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(4.5 * 2, 4))

n_epochs_actual = len(train_history.history['reconstruction_loss'])

ax1.plot(np.arange(1, n_epochs_actual + 1), train_history.history['reconstruction_loss'], linewidth=3, color='green')
ax1.plot(np.arange(1, n_epochs_actual + 1), train_history.history['val_reconstruction_loss'], linewidth=3, color='orange')

plt.sca(ax1)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Reconstruction Loss", fontsize=14)
plt.xlim(1, n_epochs_actual)
plt.xticks([1, n_epochs_actual], [1, n_epochs], fontsize=12)
plt.yticks(fontsize=12)

ax2.plot(np.arange(1, n_epochs_actual + 1), train_history.history['kl_loss'], linewidth=3, color='green')
ax2.plot(np.arange(1, n_epochs_actual + 1), train_history.history['val_kl_loss'], linewidth=3, color='orange')

plt.sca(ax2)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("KL Divergence", fontsize=14)
plt.xlim(1, n_epochs_actual)
plt.xticks([1, n_epochs_actual], [1, n_epochs], fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()

plt.show()

# %%
# Save model and weights
save_dir = 'saved_models'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_encoder.h5'
model_path = os.path.join(save_dir, model_name)
encoder_model.save(model_path)
print('Saved trained model at %s ' % model_path)

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_decoder.h5'
model_path = os.path.join(save_dir, model_name)
decoder_model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at saved_models/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_encoder.h5
# Saved trained model at saved_models/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_decoder.h5

# %%
#Load models
save_dir = 'saved_models'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_encoder.h5'
model_path = os.path.join(save_dir, model_name)
encoder_model = load_model(model_path, custom_objects={'st_sampled_softmax':st_sampled_softmax, 'st_hardmax_softmax':st_hardmax_softmax, 'min_pred':min_pred})

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_decoder.h5'
model_path = os.path.join(save_dir, model_name)
decoder_model = load_model(model_path, custom_objects={'st_sampled_softmax':st_sampled_softmax, 'st_hardmax_softmax':st_hardmax_softmax, 'min_pred':min_pred})

# %%
encoder_model.load_weights("model_checkpoints/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_epoch_50.hdf5", by_name=True)
decoder_model.load_weights("model_checkpoints/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_epoch_50.hdf5", by_name=True)

# %%
# Save model and weights
save_dir = 'saved_models'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_encoder_epoch_50.h5'
model_path = os.path.join(save_dir, model_name)
encoder_model.save(model_path)
print('Saved trained model at %s ' % model_path)

model_name = 'vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_decoder_epoch_50.h5'
model_path = os.path.join(save_dir, model_name)
decoder_model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at saved_models/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_encoder_epoch_50.h5
# Saved trained model at saved_models/vae_apa_max_isoform_doubledope_weak_cano_pas_len_128_100_epochs_kl_factor_125_convnet_no_drop_annealed_decoder_epoch_50.h5

# %%
#Visualize a few fake and real sequence patterns

s_test = np.zeros((x_test.shape[0], 1))

z_mean_test, z_log_var_test, z_test = encoder_model.predict([x_test], batch_size=32, verbose=True)

fake_pwm_test_batch = decoder_model.predict([s_test, z_test], batch_size=32, verbose=True)

for plot_i in range(5) :
    print("Test sequence " + str(plot_i) + ":")
    plot_gan_logo(x_test[plot_i, 0, :, :], 0, sequence_template=('N' * 128), figsize=(12, 0.75), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=81)
    plot_gan_logo(fake_pwm_test_batch[1][plot_i, 0, :, :], 0, sequence_template=('N' * 128), figsize=(12, 0.75), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=81)
# Out:
# 544/544 [==============================] - 0s 136us/step
# 544/544 [==============================] - 0s 278us/step
# Test sequence 0:
# Test sequence 1:
# Test sequence 2:
# Test sequence 3:
# Test sequence 4:

# %%
#Sample new patterns

z_test_new = np.random.normal(loc=0.0, scale=1.0, size=(32, 100))

fake_pwm_test_batch = decoder_model.predict_on_batch([s_test[:32], z_test_new[:32]])

print("- Fake PWMs (Randomly Generated) -")

for plot_i in range(32) :
    plot_gan_logo(fake_pwm_test_batch[1][plot_i, 0, :, :], 0, sequence_template=('N' * 128), figsize=(12, 0.55), width_ratios=[1, 7], logo_height=1.0, plot_start=0, plot_end=128)
# Out:
# - Fake PWMs (Randomly Generated) -
