# %%
import torch
from torch import optim
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd
from torch.autograd import Variable

from sklearn.preprocessing import OneHotEncoder
import os, math, glob, argparse
from utils.torch_utils import *
from utils.utils import *
from mpradragonn_predictor_pytorch import *
import matplotlib.pyplot as plt
import utils.language_helpers
plt.switch_backend('agg')
import numpy as np
from models import *

from wgan_gp_mpradragonn_analyzer_quantile_cutoff import *
# Out:
# /home/ubuntu/anaconda3/envs/pytorch_p36_fbgan/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
run_names = [
    'mpradragonn_sample',
    'mpradragonn_strong',
    'fbgan_mpradragonn_sample_quantile_cutoff_60',
    'fbgan_mpradragonn_sample_quantile_cutoff_60',
    'fbgan_mpradragonn_sample_quantile_cutoff_60',
    'fbgan_mpradragonn_sample_quantile_cutoff_80',
    'fbgan_mpradragonn_sample_quantile_cutoff_80',
    'fbgan_mpradragonn_sample_quantile_cutoff_80'
]

iterations = [
    None,
    None,
    50,
    100,
    None,
    50,
    100,
    None
]

sampling_factors = [
    1,
    10
]

n_seqs = 4096

file_suffix = '_4094_sequences'

for sampling_factor in sampling_factors :
    print("Sampling factor = " + str(sampling_factor))
    
    n_seqs_upsampled = n_seqs * sampling_factor
    
    for run_name, run_iter in zip(run_names, iterations) :
        model = WGAN_LangGP(run_name=run_name)
        model.load_model(directory = './checkpoint/' + run_name + '/', iteration=run_iter)

        num_batches_sample = int(n_seqs_upsampled / model.batch_size)

        print("Starting sampling...")

        seqs = model.sample(num_batches_sample, 1)

        print("Finished sampling.")

        if sampling_factor > 1 :
            preds = np.ravel(model.analyzer.predict_model(seqs))
            sort_index = np.argsort(preds)[::-1]
            
            seqs = [seqs[sort_index[k]] for k in range(len(seqs))][:n_seqs]
        
        #Save sequences to file
        with open(run_name + "_iter_" + str(run_iter) + file_suffix + "_sampling_factor_" + str(sampling_factor) + ".txt", "wt") as f :
            for i in range(len(seqs)) :
                seq = seqs[i]

                f.write(seq + "\n")
# Out:
# Sampling factor = 1
# loading dataset...
# ('G', 'T', 'C', 'C', 'C', 'T', 'G', 'C', 'T', 'C', 'T', 'G', 'C', 'C', 'C', 'C', 'G', 'C', 'C', 'C', 'C', 'C', 'A', 'A', 'C', 'C', 'T', 'C', 'A', 'C', 'C', 'C', 'C', 'T', 'C', 'C', 'A', 'C', 'C', 'A', 'C', 'C', 'A', 'A', 'A', 'T', 'C', 'A', 'A', 'T', 'A', 'A', 'G', 'C', 'C', 'G', 'C', 'C', 'T', 'G', 'G', 'A', 'A', 'T', 'G', 'G', 'A', 'G', 'A', 'C', 'A', 'G', 'C', 'C', 'T', 'G', 'C', 'A', 'G', 'A', 'G', 'T', 'C', 'T', 'C', 'A', 'C', 'C', 'A', 'C', 'C', 'G', 'G', 'C', 'G', 'G', 'G', 'A', 'G', 'A', 'A', 'G', 'C', 'T', 'G', 'A', 'G', 'T', 'G', 'A', 'G', 'T', 'G', 'A', 'T', 'T', 'A', 'T', 'A', 'A', 'G', 'G', 'A', 'G', 'A', 'A', 'A', 'A', 'C', 'C', 'A', 'C', 'T', 'C', 'A', 'G', 'G', 'C', 'T', 'T', 'A', 'T', 'C', 'T', 'C')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# Loading most recently saved...
# [*] Checkpoint 23399 found at ./checkpoint/mpradragonn_sample/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('C', 'A', 'G', 'C', 'C', 'A', 'G', 'C', 'C', 'A', 'T', 'G', 'G', 'T', 'C', 'C', 'C', 'A', 'T', 'G', 'C', 'T', 'T', 'G', 'C', 'T', 'A', 'G', 'C', 'A', 'A', 'C', 'A', 'G', 'A', 'A', 'A', 'G', 'T', 'A', 'C', 'A', 'G', 'C', 'A', 'G', 'A', 'T', 'G', 'G', 'C', 'A', 'G', 'C', 'A', 'A', 'G', 'C', 'A', 'G', 'C', 'T', 'G', 'C', 'T', 'G', 'C', 'A', 'T', 'T', 'T', 'T', 'C', 'C', 'A', 'A', 'A', 'C', 'C', 'T', 'T', 'G', 'G', 'T', 'C', 'A', 'G', 'C', 'A', 'A', 'C', 'T', 'G', 'T', 'T', 'T', 'T', 'C', 'A', 'A', 'G', 'C', 'C', 'A', 'G', 'C', 'A', 'C', 'A', 'A', 'G', 'G', 'C', 'A', 'G', 'G', 'T', 'T', 'G', 'A', 'A', 'T', 'G', 'G', 'A', 'G', 'G', 'C', 'A', 'A', 'A', 'G', 'A', 'T', 'G', 'G', 'A', 'T', 'G', 'T', 'G', 'G', 'A', 'T', 'T')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# Loading most recently saved...
# [*] Checkpoint 23399 found at ./checkpoint/mpradragonn_strong/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('T', 'T', 'G', 'T', 'T', 'T', 'C', 'C', 'A', 'T', 'G', 'T', 'G', 'C', 'T', 'T', 'T', 'T', 'G', 'T', 'C', 'T', 'T', 'T', 'T', 'G', 'T', 'T', 'G', 'G', 'C', 'G', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'A', 'T', 'A', 'C', 'T', 'C', 'G', 'A', 'T', 'G', 'G', 'G', 'C', 'G', 'G', 'G', 'A', 'G', 'A', 'A', 'G', 'A', 'G', 'G', 'C', 'C', 'C', 'T', 'G', 'G', 'G', 'G', 'A', 'C', 'A', 'G', 'G', 'G', 'C', 'T', 'G', 'G', 'T', 'T', 'G', 'A', 'C', 'A', 'T', 'T', 'T', 'C', 'T', 'G', 'G', 'A', 'G', 'C', 'A', 'C', 'T', 'A', 'C', 'T', 'G', 'C', 'C', 'A', 'T', 'C', 'G', 'T', 'G', 'A', 'G', 'G', 'A', 'A', 'A', 'T', 'C', 'A', 'G', 'T', 'T', 'G', 'A', 'T', 'G', 'A', 'A', 'A', 'A', 'T', 'C', 'C', 'A', 'A', 'G', 'C', 'C', 'A', 'T', 'G', 'A', 'A')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# [*] Checkpoint 50 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_60/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('C', 'A', 'G', 'T', 'G', 'A', 'G', 'C', 'A', 'T', 'C', 'T', 'T', 'T', 'G', 'C', 'C', 'C', 'C', 'C', 'T', 'A', 'G', 'A', 'G', 'G', 'C', 'T', 'C', 'A', 'T', 'G', 'C', 'T', 'G', 'A', 'G', 'A', 'T', 'G', 'A', 'C', 'A', 'G', 'T', 'C', 'A', 'C', 'C', 'T', 'G', 'A', 'G', 'C', 'C', 'C', 'C', 'A', 'G', 'A', 'C', 'T', 'G', 'T', 'C', 'T', 'C', 'C', 'T', 'A', 'G', 'A', 'A', 'A', 'G', 'C', 'A', 'C', 'T', 'G', 'A', 'A', 'A', 'T', 'G', 'T', 'G', 'A', 'C', 'A', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'C', 'C', 'C', 'T', 'C', 'C', 'C', 'C', 'A', 'G', 'A', 'A', 'G', 'C', 'C', 'A', 'G', 'C', 'A', 'A', 'A', 'C', 'C', 'C', 'A', 'A', 'G', 'G', 'C', 'C', 'T', 'G', 'T', 'G', 'G', 'C', 'A', 'A', 'C', 'A', 'C', 'A', 'C', 'A', 'A', 'G', 'T')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# [*] Checkpoint 100 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_60/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('C', 'T', 'G', 'G', 'G', 'C', 'C', 'C', 'T', 'G', 'T', 'T', 'T', 'C', 'T', 'T', 'T', 'T', 'C', 'A', 'G', 'A', 'G', 'C', 'A', 'A', 'A', 'G', 'A', 'G', 'A', 'T', 'C', 'T', 'T', 'C', 'A', 'G', 'C', 'A', 'A', 'G', 'A', 'A', 'T', 'C', 'C', 'A', 'G', 'A', 'T', 'C', 'C', 'T', 'T', 'G', 'A', 'T', 'T', 'T', 'T', 'A', 'A', 'A', 'C', 'T', 'C', 'T', 'G', 'G', 'C', 'T', 'T', 'C', 'A', 'T', 'T', 'A', 'A', 'C', 'T', 'T', 'C', 'A', 'G', 'T', 'C', 'A', 'A', 'A', 'C', 'T', 'T', 'C', 'A', 'C', 'T', 'T', 'T', 'A', 'C', 'C', 'T', 'G', 'A', 'A', 'G', 'G', 'C', 'T', 'C', 'A', 'G', 'G', 'G', 'G', 'C', 'A', 'T', 'A', 'G', 'C', 'T', 'A', 'C', 'C', 'C', 'A', 'C', 'T', 'G', 'T', 'A', 'A', 'T', 'C', 'A', 'T', 'G', 'G', 'G', 'A', 'A', 'A', 'G')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# Loading most recently saved...
# [*] Checkpoint 150 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_60/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('C', 'T', 'T', 'G', 'T', 'T', 'C', 'C', 'A', 'C', 'A', 'G', 'G', 'C', 'T', 'G', 'C', 'A', 'C', 'A', 'T', 'T', 'C', 'C', 'A', 'T', 'T', 'C', 'T', 'G', 'A', 'G', 'T', 'C', 'A', 'A', 'G', 'C', 'A', 'G', 'G', 'G', 'G', 'G', 'C', 'G', 'G', 'G', 'G', 'A', 'C', 'T', 'G', 'G', 'G', 'G', 'G', 'A', 'G', 'G', 'T', 'A', 'A', 'G', 'G', 'C', 'A', 'G', 'A', 'G', 'G', 'G', 'G', 'A', 'G', 'G', 'A', 'G', 'A', 'A', 'C', 'A', 'G', 'T', 'C', 'G', 'G', 'G', 'C', 'C', 'T', 'C', 'C', 'T', 'C', 'T', 'G', 'G', 'G', 'G', 'C', 'G', 'G', 'A', 'T', 'C', 'C', 'C', 'C', 'C', 'A', 'G', 'G', 'G', 'A', 'G', 'C', 'T', 'C', 'C', 'A', 'G', 'G', 'C', 'T', 'T', 'G', 'G', 'C', 'A', 'G', 'G', 'C', 'A', 'G', 'G', 'G', 'A', 'T', 'T', 'A', 'C', 'G', 'A', 'T')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# [*] Checkpoint 50 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_80/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('A', 'A', 'T', 'T', 'A', 'C', 'C', 'T', 'C', 'A', 'A', 'C', 'A', 'C', 'A', 'G', 'T', 'T', 'A', 'T', 'A', 'T', 'A', 'A', 'T', 'C', 'C', 'T', 'T', 'C', 'T', 'C', 'A', 'T', 'T', 'T', 'T', 'T', 'T', 'C', 'C', 'C', 'T', 'T', 'A', 'C', 'A', 'A', 'A', 'T', 'C', 'T', 'T', 'T', 'G', 'T', 'C', 'G', 'C', 'T', 'G', 'A', 'G', 'C', 'T', 'C', 'G', 'G', 'T', 'G', 'G', 'C', 'T', 'C', 'A', 'C', 'G', 'C', 'C', 'T', 'G', 'T', 'A', 'A', 'T', 'C', 'C', 'C', 'A', 'G', 'C', 'A', 'C', 'T', 'T', 'T', 'A', 'T', 'A', 'T', 'T', 'C', 'T', 'G', 'G', 'A', 'T', 'C', 'A', 'T', 'G', 'A', 'G', 'G', 'T', 'C', 'A', 'G', 'G', 'T', 'G', 'G', 'G', 'C', 'G', 'G', 'A', 'T', 'C', 'A', 'T', 'G', 'A', 'G', 'G', 'T', 'C', 'A', 'G', 'G', 'A', 'G', 'T', 'T', 'C')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# [*] Checkpoint 100 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_80/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('C', 'A', 'C', 'G', 'A', 'G', 'C', 'A', 'G', 'G', 'A', 'G', 'G', 'C', 'A', 'G', 'A', 'G', 'G', 'A', 'T', 'C', 'A', 'C', 'A', 'G', 'T', 'G', 'T', 'T', 'A', 'C', 'A', 'G', 'C', 'C', 'T', 'T', 'T', 'T', 'T', 'T', 'G', 'T', 'A', 'C', 'C', 'C', 'A', 'C', 'A', 'T', 'T', 'T', 'G', 'G', 'C', 'A', 'G', 'A', 'T', 'C', 'G', 'C', 'A', 'A', 'G', 'T', 'T', 'C', 'T', 'T', 'G', 'T', 'C', 'C', 'T', 'G', 'C', 'A', 'T', 'T', 'C', 'A', 'A', 'G', 'A', 'A', 'G', 'A', 'A', 'T', 'G', 'A', 'G', 'G', 'T', 'T', 'A', 'T', 'G', 'C', 'T', 'G', 'A', 'A', 'A', 'A', 'C', 'C', 'A', 'A', 'A', 'G', 'A', 'G', 'T', 'G', 'A', 'G', 'A', 'A', 'G', 'G', 'G', 'C', 'A', 'G', 'A', 'G', 'A', 'A', 'G', 'A', 'G', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'G', 'A', 'A')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# Loading most recently saved...
# [*] Checkpoint 150 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_80/!
# Starting sampling...
# Finished sampling.
# Sampling factor = 10
# loading dataset...
# ('C', 'C', 'T', 'G', 'G', 'C', 'C', 'C', 'A', 'G', 'C', 'T', 'G', 'G', 'T', 'G', 'G', 'T', 'C', 'T', 'C', 'G', 'G', 'C', 'T', 'C', 'A', 'T', 'C', 'A', 'A', 'A', 'G', 'C', 'A', 'G', 'C', 'A', 'A', 'G', 'G', 'C', 'A', 'A', 'G', 'A', 'G', 'A', 'A', 'A', 'A', 'G', 'G', 'G', 'G', 'G', 'G', 'T', 'T', 'A', 'G', 'A', 'A', 'G', 'C', 'C', 'C', 'A', 'G', 'A', 'G', 'A', 'G', 'C', 'T', 'T', 'T', 'A', 'G', 'A', 'A', 'G', 'T', 'G', 'G', 'A', 'A', 'C', 'A', 'C', 'T', 'G', 'G', 'C', 'T', 'C', 'A', 'C', 'T', 'T', 'T', 'T', 'G', 'C', 'T', 'T', 'A', 'A', 'A', 'A', 'T', 'G', 'A', 'C', 'A', 'A', 'T', 'T', 'A', 'A', 'G', 'C', 'T', 'A', 'T', 'G', 'C', 'A', 'T', 'G', 'A', 'G', 'T', 'A', 'A', 'G', 'A', 'A', 'T', 'T', 'C', 'C', 'T', 'C', 'T')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# Loading most recently saved...
# [*] Checkpoint 23399 found at ./checkpoint/mpradragonn_sample/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('G', 'A', 'G', 'G', 'C', 'A', 'A', 'A', 'C', 'G', 'G', 'A', 'A', 'T', 'T', 'G', 'T', 'T', 'G', 'A', 'A', 'G', 'G', 'G', 'T', 'A', 'A', 'A', 'C', 'T', 'G', 'G', 'G', 'G', 'A', 'A', 'A', 'C', 'A', 'G', 'T', 'T', 'T', 'T', 'G', 'G', 'C', 'A', 'A', 'C', 'A', 'A', 'C', 'T', 'T', 'G', 'G', 'C', 'A', 'T', 'T', 'A', 'T', 'T', 'T', 'G', 'T', 'T', 'A', 'A', 'G', 'T', 'T', 'G', 'A', 'A', 'G', 'A', 'C', 'G', 'C', 'A', 'C', 'A', 'T', 'A', 'C', 'C', 'C', 'T', 'G', 'T', 'G', 'A', 'C', 'T', 'C', 'C', 'A', 'C', 'T', 'C', 'C', 'C', 'A', 'G', 'C', 'T', 'G', 'C', 'A', 'G', 'T', 'C', 'C', 'C', 'T', 'G', 'G', 'A', 'G', 'A', 'G', 'G', 'C', 'T', 'G', 'T', 'G', 'C', 'A', 'T', 'A', 'C', 'A', 'T', 'G', 'T', 'C', 'C', 'C', 'G', 'G', 'G', 'A')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# Loading most recently saved...
# [*] Checkpoint 23399 found at ./checkpoint/mpradragonn_strong/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('A', 'C', 'T', 'T', 'T', 'T', 'T', 'C', 'A', 'G', 'T', 'C', 'T', 'T', 'G', 'C', 'A', 'A', 'A', 'A', 'T', 'T', 'G', 'A', 'A', 'A', 'C', 'T', 'C', 'T', 'A', 'T', 'A', 'C', 'T', 'C', 'A', 'T', 'T', 'A', 'A', 'A', 'C', 'A', 'G', 'T', 'A', 'A', 'C', 'T', 'C', 'C', 'C', 'C', 'A', 'T', 'T', 'C', 'C', 'C', 'C', 'C', 'T', 'C', 'C', 'C', 'A', 'C', 'C', 'T', 'C', 'A', 'C', 'A', 'T', 'T', 'C', 'C', 'C', 'T', 'G', 'G', 'C', 'A', 'A', 'C', 'C', 'A', 'C', 'A', 'T', 'T', 'C', 'A', 'T', 'A', 'T', 'A', 'G', 'T', 'A', 'T', 'T', 'T', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'A', 'C', 'T', 'G', 'G', 'C', 'T', 'T', 'A')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# [*] Checkpoint 50 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_60/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('A', 'T', 'G', 'A', 'A', 'T', 'G', 'T', 'G', 'T', 'G', 'G', 'G', 'G', 'C', 'A', 'G', 'A', 'A', 'C', 'A', 'G', 'C', 'T', 'A', 'C', 'A', 'A', 'T', 'G', 'T', 'G', 'C', 'A', 'G', 'C', 'C', 'A', 'A', 'G', 'G', 'T', 'T', 'G', 'T', 'A', 'A', 'A', 'G', 'C', 'A', 'T', 'T', 'G', 'A', 'T', 'C', 'T', 'G', 'G', 'T', 'A', 'T', 'T', 'A', 'T', 'C', 'A', 'G', 'C', 'T', 'G', 'T', 'T', 'G', 'A', 'T', 'C', 'T', 'G', 'T', 'A', 'A', 'C', 'C', 'G', 'T', 'T', 'A', 'A', 'T', 'T', 'G', 'C', 'C', 'A', 'A', 'A', 'G', 'T', 'C', 'T', 'A', 'C', 'C', 'A', 'C', 'A', 'A', 'T', 'A', 'A', 'A', 'G', 'C', 'A', 'C', 'A', 'G', 'A', 'T', 'G', 'G', 'G', 'C', 'T', 'A', 'A', 'G', 'A', 'C', 'C', 'A', 'T', 'C', 'T', 'T', 'T', 'C', 'C', 'T', 'G', 'T', 'A', 'A')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# [*] Checkpoint 100 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_60/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('A', 'A', 'A', 'T', 'C', 'C', 'A', 'T', 'G', 'A', 'A', 'G', 'G', 'C', 'C', 'A', 'T', 'T', 'T', 'G', 'C', 'T', 'G', 'G', 'G', 'A', 'T', 'G', 'T', 'G', 'G', 'C', 'T', 'C', 'T', 'C', 'A', 'G', 'T', 'T', 'A', 'A', 'A', 'G', 'A', 'C', 'T', 'G', 'T', 'T', 'T', 'A', 'C', 'A', 'G', 'A', 'C', 'C', 'A', 'G', 'C', 'T', 'G', 'G', 'G', 'G', 'C', 'T', 'T', 'T', 'T', 'G', 'T', 'C', 'C', 'T', 'G', 'G', 'G', 'G', 'A', 'G', 'G', 'A', 'G', 'C', 'C', 'T', 'G', 'T', 'A', 'T', 'C', 'T', 'A', 'T', 'A', 'A', 'G', 'C', 'T', 'C', 'C', 'A', 'C', 'C', 'C', 'G', 'C', 'T', 'G', 'A', 'G', 'T', 'C', 'C', 'A', 'T', 'C', 'A', 'A', 'G', 'T', 'T', 'A', 'G', 'G', 'T', 'A', 'G', 'A', 'A', 'G', 'C', 'T', 'G', 'G', 'G', 'C', 'G', 'G', 'G', 'G', 'A', 'C')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# Loading most recently saved...
# [*] Checkpoint 150 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_60/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('G', 'G', 'G', 'G', 'C', 'C', 'T', 'T', 'T', 'C', 'G', 'C', 'A', 'C', 'G', 'G', 'T', 'T', 'G', 'A', 'T', 'T', 'T', 'T', 'T', 'A', 'T', 'C', 'T', 'C', 'C', 'C', 'T', 'G', 'T', 'G', 'A', 'G', 'A', 'T', 'T', 'A', 'G', 'C', 'G', 'C', 'C', 'T', 'G', 'C', 'C', 'C', 'T', 'G', 'C', 'T', 'C', 'T', 'G', 'C', 'C', 'T', 'C', 'A', 'C', 'G', 'G', 'C', 'T', 'C', 'T', 'G', 'G', 'C', 'T', 'C', 'T', 'C', 'C', 'G', 'G', 'G', 'A', 'C', 'T', 'G', 'A', 'G', 'A', 'C', 'C', 'A', 'C', 'C', 'T', 'G', 'C', 'T', 'A', 'A', 'G', 'T', 'G', 'A', 'C', 'A', 'G', 'G', 'G', 'G', 'C', 'G', 'G', 'A', 'A', 'G', 'G', 'A', 'C', 'C', 'T', 'T', 'G', 'C', 'A', 'A', 'C', 'A', 'C', 'A', 'G', 'A', 'G', 'C', 'A', 'A', 'G', 'A', 'C', 'G', 'T', 'G', 'A', 'T', 'A')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# [*] Checkpoint 50 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_80/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('C', 'T', 'T', 'G', 'G', 'C', 'T', 'G', 'T', 'A', 'T', 'C', 'C', 'T', 'T', 'C', 'C', 'A', 'A', 'A', 'T', 'G', 'A', 'G', 'T', 'C', 'A', 'T', 'G', 'T', 'C', 'T', 'G', 'C', 'A', 'T', 'C', 'T', 'A', 'C', 'T', 'T', 'A', 'A', 'G', 'C', 'A', 'G', 'A', 'C', 'T', 'G', 'G', 'G', 'A', 'C', 'A', 'C', 'C', 'A', 'C', 'T', 'T', 'C', 'C', 'C', 'A', 'G', 'C', 'T', 'C', 'A', 'A', 'G', 'A', 'A', 'T', 'G', 'C', 'C', 'A', 'C', 'C', 'C', 'G', 'C', 'A', 'T', 'G', 'T', 'G', 'C', 'T', 'A', 'T', 'C', 'A', 'C', 'A', 'A', 'C', 'A', 'G', 'C', 'T', 'T', 'T', 'G', 'A', 'T', 'G', 'A', 'G', 'G', 'C', 'T', 'T', 'G', 'G', 'C', 'C', 'A', 'C', 'C', 'A', 'G', 'G', 'C', 'C', 'C', 'T', 'G', 'G', 'G', 'T', 'C', 'C', 'T', 'G', 'A', 'C', 'C', 'A', 'C', 'T')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# [*] Checkpoint 100 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_80/!
# Starting sampling...
# Finished sampling.
# loading dataset...
# ('A', 'C', 'C', 'T', 'G', 'T', 'G', 'C', 'G', 'A', 'G', 'C', 'T', 'T', 'T', 'T', 'T', 'A', 'T', 'T', 'G', 'T', 'A', 'T', 'C', 'T', 'T', 'A', 'T', 'T', 'A', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'G', 'T', 'C', 'T', 'T', 'A', 'A', 'C', 'T', 'G', 'T', 'T', 'A', 'T', 'T', 'A', 'T', 'T', 'C', 'A', 'T', 'C', 'A', 'T', 'G', 'T', 'C', 'A', 'A', 'T', 'C', 'T', 'C', 'T', 'A', 'T', 'A', 'T', 'C', 'C', 'T', 'G', 'G', 'G', 'A', 'A', 'T', 'C', 'T', 'G', 'A', 'T', 'A', 'G', 'A', 'A', 'T', 'G', 'C', 'C', 'T', 'A', 'G', 'A', 'A', 'T', 'T', 'A', 'T', 'T', 'G', 'T', 'G', 'T', 'A', 'G', 'A', 'A', 'T', 'A', 'A', 'A', 'T', 'G', 'A', 'C', 'A', 'A', 'T', 'G', 'A', 'C', 'C', 'T', 'A', 'T', 'T', 'T', 'A', 'T', 'A', 'C', 'T')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# Loading most recently saved...
# [*] Checkpoint 150 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_80/!
# Starting sampling...
# Finished sampling.

# %%
#Estimate duplication rates

def get_consensus_sequence(pwm) :
    consensus = ''
    
    for j in range(pwm.shape[0]) :
        nt_ix = np.argmax(pwm[j, :])
        
        if nt_ix == 0 :
            consensus += 'A'
        elif nt_ix == 1 :
            consensus += 'C'
        elif nt_ix == 2 :
            consensus += 'G'
        elif nt_ix == 3 :
            consensus += 'T'
    
    return consensus


run_name = "fbgan_mpradragonn_sample_quantile_cutoff_60"

f = plt.figure(figsize=(5, 4))

n_sequences_list = [10, 100, 1000, 10000, 100000]

ls = []

save_figs = False

dup_rates = []

model = WGAN_LangGP(run_name=run_name)
model.load_model(directory = './checkpoint/' + run_name + '/')

for n_sequences in n_sequences_list :
    n_sequences_ceil = int(n_sequences / model.batch_size) * model.batch_size + model.batch_size

    print("N Sequences = " + str(n_sequences))

    num_batches_sample = int(n_sequences_ceil / model.batch_size)

    print("Starting sampling...")

    seqs = model.sample(num_batches_sample, 1)

    print("Finished sampling.")

    #Sample first n_sequences
    consensus_seqs_kept = seqs[:n_sequences]

    n_unique_seqs_kept = len(np.unique(consensus_seqs_kept))

    print("Number of unique sequences = " + str(n_unique_seqs_kept))

    dup_rate = 1. - n_unique_seqs_kept / n_sequences
    dup_rates.append(dup_rate)

    print("Duplication rate = " + str(round(dup_rate, 4)))


l1 = plt.plot(np.arange(len(n_sequences_list)), dup_rates, linewidth=3, linestyle='-')
plt.scatter(np.arange(len(n_sequences_list)), dup_rates, s=45)

ls.append(l1[0])

plt.xlabel("# Sequences", fontsize=14)
plt.ylabel("Duplication Rate", fontsize=14)
plt.xticks(np.arange(len(n_sequences_list)), n_sequences_list, fontsize=14, rotation=45)
plt.yticks(fontsize=14)

plt.ylim(0, np.max(dup_rates) * 1.10 + 0.001)

plt.title("Duplication rate curve", fontsize=14)

plt.tight_layout()

if save_figs :
    plt.savefig(model_prefix + "_dup_rate_curve.eps")
    plt.savefig(model_prefix + "_dup_rate_curve.svg")
    plt.savefig(model_prefix + "_dup_rate_curve.png", transparent=True, dpi=150)

plt.show()

for i in range(len(n_sequences_list)) :
    print(str(n_sequences_list[i]) + ": " + str(dup_rates[i]))
# Out:
# loading dataset...
# ('G', 'G', 'A', 'C', 'C', 'A', 'C', 'A', 'T', 'G', 'G', 'A', 'G', 'G', 'A', 'G', 'C', 'T', 'G', 'C', 'T', 'C', 'T', 'G', 'C', 'A', 'G', 'C', 'G', 'C', 'T', 'G', 'A', 'A', 'G', 'C', 'C', 'A', 'C', 'G', 'T', 'T', 'A', 'G', 'C', 'G', 'C', 'T', 'C', 'C', 'A', 'C', 'A', 'C', 'C', 'C', 'A', 'G', 'T', 'C', 'C', 'T', 'C', 'C', 'G', 'A', 'G', 'A', 'C', 'A', 'G', 'C', 'A', 'G', 'G', 'G', 'A', 'G', 'C', 'C', 'C', 'G', 'T', 'C', 'T', 'G', 'G', 'G', 'C', 'C', 'A', 'G', 'A', 'C', 'T', 'C', 'T', 'T', 'C', 'T', 'G', 'A', 'G', 'G', 'A', 'T', 'G', 'C', 'T', 'T', 'G', 'T', 'G', 'A', 'G', 'G', 'A', 'T', 'G', 'A', 'C', 'A', 'G', 'T', 'C', 'G', 'C', 'T', 'T', 'G', 'C', 'A', 'G', 'C', 'T', 'G', 'G', 'C', 'T', 'C', 'A', 'A', 'A', 'C', 'A')
# loaded 2000 lines in dataset
# Generator_lang(
#   (fc1): Linear(in_features=128, out_features=74240, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1): Conv1d(512, 4, kernel_size=(1,), stride=(1,))
# )
# Discriminator_lang(
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (2): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (3): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (4): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace)
#         (1): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace)
#         (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#   )
#   (conv1d): Conv1d(4, 512, kernel_size=(1,), stride=(1,))
#   (linear): Linear(in_features=74240, out_features=1, bias=True)
# )
# [*] Checkpoint 10 found!
# Loading most recently saved...
# [*] Checkpoint 150 found at ./checkpoint/fbgan_mpradragonn_sample_quantile_cutoff_60/!
# N Sequences = 10
# Starting sampling...
# Finished sampling.
# Number of unique sequences = 10
# Duplication rate = 0.0
# N Sequences = 100
# Starting sampling...
# Finished sampling.
# Number of unique sequences = 100
# Duplication rate = 0.0
# N Sequences = 1000
# Starting sampling...
# Finished sampling.
# Number of unique sequences = 1000
# Duplication rate = 0.0
# N Sequences = 10000
# Starting sampling...
# Finished sampling.
# Number of unique sequences = 10000
# Duplication rate = 0.0
# N Sequences = 100000
# Starting sampling...
# Finished sampling.
# Number of unique sequences = 100000
# Duplication rate = 0.0
# 10: 0.0
# 100: 0.0
# 1000: 0.0
# 10000: 0.0
# 100000: 0.0
