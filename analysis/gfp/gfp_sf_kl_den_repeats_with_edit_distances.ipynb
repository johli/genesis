# %%
import sys

import itertools
from keras.layers import Input, Dense, Reshape, Flatten
from keras import layers, initializers
from keras.models import Model, load_model
import keras.backend as K
import tensorflow as tf
import numpy as np
from seqtools import SequenceTools as ST
from gfp_gp import SequenceGP
from util import AA, AA_IDX
from util import build_vae
from sklearn.model_selection import train_test_split, ShuffleSplit
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
from gan import WGAN
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
import scipy.stats
from scipy.stats import norm
from scipy.optimize import minimize
from keras.utils.generic_utils import get_custom_objects
from util import one_hot_encode_aa, partition_data, get_balaji_predictions, get_samples, get_argmax
from util import convert_idx_array_to_aas, build_pred_vae_model, get_experimental_X_y
from util import get_gfp_X_y_aa
from losses import neg_log_likelihood
import json

import isolearn.io as isoio
import isolearn.keras as isol

from genesis_generator_protein import *
from genesis_predictor_protein import *

from keras.callbacks import ModelCheckpoint, EarlyStopping
import keras
from keras.models import Sequential, Model, load_model
from keras import backend as K

from keras.layers import Dense, Dropout, Activation, Flatten, Input, Lambda
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, LSTM, CuDNNLSTM, ConvLSTM2D, GRU, CuDNNGRU, Bidirectional, BatchNormalization, LocallyConnected2D, Permute
from keras.layers import Concatenate, Reshape, Softmax, Conv2DTranspose, Embedding, Multiply

import warnings
warnings.filterwarnings("ignore")

def build_loss_model(predictor_model, loss_func, extra_loss_tensors=[]) :

    loss_out = Lambda(lambda out: loss_func(out), output_shape = (1,))(predictor_model.inputs + predictor_model.outputs + extra_loss_tensors)

    loss_model = Model(predictor_model.inputs, loss_out)

    return 'loss_model', loss_model

def build_model(M):
    x = Input(shape=(M, 20,))
    y = Flatten()(x)
    y = Dense(50, activation='elu')(y)
    y = Dense(2)(y)
    model = Model(inputs=x, outputs=y)
    return model

import editdistance

def compute_edit_distance(seqs, opt_len=None) :
    shuffle_index = np.arange(len(seqs))
    shuffle_index = shuffle_index[::-1]
    
    seqs_shuffled = [seqs[shuffle_index[i]] for i in range(len(seqs))]
    edit_distances = np.ravel([float(editdistance.eval(seq_1, seq_2)) for seq_1, seq_2 in zip(seqs, seqs_shuffled)])
    if opt_len is not None :
        edit_distances /= opt_len
    
    return edit_distances

from keras.backend.tensorflow_backend import set_session

def contain_tf_gpu_mem_usage() :
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
    set_session(sess)

contain_tf_gpu_mem_usage()
# Out:
# Using TensorFlow backend.

# %%
def get_z_sample_numpy(z_mean, z_log_var, n_samples=1) :
    
    n = z_mean.shape[0]
    m = z_mean.shape[2]
    
    epsilon = np.random.normal(loc=0., scale=1., size=(n, n_samples, m))
    
    return z_mean + np.exp(0.5 * z_log_var) * epsilon

#Evaluate VAE Likelihood (ELBO) on supplied data
def evaluate_elbo(vae_encoder_model, vae_decoder_model, sequence_one_hots, pwm_start=0, pwm_end=-1, n_samples=1, decoded_pwm_eps=1e-6) :
    _epsilon = 10**-6
    
    if pwm_end == -1 :
        pwm_end = sequence_one_hots.shape[2]
    
    #Get sequence VAE encodings
    z_mean, z_log_var = vae_encoder_model.predict(x=sequence_one_hots, batch_size=32, verbose=False)

    z_mean = np.tile(np.expand_dims(z_mean, axis=1), (1, n_samples, 1))
    z_log_var = np.tile(np.expand_dims(z_log_var, axis=1), (1, n_samples, 1))
    z = get_z_sample_numpy(z_mean, z_log_var, n_samples=n_samples)
    
    #Get re-decoded sequence PWMs
    decoded_pwms = np.zeros((sequence_one_hots.shape[0], n_samples) + sequence_one_hots.shape[1:])

    for sample_ix in range(n_samples) :
        decoded_pwms[:, sample_ix, :, :] = vae_decoder_model.predict(x=z[:, sample_ix, :], batch_size=32, verbose=False)

    decoded_pwms = np.clip(decoded_pwms, decoded_pwm_eps, 1. - decoded_pwm_eps)
    
    sequence_one_hots_expanded = np.tile(np.expand_dims(sequence_one_hots, axis=1), (1, n_samples, 1, 1))
    
    #Calculate reconstruction log prob
    log_p_x_given_z = np.sum(np.sum(sequence_one_hots_expanded[:, :, pwm_start:pwm_end, :] * np.log(np.clip(decoded_pwms[:, :, pwm_start:pwm_end, :], _epsilon, 1. - _epsilon)) / np.log(10.), axis=3), axis=2)

    #Calculate standard normal and importance log probs
    log_p_std_normal = np.sum(norm.logpdf(z, 0., 1.) / np.log(10.), axis=-1)
    log_p_importance = np.sum(norm.logpdf(z, z_mean, np.sqrt(np.exp(z_log_var))) / np.log(10.), axis=-1)

    #Calculate per-sample ELBO
    log_p_vae = log_p_x_given_z + log_p_std_normal - log_p_importance
    log_p_vae_div_n = log_p_vae - np.log(n_samples) / np.log(10.)

    #Calculate mean ELBO across samples (log-sum-exp trick)
    max_log_p_vae = np.max(log_p_vae_div_n, axis=-1)
    
    log_mean_p_vae = max_log_p_vae + np.log(np.sum(10**(log_p_vae_div_n - np.expand_dims(max_log_p_vae, axis=-1)), axis=-1)) / np.log(10.)
    mean_log_p_vae = np.mean(log_mean_p_vae)
    
    return log_mean_p_vae, mean_log_p_vae, log_p_vae

# %%
#Evaluate ELBO distribution on GFP dataset, decoder epislon = 1e-6

n_z_samples = 128

it = 0
TRAIN_SIZE = 5000
train_size_str = "%ik" % (TRAIN_SIZE/1000)
num_models = [1, 5, 20][it]
RANDOM_STATE = it + 1

X_train, y_train, gt_train  = get_experimental_X_y(random_state=RANDOM_STATE, train_size=TRAIN_SIZE)

L = X_train.shape[1]

vae_suffix = '_%s_%i' % (train_size_str, RANDOM_STATE)

vae_0 = build_vae(latent_dim=20, n_tokens=20, seq_length=L, enc1_units=50)

vae_0.encoder_.load_weights("models/vae_0_encoder_weights%s.h5" % vae_suffix)
vae_0.decoder_.load_weights("models/vae_0_decoder_weights%s.h5"% vae_suffix)
vae_0.vae_.load_weights("models/vae_0_vae_weights%s.h5"% vae_suffix)

#Compute multi-sample ELBO on test set
log_mean_p_vae_test, mean_log_p_vae_test, log_p_vae_test = evaluate_elbo(vae_0.encoder_, vae_0.decoder_, X_train, n_samples=n_z_samples)

#Log Likelihood Plot
plot_min_val = None
plot_max_val = None

f = plt.figure(figsize=(6, 4))

log_p_vae_test_hist, log_p_vae_test_edges = np.histogram(log_mean_p_vae_test, bins=50, density=True)
bin_width_test = log_p_vae_test_edges[1] - log_p_vae_test_edges[0]

mean_log_p_vae_test = np.mean(log_mean_p_vae_test)
mode_log_p_vae_test = log_p_vae_test_edges[np.argmax(log_p_vae_test_hist)] + bin_width_test / 2.

print("mean log(likelihood) = " + str(round(mean_log_p_vae_test, 4)))
print("mode log(likelihood) = " + str(round(mode_log_p_vae_test, 4)))


plt.bar(log_p_vae_test_edges[1:] - bin_width_test/2., log_p_vae_test_hist, width=bin_width_test, linewidth=2, edgecolor='black', color='orange')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

if plot_min_val is not None and plot_max_val is not None :
    plt.xlim(plot_min_val, plot_max_val)

plt.xlabel("VAE Log Likelihood", fontsize=14)
plt.ylabel("Data Density", fontsize=14)

plt.axvline(x=mean_log_p_vae_test, linewidth=2, color='red', linestyle="--")
plt.axvline(x=mode_log_p_vae_test, linewidth=2, color='purple', linestyle="--")

plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# mean log(likelihood) = -0.8908
# mode log(likelihood) = -0.1512

# %%
#GENESIS Generator Model definitions

def get_load_generator_network(seed_mode='new', rand_mode='uniform') :

    def _load_generator_network(batch_size, sequence_class, n_classes=1, n_out_channels=20, seq_length=237, supply_inputs=False, seed_mode=seed_mode, rand_mode=rand_mode) :

        sequence_class_onehots = np.eye(n_classes)

        #Generator network parameters
        latent_size = 100

        init_seq_length = 256 // 8
        unclipped_seq_length = 256

        #Generator inputs
        latent_input_1 = None
        latent_input_2 = None
        latent_input_1_out = None
        latent_input_2_out = None
        if seed_mode == 'new' :
            latent_input_1 = Input(tensor=K.ones((batch_size, latent_size)), name='noise_input_1')
            latent_input_2 = Input(tensor=K.ones((batch_size, latent_size)), name='noise_input_2')
            if rand_mode == 'uniform' :
                latent_input_1_out = Lambda(lambda inp: inp * K.random_uniform((batch_size, latent_size), minval=-1.0, maxval=1.0), name='lambda_rand_input_1')(latent_input_1)
                latent_input_2_out = Lambda(lambda inp: inp * K.random_uniform((batch_size, latent_size), minval=-1.0, maxval=1.0), name='lambda_rand_input_2')(latent_input_2)
            elif rand_mode == 'normal' :
                latent_input_1_out = Lambda(lambda inp: inp * K.random_normal((batch_size, latent_size)), name='lambda_rand_input_1')(latent_input_1)
                latent_input_2_out = Lambda(lambda inp: inp * K.random_normal((batch_size, latent_size)), name='lambda_rand_input_2')(latent_input_2)
        elif seed_mode == 'fixed' :
            if rand_mode == 'uniform' :
                latent_input_1 = Input(tensor=K.variable(K.random_uniform((batch_size, latent_size))), name='noise_input_1')
                latent_input_2 = Input(tensor=K.variable(K.random_uniform((batch_size, latent_size))), name='noise_input_2')
            elif rand_mode == 'normal' :
                latent_input_1 = Input(tensor=K.variable(K.random_normal((batch_size, latent_size))), name='noise_input_1')
                latent_input_2 = Input(tensor=K.variable(K.random_normal((batch_size, latent_size))), name='noise_input_2')

            latent_input_1_out = Lambda(lambda inp: inp, name='lambda_rand_input_1')(latent_input_1)
            latent_input_2_out = Lambda(lambda inp: inp, name='lambda_rand_input_2')(latent_input_2)

        class_embedding = Lambda(lambda x: K.gather(K.constant(sequence_class_onehots), K.cast(x[:, 0], dtype='int32')))(sequence_class)

        seed_input_1 = Concatenate(axis=-1)([latent_input_1_out, class_embedding])
        seed_input_2 = Concatenate(axis=-1)([latent_input_2_out, class_embedding])


        #Policy network definition
        policy_dense_1 = Dense(init_seq_length * 384, activation='relu', kernel_initializer='glorot_uniform', name='policy_dense_1')

        policy_dense_1_reshape = Reshape((init_seq_length, 1, 384))

        policy_deconv_0 = Conv2DTranspose(256, (8, 1), strides=(2, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_deconv_0')

        policy_deconv_1 = Conv2DTranspose(192, (8, 1), strides=(2, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_deconv_1')

        policy_deconv_2 = Conv2DTranspose(128, (8, 1), strides=(2, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_deconv_2')

        policy_recurrent_collapse = Lambda(lambda x: x[:, :, 0, :])

        policy_recurrent_4 = CuDNNLSTM(n_out_channels, return_sequences=True, name='policy_recurrent_4')

        policy_recurrent_expand = Lambda(lambda x: K.expand_dims(x, axis=2))

        batch_norm_0 = BatchNormalization(name='policy_batch_norm_0')
        relu_0 = Lambda(lambda x: K.relu(x))
        batch_norm_1 = BatchNormalization(name='policy_batch_norm_1')
        relu_1 = Lambda(lambda x: K.relu(x))
        batch_norm_2 = BatchNormalization(name='policy_batch_norm_2')
        relu_2 = Lambda(lambda x: K.relu(x))

        batch_norm_scale = BatchNormalization(name='policy_batch_norm_scale')
        policy_conv_scale = Conv2D(n_out_channels, (1, 1), strides=(1, 1), padding='same', activation='linear', kernel_initializer='glorot_normal', name='policy_conv_scale')

        policy_out_1 = Lambda(lambda x: x[:, :seq_length, ...])(Reshape((unclipped_seq_length, n_out_channels, 1))(policy_conv_scale(batch_norm_scale(policy_recurrent_expand(policy_recurrent_4(policy_recurrent_collapse(relu_2(batch_norm_2(policy_deconv_2(relu_1(batch_norm_1(policy_deconv_1(relu_0(batch_norm_0(policy_deconv_0(policy_dense_1_reshape(policy_dense_1(seed_input_1))), training=True))), training=True))), training=True))))), training=True))))
        policy_out_2 = Lambda(lambda x: x[:, :seq_length, ...])(Reshape((unclipped_seq_length, n_out_channels, 1))(policy_conv_scale(batch_norm_scale(policy_recurrent_expand(policy_recurrent_4(policy_recurrent_collapse(relu_2(batch_norm_2(policy_deconv_2(relu_1(batch_norm_1(policy_deconv_1(relu_0(batch_norm_0(policy_deconv_0(policy_dense_1_reshape(policy_dense_1(seed_input_2))), training=True))), training=True))), training=True))))), training=True))))

        return [latent_input_1, latent_input_2], [policy_out_1, policy_out_2], []
    
    return _load_generator_network

# %%
#GFP Oracle Model definition

def load_saved_predictor(model_path, seq_len, oracle_suffix, random_state, num_models) :

    saved_oracles = [build_model(seq_len) for i in range(num_models)]
    for i in range(num_models) :
        saved_oracles[i].load_weights(model_path + "oracle_%i%s.h5" % (random_state, oracle_suffix))
    
    def _initialize_predictor_weights(predictor_model, saved_oracles=saved_oracles) :
        #Load pre-trained weights
        for i in range(len(saved_oracles)) :
            
            dense_1_name = 'dense_1'
            dense_2_name = 'dense_2'
            
            curr_dense_found = 0
            for saved_layer in saved_oracles[i].layers :
                if 'dense_' in saved_layer.name :
                    if curr_dense_found == 0 :
                        dense_1_name = saved_layer.name
                        curr_dense_found += 1
                    elif curr_dense_found == 1 :
                        dense_2_name = saved_layer.name
                        curr_dense_found += 1
            
            predictor_model.get_layer('gfp_' + str(i) + '_' + str(num_models) + '_dense_1').set_weights(saved_oracles[i].get_layer(dense_1_name).get_weights())
            predictor_model.get_layer('gfp_' + str(i) + '_' + str(num_models) + '_dense_1').trainable = False
            
            predictor_model.get_layer('gfp_' + str(i) + '_' + str(num_models) + '_dense_2').set_weights(saved_oracles[i].get_layer(dense_2_name).get_weights())
            predictor_model.get_layer('gfp_' + str(i) + '_' + str(num_models) + '_dense_2').trainable = False

    def _load_predictor_func(sequence_input, sequence_class, random_state=random_state, num_models=num_models) :
        
        #Build single model
        def build_model(x, i, num_models) :
            y = Flatten()(x)
            y = Dense(50, activation='elu', name='gfp_' + str(i) + '_' + str(num_models) + '_dense_1')(y)
            y = Dense(2, name='gfp_' + str(i) + '_' + str(num_models) + '_dense_2')(y)
            y = Lambda(lambda yy: K.concatenate([K.expand_dims(K.expand_dims(yy[:, 0], axis=-1), axis=-1), K.expand_dims(K.expand_dims(K.log(1.+K.exp(yy[:, 1])) + K.epsilon(), axis=-1), axis=-1)], axis=1))(y)
            return y
        
        oracles = [build_model(sequence_input, i, num_models) for i in range(num_models)]
        
        oracles_mean = None
        oracles_var = None
        if len(oracles) > 1 :
            oracles_concat = Concatenate(axis=-1)(oracles)
            oracles_means = Lambda(lambda y: y[:, 0, :])(oracles_concat)
            oracles_vars = Lambda(lambda y: y[:, 1, :])(oracles_concat)
            oracles_mean = Lambda(lambda y: K.expand_dims(K.mean(y, axis=-1), axis=-1))(oracles_means)
            oracles_var = Lambda(lambda l: (1. / K.constant(num_models)) * (K.expand_dims(K.sum(l[1], axis=-1), axis=-1) + K.expand_dims(K.sum(l[0]**2, axis=-1), axis=-1)) - l[2]**2)([oracles_means, oracles_vars, oracles_mean])
        else :
            oracles_mean = Lambda(lambda y: K.expand_dims(y[:, 0, 0], axis=-1))(oracles[0])
            oracles_var = Lambda(lambda y: K.expand_dims(y[:, 1, 0], axis=-1))(oracles[0])

        predictor_inputs = []
        predictor_outputs = [oracles_mean, oracles_var]

        return predictor_inputs, predictor_outputs, _initialize_predictor_weights

    return _load_predictor_func

# %%
from keras.callbacks import Callback

class PredictorCallback(Callback):
    def __init__(self, generator_model, oracles, ground_truth, n_epochs=10, n_sequences=32, batch_size=32) :
        self.generator_model = generator_model
        self.oracles = oracles
        self.ground_truth = ground_truth
        self.batch_size = batch_size
        self.n_sequences = n_sequences
        
        self.traj = np.zeros((n_epochs + 1, 7))
        self.oracle_samples = np.zeros((n_epochs + 1, n_sequences))
        self.gt_samples = np.zeros((n_epochs + 1, n_sequences))
        self.edit_distance_samples = np.zeros((n_epochs + 1, n_sequences))
        
        self.oracle_max = -np.inf
        self.gt_of_oracle_max = -np.inf
        self.oracle_max_seq = ''
        
        self._predict_sequences(0)
    
    def _predict_sequences(self, epoch) :
        n_batches = self.n_sequences // self.batch_size
        
        gen_bundle = self.generator_model.predict(x=None, steps=n_batches)
        
        _, _, _, _, _, sampled_pwm, _, _, _ = gen_bundle
        
        onehots = sampled_pwm[:, 0, :, :, 0]
        onehots_aa = np.argmax(onehots, axis=-1)
        
        yt_sample, _ = get_balaji_predictions(self.oracles, onehots)
        yt_gt_sample = self.ground_truth.predict(onehots_aa, print_every=1000000)[:, 0]
        
        rand_idx = np.random.randint(0, len(yt_sample), self.n_sequences)
        self.oracle_samples[epoch, :] = yt_sample[rand_idx]
        self.gt_samples[epoch, :] = yt_gt_sample[rand_idx]
        
        self.edit_distance_samples[epoch, :] = compute_edit_distance(convert_idx_array_to_aas(onehots_aa))

        self.traj[epoch, 0] = np.max(yt_gt_sample)
        self.traj[epoch, 1] = np.mean(yt_gt_sample)
        self.traj[epoch, 2] = np.std(yt_gt_sample)
        self.traj[epoch, 3] = np.max(yt_sample)
        self.traj[epoch, 4] = np.mean(yt_sample)
        self.traj[epoch, 5] = np.std(yt_sample)
        if epoch > 0:
            self.traj[epoch, 6] = 0
        else:
            self.traj[epoch, 6] = 0
        
        yt_max = np.max(yt_sample)
        
        print(" - Oracle (80-th perc.) = " + str(round(np.percentile(yt_sample, 80), 4)))
        print(" - Ground-thruth (80-th perc.) = " + str(round(np.percentile(yt_gt_sample, 80), 4)))
        print(" - Ground-thruth (95-th perc.) = " + str(round(np.percentile(yt_gt_sample, 95), 4)))
        print(" - Ground-thruth (100-th perc.) = " + str(round(np.percentile(yt_gt_sample, 100), 4)))
        
        print(" - Edit distance (median) = " + str(round(np.median(self.edit_distance_samples[epoch, :]), 4)))
        
        if yt_max > self.oracle_max :
            yt_max_idx = np.argmax(yt_sample)
            self.oracle_max = yt_max
            self.gt_of_oracle_max = yt_gt_sample[yt_max_idx]
            self.oracle_max_seq = convert_idx_array_to_aas(np.expand_dims(onehots_aa[yt_max_idx], axis=0))[0]
    
    def on_epoch_end(self, epoch, logs={}) :
        
        self._predict_sequences(epoch + 1)

class EpochVariableCallback(Callback):
    def __init__(self, my_variable, my_func):
        self.my_variable = my_variable       
        self.my_func = my_func
    def on_epoch_end(self, epoch, logs={}):
        K.set_value(self.my_variable, self.my_func(K.get_value(self.my_variable), epoch))

class InputSeedCallback(Callback) :
    def __init__(self, model, n_sequences=128, n_sequences_per_epoch=32, latent_size=100, batch_size=64, rand_mode='uniform') :
        self.model = model
        self.seed_1 = self.model.get_layer("noise_input_1").input
        self.seed_2 = self.model.get_layer("noise_input_2").input
        
        self.n_sequences = n_sequences
        self.n_sequences_per_epoch = n_sequences_per_epoch
        self.n_batches = self.n_sequences // batch_size
        self.n_batches_per_epoch = self.n_sequences_per_epoch // batch_size
        self.batch_size = batch_size
        self.latent_size = latent_size
        self.rand_mode = rand_mode
        
        self.seed_1_data = [
            (np.random.normal(size=(self.batch_size, latent_size)) if self.rand_mode == 'normal' else np.random.uniform(size=(self.batch_size, latent_size)))
            for batch_i in range(self.n_batches)
        ]
        self.seed_2_data = [
            (np.random.normal(size=(self.batch_size, latent_size)) if self.rand_mode == 'normal' else np.random.uniform(size=(self.batch_size, latent_size)))
            for batch_i in range(self.n_batches)
        ]
        
    def on_epoch_end(self, epoch, logs={}) :
        for batch_i in range(self.n_batches_per_epoch) :
            self.seed_1_data.pop()
            self.seed_2_data.pop()
        
        for batch_i in range(self.n_batches_per_epoch) :
            if self.rand_mode == 'normal' :
                self.seed_1_data.insert(0, np.random.normal(size=(self.batch_size, self.latent_size)))
                self.seed_2_data.insert(0, np.random.normal(size=(self.batch_size, self.latent_size)))
            elif self.rand_mode == 'uniform' :
                self.seed_1_data.insert(0, np.random.uniform(size=(self.batch_size, self.latent_size)))
                self.seed_2_data.insert(0, np.random.uniform(size=(self.batch_size, self.latent_size)))
    
    def on_batch_end(self, batch, logs={}) :
        rand_ix_1 = np.random.randint(low=0, high=self.n_batches)
        rand_ix_2 = np.random.randint(low=0, high=self.n_batches)
        
        K.set_value(self.seed_1, self.seed_1_data[rand_ix_1])
        K.set_value(self.seed_2, self.seed_2_data[rand_ix_2])

# %%
#Keras function to calculate normal distribution log pdf
def normal_log_prob(x, loc=0., scale=1.) :
    return _normal_log_unnormalized_prob(x, loc, scale) - _normal_log_normalization(scale)

def _normal_log_unnormalized_prob(x, loc, scale):
    return -0.5 * K.square((x - loc) / scale)

def _normal_log_normalization(scale):
    return 0.5 * K.log(2. * K.constant(np.pi)) + K.log(scale)

#Keras function to sample latent vectors
def get_z_sample(z_inputs) :
    
    z_mean, z_log_var = z_inputs
    
    batch_size = K.shape(z_mean)[0]
    latent_dim = K.int_shape(z_mean)[1]
    
    epsilon = K.random_normal(shape=(batch_size, latent_dim))
    
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

#Keras function to sample (multiple) latent vectors
def get_z_samples(z_inputs, n_z_samples=1) :
    
    z_mean, z_log_var = z_inputs
    
    batch_size = K.shape(z_mean)[0]
    n_samples = K.shape(z_mean)[1]
    latent_dim = K.int_shape(z_mean)[3]
    
    epsilon = K.random_normal(shape=(batch_size, n_samples, n_z_samples, latent_dim))
    
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

#Code for constructing a (differentiable) VAE ELBO estimator in Keras
def build_den_vae(generator, vae_path, vae_suffix, build_vae_func, batch_size=1, seq_length=237, n_samples=1, n_z_samples=1, vae_latent_dim=100, vae_pwm_start=0, vae_pwm_end=-1, transform_adversary=False) :
    
    #Connect generated sequence samples from generator to vae
    generated_sequence_pwm = generator.outputs[3]
    generated_sequence_adv = generator.outputs[4]
    generated_sequence_samples = generator.outputs[5]
    generated_sequence_adv_samples = generator.outputs[6]
    
    if vae_pwm_end == -1 :
        vae_pwm_end = seq_length
    
    vae_0 = build_vae_func(latent_dim=20, n_tokens=20, seq_length=seq_length, enc1_units=50)

    vae_0.encoder_.load_weights(vae_path + "vae_0_encoder_weights%s.h5" % vae_suffix)
    vae_0.decoder_.load_weights(vae_path + "vae_0_decoder_weights%s.h5"% vae_suffix)
    vae_0.vae_.load_weights(vae_path + "vae_0_vae_weights%s.h5"% vae_suffix)
    
    #Freeze encoder model
    vae_0.encoder_.trainable = False
    vae_0.encoder_.compile(loss='mse', optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999))
    saved_vae_encoder_model = vae_0.encoder_
    
    #Load decoder model
    vae_0.decoder_.trainable = False
    vae_0.decoder_.compile(loss='mse', optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999))
    saved_vae_decoder_model = vae_0.decoder_
    
    #Construct vae elbo keras function (lambda layer)
    def _vae_elbo_func(pwm_and_sampled_pwm, batch_size=batch_size, n_samples=n_samples, n_z_samples=n_z_samples, transform_adversary=transform_adversary) :
        
        pwm_1, pwm_2, sampled_pwm_1, sampled_pwm_2 = pwm_and_sampled_pwm
        
        def _encode_and_sample(saved_vae_encoder_model, pwm, sampled_pwm, vae_pwm_start, vae_pwm_end, vae_latent_dim, n_z_samples) :
            vae_pwm = pwm[:, vae_pwm_start:vae_pwm_end, :, :]
            vae_sampled_pwm = sampled_pwm[:, :, vae_pwm_start:vae_pwm_end, :, :]
            
            vae_sampled_pwm_permuted = K.permute_dimensions(vae_sampled_pwm, (1, 0, 4, 2, 3))

            z_param_collection = tf.map_fn(lambda x_in: K.concatenate(saved_vae_encoder_model(x_in[:, 0, ...]), axis=-1)[..., :2*vae_latent_dim], vae_sampled_pwm_permuted, parallel_iterations=16)

            z_mean = K.permute_dimensions(z_param_collection[..., :vae_latent_dim], (1, 0, 2))
            z_log_var = K.permute_dimensions(z_param_collection[..., vae_latent_dim:2*vae_latent_dim], (1, 0, 2))

            z_mean = K.tile(K.expand_dims(z_mean, axis=2), (1, 1, n_z_samples, 1))
            z_log_var = K.tile(K.expand_dims(z_log_var, axis=2), (1, 1, n_z_samples, 1))

            z = get_z_samples([z_mean, z_log_var], n_z_samples=n_z_samples)
            
            return vae_pwm, vae_sampled_pwm, z_mean, z_log_var, z
        
        vae_pwm_1, vae_sampled_pwm_1, z_mean_1, z_log_var_1, z_1 = _encode_and_sample(saved_vae_encoder_model, pwm_1, sampled_pwm_1, vae_pwm_start, vae_pwm_end, vae_latent_dim, n_z_samples)
        
        if transform_adversary :
            vae_pwm_2, vae_sampled_pwm_2, z_mean_2, z_log_var_2, z_2 = _encode_and_sample(saved_vae_encoder_model, pwm_2, sampled_pwm_2, vae_pwm_start, vae_pwm_end, vae_latent_dim, n_z_samples)
            
        z_1_permuted = K.permute_dimensions(z_1, (1, 2, 0, 3))
        
        decoded_pwm_1 = tf.map_fn(lambda z_in: tf.map_fn(lambda z_in_in: saved_vae_decoder_model([z_in_in]), z_in, parallel_iterations=16), z_1_permuted, parallel_iterations=16)
        decoded_pwm_1 = K.expand_dims(decoded_pwm_1, axis=-3)
        decoded_pwm_1 = K.permute_dimensions(decoded_pwm_1, (2, 0, 1, 4, 5, 3))

        vae_pwm_tiled_1 = K.tile(K.expand_dims(vae_pwm_1, axis=1), (1, n_z_samples, 1, 1, 1))
        vae_sampled_pwm_tiled_1 = K.tile(K.expand_dims(vae_sampled_pwm_1, axis=2), (1, 1, n_z_samples, 1, 1, 1))

        if transform_adversary :
            return [vae_pwm_tiled_1, vae_sampled_pwm_tiled_1, z_mean_1, z_log_var_1, z_1, decoded_pwm_1, vae_pwm_2, vae_sampled_pwm_2, z_mean_2, z_log_var_2, z_2]
        else :
            return [vae_pwm_tiled_1, vae_sampled_pwm_tiled_1, z_mean_1, z_log_var_1, z_1, decoded_pwm_1]
    
    vae_elbo_layer = Lambda(_vae_elbo_func)
    
    #Call vae elbo estimator on generator sequences
    vae_elbo_outputs = vae_elbo_layer([generated_sequence_pwm, generated_sequence_adv, generated_sequence_samples, generated_sequence_adv_samples])
    
    return vae_elbo_outputs

# %%
from tensorflow.distributions import Normal as tf_normal
from tensorflow.contrib.distributions import percentile as tf_perc

def get_margin_entropy_ame(pwm_start=0, pwm_end=100, min_bits=1.0, n_channels=20) :
    
    def margin_entropy_ame(pwm) :
        pwm_section = pwm[:, pwm_start:pwm_end, :, :]
        entropy = pwm_section * -K.log(K.clip(pwm_section, K.epsilon(), 1. - K.epsilon())) / K.log(2.0)
        entropy = K.sum(entropy, axis=(2, 3))
        conservation = np.log2(n_channels) - entropy

        mean_conservation = K.mean(conservation, axis=-1)

        margin_conservation = K.switch(mean_conservation < K.constant(min_bits, shape=(1,)), K.constant(min_bits, shape=(1,)) - mean_conservation, K.zeros_like(mean_conservation))
    
        return margin_conservation
    
    return margin_entropy_ame

def get_pwm_margin_sample_entropy(pwm_start=0, pwm_end=100, margin=0.5, shift_1_nt=False) : 

    def pwm_margin_sample_entropy(pwm1, pwm2) :
        sampled_pwm_1 = pwm1[..., pwm_start:pwm_end, :, :]
        sampled_pwm_2 = pwm2[..., pwm_start:pwm_end, :, :]
        
        mean_sample_ent = K.mean(K.sum(sampled_pwm_1 * sampled_pwm_2, axis=(-2, -1)), axis=-1)
        mean_sample_ent_shift_l_1 = K.mean(K.sum(sampled_pwm_1[..., 1:, :, :] * sampled_pwm_2[..., :-1, :, :], axis=(-2, -1)), axis=-1)
        mean_sample_ent_shift_r_1 = K.mean(K.sum(sampled_pwm_1[..., :-1, :, :] * sampled_pwm_2[..., 1:, :, :], axis=(-2, -1)), axis=-1)
        
        margin_sample_ent = K.switch(mean_sample_ent > K.constant(margin, shape=(1,)), mean_sample_ent - margin, K.zeros_like(mean_sample_ent))
        margin_sample_ent_l_1 = K.switch(mean_sample_ent_shift_l_1 > K.constant(margin, shape=(1,)), mean_sample_ent_shift_l_1 - margin, K.zeros_like(mean_sample_ent))
        margin_sample_ent_r_1 = K.switch(mean_sample_ent_shift_r_1 > K.constant(margin, shape=(1,)), mean_sample_ent_shift_r_1 - margin, K.zeros_like(mean_sample_ent))
        
        if shift_1_nt :
            return margin_sample_ent + margin_sample_ent_l_1 + margin_sample_ent_r_1
        else :
            return margin_sample_ent

    return pwm_margin_sample_entropy

#Define target isoform loss function
def get_den_loss(target_val, fitness_weight=1.0, fitness_loss_mode='target', seq_length=237, pwm_start=0, pwm_end=237, n_samples=1, n_z_samples=1, batch_size=32, mini_batch_size=1, vae_loss_mode='bound', vae_divergence_weight=1., ref_vae_log_p=-10, vae_log_p_margin=1, decoded_pwm_eps=1e-6, pwm_target_bits=1.8, entropy_weight=0.0, similarity_weight=0.0, similarity_margin=0.5) :
    
    pwm_entropy_mse = get_margin_entropy_ame(pwm_start=pwm_start, pwm_end=pwm_end, min_bits=pwm_target_bits)
    sample_entropy_func = get_pwm_margin_sample_entropy(pwm_start=pwm_start, pwm_end=pwm_end, margin=similarity_margin, shift_1_nt=True)
    
    def loss_func(loss_tensors) :
        _, _, _, sequence_class, pwm_logits_1, pwm_logits_2, pwm_1, pwm_2, sampled_pwm_1, sampled_pwm_2, mask, sampled_mask, score_pred, var_pred, vae_pwm_1, vae_sampled_pwm_1, z_mean_1, z_log_var_1, z_1, decoded_pwm_1 = loss_tensors
        
        #Specify costs
        
        fitness_loss= 0.
        if fitness_loss_mode == 'bound' :
            fitness_loss = fitness_weight * K.mean(K.maximum(-score_pred[..., 0] + target_val, K.zeros_like(score_pred[..., 0])), axis=1)
        elif fitness_loss_mode == 'target' :
            fitness_loss = fitness_weight * K.mean(K.abs(score_pred[..., 0] - target_val), axis=1)
        elif fitness_loss_mode == 'mini_batch_bound' :
            mini_batch_fitness_score = K.permute_dimensions(K.reshape(score_pred[..., 0], (int(batch_size / mini_batch_size), mini_batch_size, n_samples)), (0, 2, 1))
            mini_batch_mean_fitness_score = K.mean(mini_batch_fitness_score, axis=-1)
            tiled_mini_batch_mean_fitness_score = K.tile(mini_batch_mean_fitness_score, (mini_batch_size, 1))
            
            fitness_loss = fitness_weight * K.mean(K.maximum(-tiled_mini_batch_mean_fitness_score + target_val, K.zeros_like(tiled_mini_batch_mean_fitness_score)), axis=1)
        elif fitness_loss_mode == 'log_sf' :
            fitness_distr_w_var_grad = tf_normal(loc=score_pred[..., 0], scale=K.sqrt(var_pred[..., 0]))
            fitness_log_sf_w_var_grad = fitness_distr_w_var_grad.log_survival_function(K.constant(target_val))

            fitness_distr = tf_normal(loc=score_pred[..., 0], scale=K.stop_gradient(K.sqrt(var_pred[..., 0])))
            fitness_log_sf = fitness_distr.log_survival_function(K.constant(target_val))

            fitness_log_sf_actual = K.switch(score_pred[..., 0] < 0.7 * K.constant(target_val), fitness_log_sf, fitness_log_sf_w_var_grad)

            fitness_loss = fitness_weight * K.mean(-fitness_log_sf_actual, axis=1)
        
        entropy_loss = entropy_weight * pwm_entropy_mse(pwm_1)
        
        similarity_loss = similarity_weight * K.mean(sample_entropy_func(sampled_pwm_1, sampled_pwm_2), axis=1)
        
        #Construct VAE sequence inputs
        decoded_pwm_1 = K.clip(decoded_pwm_1, decoded_pwm_eps, 1. - decoded_pwm_eps)
        
        log_p_x_given_z_1 = K.sum(K.sum(vae_sampled_pwm_1[:, :, :, pwm_start:pwm_end, ...] * K.log(K.stop_gradient(decoded_pwm_1[:, :, :, pwm_start:pwm_end, ...])) / K.log(K.constant(10.)), axis=(-1, -2)), axis=-1)
        
        log_p_std_normal_1 = K.sum(normal_log_prob(z_1, 0., 1.) / K.log(K.constant(10.)), axis=-1)
        log_p_importance_1 = K.sum(normal_log_prob(z_1, z_mean_1, K.sqrt(K.exp(z_log_var_1))) / K.log(K.constant(10.)), axis=-1)
        
        log_p_vae_1 = log_p_x_given_z_1 + log_p_std_normal_1 - log_p_importance_1
        log_p_vae_div_n_1 = log_p_vae_1 - K.log(K.constant(n_z_samples, dtype='float32')) / K.log(K.constant(10.))

        #Calculate mean ELBO across samples (log-sum-exp trick)
        max_log_p_vae_1 = K.max(log_p_vae_div_n_1, axis=-1)

        log_mean_p_vae_1 = max_log_p_vae_1 + K.log(K.sum(10**(log_p_vae_div_n_1 - K.expand_dims(max_log_p_vae_1, axis=-1)), axis=-1)) / K.log(K.constant(10.))
        
        #Specify VAE divergence loss function
        vae_divergence_loss = 0.
        
        if vae_loss_mode == 'bound' :
            vae_divergence_loss = vae_divergence_weight * K.mean(K.switch(log_mean_p_vae_1 < ref_vae_log_p - vae_log_p_margin, -log_mean_p_vae_1 + (ref_vae_log_p - vae_log_p_margin), K.zeros_like(log_mean_p_vae_1)), axis=1)
        
        elif vae_loss_mode == 'penalty' :
            vae_divergence_loss = vae_divergence_weight * K.mean(-log_mean_p_vae_1, axis=1)
        
        elif vae_loss_mode == 'target' :
            vae_divergence_loss = vae_divergence_weight * K.mean((log_mean_p_vae_1 - (ref_vae_log_p - vae_log_p_margin))**2, axis=1)
        
        elif 'mini_batch_' in vae_loss_mode :
            mini_batch_log_mean_p_vae_1 = K.permute_dimensions(K.reshape(log_mean_p_vae_1, (int(batch_size / mini_batch_size), mini_batch_size, n_samples)), (0, 2, 1))
            mini_batch_mean_log_p_vae_1 = K.mean(mini_batch_log_mean_p_vae_1, axis=-1)
            tiled_mini_batch_mean_log_p_vae_1 = K.tile(mini_batch_mean_log_p_vae_1, (mini_batch_size, 1))
            
            if vae_loss_mode == 'mini_batch_bound' :
                vae_divergence_loss = vae_divergence_weight * K.mean(K.switch(tiled_mini_batch_mean_log_p_vae_1 < ref_vae_log_p - vae_log_p_margin, -tiled_mini_batch_mean_log_p_vae_1 + (ref_vae_log_p - vae_log_p_margin), K.zeros_like(tiled_mini_batch_mean_log_p_vae_1)), axis=1)
            elif vae_loss_mode == 'mini_batch_target' :
                vae_divergence_loss = vae_divergence_weight * K.mean((tiled_mini_batch_mean_log_p_vae_1 - (ref_vae_log_p - vae_log_p_margin))**2, axis=1)
        
        #Compute total loss
        total_loss = fitness_loss + entropy_loss + similarity_loss + vae_divergence_loss

        return total_loss
    
    return loss_func

#Function for running GENESIS
def run_genesis(loss_func, model_path, oracle_suffix, random_state, num_models, oracles, ground_truth, seq_len=237, batch_size=32, n_samples=1, n_z_samples=1, vae_params=None, n_epochs=10, n_sequences_init=128, n_sequences_per_epoch=32, seed_mode='new', rand_mode='uniform', steps_per_epoch=100, n_valid_samples=512, track_metrics=True) :
    
    #Build Generator Network
    _, generator = build_generator(batch_size, seq_len, get_load_generator_network(seed_mode=seed_mode, rand_mode=rand_mode), n_classes=1, n_samples=n_samples, sequence_templates=None, batch_normalize_pwm=False)

    #Build Predictor Network and hook it on the generator PWM output tensor
    _, predictor = build_predictor(generator, load_saved_predictor(model_path, seq_len, oracle_suffix, random_state, num_models), batch_size, n_samples=n_samples, eval_mode='sample')

    #Build VAE model
    vae_tensors = []
    if vae_params is not None :
        vae_path, vae_suffix, build_vae_func, vae_latent_dim, vae_pwm_start, vae_pwm_end = vae_params
        vae_tensors = build_den_vae(generator, vae_path, vae_suffix, build_vae_func, batch_size=batch_size, seq_length=seq_len, n_samples=n_samples, n_z_samples=n_z_samples, vae_latent_dim=vae_latent_dim, vae_pwm_start=vae_pwm_start, vae_pwm_end=vae_pwm_end)
    
    #Build Loss Model (In: Generator seed, Out: Loss function)
    _, loss_model = build_loss_model(predictor, loss_func, extra_loss_tensors=vae_tensors)
    
    #Specify Optimizer to use
    opt = keras.optimizers.Adam(lr=0.0001, beta_1=0.5, beta_2=0.9)
    
    #Compile Loss Model (Minimize self)
    loss_model.compile(loss=lambda true, pred: pred, optimizer=opt)

    #Build callback for evaluating intermediate sequences
    random_genesis_monitor = PredictorCallback(generator, oracles, ground_truth, n_epochs=n_epochs, n_sequences=n_valid_samples, batch_size=batch_size)

    seed_callback = None
    if seed_mode == 'fixed' :
        seed_callback = InputSeedCallback(loss_model, n_sequences=n_sequences_init, n_sequences_per_epoch=n_sequences_per_epoch, rand_mode=rand_mode, latent_size=100, batch_size=batch_size)
    
    #Fit Loss Model
    train_history = loss_model.fit(
        [], np.ones((1, 1)),
        epochs=n_epochs,
        steps_per_epoch=steps_per_epoch,
        callbacks= ([random_genesis_monitor] if track_metrics else []) + ([seed_callback] if seed_callback is not None else [])
    )
    
    train_history = None
    
    traj = random_genesis_monitor.traj
    oracle_samples = random_genesis_monitor.oracle_samples
    gt_samples = random_genesis_monitor.gt_samples
    edit_distance_samples = random_genesis_monitor.edit_distance_samples

    oracle_max = random_genesis_monitor.oracle_max
    gt_of_oracle_max = random_genesis_monitor.gt_of_oracle_max
    oracle_max_seq = random_genesis_monitor.oracle_max_seq
    
    max_dict = {'oracle_max' : oracle_max, 
                'oracle_max_seq': oracle_max_seq, 
                'gt_of_oracle_max': gt_of_oracle_max}
    
    return generator, traj, oracle_samples, gt_samples, edit_distance_samples, max_dict

# %%
def run_experimental_den_opt(it, repeat_start=0, repeats=3, fitness_loss_mode='target', target_val=3.2, similarity_margin=0.985, vae_log_p_margin=7.0, decoded_pwm_eps=0.05, fitness_weight=0.5, vae_divergence_coeff=2.0) :
    
    assert it in [0, 1, 2]
    
    TRAIN_SIZE = 5000
    train_size_str = "%ik" % (TRAIN_SIZE/1000)
    num_models = [1, 5, 20][it]
    RANDOM_STATE = it + 1
    
    X_train, y_train, gt_train  = get_experimental_X_y(random_state=RANDOM_STATE, train_size=TRAIN_SIZE)
    
    L = X_train.shape[1]
    
    vae_suffix = '_%s_%i' % (train_size_str, RANDOM_STATE)
    oracle_suffix = '_%s_%i_%i' % (train_size_str, num_models, RANDOM_STATE)
    
    #Number of PWMs to generate per objective
    batch_size = 50
    mini_batch_size = 10
    #Number of One-hot sequences to sample from the PWM at each grad step
    n_samples = 1
    #Number of VAE latent vector samples  at each grad step
    n_z_samples = 50
    #Number of epochs per objective to optimize
    n_epochs = 50
    #Number of steps (grad updates) per epoch
    steps_per_epoch = 100
    #Number of sequences to evaluate at each epoch for metrics
    n_valid_samples = 100

    #New or fixed set of seeds
    seed_mode = 'new'
    #Uniform or Normally distributed seeds
    rand_mode = 'uniform'

    #Number of initial seeds to start with
    n_sequences = 5000
    #Number of seeds to sample per epoch
    n_sequences_per_epoch = 500

    if seed_mode == 'fixed' :
        steps_per_epoch = (n_sequences // batch_size) * 2
    
    for k in range(repeat_start, repeats):
        test_name = "kl_den_" + str(fitness_loss_mode) + "_fitness_" + str(target_val).replace(".", "") + "_sim_" + str(similarity_margin).replace(".", "") + "_p_margin_" + str(int(vae_log_p_margin)) + "_decoder_eps_" + str(decoded_pwm_eps).replace(".", "") + "_fitness_weight_" + str(fitness_weight).replace(".", "")
        suffix = "_%s_%i_%i_w_edit_distances" % (train_size_str, RANDOM_STATE, k)
        
        K.clear_session()
        
        vae_0 = build_vae(latent_dim=20,
                      n_tokens=20, 
                      seq_length=X_train.shape[1],
                      enc1_units=50)

        vae_0.encoder_.load_weights("models/vae_0_encoder_weights%s.h5" % vae_suffix)
        vae_0.decoder_.load_weights("models/vae_0_decoder_weights%s.h5"% vae_suffix)
        vae_0.vae_.load_weights("models/vae_0_vae_weights%s.h5"% vae_suffix)

        vae_latent_dim = 20
        vae_pwm_start = 0
        vae_pwm_end = L

        #VAE parameter collection
        vae_params = [
            "models/",
            vae_suffix,
            build_vae,
            vae_latent_dim,
            vae_pwm_start,
            vae_pwm_end
        ]

        ground_truth = SequenceGP(load=True, load_prefix="data/gfp_gp")

        #oracles = [load_model("models/oracle_%i%s.h5" % (i, oracle_suffix)) for i in range(num_models)]
        oracles = [build_model(L) for i in range(num_models)]
        for i in range(num_models) :
            oracles[i].load_weights("models/oracle_%i%s.h5" % (i, oracle_suffix))

        loss = get_den_loss(
            target_val=target_val,
            fitness_weight=fitness_weight,
            fitness_loss_mode=fitness_loss_mode,
            pwm_start=0,
            pwm_end=L,
            pwm_target_bits=1.5,
            entropy_weight=0.0,
            similarity_weight=2.5,
            similarity_margin=similarity_margin,
            n_samples=n_samples,
            n_z_samples=n_z_samples,
            batch_size=batch_size,
            mini_batch_size=mini_batch_size,
            vae_loss_mode='mini_batch_bound',
            vae_divergence_weight=vae_divergence_coeff / L,
            ref_vae_log_p=-0.15,
            vae_log_p_margin=vae_log_p_margin,
            decoded_pwm_eps=decoded_pwm_eps
        )

        _, test_traj, test_oracle_samples, test_gt_samples, test_edit_distance_samples, test_max = run_genesis(
            loss,
            "models/",
            oracle_suffix,
            i,
            num_models,
            oracles,
            ground_truth,
            seq_len=L,
            batch_size=batch_size,
            n_samples=n_samples,
            n_z_samples=n_z_samples,
            vae_params=vae_params,
            n_epochs=n_epochs,
            n_sequences_init=n_sequences,
            n_sequences_per_epoch=n_sequences_per_epoch,
            seed_mode=seed_mode,
            rand_mode=rand_mode,
            steps_per_epoch=steps_per_epoch,
            n_valid_samples=n_valid_samples,
            track_metrics=True
        )
        
        np.save('results/%s_traj%s.npy' %(test_name, suffix), test_traj)
        np.save('results/%s_oracle_samples%s.npy' % (test_name, suffix), test_oracle_samples)
        np.save('results/%s_gt_samples%s.npy'%(test_name, suffix), test_gt_samples )
        np.save('results/%s_edit_distance_samples%s.npy'%(test_name, suffix), test_edit_distance_samples )

        with open('results/%s_max%s.json'% (test_name, suffix), 'w') as outfile:
            json.dump(test_max, outfile)

# %%
run_experimental_den_opt(0, repeat_start=0, repeats=3, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.985, vae_log_p_margin=1.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
run_experimental_den_opt(1, repeat_start=0, repeats=3, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.985, vae_log_p_margin=1.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
run_experimental_den_opt(2, repeat_start=0, repeats=3, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.985, vae_log_p_margin=1.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
# Out:
#  - Oracle (80-th perc.) = -0.9571
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 205.0
# Epoch 1/50
# 100/100 [==============================] - 9s 92ms/step - loss: 8.5466
#  - Oracle (80-th perc.) = 3.4673
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 86.0
# Epoch 2/50
# 100/100 [==============================] - 6s 62ms/step - loss: 2.8798
#  - Oracle (80-th perc.) = 3.2586
#  - Ground-thruth (80-th perc.) = 2.8958
#  - Ground-thruth (95-th perc.) = 2.8963
#  - Ground-thruth (100-th perc.) = 2.8971
#  - Edit distance (median) = 12.0
# Epoch 3/50
# 100/100 [==============================] - 6s 59ms/step - loss: 0.4293
#  - Oracle (80-th perc.) = 3.2336
#  - Ground-thruth (80-th perc.) = 3.059
#  - Ground-thruth (95-th perc.) = 3.0789
#  - Ground-thruth (100-th perc.) = 3.0972
#  - Edit distance (median) = 4.5
# Epoch 4/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1676
#  - Oracle (80-th perc.) = 3.1912
#  - Ground-thruth (80-th perc.) = 3.2741
#  - Ground-thruth (95-th perc.) = 3.3114
#  - Ground-thruth (100-th perc.) = 3.3455
#  - Edit distance (median) = 2.0
# Epoch 5/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1117
#  - Oracle (80-th perc.) = 3.1927
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 1.0
# Epoch 6/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1049
#  - Oracle (80-th perc.) = 3.1888
#  - Ground-thruth (80-th perc.) = 3.3378
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 2.0
# Epoch 7/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0991
#  - Oracle (80-th perc.) = 3.2515
#  - Ground-thruth (80-th perc.) = 3.3392
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 2.0
# Epoch 8/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0966
#  - Oracle (80-th perc.) = 3.1868
#  - Ground-thruth (80-th perc.) = 3.3378
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 1.0
# Epoch 9/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0930
#  - Oracle (80-th perc.) = 3.1902
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3607
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 1.0
# Epoch 10/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0897
#  - Oracle (80-th perc.) = 3.2054
#  - Ground-thruth (80-th perc.) = 3.3004
#  - Ground-thruth (95-th perc.) = 3.315
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 2.0
# Epoch 11/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0888
#  - Oracle (80-th perc.) = 3.1969
#  - Ground-thruth (80-th perc.) = 3.3455
#  - Ground-thruth (95-th perc.) = 3.3508
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 1.0
# Epoch 12/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0869
#  - Oracle (80-th perc.) = 3.2051
#  - Ground-thruth (80-th perc.) = 3.3116
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3286
#  - Edit distance (median) = 2.0
# Epoch 13/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0866
#  - Oracle (80-th perc.) = 3.1969
#  - Ground-thruth (80-th perc.) = 3.3455
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 2.0
# Epoch 14/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0856
#  - Oracle (80-th perc.) = 3.1889
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3607
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 1.0
# Epoch 15/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0847
#  - Oracle (80-th perc.) = 3.2016
#  - Ground-thruth (80-th perc.) = 3.3467
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 2.0
# Epoch 16/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0841
#  - Oracle (80-th perc.) = 3.1889
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 1.0
# Epoch 17/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0837
#  - Oracle (80-th perc.) = 3.1927
#  - Ground-thruth (80-th perc.) = 3.3184
#  - Ground-thruth (95-th perc.) = 3.3387
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 3.0
# Epoch 18/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0843
#  - Oracle (80-th perc.) = 3.2677
#  - Ground-thruth (80-th perc.) = 3.3366
#  - Ground-thruth (95-th perc.) = 3.3476
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 3.0
# Epoch 19/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0831
#  - Oracle (80-th perc.) = 3.2118
#  - Ground-thruth (80-th perc.) = 3.3607
#  - Ground-thruth (95-th perc.) = 3.3647
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 2.0
# Epoch 20/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0828
#  - Oracle (80-th perc.) = 3.2266
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3647
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 2.0
# Epoch 21/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0829
#  - Oracle (80-th perc.) = 3.218
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 3.0
# Epoch 22/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0821
#  - Oracle (80-th perc.) = 3.2611
#  - Ground-thruth (80-th perc.) = 3.3311
#  - Ground-thruth (95-th perc.) = 3.3647
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 4.0
# Epoch 23/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0826
#  - Oracle (80-th perc.) = 3.2122
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3607
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 2.0
# Epoch 24/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0820
#  - Oracle (80-th perc.) = 3.2204
#  - Ground-thruth (80-th perc.) = 3.3905
#  - Ground-thruth (95-th perc.) = 3.428
#  - Ground-thruth (100-th perc.) = 3.4296
#  - Edit distance (median) = 2.0
# Epoch 25/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0826
#  - Oracle (80-th perc.) = 3.2263
#  - Ground-thruth (80-th perc.) = 3.3455
#  - Ground-thruth (95-th perc.) = 3.391
#  - Ground-thruth (100-th perc.) = 3.4055
#  - Edit distance (median) = 2.0
# Epoch 26/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0815
#  - Oracle (80-th perc.) = 3.2509
#  - Ground-thruth (80-th perc.) = 3.3675
#  - Ground-thruth (95-th perc.) = 3.425
#  - Ground-thruth (100-th perc.) = 3.4296
#  - Edit distance (median) = 3.0
# Epoch 27/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0819
#  - Oracle (80-th perc.) = 3.2097
#  - Ground-thruth (80-th perc.) = 3.3378
#  - Ground-thruth (95-th perc.) = 3.3554
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 2.0
# Epoch 28/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0815
#  - Oracle (80-th perc.) = 3.2159
#  - Ground-thruth (80-th perc.) = 3.3455
#  - Ground-thruth (95-th perc.) = 3.3607
#  - Ground-thruth (100-th perc.) = 3.3699
#  - Edit distance (median) = 3.0
# Epoch 29/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0812
#  - Oracle (80-th perc.) = 3.1889
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3607
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 1.0
# Epoch 30/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0807
#  - Oracle (80-th perc.) = 3.2092
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3607
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 2.0
# Epoch 31/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0813
#  - Oracle (80-th perc.) = 3.1939
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3554
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 1.5
# Epoch 32/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0792
#  - Oracle (80-th perc.) = 3.2106
#  - Ground-thruth (80-th perc.) = 3.3385
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 2.0
# Epoch 33/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0794
#  - Oracle (80-th perc.) = 3.2208
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.425
#  - Ground-thruth (100-th perc.) = 3.4296
#  - Edit distance (median) = 3.0
# Epoch 34/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0795
#  - Oracle (80-th perc.) = 3.2194
#  - Ground-thruth (80-th perc.) = 3.3411
#  - Ground-thruth (95-th perc.) = 3.3613
#  - Ground-thruth (100-th perc.) = 3.425
#  - Edit distance (median) = 3.0
# Epoch 35/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0796
#  - Oracle (80-th perc.) = 3.1991
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 1.0
# Epoch 36/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0786
#  - Oracle (80-th perc.) = 3.1952
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.4296
#  - Edit distance (median) = 2.0
# Epoch 37/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0786
#  - Oracle (80-th perc.) = 3.1889
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3607
#  - Ground-thruth (100-th perc.) = 3.428
#  - Edit distance (median) = 1.0
# Epoch 38/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0789
#  - Oracle (80-th perc.) = 3.2194
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.425
#  - Edit distance (median) = 2.0
# Epoch 39/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0787
#  - Oracle (80-th perc.) = 3.1889
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.425
#  - Edit distance (median) = 1.0
# Epoch 40/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0793
#  - Oracle (80-th perc.) = 3.1903
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 2.0
# Epoch 41/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0787
#  - Oracle (80-th perc.) = 3.1889
#  - Ground-thruth (80-th perc.) = 3.3455
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 2.0
# Epoch 42/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0788
#  - Oracle (80-th perc.) = 3.2194
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 2.0
# Epoch 43/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0792
#  - Oracle (80-th perc.) = 3.1889
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3607
#  - Edit distance (median) = 1.0
# Epoch 44/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0784
#  - Oracle (80-th perc.) = 3.2178
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3755
#  - Edit distance (median) = 1.5
# Epoch 45/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0784
#  - Oracle (80-th perc.) = 3.2292
#  - Ground-thruth (80-th perc.) = 3.3455
#  - Ground-thruth (95-th perc.) = 3.3904
#  - Ground-thruth (100-th perc.) = 3.4078
#  - Edit distance (median) = 3.0
# Epoch 46/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0789
#  - Oracle (80-th perc.) = 3.1969
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3964
#  - Ground-thruth (100-th perc.) = 3.428
#  - Edit distance (median) = 2.0
# Epoch 47/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0789
#  - Oracle (80-th perc.) = 3.2108
#  - Ground-thruth (80-th perc.) = 3.3455
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.428
#  - Edit distance (median) = 2.0
# Epoch 48/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0776
#  - Oracle (80-th perc.) = 3.2109
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 2.0
# Epoch 49/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0790
#  - Oracle (80-th perc.) = 3.2091
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.4046
#  - Ground-thruth (100-th perc.) = 3.4296
#  - Edit distance (median) = 2.0
# Epoch 50/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0780
#  - Oracle (80-th perc.) = 3.2196
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.365
#  - Ground-thruth (100-th perc.) = 3.425
#  - Edit distance (median) = 2.0
#  - Oracle (80-th perc.) = -0.6325
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 203.0
# Epoch 1/50
# 100/100 [==============================] - 9s 92ms/step - loss: 7.9775
#  - Oracle (80-th perc.) = 3.4027
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 81.0
# Epoch 2/50
# 100/100 [==============================] - 6s 62ms/step - loss: 2.3464
#  - Oracle (80-th perc.) = 3.2084
#  - Ground-thruth (80-th perc.) = 2.9012
#  - Ground-thruth (95-th perc.) = 2.9027
#  - Ground-thruth (100-th perc.) = 2.904
#  - Edit distance (median) = 5.0
# Epoch 3/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2316
#  - Oracle (80-th perc.) = 3.1816
#  - Ground-thruth (80-th perc.) = 3.2908
#  - Ground-thruth (95-th perc.) = 3.2908
#  - Ground-thruth (100-th perc.) = 3.3019
#  - Edit distance (median) = 1.0
# Epoch 4/50
# 100/100 [==============================] - 7s 73ms/step - loss: 0.0846
#  - Oracle (80-th perc.) = 3.1884
#  - Ground-thruth (80-th perc.) = 3.3517
#  - Ground-thruth (95-th perc.) = 3.3517
#  - Ground-thruth (100-th perc.) = 3.3517
#  - Edit distance (median) = 1.0
# Epoch 5/50
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0734
#  - Oracle (80-th perc.) = 3.157
#  - Ground-thruth (80-th perc.) = 3.2555
#  - Ground-thruth (95-th perc.) = 3.2567
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 1.0
# Epoch 6/50
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0752
#  - Oracle (80-th perc.) = 3.2741
#  - Ground-thruth (80-th perc.) = 3.247
#  - Ground-thruth (95-th perc.) = 3.247
#  - Ground-thruth (100-th perc.) = 3.3051
#  - Edit distance (median) = 2.0
# Epoch 7/50
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0752
#  - Oracle (80-th perc.) = 3.1662
#  - Ground-thruth (80-th perc.) = 3.2919
#  - Ground-thruth (95-th perc.) = 3.3101
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 1.0
# Epoch 8/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0748
#  - Oracle (80-th perc.) = 3.245
#  - Ground-thruth (80-th perc.) = 3.3319
#  - Ground-thruth (95-th perc.) = 3.3425
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 2.0
# Epoch 9/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0738
#  - Oracle (80-th perc.) = 3.2657
#  - Ground-thruth (80-th perc.) = 3.2835
#  - Ground-thruth (95-th perc.) = 3.3052
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 2.0
# Epoch 10/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0753
#  - Oracle (80-th perc.) = 3.2036
#  - Ground-thruth (80-th perc.) = 3.3318
#  - Ground-thruth (95-th perc.) = 3.3329
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 2.0
# Epoch 11/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0741
#  - Oracle (80-th perc.) = 3.2144
#  - Ground-thruth (80-th perc.) = 3.2555
#  - Ground-thruth (95-th perc.) = 3.287
#  - Ground-thruth (100-th perc.) = 3.2983
#  - Edit distance (median) = 2.0
# Epoch 12/50
# 100/100 [==============================] - 8s 75ms/step - loss: 0.0723
#  - Oracle (80-th perc.) = 3.1779
#  - Ground-thruth (80-th perc.) = 3.2803
#  - Ground-thruth (95-th perc.) = 3.2919
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 2.0
# Epoch 13/50
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0726
#  - Oracle (80-th perc.) = 3.2066
#  - Ground-thruth (80-th perc.) = 3.3318
#  - Ground-thruth (95-th perc.) = 3.3318
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 2.0
# Epoch 14/50
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0739
#  - Oracle (80-th perc.) = 3.169
#  - Ground-thruth (80-th perc.) = 3.2875
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 1.0
# Epoch 15/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.0733
#  - Oracle (80-th perc.) = 3.3134
#  - Ground-thruth (80-th perc.) = 3.2347
#  - Ground-thruth (95-th perc.) = 3.2866
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 3.0
# Epoch 16/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0742
#  - Oracle (80-th perc.) = 3.1841
#  - Ground-thruth (80-th perc.) = 3.274
#  - Ground-thruth (95-th perc.) = 3.31
#  - Ground-thruth (100-th perc.) = 3.3146
#  - Edit distance (median) = 1.0
# Epoch 17/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0736
#  - Oracle (80-th perc.) = 3.2349
#  - Ground-thruth (80-th perc.) = 3.2513
#  - Ground-thruth (95-th perc.) = 3.267
#  - Ground-thruth (100-th perc.) = 3.3139
#  - Edit distance (median) = 2.0
# Epoch 18/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0751
#  - Oracle (80-th perc.) = 3.3274
#  - Ground-thruth (80-th perc.) = 3.2234
#  - Ground-thruth (95-th perc.) = 3.2659
#  - Ground-thruth (100-th perc.) = 3.3263
#  - Edit distance (median) = 4.0
# Epoch 19/50
# 100/100 [==============================] - 7s 72ms/step - loss: 0.0754
#  - Oracle (80-th perc.) = 3.1722
#  - Ground-thruth (80-th perc.) = 3.2919
#  - Ground-thruth (95-th perc.) = 3.299
#  - Ground-thruth (100-th perc.) = 3.3123
#  - Edit distance (median) = 1.0
# Epoch 20/50
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0747
#  - Oracle (80-th perc.) = 3.2745
#  - Ground-thruth (80-th perc.) = 3.2996
#  - Ground-thruth (95-th perc.) = 3.3036
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 3.0
# Epoch 21/50
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0768
#  - Oracle (80-th perc.) = 3.2063
#  - Ground-thruth (80-th perc.) = 3.2567
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 1.0
# Epoch 22/50
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0761
#  - Oracle (80-th perc.) = 3.1829
#  - Ground-thruth (80-th perc.) = 3.3274
#  - Ground-thruth (95-th perc.) = 3.3376
#  - Ground-thruth (100-th perc.) = 3.3376
#  - Edit distance (median) = 1.5
# Epoch 23/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0761
#  - Oracle (80-th perc.) = 3.1726
#  - Ground-thruth (80-th perc.) = 3.2919
#  - Ground-thruth (95-th perc.) = 3.2937
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 2.0
# Epoch 24/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0759
#  - Oracle (80-th perc.) = 3.165
#  - Ground-thruth (80-th perc.) = 3.286
#  - Ground-thruth (95-th perc.) = 3.2919
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 1.0
# Epoch 25/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0737
#  - Oracle (80-th perc.) = 3.1829
#  - Ground-thruth (80-th perc.) = 3.3366
#  - Ground-thruth (95-th perc.) = 3.3425
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 1.0
# Epoch 26/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0742
#  - Oracle (80-th perc.) = 3.3639
#  - Ground-thruth (80-th perc.) = 3.1698
#  - Ground-thruth (95-th perc.) = 3.1917
#  - Ground-thruth (100-th perc.) = 3.2344
#  - Edit distance (median) = 3.5
# Epoch 27/50
# 100/100 [==============================] - 7s 72ms/step - loss: 0.0755
#  - Oracle (80-th perc.) = 3.1829
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3318
#  - Ground-thruth (100-th perc.) = 3.3376
#  - Edit distance (median) = 1.0
# Epoch 28/50
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0763
#  - Oracle (80-th perc.) = 3.2008
#  - Ground-thruth (80-th perc.) = 3.2812
#  - Ground-thruth (95-th perc.) = 3.2919
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 2.0
# Epoch 29/50
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0758
#  - Oracle (80-th perc.) = 3.169
#  - Ground-thruth (80-th perc.) = 3.2919
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 1.0
# Epoch 30/50
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0758
#  - Oracle (80-th perc.) = 3.1829
#  - Ground-thruth (80-th perc.) = 3.2555
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 0.0
# Epoch 31/50
# 100/100 [==============================] - 7s 72ms/step - loss: 0.0748
#  - Oracle (80-th perc.) = 3.1829
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3235
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 1.0
# Epoch 32/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0755
#  - Oracle (80-th perc.) = 3.323
#  - Ground-thruth (80-th perc.) = 3.2433
#  - Ground-thruth (95-th perc.) = 3.2793
#  - Ground-thruth (100-th perc.) = 3.3033
#  - Edit distance (median) = 3.0
# Epoch 33/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0740
#  - Oracle (80-th perc.) = 3.2727
#  - Ground-thruth (80-th perc.) = 3.2502
#  - Ground-thruth (95-th perc.) = 3.3079
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 1.0
# Epoch 34/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0748
#  - Oracle (80-th perc.) = 3.2935
#  - Ground-thruth (80-th perc.) = 3.2595
#  - Ground-thruth (95-th perc.) = 3.2926
#  - Ground-thruth (100-th perc.) = 3.3319
#  - Edit distance (median) = 3.0
# Epoch 35/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0750
#  - Oracle (80-th perc.) = 3.157
#  - Ground-thruth (80-th perc.) = 3.2555
#  - Ground-thruth (95-th perc.) = 3.2624
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 0.0
# Epoch 36/50
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0755
#  - Oracle (80-th perc.) = 3.2404
#  - Ground-thruth (80-th perc.) = 3.3123
#  - Ground-thruth (95-th perc.) = 3.3319
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 3.0
# Epoch 37/50
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0770
#  - Oracle (80-th perc.) = 3.2653
#  - Ground-thruth (80-th perc.) = 3.2618
#  - Ground-thruth (95-th perc.) = 3.2881
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 3.0
# Epoch 38/50
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0763
#  - Oracle (80-th perc.) = 3.2508
#  - Ground-thruth (80-th perc.) = 3.2632
#  - Ground-thruth (95-th perc.) = 3.2918
#  - Ground-thruth (100-th perc.) = 3.3318
#  - Edit distance (median) = 3.0
# Epoch 39/50
# 100/100 [==============================] - 7s 72ms/step - loss: 0.0743
#  - Oracle (80-th perc.) = 3.2722
#  - Ground-thruth (80-th perc.) = 3.2766
#  - Ground-thruth (95-th perc.) = 3.2766
#  - Ground-thruth (100-th perc.) = 3.3086
#  - Edit distance (median) = 1.0
# Epoch 40/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0762
#  - Oracle (80-th perc.) = 3.3313
#  - Ground-thruth (80-th perc.) = 3.2423
#  - Ground-thruth (95-th perc.) = 3.2896
#  - Ground-thruth (100-th perc.) = 3.3263
#  - Edit distance (median) = 4.0
# Epoch 41/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0758
#  - Oracle (80-th perc.) = 3.1817
#  - Ground-thruth (80-th perc.) = 3.2875
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 1.0
# Epoch 42/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0753
#  - Oracle (80-th perc.) = 3.1956
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 2.0
# Epoch 43/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0777
#  - Oracle (80-th perc.) = 3.2378
#  - Ground-thruth (80-th perc.) = 3.3051
#  - Ground-thruth (95-th perc.) = 3.3329
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 2.0
# Epoch 44/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0771
#  - Oracle (80-th perc.) = 3.2869
#  - Ground-thruth (80-th perc.) = 3.2223
#  - Ground-thruth (95-th perc.) = 3.2622
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 2.0
# Epoch 45/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0756
#  - Oracle (80-th perc.) = 3.1697
#  - Ground-thruth (80-th perc.) = 3.2767
#  - Ground-thruth (95-th perc.) = 3.2831
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 0.0
# Epoch 46/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0757
#  - Oracle (80-th perc.) = 3.2339
#  - Ground-thruth (80-th perc.) = 3.2819
#  - Ground-thruth (95-th perc.) = 3.2895
#  - Ground-thruth (100-th perc.) = 3.2895
#  - Edit distance (median) = 2.0
# Epoch 47/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0762
#  - Oracle (80-th perc.) = 3.3221
#  - Ground-thruth (80-th perc.) = 3.2266
#  - Ground-thruth (95-th perc.) = 3.2595
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 3.0
# Epoch 48/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0763
#  - Oracle (80-th perc.) = 3.2462
#  - Ground-thruth (80-th perc.) = 3.2752
#  - Ground-thruth (95-th perc.) = 3.2886
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 1.0
# Epoch 49/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0755
#  - Oracle (80-th perc.) = 3.1608
#  - Ground-thruth (80-th perc.) = 3.2555
#  - Ground-thruth (95-th perc.) = 3.3366
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 0.0
# Epoch 50/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0761
#  - Oracle (80-th perc.) = 3.2414
#  - Ground-thruth (80-th perc.) = 3.2538
#  - Ground-thruth (95-th perc.) = 3.2895
#  - Ground-thruth (100-th perc.) = 3.3093
#  - Edit distance (median) = 3.0
#  - Oracle (80-th perc.) = -0.3775
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 203.0
# Epoch 1/50
# 100/100 [==============================] - 9s 92ms/step - loss: 8.0591
#  - Oracle (80-th perc.) = 3.4311
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 87.0
# Epoch 2/50
# 100/100 [==============================] - 6s 61ms/step - loss: 2.1082
#  - Oracle (80-th perc.) = 3.2344
#  - Ground-thruth (80-th perc.) = 3.0394
#  - Ground-thruth (95-th perc.) = 3.0544
#  - Ground-thruth (100-th perc.) = 3.0646
#  - Edit distance (median) = 2.5
# Epoch 3/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1012
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2666
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.3069
#  - Edit distance (median) = 1.0
# Epoch 4/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0817
#  - Oracle (80-th perc.) = 3.2486
#  - Ground-thruth (80-th perc.) = 3.2996
#  - Ground-thruth (95-th perc.) = 3.3069
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 1.0
# Epoch 5/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0826
#  - Oracle (80-th perc.) = 3.3241
#  - Ground-thruth (80-th perc.) = 3.2704
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.3182
#  - Edit distance (median) = 3.0
# Epoch 6/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0830
#  - Oracle (80-th perc.) = 3.2251
#  - Ground-thruth (80-th perc.) = 3.2996
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 1.0
# Epoch 7/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0830
#  - Oracle (80-th perc.) = 3.2486
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2993
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 1.0
# Epoch 8/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0825
#  - Oracle (80-th perc.) = 3.2632
#  - Ground-thruth (80-th perc.) = 3.2735
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.3069
#  - Edit distance (median) = 2.0
# Epoch 9/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.0834
#  - Oracle (80-th perc.) = 3.2486
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2876
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 1.0
# Epoch 10/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0818
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2972
#  - Ground-thruth (100-th perc.) = 3.3039
#  - Edit distance (median) = 1.0
# Epoch 11/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0827
#  - Oracle (80-th perc.) = 3.2251
#  - Ground-thruth (80-th perc.) = 3.2996
#  - Ground-thruth (95-th perc.) = 3.3069
#  - Ground-thruth (100-th perc.) = 3.3182
#  - Edit distance (median) = 1.0
# Epoch 12/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0815
#  - Oracle (80-th perc.) = 3.2251
#  - Ground-thruth (80-th perc.) = 3.2996
#  - Ground-thruth (95-th perc.) = 3.3001
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 1.0
# Epoch 13/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0812
#  - Oracle (80-th perc.) = 3.2251
#  - Ground-thruth (80-th perc.) = 3.2899
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 1.0
# Epoch 14/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0808
#  - Oracle (80-th perc.) = 3.2251
#  - Ground-thruth (80-th perc.) = 3.2885
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 1.0
# Epoch 15/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0808
#  - Oracle (80-th perc.) = 3.2664
#  - Ground-thruth (80-th perc.) = 3.2887
#  - Ground-thruth (95-th perc.) = 3.308
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 3.0
# Epoch 16/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0804
#  - Oracle (80-th perc.) = 3.1569
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2876
#  - Ground-thruth (100-th perc.) = 3.2876
#  - Edit distance (median) = 0.0
# Epoch 17/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0800
#  - Oracle (80-th perc.) = 3.2624
#  - Ground-thruth (80-th perc.) = 3.2993
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 2.0
# Epoch 18/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0810
#  - Oracle (80-th perc.) = 3.2251
#  - Ground-thruth (80-th perc.) = 3.2982
#  - Ground-thruth (95-th perc.) = 3.3069
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 1.0
# Epoch 19/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0793
#  - Oracle (80-th perc.) = 3.1569
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2616
#  - Ground-thruth (100-th perc.) = 3.2664
#  - Edit distance (median) = 0.0
# Epoch 20/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.0798
#  - Oracle (80-th perc.) = 3.225
#  - Ground-thruth (80-th perc.) = 3.2664
#  - Ground-thruth (95-th perc.) = 3.28
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 2.0
# Epoch 21/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0805
#  - Oracle (80-th perc.) = 3.2015
#  - Ground-thruth (80-th perc.) = 3.2505
#  - Ground-thruth (95-th perc.) = 3.2675
#  - Ground-thruth (100-th perc.) = 3.2675
#  - Edit distance (median) = 0.0
# Epoch 22/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0814
#  - Oracle (80-th perc.) = 3.2443
#  - Ground-thruth (80-th perc.) = 3.2876
#  - Ground-thruth (95-th perc.) = 3.3069
#  - Ground-thruth (100-th perc.) = 3.3069
#  - Edit distance (median) = 2.0
# Epoch 23/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0803
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.252
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 0.0
# Epoch 24/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0809
#  - Oracle (80-th perc.) = 3.1608
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.2972
#  - Edit distance (median) = 0.0
# Epoch 25/50
# 100/100 [==============================] - 6s 59ms/step - loss: 0.0801
#  - Oracle (80-th perc.) = 3.1798
#  - Ground-thruth (80-th perc.) = 3.2797
#  - Ground-thruth (95-th perc.) = 3.2972
#  - Ground-thruth (100-th perc.) = 3.3064
#  - Edit distance (median) = 1.0
# Epoch 26/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0798
#  - Oracle (80-th perc.) = 3.2192
#  - Ground-thruth (80-th perc.) = 3.2675
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 1.0
# Epoch 27/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0799
#  - Oracle (80-th perc.) = 3.1569
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2618
#  - Ground-thruth (100-th perc.) = 3.2664
#  - Edit distance (median) = 0.0
# Epoch 28/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0797
#  - Oracle (80-th perc.) = 3.2443
#  - Ground-thruth (80-th perc.) = 3.2512
#  - Ground-thruth (95-th perc.) = 3.2978
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 1.0
# Epoch 29/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0799
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2627
#  - Ground-thruth (100-th perc.) = 3.2664
#  - Edit distance (median) = 0.0
# Epoch 30/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0803
#  - Oracle (80-th perc.) = 3.2251
#  - Ground-thruth (80-th perc.) = 3.2993
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.3069
#  - Edit distance (median) = 1.0
# Epoch 31/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0798
#  - Oracle (80-th perc.) = 3.1608
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.2664
#  - Edit distance (median) = 1.0
# Epoch 32/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0799
#  - Oracle (80-th perc.) = 3.2119
#  - Ground-thruth (80-th perc.) = 3.2625
#  - Ground-thruth (95-th perc.) = 3.2979
#  - Ground-thruth (100-th perc.) = 3.3069
#  - Edit distance (median) = 0.0
# Epoch 33/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0796
#  - Oracle (80-th perc.) = 3.2031
#  - Ground-thruth (80-th perc.) = 3.2664
#  - Ground-thruth (95-th perc.) = 3.3502
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 2.0
# Epoch 34/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0793
#  - Oracle (80-th perc.) = 3.1608
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.2972
#  - Edit distance (median) = 0.0
# Epoch 35/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0803
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2628
#  - Ground-thruth (100-th perc.) = 3.2675
#  - Edit distance (median) = 0.0
# Epoch 36/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0799
#  - Oracle (80-th perc.) = 3.2119
#  - Ground-thruth (80-th perc.) = 3.2564
#  - Ground-thruth (95-th perc.) = 3.2675
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 1.0
# Epoch 37/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0795
#  - Oracle (80-th perc.) = 3.2064
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2979
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 2.0
# Epoch 38/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0800
#  - Oracle (80-th perc.) = 3.1697
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.2797
#  - Edit distance (median) = 1.0
# Epoch 39/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0813
#  - Oracle (80-th perc.) = 3.2069
#  - Ground-thruth (80-th perc.) = 3.2876
#  - Ground-thruth (95-th perc.) = 3.3396
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 1.0
# Epoch 40/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0793
#  - Oracle (80-th perc.) = 3.1708
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.2664
#  - Edit distance (median) = 1.0
# Epoch 41/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0799
#  - Oracle (80-th perc.) = 3.2259
#  - Ground-thruth (80-th perc.) = 3.2675
#  - Ground-thruth (95-th perc.) = 3.3
#  - Ground-thruth (100-th perc.) = 3.3671
#  - Edit distance (median) = 1.0
# Epoch 42/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0792
#  - Oracle (80-th perc.) = 3.2924
#  - Ground-thruth (80-th perc.) = 3.2993
#  - Ground-thruth (95-th perc.) = 3.3502
#  - Ground-thruth (100-th perc.) = 3.3538
#  - Edit distance (median) = 3.0
# Epoch 43/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0799
#  - Oracle (80-th perc.) = 3.1758
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.2972
#  - Edit distance (median) = 1.0
# Epoch 44/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0801
#  - Oracle (80-th perc.) = 3.2221
#  - Ground-thruth (80-th perc.) = 3.2666
#  - Ground-thruth (95-th perc.) = 3.3069
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 1.0
# Epoch 45/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0789
#  - Oracle (80-th perc.) = 3.2998
#  - Ground-thruth (80-th perc.) = 3.3035
#  - Ground-thruth (95-th perc.) = 3.3502
#  - Ground-thruth (100-th perc.) = 3.3538
#  - Edit distance (median) = 3.0
# Epoch 46/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0799
#  - Oracle (80-th perc.) = 3.218
#  - Ground-thruth (80-th perc.) = 3.2664
#  - Ground-thruth (95-th perc.) = 3.3
#  - Ground-thruth (100-th perc.) = 3.3671
#  - Edit distance (median) = 2.0
# Epoch 47/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0791
#  - Oracle (80-th perc.) = 3.2168
#  - Ground-thruth (80-th perc.) = 3.2625
#  - Ground-thruth (95-th perc.) = 3.2978
#  - Ground-thruth (100-th perc.) = 3.3069
#  - Edit distance (median) = 1.0
# Epoch 48/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0795
#  - Oracle (80-th perc.) = 3.1697
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2972
#  - Ground-thruth (100-th perc.) = 3.2972
#  - Edit distance (median) = 1.0
# Epoch 49/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0793
#  - Oracle (80-th perc.) = 3.1613
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.2876
#  - Edit distance (median) = 1.0
# Epoch 50/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0797
#  - Oracle (80-th perc.) = 3.2107
#  - Ground-thruth (80-th perc.) = 3.2625
#  - Ground-thruth (95-th perc.) = 3.2972
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 1.0
#  - Oracle (80-th perc.) = -1.7711
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 205.0
# Epoch 1/50
# 100/100 [==============================] - 9s 94ms/step - loss: 9.2915
#  - Oracle (80-th perc.) = 2.0095
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 69.5
# Epoch 2/50
# 100/100 [==============================] - 6s 64ms/step - loss: 4.1197
#  - Oracle (80-th perc.) = 3.1218
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 30.0
# Epoch 3/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.4545
#  - Oracle (80-th perc.) = 3.1773
#  - Ground-thruth (80-th perc.) = 3.3285
#  - Ground-thruth (95-th perc.) = 3.3285
#  - Ground-thruth (100-th perc.) = 3.3357
#  - Edit distance (median) = 1.0
# Epoch 4/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0551
#  - Oracle (80-th perc.) = 3.1695
#  - Ground-thruth (80-th perc.) = 3.2555
#  - Ground-thruth (95-th perc.) = 3.2555
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 0.0
# Epoch 5/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.0550
#  - Oracle (80-th perc.) = 3.2014
#  - Ground-thruth (80-th perc.) = 3.3471
#  - Ground-thruth (95-th perc.) = 3.4027
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 1.0
# Epoch 6/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0550
#  - Oracle (80-th perc.) = 3.2225
#  - Ground-thruth (80-th perc.) = 3.3937
#  - Ground-thruth (95-th perc.) = 3.403
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 2.5
# Epoch 7/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0553
#  - Oracle (80-th perc.) = 3.1695
#  - Ground-thruth (80-th perc.) = 3.2555
#  - Ground-thruth (95-th perc.) = 3.2592
#  - Ground-thruth (100-th perc.) = 3.3285
#  - Edit distance (median) = 0.0
# Epoch 8/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0549
#  - Oracle (80-th perc.) = 3.1695
#  - Ground-thruth (80-th perc.) = 3.2555
#  - Ground-thruth (95-th perc.) = 3.2564
#  - Ground-thruth (100-th perc.) = 3.3185
#  - Edit distance (median) = 0.0
# Epoch 9/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0541
#  - Oracle (80-th perc.) = 3.2167
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3315
#  - Ground-thruth (100-th perc.) = 3.4027
#  - Edit distance (median) = 1.0
# Epoch 10/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0546
#  - Oracle (80-th perc.) = 3.1933
#  - Ground-thruth (80-th perc.) = 3.3881
#  - Ground-thruth (95-th perc.) = 3.3937
#  - Ground-thruth (100-th perc.) = 3.4027
#  - Edit distance (median) = 1.0
# Epoch 11/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0547
#  - Oracle (80-th perc.) = 3.1876
#  - Ground-thruth (80-th perc.) = 3.3421
#  - Ground-thruth (95-th perc.) = 3.3562
#  - Ground-thruth (100-th perc.) = 3.3562
#  - Edit distance (median) = 2.0
# Epoch 12/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0535
#  - Oracle (80-th perc.) = 3.1876
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3241
#  - Ground-thruth (100-th perc.) = 3.3471
#  - Edit distance (median) = 1.0
# Epoch 13/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.0533
#  - Oracle (80-th perc.) = 3.1983
#  - Ground-thruth (80-th perc.) = 3.3421
#  - Ground-thruth (95-th perc.) = 3.3471
#  - Ground-thruth (100-th perc.) = 3.3562
#  - Edit distance (median) = 1.0
# Epoch 14/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0530
#  - Oracle (80-th perc.) = 3.2241
#  - Ground-thruth (80-th perc.) = 3.3421
#  - Ground-thruth (95-th perc.) = 3.3891
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 2.0
# Epoch 15/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0530
#  - Oracle (80-th perc.) = 3.1923
#  - Ground-thruth (80-th perc.) = 3.362
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4027
#  - Edit distance (median) = 1.0
# Epoch 16/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0527
#  - Oracle (80-th perc.) = 3.1838
#  - Ground-thruth (80-th perc.) = 3.2915
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 1.0
# Epoch 17/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0530
#  - Oracle (80-th perc.) = 3.1934
#  - Ground-thruth (80-th perc.) = 3.3307
#  - Ground-thruth (95-th perc.) = 3.3888
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 2.0
# Epoch 18/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0532
#  - Oracle (80-th perc.) = 3.2115
#  - Ground-thruth (80-th perc.) = 3.4076
#  - Ground-thruth (95-th perc.) = 3.4076
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 2.0
# Epoch 19/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0526
#  - Oracle (80-th perc.) = 3.1695
#  - Ground-thruth (80-th perc.) = 3.2555
#  - Ground-thruth (95-th perc.) = 3.2735
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 0.0
# Epoch 20/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0525
#  - Oracle (80-th perc.) = 3.1876
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 1.0
# Epoch 21/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0527
#  - Oracle (80-th perc.) = 3.1868
#  - Ground-thruth (80-th perc.) = 3.3185
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 2.0
# Epoch 22/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0516
#  - Oracle (80-th perc.) = 3.1876
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3627
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 1.0
# Epoch 23/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0517
#  - Oracle (80-th perc.) = 3.2006
#  - Ground-thruth (80-th perc.) = 3.3668
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 2.0
# Epoch 24/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0516
#  - Oracle (80-th perc.) = 3.1949
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 2.0
# Epoch 25/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0518
#  - Oracle (80-th perc.) = 3.1933
#  - Ground-thruth (80-th perc.) = 3.3421
#  - Ground-thruth (95-th perc.) = 3.4076
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 1.0
# Epoch 26/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0509
#  - Oracle (80-th perc.) = 3.1695
#  - Ground-thruth (80-th perc.) = 3.2769
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 1.5
# ...
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1015
#  - Oracle (80-th perc.) = 3.2515
#  - Ground-thruth (80-th perc.) = 3.2232
#  - Ground-thruth (95-th perc.) = 3.254
#  - Ground-thruth (100-th perc.) = 3.2559
#  - Edit distance (median) = 2.0
# Epoch 43/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0992
#  - Oracle (80-th perc.) = 3.2451
#  - Ground-thruth (80-th perc.) = 3.2917
#  - Ground-thruth (95-th perc.) = 3.3186
#  - Ground-thruth (100-th perc.) = 3.3516
#  - Edit distance (median) = 3.0
# Epoch 44/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1013
#  - Oracle (80-th perc.) = 3.2295
#  - Ground-thruth (80-th perc.) = 3.2696
#  - Ground-thruth (95-th perc.) = 3.3262
#  - Ground-thruth (100-th perc.) = 3.3852
#  - Edit distance (median) = 3.0
# Epoch 45/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1013
#  - Oracle (80-th perc.) = 3.218
#  - Ground-thruth (80-th perc.) = 3.335
#  - Ground-thruth (95-th perc.) = 3.3482
#  - Ground-thruth (100-th perc.) = 3.3524
#  - Edit distance (median) = 2.0
# Epoch 46/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1007
#  - Oracle (80-th perc.) = 3.2499
#  - Ground-thruth (80-th perc.) = 3.2842
#  - Ground-thruth (95-th perc.) = 3.31
#  - Ground-thruth (100-th perc.) = 3.3347
#  - Edit distance (median) = 2.0
# Epoch 47/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1029
#  - Oracle (80-th perc.) = 3.1802
#  - Ground-thruth (80-th perc.) = 3.2658
#  - Ground-thruth (95-th perc.) = 3.3286
#  - Ground-thruth (100-th perc.) = 3.3948
#  - Edit distance (median) = 1.0
# Epoch 48/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1007
#  - Oracle (80-th perc.) = 3.2077
#  - Ground-thruth (80-th perc.) = 3.3463
#  - Ground-thruth (95-th perc.) = 3.3699
#  - Ground-thruth (100-th perc.) = 3.3988
#  - Edit distance (median) = 2.0
# Epoch 49/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1005
#  - Oracle (80-th perc.) = 3.1858
#  - Ground-thruth (80-th perc.) = 3.2686
#  - Ground-thruth (95-th perc.) = 3.2894
#  - Ground-thruth (100-th perc.) = 3.3524
#  - Edit distance (median) = 1.0
# Epoch 50/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1021
#  - Oracle (80-th perc.) = 3.2015
#  - Ground-thruth (80-th perc.) = 3.3107
#  - Ground-thruth (95-th perc.) = 3.3108
#  - Ground-thruth (100-th perc.) = 3.3447
#  - Edit distance (median) = 2.0
#  - Oracle (80-th perc.) = -1.95
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 203.0
# Epoch 1/50
# 100/100 [==============================] - 11s 107ms/step - loss: 8.0358
#  - Oracle (80-th perc.) = 2.6174
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 70.0
# Epoch 2/50
# 100/100 [==============================] - 7s 68ms/step - loss: 2.0542
#  - Oracle (80-th perc.) = 3.2516
#  - Ground-thruth (80-th perc.) = 2.9751
#  - Ground-thruth (95-th perc.) = 2.9896
#  - Ground-thruth (100-th perc.) = 3.001
#  - Edit distance (median) = 4.0
# Epoch 3/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1341
#  - Oracle (80-th perc.) = 3.233
#  - Ground-thruth (80-th perc.) = 3.3084
#  - Ground-thruth (95-th perc.) = 3.3398
#  - Ground-thruth (100-th perc.) = 3.3617
#  - Edit distance (median) = 3.0
# Epoch 4/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0883
#  - Oracle (80-th perc.) = 3.2461
#  - Ground-thruth (80-th perc.) = 3.2844
#  - Ground-thruth (95-th perc.) = 3.311
#  - Ground-thruth (100-th perc.) = 3.3307
#  - Edit distance (median) = 3.0
# Epoch 5/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0886
#  - Oracle (80-th perc.) = 3.229
#  - Ground-thruth (80-th perc.) = 3.3368
#  - Ground-thruth (95-th perc.) = 3.364
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 2.0
# Epoch 6/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.0915
#  - Oracle (80-th perc.) = 3.196
#  - Ground-thruth (80-th perc.) = 3.3808
#  - Ground-thruth (95-th perc.) = 3.3908
#  - Ground-thruth (100-th perc.) = 3.3908
#  - Edit distance (median) = 2.0
# Epoch 7/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0913
#  - Oracle (80-th perc.) = 3.2506
#  - Ground-thruth (80-th perc.) = 3.3355
#  - Ground-thruth (95-th perc.) = 3.3617
#  - Ground-thruth (100-th perc.) = 3.3926
#  - Edit distance (median) = 4.0
# Epoch 8/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0891
#  - Oracle (80-th perc.) = 3.2099
#  - Ground-thruth (80-th perc.) = 3.3449
#  - Ground-thruth (95-th perc.) = 3.3521
#  - Ground-thruth (100-th perc.) = 3.3549
#  - Edit distance (median) = 2.0
# Epoch 9/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.0889
#  - Oracle (80-th perc.) = 3.2218
#  - Ground-thruth (80-th perc.) = 3.364
#  - Ground-thruth (95-th perc.) = 3.383
#  - Ground-thruth (100-th perc.) = 3.4024
#  - Edit distance (median) = 2.0
# Epoch 10/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0906
#  - Oracle (80-th perc.) = 3.2634
#  - Ground-thruth (80-th perc.) = 3.3515
#  - Ground-thruth (95-th perc.) = 3.367
#  - Ground-thruth (100-th perc.) = 3.3701
#  - Edit distance (median) = 2.5
# Epoch 11/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0914
#  - Oracle (80-th perc.) = 3.2426
#  - Ground-thruth (80-th perc.) = 3.3203
#  - Ground-thruth (95-th perc.) = 3.3448
#  - Ground-thruth (100-th perc.) = 3.3685
#  - Edit distance (median) = 2.5
# Epoch 12/50
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0878
#  - Oracle (80-th perc.) = 3.1988
#  - Ground-thruth (80-th perc.) = 3.3477
#  - Ground-thruth (95-th perc.) = 3.3866
#  - Ground-thruth (100-th perc.) = 3.3908
#  - Edit distance (median) = 2.0
# Epoch 13/50
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0888
#  - Oracle (80-th perc.) = 3.2068
#  - Ground-thruth (80-th perc.) = 3.3687
#  - Ground-thruth (95-th perc.) = 3.3808
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 2.0
# Epoch 14/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.0871
#  - Oracle (80-th perc.) = 3.2264
#  - Ground-thruth (80-th perc.) = 3.3115
#  - Ground-thruth (95-th perc.) = 3.3453
#  - Ground-thruth (100-th perc.) = 3.3704
#  - Edit distance (median) = 3.0
# Epoch 15/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0879
#  - Oracle (80-th perc.) = 3.1908
#  - Ground-thruth (80-th perc.) = 3.3549
#  - Ground-thruth (95-th perc.) = 3.3693
#  - Ground-thruth (100-th perc.) = 3.3799
#  - Edit distance (median) = 1.0
# Epoch 16/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0858
#  - Oracle (80-th perc.) = 3.2128
#  - Ground-thruth (80-th perc.) = 3.3546
#  - Ground-thruth (95-th perc.) = 3.3636
#  - Ground-thruth (100-th perc.) = 3.383
#  - Edit distance (median) = 2.0
# Epoch 17/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0863
#  - Oracle (80-th perc.) = 3.2289
#  - Ground-thruth (80-th perc.) = 3.3627
#  - Ground-thruth (95-th perc.) = 3.3733
#  - Ground-thruth (100-th perc.) = 3.3901
#  - Edit distance (median) = 2.0
# Epoch 18/50
# 100/100 [==============================] - 7s 75ms/step - loss: 0.0872
#  - Oracle (80-th perc.) = 3.224
#  - Ground-thruth (80-th perc.) = 3.3527
#  - Ground-thruth (95-th perc.) = 3.3685
#  - Ground-thruth (100-th perc.) = 3.3799
#  - Edit distance (median) = 3.0
# Epoch 19/50
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0858
#  - Oracle (80-th perc.) = 3.1858
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3355
#  - Ground-thruth (100-th perc.) = 3.3547
#  - Edit distance (median) = 2.0
# Epoch 20/50
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0868
#  - Oracle (80-th perc.) = 3.175
#  - Ground-thruth (80-th perc.) = 3.3706
#  - Ground-thruth (95-th perc.) = 3.3706
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 1.5
# Epoch 21/50
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0868
#  - Oracle (80-th perc.) = 3.1636
#  - Ground-thruth (80-th perc.) = 3.2795
#  - Ground-thruth (95-th perc.) = 3.3185
#  - Ground-thruth (100-th perc.) = 3.3526
#  - Edit distance (median) = 1.0
# Epoch 22/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.0850
#  - Oracle (80-th perc.) = 3.2137
#  - Ground-thruth (80-th perc.) = 3.3687
#  - Ground-thruth (95-th perc.) = 3.38
#  - Ground-thruth (100-th perc.) = 3.4024
#  - Edit distance (median) = 3.0
# Epoch 23/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0848
#  - Oracle (80-th perc.) = 3.2465
#  - Ground-thruth (80-th perc.) = 3.3447
#  - Ground-thruth (95-th perc.) = 3.3643
#  - Ground-thruth (100-th perc.) = 3.378
#  - Edit distance (median) = 3.0
# Epoch 24/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0856
#  - Oracle (80-th perc.) = 3.2099
#  - Ground-thruth (80-th perc.) = 3.3537
#  - Ground-thruth (95-th perc.) = 3.3568
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 1.5
# Epoch 25/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0859
#  - Oracle (80-th perc.) = 3.2413
#  - Ground-thruth (80-th perc.) = 3.3063
#  - Ground-thruth (95-th perc.) = 3.3515
#  - Ground-thruth (100-th perc.) = 3.3515
#  - Edit distance (median) = 3.0
# Epoch 26/50
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0854
#  - Oracle (80-th perc.) = 3.2439
#  - Ground-thruth (80-th perc.) = 3.2967
#  - Ground-thruth (95-th perc.) = 3.3317
#  - Ground-thruth (100-th perc.) = 3.3711
#  - Edit distance (median) = 4.0
# Epoch 27/50
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0856
#  - Oracle (80-th perc.) = 3.2032
#  - Ground-thruth (80-th perc.) = 3.3771
#  - Ground-thruth (95-th perc.) = 3.3901
#  - Ground-thruth (100-th perc.) = 3.3901
#  - Edit distance (median) = 3.0
# Epoch 28/50
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0866
#  - Oracle (80-th perc.) = 3.1939
#  - Ground-thruth (80-th perc.) = 3.3526
#  - Ground-thruth (95-th perc.) = 3.3588
#  - Ground-thruth (100-th perc.) = 3.3908
#  - Edit distance (median) = 3.0
# Epoch 29/50
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0854
#  - Oracle (80-th perc.) = 3.1692
#  - Ground-thruth (80-th perc.) = 3.297
#  - Ground-thruth (95-th perc.) = 3.3381
#  - Ground-thruth (100-th perc.) = 3.3421
#  - Edit distance (median) = 3.0
# Epoch 30/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0844
#  - Oracle (80-th perc.) = 3.1791
#  - Ground-thruth (80-th perc.) = 3.3808
#  - Ground-thruth (95-th perc.) = 3.3808
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 1.0
# Epoch 31/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0846
#  - Oracle (80-th perc.) = 3.2001
#  - Ground-thruth (80-th perc.) = 3.3361
#  - Ground-thruth (95-th perc.) = 3.3643
#  - Ground-thruth (100-th perc.) = 3.3767
#  - Edit distance (median) = 4.0
# Epoch 32/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0853
#  - Oracle (80-th perc.) = 3.1754
#  - Ground-thruth (80-th perc.) = 3.3771
#  - Ground-thruth (95-th perc.) = 3.3773
#  - Ground-thruth (100-th perc.) = 3.3908
#  - Edit distance (median) = 1.0
# Epoch 33/50
# 100/100 [==============================] - 8s 76ms/step - loss: 0.0852
#  - Oracle (80-th perc.) = 3.2553
#  - Ground-thruth (80-th perc.) = 3.2893
#  - Ground-thruth (95-th perc.) = 3.3035
#  - Ground-thruth (100-th perc.) = 3.3264
#  - Edit distance (median) = 2.0
# Epoch 34/50
# 100/100 [==============================] - 9s 85ms/step - loss: 0.0842
#  - Oracle (80-th perc.) = 3.2265
#  - Ground-thruth (80-th perc.) = 3.3502
#  - Ground-thruth (95-th perc.) = 3.3701
#  - Ground-thruth (100-th perc.) = 3.378
#  - Edit distance (median) = 3.0
# Epoch 35/50
# 100/100 [==============================] - 8s 85ms/step - loss: 0.0842
#  - Oracle (80-th perc.) = 3.2764
#  - Ground-thruth (80-th perc.) = 3.267
#  - Ground-thruth (95-th perc.) = 3.2997
#  - Ground-thruth (100-th perc.) = 3.3255
#  - Edit distance (median) = 3.0
# Epoch 36/50
# 100/100 [==============================] - 8s 81ms/step - loss: 0.0850
#  - Oracle (80-th perc.) = 3.188
#  - Ground-thruth (80-th perc.) = 3.3527
#  - Ground-thruth (95-th perc.) = 3.3586
#  - Ground-thruth (100-th perc.) = 3.3586
#  - Edit distance (median) = 2.0
# Epoch 37/50
# 100/100 [==============================] - 7s 73ms/step - loss: 0.0841
#  - Oracle (80-th perc.) = 3.1977
#  - Ground-thruth (80-th perc.) = 3.3401
#  - Ground-thruth (95-th perc.) = 3.3407
#  - Ground-thruth (100-th perc.) = 3.3538
#  - Edit distance (median) = 2.0
# Epoch 38/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0849
#  - Oracle (80-th perc.) = 3.2206
#  - Ground-thruth (80-th perc.) = 3.364
#  - Ground-thruth (95-th perc.) = 3.3767
#  - Ground-thruth (100-th perc.) = 3.378
#  - Edit distance (median) = 3.0
# Epoch 39/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.0864
#  - Oracle (80-th perc.) = 3.2151
#  - Ground-thruth (80-th perc.) = 3.3806
#  - Ground-thruth (95-th perc.) = 3.3806
#  - Ground-thruth (100-th perc.) = 3.3901
#  - Edit distance (median) = 2.0
# Epoch 40/50
# 100/100 [==============================] - 7s 73ms/step - loss: 0.0852
#  - Oracle (80-th perc.) = 3.1842
#  - Ground-thruth (80-th perc.) = 3.3277
#  - Ground-thruth (95-th perc.) = 3.3771
#  - Ground-thruth (100-th perc.) = 3.3883
#  - Edit distance (median) = 2.0
# Epoch 41/50
# 100/100 [==============================] - 8s 85ms/step - loss: 0.0857
#  - Oracle (80-th perc.) = 3.1601
#  - Ground-thruth (80-th perc.) = 3.2633
#  - Ground-thruth (95-th perc.) = 3.3285
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 0.0
# Epoch 42/50
# 100/100 [==============================] - 9s 86ms/step - loss: 0.0865
#  - Oracle (80-th perc.) = 3.2135
#  - Ground-thruth (80-th perc.) = 3.3535
#  - Ground-thruth (95-th perc.) = 3.355
#  - Ground-thruth (100-th perc.) = 3.3908
#  - Edit distance (median) = 1.5
# Epoch 43/50
# 100/100 [==============================] - 8s 83ms/step - loss: 0.0850
#  - Oracle (80-th perc.) = 3.2008
#  - Ground-thruth (80-th perc.) = 3.378
#  - Ground-thruth (95-th perc.) = 3.3799
#  - Ground-thruth (100-th perc.) = 3.3839
#  - Edit distance (median) = 2.0
# Epoch 44/50
# 100/100 [==============================] - 7s 73ms/step - loss: 0.0846
#  - Oracle (80-th perc.) = 3.2018
#  - Ground-thruth (80-th perc.) = 3.3706
#  - Ground-thruth (95-th perc.) = 3.378
#  - Ground-thruth (100-th perc.) = 3.378
#  - Edit distance (median) = 2.5
# Epoch 45/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.0854
#  - Oracle (80-th perc.) = 3.2417
#  - Ground-thruth (80-th perc.) = 3.32
#  - Ground-thruth (95-th perc.) = 3.3455
#  - Ground-thruth (100-th perc.) = 3.3687
#  - Edit distance (median) = 3.0
# Epoch 46/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.0864
#  - Oracle (80-th perc.) = 3.179
#  - Ground-thruth (80-th perc.) = 3.3908
#  - Ground-thruth (95-th perc.) = 3.3908
#  - Ground-thruth (100-th perc.) = 3.3908
#  - Edit distance (median) = 1.0
# Epoch 47/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.0851
#  - Oracle (80-th perc.) = 3.1846
#  - Ground-thruth (80-th perc.) = 3.3249
#  - Ground-thruth (95-th perc.) = 3.3435
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 2.0
# Epoch 48/50
# 100/100 [==============================] - 8s 77ms/step - loss: 0.0850
#  - Oracle (80-th perc.) = 3.1807
#  - Ground-thruth (80-th perc.) = 3.3527
#  - Ground-thruth (95-th perc.) = 3.353
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 1.0
# Epoch 49/50
# 100/100 [==============================] - 8s 84ms/step - loss: 0.0832
#  - Oracle (80-th perc.) = 3.2258
#  - Ground-thruth (80-th perc.) = 3.3901
#  - Ground-thruth (95-th perc.) = 3.3901
#  - Ground-thruth (100-th perc.) = 3.3901
#  - Edit distance (median) = 2.0
# Epoch 50/50
# 100/100 [==============================] - 8s 82ms/step - loss: 0.0851
#  - Oracle (80-th perc.) = 3.1792
#  - Ground-thruth (80-th perc.) = 3.3706
#  - Ground-thruth (95-th perc.) = 3.371
#  - Ground-thruth (100-th perc.) = 3.378
#  - Edit distance (median) = 1.0

# %%
run_experimental_den_opt(0, repeat_start=0, repeats=3, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.95, vae_log_p_margin=1.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
run_experimental_den_opt(1, repeat_start=0, repeats=3, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.95, vae_log_p_margin=1.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
run_experimental_den_opt(2, repeat_start=0, repeats=3, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.95, vae_log_p_margin=1.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ubuntu/CbAS/genesis_generator_protein.py:167: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From <ipython-input-7-b689ca90135f>:72: Normal.__init__ (from tensorflow.python.ops.distributions.normal) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/distributions/normal.py:160: Distribution.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
#  - Oracle (80-th perc.) = -0.9571
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 205.0
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/50
# 100/100 [==============================] - 9s 89ms/step - loss: 8.5305
#  - Oracle (80-th perc.) = 3.4308
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 87.0
# Epoch 2/50
# 100/100 [==============================] - 6s 61ms/step - loss: 2.8713
#  - Oracle (80-th perc.) = 3.2634
#  - Ground-thruth (80-th perc.) = 2.8956
#  - Ground-thruth (95-th perc.) = 2.8962
#  - Ground-thruth (100-th perc.) = 2.8971
#  - Edit distance (median) = 13.0
# Epoch 3/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.3524
#  - Oracle (80-th perc.) = 3.2271
#  - Ground-thruth (80-th perc.) = 3.2237
#  - Ground-thruth (95-th perc.) = 3.2727
#  - Ground-thruth (100-th perc.) = 3.3068
#  - Edit distance (median) = 8.0
# Epoch 4/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1902
#  - Oracle (80-th perc.) = 3.211
#  - Ground-thruth (80-th perc.) = 3.2751
#  - Ground-thruth (95-th perc.) = 3.3207
#  - Ground-thruth (100-th perc.) = 3.3458
#  - Edit distance (median) = 7.0
# Epoch 5/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1794
#  - Oracle (80-th perc.) = 3.3072
#  - Ground-thruth (80-th perc.) = 3.2845
#  - Ground-thruth (95-th perc.) = 3.3273
#  - Ground-thruth (100-th perc.) = 3.4078
#  - Edit distance (median) = 7.0
# Epoch 6/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1708
#  - Oracle (80-th perc.) = 3.1998
#  - Ground-thruth (80-th perc.) = 3.3271
#  - Ground-thruth (95-th perc.) = 3.3675
#  - Ground-thruth (100-th perc.) = 3.425
#  - Edit distance (median) = 5.5
# Epoch 7/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1653
#  - Oracle (80-th perc.) = 3.2406
#  - Ground-thruth (80-th perc.) = 3.3314
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3927
#  - Edit distance (median) = 5.0
# Epoch 8/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1617
#  - Oracle (80-th perc.) = 3.2261
#  - Ground-thruth (80-th perc.) = 3.3107
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 5.0
# Epoch 9/50
# 100/100 [==============================] - 6s 59ms/step - loss: 0.1607
#  - Oracle (80-th perc.) = 3.2092
#  - Ground-thruth (80-th perc.) = 3.3411
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 4.0
# Epoch 10/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1596
#  - Oracle (80-th perc.) = 3.2089
#  - Ground-thruth (80-th perc.) = 3.3455
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 5.0
# Epoch 11/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1592
#  - Oracle (80-th perc.) = 3.2262
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3964
#  - Edit distance (median) = 4.0
# Epoch 12/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1574
#  - Oracle (80-th perc.) = 3.2347
#  - Ground-thruth (80-th perc.) = 3.3455
#  - Ground-thruth (95-th perc.) = 3.3554
#  - Ground-thruth (100-th perc.) = 3.3755
#  - Edit distance (median) = 5.0
# Epoch 13/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1578
#  - Oracle (80-th perc.) = 3.2489
#  - Ground-thruth (80-th perc.) = 3.3307
#  - Ground-thruth (95-th perc.) = 3.3455
#  - Ground-thruth (100-th perc.) = 3.363
#  - Edit distance (median) = 4.0
# Epoch 14/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1571
#  - Oracle (80-th perc.) = 3.2214
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3589
#  - Ground-thruth (100-th perc.) = 3.425
#  - Edit distance (median) = 4.0
# Epoch 15/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1567
#  - Oracle (80-th perc.) = 3.2315
#  - Ground-thruth (80-th perc.) = 3.3411
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 4.0
# Epoch 16/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1567
#  - Oracle (80-th perc.) = 3.2104
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.363
#  - Ground-thruth (100-th perc.) = 3.425
#  - Edit distance (median) = 3.0
# Epoch 17/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1550
#  - Oracle (80-th perc.) = 3.2194
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3556
#  - Ground-thruth (100-th perc.) = 3.425
#  - Edit distance (median) = 3.0
# Epoch 18/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1547
#  - Oracle (80-th perc.) = 3.2119
#  - Ground-thruth (80-th perc.) = 3.3552
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 4.0
# Epoch 19/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1539
#  - Oracle (80-th perc.) = 3.225
#  - Ground-thruth (80-th perc.) = 3.3411
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 5.0
# Epoch 20/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1513
#  - Oracle (80-th perc.) = 3.1919
#  - Ground-thruth (80-th perc.) = 3.3083
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 4.0
# Epoch 21/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1463
#  - Oracle (80-th perc.) = 3.2213
#  - Ground-thruth (80-th perc.) = 3.3057
#  - Ground-thruth (95-th perc.) = 3.3387
#  - Ground-thruth (100-th perc.) = 3.3799
#  - Edit distance (median) = 5.0
# Epoch 22/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1461
#  - Oracle (80-th perc.) = 3.2004
#  - Ground-thruth (80-th perc.) = 3.3033
#  - Ground-thruth (95-th perc.) = 3.3281
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 4.0
# Epoch 23/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1460
#  - Oracle (80-th perc.) = 3.2357
#  - Ground-thruth (80-th perc.) = 3.3049
#  - Ground-thruth (95-th perc.) = 3.3404
#  - Ground-thruth (100-th perc.) = 3.3569
#  - Edit distance (median) = 5.0
# Epoch 24/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1456
#  - Oracle (80-th perc.) = 3.209
#  - Ground-thruth (80-th perc.) = 3.3025
#  - Ground-thruth (95-th perc.) = 3.3094
#  - Ground-thruth (100-th perc.) = 3.3647
#  - Edit distance (median) = 5.0
# Epoch 25/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1460
#  - Oracle (80-th perc.) = 3.1973
#  - Ground-thruth (80-th perc.) = 3.2802
#  - Ground-thruth (95-th perc.) = 3.3081
#  - Ground-thruth (100-th perc.) = 3.3689
#  - Edit distance (median) = 4.5
# Epoch 26/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1461
#  - Oracle (80-th perc.) = 3.2079
#  - Ground-thruth (80-th perc.) = 3.3057
#  - Ground-thruth (95-th perc.) = 3.3386
#  - Ground-thruth (100-th perc.) = 3.4045
#  - Edit distance (median) = 5.0
# Epoch 27/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1461
#  - Oracle (80-th perc.) = 3.2133
#  - Ground-thruth (80-th perc.) = 3.3152
#  - Ground-thruth (95-th perc.) = 3.3552
#  - Ground-thruth (100-th perc.) = 3.425
#  - Edit distance (median) = 3.5
# Epoch 28/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1458
#  - Oracle (80-th perc.) = 3.2145
#  - Ground-thruth (80-th perc.) = 3.3098
#  - Ground-thruth (95-th perc.) = 3.3411
#  - Ground-thruth (100-th perc.) = 3.3964
#  - Edit distance (median) = 4.0
# Epoch 29/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1457
#  - Oracle (80-th perc.) = 3.2352
#  - Ground-thruth (80-th perc.) = 3.3035
#  - Ground-thruth (95-th perc.) = 3.3372
#  - Ground-thruth (100-th perc.) = 3.3964
#  - Edit distance (median) = 5.0
# Epoch 30/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1447
#  - Oracle (80-th perc.) = 3.2431
#  - Ground-thruth (80-th perc.) = 3.2848
#  - Ground-thruth (95-th perc.) = 3.3036
#  - Ground-thruth (100-th perc.) = 3.3371
#  - Edit distance (median) = 6.0
# Epoch 31/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1461
#  - Oracle (80-th perc.) = 3.2434
#  - Ground-thruth (80-th perc.) = 3.303
#  - Ground-thruth (95-th perc.) = 3.3378
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 6.0
# Epoch 32/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1453
#  - Oracle (80-th perc.) = 3.2215
#  - Ground-thruth (80-th perc.) = 3.3039
#  - Ground-thruth (95-th perc.) = 3.3577
#  - Ground-thruth (100-th perc.) = 3.425
#  - Edit distance (median) = 5.0
# Epoch 33/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1451
#  - Oracle (80-th perc.) = 3.2032
#  - Ground-thruth (80-th perc.) = 3.3025
#  - Ground-thruth (95-th perc.) = 3.3373
#  - Ground-thruth (100-th perc.) = 3.3559
#  - Edit distance (median) = 4.0
# Epoch 34/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1451
#  - Oracle (80-th perc.) = 3.1954
#  - Ground-thruth (80-th perc.) = 3.3057
#  - Ground-thruth (95-th perc.) = 3.3372
#  - Ground-thruth (100-th perc.) = 3.3622
#  - Edit distance (median) = 5.0
# Epoch 35/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1445
#  - Oracle (80-th perc.) = 3.2109
#  - Ground-thruth (80-th perc.) = 3.3051
#  - Ground-thruth (95-th perc.) = 3.3394
#  - Ground-thruth (100-th perc.) = 3.4045
#  - Edit distance (median) = 5.0
# Epoch 36/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1458
#  - Oracle (80-th perc.) = 3.232
#  - Ground-thruth (80-th perc.) = 3.3029
#  - Ground-thruth (95-th perc.) = 3.3387
#  - Ground-thruth (100-th perc.) = 3.3964
#  - Edit distance (median) = 5.0
# Epoch 37/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1437
#  - Oracle (80-th perc.) = 3.2088
#  - Ground-thruth (80-th perc.) = 3.3134
#  - Ground-thruth (95-th perc.) = 3.3386
#  - Ground-thruth (100-th perc.) = 3.3917
#  - Edit distance (median) = 4.0
# Epoch 38/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1449
#  - Oracle (80-th perc.) = 3.2155
#  - Ground-thruth (80-th perc.) = 3.3025
#  - Ground-thruth (95-th perc.) = 3.338
#  - Ground-thruth (100-th perc.) = 3.3861
#  - Edit distance (median) = 5.0
# Epoch 39/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1448
#  - Oracle (80-th perc.) = 3.2258
#  - Ground-thruth (80-th perc.) = 3.3097
#  - Ground-thruth (95-th perc.) = 3.3866
#  - Ground-thruth (100-th perc.) = 3.4045
#  - Edit distance (median) = 5.0
# Epoch 40/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1442
#  - Oracle (80-th perc.) = 3.2129
#  - Ground-thruth (80-th perc.) = 3.3025
#  - Ground-thruth (95-th perc.) = 3.3371
#  - Ground-thruth (100-th perc.) = 3.3861
#  - Edit distance (median) = 6.5
# Epoch 41/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1441
#  - Oracle (80-th perc.) = 3.2237
#  - Ground-thruth (80-th perc.) = 3.3026
#  - Ground-thruth (95-th perc.) = 3.3366
#  - Ground-thruth (100-th perc.) = 3.4045
#  - Edit distance (median) = 5.0
# Epoch 42/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1436
#  - Oracle (80-th perc.) = 3.2295
#  - Ground-thruth (80-th perc.) = 3.3025
#  - Ground-thruth (95-th perc.) = 3.3133
#  - Ground-thruth (100-th perc.) = 3.3763
#  - Edit distance (median) = 5.0
# Epoch 43/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1447
#  - Oracle (80-th perc.) = 3.2151
#  - Ground-thruth (80-th perc.) = 3.3051
#  - Ground-thruth (95-th perc.) = 3.3389
#  - Ground-thruth (100-th perc.) = 3.4045
#  - Edit distance (median) = 5.0
# Epoch 44/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1432
#  - Oracle (80-th perc.) = 3.2548
#  - Ground-thruth (80-th perc.) = 3.2913
#  - Ground-thruth (95-th perc.) = 3.3371
#  - Ground-thruth (100-th perc.) = 3.3552
#  - Edit distance (median) = 8.0
# Epoch 45/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1438
#  - Oracle (80-th perc.) = 3.2035
#  - Ground-thruth (80-th perc.) = 3.3025
#  - Ground-thruth (95-th perc.) = 3.3537
#  - Ground-thruth (100-th perc.) = 3.4045
#  - Edit distance (median) = 4.0
# Epoch 46/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1440
#  - Oracle (80-th perc.) = 3.2069
#  - Ground-thruth (80-th perc.) = 3.3121
#  - Ground-thruth (95-th perc.) = 3.3372
#  - Ground-thruth (100-th perc.) = 3.3861
#  - Edit distance (median) = 5.0
# Epoch 47/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1426
#  - Oracle (80-th perc.) = 3.2051
#  - Ground-thruth (80-th perc.) = 3.3025
#  - Ground-thruth (95-th perc.) = 3.3386
#  - Ground-thruth (100-th perc.) = 3.4045
#  - Edit distance (median) = 5.0
# Epoch 48/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1420
#  - Oracle (80-th perc.) = 3.2154
#  - Ground-thruth (80-th perc.) = 3.3239
#  - Ground-thruth (95-th perc.) = 3.3386
#  - Ground-thruth (100-th perc.) = 3.3559
#  - Edit distance (median) = 6.0
# Epoch 49/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1426
#  - Oracle (80-th perc.) = 3.2199
#  - Ground-thruth (80-th perc.) = 3.3025
#  - Ground-thruth (95-th perc.) = 3.3321
#  - Ground-thruth (100-th perc.) = 3.3964
#  - Edit distance (median) = 6.0
# Epoch 50/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1439
#  - Oracle (80-th perc.) = 3.2233
#  - Ground-thruth (80-th perc.) = 3.3009
#  - Ground-thruth (95-th perc.) = 3.3372
#  - Ground-thruth (100-th perc.) = 3.3861
#  - Edit distance (median) = 7.0
#  - Oracle (80-th perc.) = -0.6325
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 203.0
# Epoch 1/50
# 100/100 [==============================] - 9s 91ms/step - loss: 7.9676
#  - Oracle (80-th perc.) = 3.4098
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 81.5
# Epoch 2/50
# 100/100 [==============================] - 6s 61ms/step - loss: 2.2583
#  - Oracle (80-th perc.) = 3.2215
#  - Ground-thruth (80-th perc.) = 2.9549
#  - Ground-thruth (95-th perc.) = 2.9748
#  - Ground-thruth (100-th perc.) = 3.0036
#  - Edit distance (median) = 11.0
# Epoch 3/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1987
#  - Oracle (80-th perc.) = 3.2025
#  - Ground-thruth (80-th perc.) = 3.2919
#  - Ground-thruth (95-th perc.) = 3.3265
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 4.0
# Epoch 4/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1528
#  - Oracle (80-th perc.) = 3.2231
#  - Ground-thruth (80-th perc.) = 3.2764
#  - Ground-thruth (95-th perc.) = 3.3229
#  - Ground-thruth (100-th perc.) = 3.335
#  - Edit distance (median) = 4.0
# Epoch 5/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1523
#  - Oracle (80-th perc.) = 3.1893
#  - Ground-thruth (80-th perc.) = 3.2842
#  - Ground-thruth (95-th perc.) = 3.3017
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 3.0
# Epoch 6/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1500
#  - Oracle (80-th perc.) = 3.2785
#  - Ground-thruth (80-th perc.) = 3.2996
#  - Ground-thruth (95-th perc.) = 3.3321
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 5.0
# Epoch 7/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1468
#  - Oracle (80-th perc.) = 3.2839
#  - Ground-thruth (80-th perc.) = 3.2739
#  - Ground-thruth (95-th perc.) = 3.3024
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 4.5
# Epoch 8/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1463
#  - Oracle (80-th perc.) = 3.2714
#  - Ground-thruth (80-th perc.) = 3.2902
#  - Ground-thruth (95-th perc.) = 3.3232
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 4.0
# Epoch 9/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1449
#  - Oracle (80-th perc.) = 3.2577
#  - Ground-thruth (80-th perc.) = 3.2848
#  - Ground-thruth (95-th perc.) = 3.3215
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 6.0
# Epoch 10/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1439
#  - Oracle (80-th perc.) = 3.2074
#  - Ground-thruth (80-th perc.) = 3.2996
#  - Ground-thruth (95-th perc.) = 3.3299
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 3.0
# Epoch 11/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1426
#  - Oracle (80-th perc.) = 3.2132
#  - Ground-thruth (80-th perc.) = 3.2751
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 4.0
# Epoch 12/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1424
#  - Oracle (80-th perc.) = 3.2026
#  - Ground-thruth (80-th perc.) = 3.2827
#  - Ground-thruth (95-th perc.) = 3.3243
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 3.0
# Epoch 13/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1429
#  - Oracle (80-th perc.) = 3.2937
#  - Ground-thruth (80-th perc.) = 3.2743
#  - Ground-thruth (95-th perc.) = 3.3056
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 6.0
# Epoch 14/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1418
#  - Oracle (80-th perc.) = 3.2697
#  - Ground-thruth (80-th perc.) = 3.2766
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 5.0
# Epoch 15/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1401
#  - Oracle (80-th perc.) = 3.202
#  - Ground-thruth (80-th perc.) = 3.2833
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 4.0
# Epoch 16/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1416
#  - Oracle (80-th perc.) = 3.2469
#  - Ground-thruth (80-th perc.) = 3.2855
#  - Ground-thruth (95-th perc.) = 3.3243
#  - Ground-thruth (100-th perc.) = 3.3471
#  - Edit distance (median) = 4.0
# Epoch 17/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1413
#  - Oracle (80-th perc.) = 3.2412
#  - Ground-thruth (80-th perc.) = 3.2842
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 4.5
# Epoch 18/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1428
#  - Oracle (80-th perc.) = 3.1864
#  - Ground-thruth (80-th perc.) = 3.2919
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3471
#  - Edit distance (median) = 3.5
# Epoch 19/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1414
#  - Oracle (80-th perc.) = 3.2137
#  - Ground-thruth (80-th perc.) = 3.2816
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 3.0
# Epoch 20/50
# 100/100 [==============================] - 6s 59ms/step - loss: 0.1405
#  - Oracle (80-th perc.) = 3.2324
#  - Ground-thruth (80-th perc.) = 3.2855
#  - Ground-thruth (95-th perc.) = 3.3229
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 5.0
# Epoch 21/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1402
#  - Oracle (80-th perc.) = 3.219
#  - Ground-thruth (80-th perc.) = 3.2802
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 4.5
# Epoch 22/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1386
#  - Oracle (80-th perc.) = 3.2235
#  - Ground-thruth (80-th perc.) = 3.298
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 5.0
# Epoch 23/50
# 100/100 [==============================] - 6s 59ms/step - loss: 0.1395
#  - Oracle (80-th perc.) = 3.2282
#  - Ground-thruth (80-th perc.) = 3.2709
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3376
#  - Edit distance (median) = 4.5
# Epoch 24/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1386
#  - Oracle (80-th perc.) = 3.2101
#  - Ground-thruth (80-th perc.) = 3.2885
#  - Ground-thruth (95-th perc.) = 3.3299
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 5.0
# Epoch 25/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1380
#  - Oracle (80-th perc.) = 3.2189
#  - Ground-thruth (80-th perc.) = 3.2805
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 4.5
# Epoch 26/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1374
#  - Oracle (80-th perc.) = 3.1995
#  - Ground-thruth (80-th perc.) = 3.3079
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3377
#  - Edit distance (median) = 3.0
# Epoch 27/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1361
#  - Oracle (80-th perc.) = 3.228
#  - Ground-thruth (80-th perc.) = 3.2814
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3263
#  - Edit distance (median) = 4.0
# Epoch 28/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1357
#  - Oracle (80-th perc.) = 3.1996
#  - Ground-thruth (80-th perc.) = 3.3043
#  - Ground-thruth (95-th perc.) = 3.3261
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 3.0
# Epoch 29/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1361
#  - Oracle (80-th perc.) = 3.2139
#  - Ground-thruth (80-th perc.) = 3.2904
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.339
#  - Edit distance (median) = 4.0
# Epoch 30/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1368
#  - Oracle (80-th perc.) = 3.2003
#  - Ground-thruth (80-th perc.) = 3.2837
#  - Ground-thruth (95-th perc.) = 3.3265
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 4.0
# Epoch 31/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1366
#  - Oracle (80-th perc.) = 3.2235
#  - Ground-thruth (80-th perc.) = 3.3036
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3421
#  - Edit distance (median) = 4.0
# Epoch 32/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1360
#  - Oracle (80-th perc.) = 3.2063
#  - Ground-thruth (80-th perc.) = 3.2848
#  - Ground-thruth (95-th perc.) = 3.3094
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 4.0
# Epoch 33/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1357
#  - Oracle (80-th perc.) = 3.2102
#  - Ground-thruth (80-th perc.) = 3.2836
#  - Ground-thruth (95-th perc.) = 3.3222
#  - Ground-thruth (100-th perc.) = 3.3263
#  - Edit distance (median) = 4.0
# Epoch 34/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1356
#  - Oracle (80-th perc.) = 3.2162
#  - Ground-thruth (80-th perc.) = 3.2984
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 6.0
# Epoch 35/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1355
#  - Oracle (80-th perc.) = 3.1986
#  - Ground-thruth (80-th perc.) = 3.3041
#  - Ground-thruth (95-th perc.) = 3.3261
#  - Ground-thruth (100-th perc.) = 3.3421
#  - Edit distance (median) = 4.0
# Epoch 36/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1360
#  - Oracle (80-th perc.) = 3.2102
#  - Ground-thruth (80-th perc.) = 3.3035
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 4.0
# Epoch 37/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1361
#  - Oracle (80-th perc.) = 3.2019
#  - Ground-thruth (80-th perc.) = 3.2769
#  - Ground-thruth (95-th perc.) = 3.3179
#  - Ground-thruth (100-th perc.) = 3.3263
#  - Edit distance (median) = 5.0
# Epoch 38/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1357
#  - Oracle (80-th perc.) = 3.2065
#  - Ground-thruth (80-th perc.) = 3.2868
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 4.5
# Epoch 39/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1359
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.287
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 4.0
# Epoch 40/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1353
#  - Oracle (80-th perc.) = 3.2052
#  - Ground-thruth (80-th perc.) = 3.2982
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3263
#  - Edit distance (median) = 4.5
# Epoch 41/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1359
#  - Oracle (80-th perc.) = 3.2137
#  - Ground-thruth (80-th perc.) = 3.319
#  - Ground-thruth (95-th perc.) = 3.3265
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 4.0
# Epoch 42/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1356
#  - Oracle (80-th perc.) = 3.2119
#  - Ground-thruth (80-th perc.) = 3.3019
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 5.0
# Epoch 43/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1348
#  - Oracle (80-th perc.) = 3.2056
#  - Ground-thruth (80-th perc.) = 3.2825
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3318
#  - Edit distance (median) = 5.0
# Epoch 44/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1363
#  - Oracle (80-th perc.) = 3.2206
#  - Ground-thruth (80-th perc.) = 3.3042
#  - Ground-thruth (95-th perc.) = 3.3264
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 4.0
# Epoch 45/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1351
#  - Oracle (80-th perc.) = 3.2122
#  - Ground-thruth (80-th perc.) = 3.2861
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 4.0
# Epoch 46/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1354
#  - Oracle (80-th perc.) = 3.2062
#  - Ground-thruth (80-th perc.) = 3.2826
#  - Ground-thruth (95-th perc.) = 3.3222
#  - Ground-thruth (100-th perc.) = 3.3263
#  - Edit distance (median) = 5.0
# Epoch 47/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1350
#  - Oracle (80-th perc.) = 3.2019
#  - Ground-thruth (80-th perc.) = 3.3046
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 5.0
# Epoch 48/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1349
#  - Oracle (80-th perc.) = 3.2113
#  - Ground-thruth (80-th perc.) = 3.2823
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3358
#  - Edit distance (median) = 5.0
# Epoch 49/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1348
#  - Oracle (80-th perc.) = 3.1905
#  - Ground-thruth (80-th perc.) = 3.2913
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3376
#  - Edit distance (median) = 4.0
# Epoch 50/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1343
#  - Oracle (80-th perc.) = 3.2063
#  - Ground-thruth (80-th perc.) = 3.2861
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3261
#  - Edit distance (median) = 5.0
#  - Oracle (80-th perc.) = -0.3775
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 203.0
# Epoch 1/50
# 100/100 [==============================] - 10s 98ms/step - loss: 8.0600
#  - Oracle (80-th perc.) = 3.4337
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 85.0
# Epoch 2/50
# 100/100 [==============================] - 6s 64ms/step - loss: 2.1056
#  - Oracle (80-th perc.) = 3.2323
#  - Ground-thruth (80-th perc.) = 3.1929
#  - Ground-thruth (95-th perc.) = 3.242
#  - Ground-thruth (100-th perc.) = 3.2758
#  - Edit distance (median) = 5.0
# Epoch 3/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1665
#  - Oracle (80-th perc.) = 3.3197
#  - Ground-thruth (80-th perc.) = 3.2538
#  - Ground-thruth (95-th perc.) = 3.2742
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 3.0
# Epoch 4/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1651
#  - Oracle (80-th perc.) = 3.2272
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2768
#  - Ground-thruth (100-th perc.) = 3.307
#  - Edit distance (median) = 2.0
# Epoch 5/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1650
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2616
#  - Ground-thruth (100-th perc.) = 3.2705
#  - Edit distance (median) = 1.0
# Epoch 6/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1639
#  - Oracle (80-th perc.) = 3.2063
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.2731
#  - Edit distance (median) = 2.0
# Epoch 7/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1620
#  - Oracle (80-th perc.) = 3.2487
#  - Ground-thruth (80-th perc.) = 3.2487
#  - Ground-thruth (95-th perc.) = 3.2675
#  - Ground-thruth (100-th perc.) = 3.2786
#  - Edit distance (median) = 2.0
# Epoch 8/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1596
#  - Oracle (80-th perc.) = 3.2077
#  - Ground-thruth (80-th perc.) = 3.2618
#  - Ground-thruth (95-th perc.) = 3.2787
#  - Ground-thruth (100-th perc.) = 3.3171
#  - Edit distance (median) = 1.0
# Epoch 9/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1582
#  - Oracle (80-th perc.) = 3.2176
#  - Ground-thruth (80-th perc.) = 3.2632
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 2.0
# Epoch 10/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1586
#  - Oracle (80-th perc.) = 3.2959
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2629
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 4.0
# Epoch 11/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1581
#  - Oracle (80-th perc.) = 3.2295
#  - Ground-thruth (80-th perc.) = 3.2519
#  - Ground-thruth (95-th perc.) = 3.2746
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 2.0
# Epoch 12/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1581
#  - Oracle (80-th perc.) = 3.2018
#  - Ground-thruth (80-th perc.) = 3.259
#  - Ground-thruth (95-th perc.) = 3.2731
#  - Ground-thruth (100-th perc.) = 3.2751
#  - Edit distance (median) = 2.0
# Epoch 13/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1575
#  - Oracle (80-th perc.) = 3.3479
#  - Ground-thruth (80-th perc.) = 3.2532
#  - Ground-thruth (95-th perc.) = 3.2852
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 5.0
# Epoch 14/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1578
#  - Oracle (80-th perc.) = 3.2041
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2636
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 2.0
# Epoch 15/50
# 100/100 [==============================] - 6s 59ms/step - loss: 0.1568
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2663
#  - Ground-thruth (100-th perc.) = 3.2786
#  - Edit distance (median) = 2.0
# Epoch 16/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1563
#  - Oracle (80-th perc.) = 3.208
#  - Ground-thruth (80-th perc.) = 3.2618
#  - Ground-thruth (95-th perc.) = 3.274
#  - Ground-thruth (100-th perc.) = 3.2796
#  - Edit distance (median) = 2.0
# Epoch 17/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1570
#  - Oracle (80-th perc.) = 3.2495
#  - Ground-thruth (80-th perc.) = 3.2512
#  - Ground-thruth (95-th perc.) = 3.274
#  - Ground-thruth (100-th perc.) = 3.2796
#  - Edit distance (median) = 3.0
# Epoch 18/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1557
#  - Oracle (80-th perc.) = 3.213
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.2796
#  - Edit distance (median) = 3.0
# Epoch 19/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1542
#  - Oracle (80-th perc.) = 3.213
#  - Ground-thruth (80-th perc.) = 3.2502
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 2.0
# Epoch 20/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1539
#  - Oracle (80-th perc.) = 3.2029
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2731
#  - Ground-thruth (100-th perc.) = 3.321
#  - Edit distance (median) = 3.0
# Epoch 21/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1551
#  - Oracle (80-th perc.) = 3.2106
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.2697
#  - Edit distance (median) = 2.0
# Epoch 22/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1537
#  - Oracle (80-th perc.) = 3.2171
#  - Ground-thruth (80-th perc.) = 3.2505
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.2697
#  - Edit distance (median) = 3.0
# Epoch 23/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1525
#  - Oracle (80-th perc.) = 3.2298
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.2786
#  - Edit distance (median) = 5.0
# Epoch 24/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1529
#  - Oracle (80-th perc.) = 3.2072
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2659
#  - Ground-thruth (100-th perc.) = 3.2796
#  - Edit distance (median) = 2.0
# Epoch 25/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1533
#  - Oracle (80-th perc.) = 3.2098
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.266
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 2.0
# Epoch 26/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1525
#  - Oracle (80-th perc.) = 3.2152
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2697
#  - Ground-thruth (100-th perc.) = 3.2796
#  - Edit distance (median) = 4.5
# Epoch 27/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1525
#  - Oracle (80-th perc.) = 3.2167
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.274
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 3.0
# Epoch 28/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1520
#  - Oracle (80-th perc.) = 3.202
#  - Ground-thruth (80-th perc.) = 3.2588
#  - Ground-thruth (95-th perc.) = 3.2616
#  - Ground-thruth (100-th perc.) = 3.2834
#  - Edit distance (median) = 2.5
# Epoch 29/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1530
#  - Oracle (80-th perc.) = 3.2019
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 2.5
# Epoch 30/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1527
#  - Oracle (80-th perc.) = 3.2194
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 3.0
# Epoch 31/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1527
#  - Oracle (80-th perc.) = 3.2099
#  - Ground-thruth (80-th perc.) = 3.2592
#  - Ground-thruth (95-th perc.) = 3.2666
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 4.0
# Epoch 32/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1522
#  - Oracle (80-th perc.) = 3.2102
#  - Ground-thruth (80-th perc.) = 3.2492
#  - Ground-thruth (95-th perc.) = 3.2697
#  - Ground-thruth (100-th perc.) = 3.2731
#  - Edit distance (median) = 3.5
# Epoch 33/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1531
#  - Oracle (80-th perc.) = 3.2135
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2624
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 3.0
# Epoch 34/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1526
#  - Oracle (80-th perc.) = 3.212
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.2786
#  - Edit distance (median) = 3.0
# Epoch 35/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1525
#  - Oracle (80-th perc.) = 3.2276
#  - Ground-thruth (80-th perc.) = 3.2503
#  - Ground-thruth (95-th perc.) = 3.2699
#  - Ground-thruth (100-th perc.) = 3.2926
#  - Edit distance (median) = 2.0
# Epoch 36/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1531
#  - Oracle (80-th perc.) = 3.213
#  - Ground-thruth (80-th perc.) = 3.2521
#  - Ground-thruth (95-th perc.) = 3.276
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 3.0
# Epoch 37/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1511
#  - Oracle (80-th perc.) = 3.2044
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 3.0
# Epoch 38/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1526
#  - Oracle (80-th perc.) = 3.2103
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2741
#  - Ground-thruth (100-th perc.) = 3.321
#  - Edit distance (median) = 3.0
# Epoch 39/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1529
#  - Oracle (80-th perc.) = 3.2077
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.274
#  - Ground-thruth (100-th perc.) = 3.2879
#  - Edit distance (median) = 2.0
# Epoch 40/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1523
#  - Oracle (80-th perc.) = 3.2088
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2741
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 2.0
# Epoch 41/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1521
#  - Oracle (80-th perc.) = 3.213
#  - Ground-thruth (80-th perc.) = 3.2625
#  - Ground-thruth (95-th perc.) = 3.2699
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 4.5
# Epoch 42/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1525
#  - Oracle (80-th perc.) = 3.2473
#  - Ground-thruth (80-th perc.) = 3.2532
#  - Ground-thruth (95-th perc.) = 3.2787
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 3.0
# Epoch 43/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1520
#  - Oracle (80-th perc.) = 3.2109
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.276
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 3.5
# Epoch 44/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1524
#  - Oracle (80-th perc.) = 3.2526
#  - Ground-thruth (80-th perc.) = 3.2497
#  - Ground-thruth (95-th perc.) = 3.2676
#  - Ground-thruth (100-th perc.) = 3.2813
#  - Edit distance (median) = 3.0
# Epoch 45/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1520
#  - Oracle (80-th perc.) = 3.2308
#  - Ground-thruth (80-th perc.) = 3.2504
#  - Ground-thruth (95-th perc.) = 3.2743
#  - Ground-thruth (100-th perc.) = 3.3228
#  - Edit distance (median) = 3.0
# Epoch 46/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1515
#  - Oracle (80-th perc.) = 3.2026
#  - Ground-thruth (80-th perc.) = 3.2574
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 3.5
# Epoch 47/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1508
#  - Oracle (80-th perc.) = 3.2132
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2666
#  - Ground-thruth (100-th perc.) = 3.3122
#  - Edit distance (median) = 3.0
# Epoch 48/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.1521
#  - Oracle (80-th perc.) = 3.2101
#  - Ground-thruth (80-th perc.) = 3.2625
#  - Ground-thruth (95-th perc.) = 3.2786
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 4.0
# Epoch 49/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1517
#  - Oracle (80-th perc.) = 3.2053
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 4.0
# Epoch 50/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1515
#  - Oracle (80-th perc.) = 3.213
#  - Ground-thruth (80-th perc.) = 3.2511
#  - Ground-thruth (95-th perc.) = 3.2786
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 2.0
#  - Oracle (80-th perc.) = -1.7711
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 205.0
# Epoch 1/50
# 100/100 [==============================] - 11s 109ms/step - loss: 9.2817
#  - Oracle (80-th perc.) = 2.094
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 71.0
# Epoch 2/50
# 100/100 [==============================] - 8s 79ms/step - loss: 4.2252
#  - Oracle (80-th perc.) = 3.1283
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 28.5
# Epoch 3/50
# 100/100 [==============================] - 7s 74ms/step - loss: 0.4589
#  - Oracle (80-th perc.) = 3.1974
#  - Ground-thruth (80-th perc.) = 3.3418
#  - Ground-thruth (95-th perc.) = 3.3656
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 4.0
# Epoch 4/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1381
#  - Oracle (80-th perc.) = 3.2144
#  - Ground-thruth (80-th perc.) = 3.3279
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4058
#  - Edit distance (median) = 3.0
# Epoch 5/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1376
#  - Oracle (80-th perc.) = 3.2095
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3421
#  - Ground-thruth (100-th perc.) = 3.3562
#  - Edit distance (median) = 3.0
# Epoch 6/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1374
#  - Oracle (80-th perc.) = 3.1913
#  - Ground-thruth (80-th perc.) = 3.3421
#  - Ground-thruth (95-th perc.) = 3.3887
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 2.0
# Epoch 7/50
# 100/100 [==============================] - 7s 73ms/step - loss: 0.1368
#  - Oracle (80-th perc.) = 3.1777
#  - Ground-thruth (80-th perc.) = 3.3054
#  - Ground-thruth (95-th perc.) = 3.3421
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 1.0
# Epoch 8/50
# 100/100 [==============================] - 8s 81ms/step - loss: 0.1362
#  - Oracle (80-th perc.) = 3.206
#  - Ground-thruth (80-th perc.) = 3.3471
#  - Ground-thruth (95-th perc.) = 3.3996
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 3.0
# Epoch 9/50
# 100/100 [==============================] - 8s 78ms/step - loss: 0.1351
#  - Oracle (80-th perc.) = 3.1933
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3633
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 2.0
# Epoch 10/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1348
#  - Oracle (80-th perc.) = 3.1986
#  - Ground-thruth (80-th perc.) = 3.3235
#  - Ground-thruth (95-th perc.) = 3.3562
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 2.0
# Epoch 11/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.1348
#  - Oracle (80-th perc.) = 3.1933
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 2.0
# Epoch 12/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1339
#  - Oracle (80-th perc.) = 3.1876
#  - Ground-thruth (80-th perc.) = 3.329
#  - Ground-thruth (95-th perc.) = 3.3562
#  - Ground-thruth (100-th perc.) = 3.3986
#  - Edit distance (median) = 2.0
# Epoch 13/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1344
#  - Oracle (80-th perc.) = 3.1986
#  - Ground-thruth (80-th perc.) = 3.3234
#  - Ground-thruth (95-th perc.) = 3.362
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 2.0
# Epoch 14/50
# 100/100 [==============================] - 8s 76ms/step - loss: 0.1335
#  - Oracle (80-th perc.) = 3.224
#  - Ground-thruth (80-th perc.) = 3.2832
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 3.0
# Epoch 15/50
# 100/100 [==============================] - 8s 80ms/step - loss: 0.1331
#  - Oracle (80-th perc.) = 3.1927
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3558
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 2.5
# Epoch 16/50
# 100/100 [==============================] - 7s 75ms/step - loss: 0.1329
#  - Oracle (80-th perc.) = 3.1926
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3565
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 2.0
# Epoch 17/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1328
#  - Oracle (80-th perc.) = 3.1929
#  - Ground-thruth (80-th perc.) = 3.3185
#  - Ground-thruth (95-th perc.) = 3.3565
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 2.0
# Epoch 18/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.1326
#  - Oracle (80-th perc.) = 3.1936
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3575
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 3.0
# Epoch 19/50
# ...
#  - Oracle (80-th perc.) = 3.2077
#  - Ground-thruth (80-th perc.) = 3.329
#  - Ground-thruth (95-th perc.) = 3.3815
#  - Ground-thruth (100-th perc.) = 3.4199
#  - Edit distance (median) = 7.0
# Epoch 43/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1336
#  - Oracle (80-th perc.) = 3.2055
#  - Ground-thruth (80-th perc.) = 3.3257
#  - Ground-thruth (95-th perc.) = 3.4046
#  - Ground-thruth (100-th perc.) = 3.4809
#  - Edit distance (median) = 6.5
# Epoch 44/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1340
#  - Oracle (80-th perc.) = 3.2142
#  - Ground-thruth (80-th perc.) = 3.3113
#  - Ground-thruth (95-th perc.) = 3.3558
#  - Ground-thruth (100-th perc.) = 3.4809
#  - Edit distance (median) = 8.0
# Epoch 45/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1331
#  - Oracle (80-th perc.) = 3.216
#  - Ground-thruth (80-th perc.) = 3.3173
#  - Ground-thruth (95-th perc.) = 3.3931
#  - Ground-thruth (100-th perc.) = 3.4753
#  - Edit distance (median) = 8.0
# Epoch 46/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1335
#  - Oracle (80-th perc.) = 3.2142
#  - Ground-thruth (80-th perc.) = 3.3234
#  - Ground-thruth (95-th perc.) = 3.4071
#  - Ground-thruth (100-th perc.) = 3.4356
#  - Edit distance (median) = 7.0
# Epoch 47/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1333
#  - Oracle (80-th perc.) = 3.2163
#  - Ground-thruth (80-th perc.) = 3.3316
#  - Ground-thruth (95-th perc.) = 3.4131
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 7.5
# Epoch 48/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1334
#  - Oracle (80-th perc.) = 3.2101
#  - Ground-thruth (80-th perc.) = 3.3277
#  - Ground-thruth (95-th perc.) = 3.3794
#  - Ground-thruth (100-th perc.) = 3.4599
#  - Edit distance (median) = 7.0
# Epoch 49/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1331
#  - Oracle (80-th perc.) = 3.2122
#  - Ground-thruth (80-th perc.) = 3.3161
#  - Ground-thruth (95-th perc.) = 3.3966
#  - Ground-thruth (100-th perc.) = 3.4349
#  - Edit distance (median) = 8.0
# Epoch 50/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1328
#  - Oracle (80-th perc.) = 3.2035
#  - Ground-thruth (80-th perc.) = 3.3588
#  - Ground-thruth (95-th perc.) = 3.4122
#  - Ground-thruth (100-th perc.) = 3.4599
#  - Edit distance (median) = 6.0
#  - Oracle (80-th perc.) = -1.95
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 203.0
# Epoch 1/50
# 100/100 [==============================] - 11s 108ms/step - loss: 8.0324
#  - Oracle (80-th perc.) = 2.6325
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 70.0
# Epoch 2/50
# 100/100 [==============================] - 6s 64ms/step - loss: 2.0115
#  - Oracle (80-th perc.) = 3.212
#  - Ground-thruth (80-th perc.) = 3.1758
#  - Ground-thruth (95-th perc.) = 3.2223
#  - Ground-thruth (100-th perc.) = 3.255
#  - Edit distance (median) = 7.5
# Epoch 3/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.1662
#  - Oracle (80-th perc.) = 3.2118
#  - Ground-thruth (80-th perc.) = 3.2978
#  - Ground-thruth (95-th perc.) = 3.3369
#  - Ground-thruth (100-th perc.) = 3.3767
#  - Edit distance (median) = 7.0
# Epoch 4/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1548
#  - Oracle (80-th perc.) = 3.2177
#  - Ground-thruth (80-th perc.) = 3.3052
#  - Ground-thruth (95-th perc.) = 3.3439
#  - Ground-thruth (100-th perc.) = 3.3799
#  - Edit distance (median) = 7.0
# Epoch 5/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1561
#  - Oracle (80-th perc.) = 3.2015
#  - Ground-thruth (80-th perc.) = 3.3434
#  - Ground-thruth (95-th perc.) = 3.3578
#  - Ground-thruth (100-th perc.) = 3.3883
#  - Edit distance (median) = 4.0
# Epoch 6/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1540
#  - Oracle (80-th perc.) = 3.2105
#  - Ground-thruth (80-th perc.) = 3.3292
#  - Ground-thruth (95-th perc.) = 3.3503
#  - Ground-thruth (100-th perc.) = 3.3586
#  - Edit distance (median) = 6.0
# Epoch 7/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1526
#  - Oracle (80-th perc.) = 3.24
#  - Ground-thruth (80-th perc.) = 3.3118
#  - Ground-thruth (95-th perc.) = 3.3278
#  - Ground-thruth (100-th perc.) = 3.3908
#  - Edit distance (median) = 5.0
# Epoch 8/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.1523
#  - Oracle (80-th perc.) = 3.218
#  - Ground-thruth (80-th perc.) = 3.3157
#  - Ground-thruth (95-th perc.) = 3.3286
#  - Ground-thruth (100-th perc.) = 3.3883
#  - Edit distance (median) = 4.0
# Epoch 9/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1510
#  - Oracle (80-th perc.) = 3.2235
#  - Ground-thruth (80-th perc.) = 3.3174
#  - Ground-thruth (95-th perc.) = 3.3446
#  - Ground-thruth (100-th perc.) = 3.3771
#  - Edit distance (median) = 4.0
# Epoch 10/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1492
#  - Oracle (80-th perc.) = 3.2093
#  - Ground-thruth (80-th perc.) = 3.3419
#  - Ground-thruth (95-th perc.) = 3.3478
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 4.0
# Epoch 11/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1458
#  - Oracle (80-th perc.) = 3.1994
#  - Ground-thruth (80-th perc.) = 3.3355
#  - Ground-thruth (95-th perc.) = 3.3706
#  - Ground-thruth (100-th perc.) = 3.3799
#  - Edit distance (median) = 4.0
# Epoch 12/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1447
#  - Oracle (80-th perc.) = 3.2304
#  - Ground-thruth (80-th perc.) = 3.337
#  - Ground-thruth (95-th perc.) = 3.3794
#  - Ground-thruth (100-th perc.) = 3.3901
#  - Edit distance (median) = 5.0
# Epoch 13/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1426
#  - Oracle (80-th perc.) = 3.2282
#  - Ground-thruth (80-th perc.) = 3.3175
#  - Ground-thruth (95-th perc.) = 3.3329
#  - Ground-thruth (100-th perc.) = 3.3745
#  - Edit distance (median) = 6.0
# Epoch 14/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1425
#  - Oracle (80-th perc.) = 3.2059
#  - Ground-thruth (80-th perc.) = 3.3437
#  - Ground-thruth (95-th perc.) = 3.3799
#  - Ground-thruth (100-th perc.) = 3.3908
#  - Edit distance (median) = 5.0
# Epoch 15/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1423
#  - Oracle (80-th perc.) = 3.2111
#  - Ground-thruth (80-th perc.) = 3.3355
#  - Ground-thruth (95-th perc.) = 3.3706
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 5.0
# Epoch 16/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1411
#  - Oracle (80-th perc.) = 3.2241
#  - Ground-thruth (80-th perc.) = 3.3183
#  - Ground-thruth (95-th perc.) = 3.3437
#  - Ground-thruth (100-th perc.) = 3.378
#  - Edit distance (median) = 6.5
# Epoch 17/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1406
#  - Oracle (80-th perc.) = 3.2044
#  - Ground-thruth (80-th perc.) = 3.3275
#  - Ground-thruth (95-th perc.) = 3.3446
#  - Ground-thruth (100-th perc.) = 3.3799
#  - Edit distance (median) = 6.0
# Epoch 18/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1401
#  - Oracle (80-th perc.) = 3.2156
#  - Ground-thruth (80-th perc.) = 3.317
#  - Ground-thruth (95-th perc.) = 3.3426
#  - Ground-thruth (100-th perc.) = 3.3799
#  - Edit distance (median) = 6.0
# Epoch 19/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.1399
#  - Oracle (80-th perc.) = 3.2329
#  - Ground-thruth (80-th perc.) = 3.3101
#  - Ground-thruth (95-th perc.) = 3.3286
#  - Ground-thruth (100-th perc.) = 3.3586
#  - Edit distance (median) = 7.0
# Epoch 20/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.1382
#  - Oracle (80-th perc.) = 3.2156
#  - Ground-thruth (80-th perc.) = 3.3361
#  - Ground-thruth (95-th perc.) = 3.3586
#  - Ground-thruth (100-th perc.) = 3.378
#  - Edit distance (median) = 6.0
# Epoch 21/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1381
#  - Oracle (80-th perc.) = 3.2142
#  - Ground-thruth (80-th perc.) = 3.327
#  - Ground-thruth (95-th perc.) = 3.3578
#  - Ground-thruth (100-th perc.) = 3.378
#  - Edit distance (median) = 4.0
# Epoch 22/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.1383
#  - Oracle (80-th perc.) = 3.2075
#  - Ground-thruth (80-th perc.) = 3.3277
#  - Ground-thruth (95-th perc.) = 3.3478
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 6.5
# Epoch 23/50
# 100/100 [==============================] - 7s 71ms/step - loss: 0.1389
#  - Oracle (80-th perc.) = 3.2066
#  - Ground-thruth (80-th perc.) = 3.3527
#  - Ground-thruth (95-th perc.) = 3.378
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 5.0
# Epoch 24/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1394
#  - Oracle (80-th perc.) = 3.2049
#  - Ground-thruth (80-th perc.) = 3.3291
#  - Ground-thruth (95-th perc.) = 3.3546
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 5.0
# Epoch 25/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.1387
#  - Oracle (80-th perc.) = 3.2149
#  - Ground-thruth (80-th perc.) = 3.3293
#  - Ground-thruth (95-th perc.) = 3.3529
#  - Ground-thruth (100-th perc.) = 3.3745
#  - Edit distance (median) = 6.0
# Epoch 26/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1370
#  - Oracle (80-th perc.) = 3.2086
#  - Ground-thruth (80-th perc.) = 3.3406
#  - Ground-thruth (95-th perc.) = 3.3799
#  - Ground-thruth (100-th perc.) = 3.3908
#  - Edit distance (median) = 6.0
# Epoch 27/50
# 100/100 [==============================] - 7s 70ms/step - loss: 0.1383
#  - Oracle (80-th perc.) = 3.2004
#  - Ground-thruth (80-th perc.) = 3.3217
#  - Ground-thruth (95-th perc.) = 3.3529
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 6.0
# Epoch 28/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1382
#  - Oracle (80-th perc.) = 3.2329
#  - Ground-thruth (80-th perc.) = 3.3099
#  - Ground-thruth (95-th perc.) = 3.3174
#  - Ground-thruth (100-th perc.) = 3.3449
#  - Edit distance (median) = 7.0
# Epoch 29/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1366
#  - Oracle (80-th perc.) = 3.2204
#  - Ground-thruth (80-th perc.) = 3.3139
#  - Ground-thruth (95-th perc.) = 3.3529
#  - Ground-thruth (100-th perc.) = 3.3908
#  - Edit distance (median) = 7.0
# Epoch 30/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.1378
#  - Oracle (80-th perc.) = 3.2235
#  - Ground-thruth (80-th perc.) = 3.3137
#  - Ground-thruth (95-th perc.) = 3.3536
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 7.0
# Epoch 31/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1378
#  - Oracle (80-th perc.) = 3.1984
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3477
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 7.0
# Epoch 32/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1368
#  - Oracle (80-th perc.) = 3.2304
#  - Ground-thruth (80-th perc.) = 3.31
#  - Ground-thruth (95-th perc.) = 3.3184
#  - Ground-thruth (100-th perc.) = 3.354
#  - Edit distance (median) = 7.5
# Epoch 33/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1372
#  - Oracle (80-th perc.) = 3.218
#  - Ground-thruth (80-th perc.) = 3.3119
#  - Ground-thruth (95-th perc.) = 3.3592
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 6.0
# Epoch 34/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.1371
#  - Oracle (80-th perc.) = 3.2077
#  - Ground-thruth (80-th perc.) = 3.3355
#  - Ground-thruth (95-th perc.) = 3.3711
#  - Ground-thruth (100-th perc.) = 3.3988
#  - Edit distance (median) = 5.0
# Epoch 35/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1366
#  - Oracle (80-th perc.) = 3.2196
#  - Ground-thruth (80-th perc.) = 3.3121
#  - Ground-thruth (95-th perc.) = 3.3473
#  - Ground-thruth (100-th perc.) = 3.3839
#  - Edit distance (median) = 7.0
# Epoch 36/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1378
#  - Oracle (80-th perc.) = 3.195
#  - Ground-thruth (80-th perc.) = 3.329
#  - Ground-thruth (95-th perc.) = 3.3477
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 5.0
# Epoch 37/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1356
#  - Oracle (80-th perc.) = 3.221
#  - Ground-thruth (80-th perc.) = 3.3002
#  - Ground-thruth (95-th perc.) = 3.326
#  - Ground-thruth (100-th perc.) = 3.383
#  - Edit distance (median) = 8.0
# Epoch 38/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1365
#  - Oracle (80-th perc.) = 3.2239
#  - Ground-thruth (80-th perc.) = 3.3118
#  - Ground-thruth (95-th perc.) = 3.3323
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 7.0
# Epoch 39/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1372
#  - Oracle (80-th perc.) = 3.205
#  - Ground-thruth (80-th perc.) = 3.3321
#  - Ground-thruth (95-th perc.) = 3.3529
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 6.0
# Epoch 40/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1357
#  - Oracle (80-th perc.) = 3.2022
#  - Ground-thruth (80-th perc.) = 3.3275
#  - Ground-thruth (95-th perc.) = 3.3521
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 6.0
# Epoch 41/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1353
#  - Oracle (80-th perc.) = 3.2205
#  - Ground-thruth (80-th perc.) = 3.3121
#  - Ground-thruth (95-th perc.) = 3.3412
#  - Ground-thruth (100-th perc.) = 3.3839
#  - Edit distance (median) = 6.0
# Epoch 42/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.1352
#  - Oracle (80-th perc.) = 3.2155
#  - Ground-thruth (80-th perc.) = 3.3125
#  - Ground-thruth (95-th perc.) = 3.3392
#  - Ground-thruth (100-th perc.) = 3.3988
#  - Edit distance (median) = 7.0
# Epoch 43/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.1348
#  - Oracle (80-th perc.) = 3.2235
#  - Ground-thruth (80-th perc.) = 3.3116
#  - Ground-thruth (95-th perc.) = 3.3412
#  - Ground-thruth (100-th perc.) = 3.3538
#  - Edit distance (median) = 5.5
# Epoch 44/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1345
#  - Oracle (80-th perc.) = 3.2054
#  - Ground-thruth (80-th perc.) = 3.3312
#  - Ground-thruth (95-th perc.) = 3.3487
#  - Ground-thruth (100-th perc.) = 3.3799
#  - Edit distance (median) = 6.5
# Epoch 45/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1346
#  - Oracle (80-th perc.) = 3.2138
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3477
#  - Ground-thruth (100-th perc.) = 3.3799
#  - Edit distance (median) = 6.0
# Epoch 46/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.1343
#  - Oracle (80-th perc.) = 3.2035
#  - Ground-thruth (80-th perc.) = 3.3238
#  - Ground-thruth (95-th perc.) = 3.3504
#  - Ground-thruth (100-th perc.) = 3.3799
#  - Edit distance (median) = 8.0
# Epoch 47/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.1343
#  - Oracle (80-th perc.) = 3.2131
#  - Ground-thruth (80-th perc.) = 3.3117
#  - Ground-thruth (95-th perc.) = 3.3639
#  - Ground-thruth (100-th perc.) = 3.3839
#  - Edit distance (median) = 7.5
# Epoch 48/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.1334
#  - Oracle (80-th perc.) = 3.2031
#  - Ground-thruth (80-th perc.) = 3.3382
#  - Ground-thruth (95-th perc.) = 3.3572
#  - Ground-thruth (100-th perc.) = 3.3988
#  - Edit distance (median) = 6.0
# Epoch 49/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.1343
#  - Oracle (80-th perc.) = 3.215
#  - Ground-thruth (80-th perc.) = 3.3183
#  - Ground-thruth (95-th perc.) = 3.3447
#  - Ground-thruth (100-th perc.) = 3.3706
#  - Edit distance (median) = 7.0
# Epoch 50/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.1351
#  - Oracle (80-th perc.) = 3.2231
#  - Ground-thruth (80-th perc.) = 3.2933
#  - Ground-thruth (95-th perc.) = 3.3166
#  - Ground-thruth (100-th perc.) = 3.3407
#  - Edit distance (median) = 8.0

# %%
run_experimental_den_opt(0, repeat_start=0, repeats=3, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.9, vae_log_p_margin=1.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
run_experimental_den_opt(1, repeat_start=0, repeats=3, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.9, vae_log_p_margin=1.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
run_experimental_den_opt(2, repeat_start=0, repeats=3, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.9, vae_log_p_margin=1.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ubuntu/CbAS/genesis_generator_protein.py:167: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From <ipython-input-7-b689ca90135f>:72: Normal.__init__ (from tensorflow.python.ops.distributions.normal) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/distributions/normal.py:160: Distribution.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
#  - Oracle (80-th perc.) = -0.9571
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 205.0
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/50
# 100/100 [==============================] - 9s 89ms/step - loss: 8.5365
#  - Oracle (80-th perc.) = 3.4543
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 86.5
# Epoch 2/50
# 100/100 [==============================] - 7s 66ms/step - loss: 2.9189
#  - Oracle (80-th perc.) = 3.2979
#  - Ground-thruth (80-th perc.) = 2.9016
#  - Ground-thruth (95-th perc.) = 2.9046
#  - Ground-thruth (100-th perc.) = 2.9074
#  - Edit distance (median) = 20.0
# Epoch 3/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.3914
#  - Oracle (80-th perc.) = 3.1867
#  - Ground-thruth (80-th perc.) = 3.2575
#  - Ground-thruth (95-th perc.) = 3.3061
#  - Ground-thruth (100-th perc.) = 3.3771
#  - Edit distance (median) = 9.0
# Epoch 4/50
# 100/100 [==============================] - 8s 80ms/step - loss: 0.2981
#  - Oracle (80-th perc.) = 3.1855
#  - Ground-thruth (80-th perc.) = 3.273
#  - Ground-thruth (95-th perc.) = 3.3067
#  - Ground-thruth (100-th perc.) = 3.3398
#  - Edit distance (median) = 8.0
# Epoch 5/50
# 100/100 [==============================] - 8s 76ms/step - loss: 0.2883
#  - Oracle (80-th perc.) = 3.2579
#  - Ground-thruth (80-th perc.) = 3.2978
#  - Ground-thruth (95-th perc.) = 3.354
#  - Ground-thruth (100-th perc.) = 3.3771
#  - Edit distance (median) = 9.0
# Epoch 6/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.2777
#  - Oracle (80-th perc.) = 3.2303
#  - Ground-thruth (80-th perc.) = 3.3532
#  - Ground-thruth (95-th perc.) = 3.3772
#  - Ground-thruth (100-th perc.) = 3.3994
#  - Edit distance (median) = 6.0
# Epoch 7/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2727
#  - Oracle (80-th perc.) = 3.2318
#  - Ground-thruth (80-th perc.) = 3.3497
#  - Ground-thruth (95-th perc.) = 3.38
#  - Ground-thruth (100-th perc.) = 3.4293
#  - Edit distance (median) = 6.0
# Epoch 8/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2705
#  - Oracle (80-th perc.) = 3.2152
#  - Ground-thruth (80-th perc.) = 3.3536
#  - Ground-thruth (95-th perc.) = 3.38
#  - Ground-thruth (100-th perc.) = 3.4527
#  - Edit distance (median) = 6.0
# Epoch 9/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2684
#  - Oracle (80-th perc.) = 3.2267
#  - Ground-thruth (80-th perc.) = 3.3771
#  - Ground-thruth (95-th perc.) = 3.38
#  - Ground-thruth (100-th perc.) = 3.4809
#  - Edit distance (median) = 5.0
# Epoch 10/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2675
#  - Oracle (80-th perc.) = 3.227
#  - Ground-thruth (80-th perc.) = 3.3771
#  - Ground-thruth (95-th perc.) = 3.3771
#  - Ground-thruth (100-th perc.) = 3.4065
#  - Edit distance (median) = 4.0
# Epoch 11/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2673
#  - Oracle (80-th perc.) = 3.2156
#  - Ground-thruth (80-th perc.) = 3.3771
#  - Ground-thruth (95-th perc.) = 3.3801
#  - Ground-thruth (100-th perc.) = 3.4809
#  - Edit distance (median) = 4.0
# Epoch 12/50
# 100/100 [==============================] - 8s 76ms/step - loss: 0.2655
#  - Oracle (80-th perc.) = 3.2151
#  - Ground-thruth (80-th perc.) = 3.3771
#  - Ground-thruth (95-th perc.) = 3.3771
#  - Ground-thruth (100-th perc.) = 3.4809
#  - Edit distance (median) = 3.5
# Epoch 13/50
# 100/100 [==============================] - 8s 78ms/step - loss: 0.2651
#  - Oracle (80-th perc.) = 3.224
#  - Ground-thruth (80-th perc.) = 3.3721
#  - Ground-thruth (95-th perc.) = 3.3771
#  - Ground-thruth (100-th perc.) = 3.4025
#  - Edit distance (median) = 4.0
# Epoch 14/50
# 100/100 [==============================] - 8s 83ms/step - loss: 0.2570
#  - Oracle (80-th perc.) = 3.2198
#  - Ground-thruth (80-th perc.) = 3.3123
#  - Ground-thruth (95-th perc.) = 3.3771
#  - Ground-thruth (100-th perc.) = 3.4809
#  - Edit distance (median) = 5.0
# Epoch 15/50
# 100/100 [==============================] - 8s 84ms/step - loss: 0.2568
#  - Oracle (80-th perc.) = 3.2171
#  - Ground-thruth (80-th perc.) = 3.302
#  - Ground-thruth (95-th perc.) = 3.3777
#  - Ground-thruth (100-th perc.) = 3.4809
#  - Edit distance (median) = 5.5
# Epoch 16/50
# 100/100 [==============================] - 9s 86ms/step - loss: 0.2554
#  - Oracle (80-th perc.) = 3.2464
#  - Ground-thruth (80-th perc.) = 3.2785
#  - Ground-thruth (95-th perc.) = 3.3443
#  - Ground-thruth (100-th perc.) = 3.4527
#  - Edit distance (median) = 4.0
# Epoch 17/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.2551
#  - Oracle (80-th perc.) = 3.2275
#  - Ground-thruth (80-th perc.) = 3.2936
#  - Ground-thruth (95-th perc.) = 3.347
#  - Ground-thruth (100-th perc.) = 3.4261
#  - Edit distance (median) = 5.0
# Epoch 18/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.2559
#  - Oracle (80-th perc.) = 3.2142
#  - Ground-thruth (80-th perc.) = 3.307
#  - Ground-thruth (95-th perc.) = 3.3347
#  - Ground-thruth (100-th perc.) = 3.429
#  - Edit distance (median) = 3.5
# Epoch 19/50
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2537
#  - Oracle (80-th perc.) = 3.2269
#  - Ground-thruth (80-th perc.) = 3.3106
#  - Ground-thruth (95-th perc.) = 3.3443
#  - Ground-thruth (100-th perc.) = 3.4122
#  - Edit distance (median) = 5.5
# Epoch 20/50
# 100/100 [==============================] - 11s 112ms/step - loss: 0.2521
#  - Oracle (80-th perc.) = 3.2287
#  - Ground-thruth (80-th perc.) = 3.3141
#  - Ground-thruth (95-th perc.) = 3.3628
#  - Ground-thruth (100-th perc.) = 3.4045
#  - Edit distance (median) = 6.0
# Epoch 21/50
# 100/100 [==============================] - 11s 115ms/step - loss: 0.2541
#  - Oracle (80-th perc.) = 3.2092
#  - Ground-thruth (80-th perc.) = 3.2643
#  - Ground-thruth (95-th perc.) = 3.3319
#  - Ground-thruth (100-th perc.) = 3.4527
#  - Edit distance (median) = 6.0
# Epoch 22/50
# 100/100 [==============================] - 13s 128ms/step - loss: 0.2516
#  - Oracle (80-th perc.) = 3.258
#  - Ground-thruth (80-th perc.) = 3.2952
#  - Ground-thruth (95-th perc.) = 3.3298
#  - Ground-thruth (100-th perc.) = 3.3753
#  - Edit distance (median) = 5.0
# Epoch 23/50
# 100/100 [==============================] - 13s 133ms/step - loss: 0.2530
#  - Oracle (80-th perc.) = 3.2213
#  - Ground-thruth (80-th perc.) = 3.301
#  - Ground-thruth (95-th perc.) = 3.3559
#  - Ground-thruth (100-th perc.) = 3.4068
#  - Edit distance (median) = 6.0
# Epoch 24/50
# 100/100 [==============================] - 14s 140ms/step - loss: 0.2530
#  - Oracle (80-th perc.) = 3.2103
#  - Ground-thruth (80-th perc.) = 3.286
#  - Ground-thruth (95-th perc.) = 3.3441
#  - Ground-thruth (100-th perc.) = 3.3704
#  - Edit distance (median) = 4.0
# Epoch 25/50
# 100/100 [==============================] - 16s 155ms/step - loss: 0.2492
#  - Oracle (80-th perc.) = 3.2344
#  - Ground-thruth (80-th perc.) = 3.3276
#  - Ground-thruth (95-th perc.) = 3.3452
#  - Ground-thruth (100-th perc.) = 3.3771
#  - Edit distance (median) = 5.5
# Epoch 26/50
# 100/100 [==============================] - 15s 150ms/step - loss: 0.2521
#  - Oracle (80-th perc.) = 3.2068
#  - Ground-thruth (80-th perc.) = 3.307
#  - Ground-thruth (95-th perc.) = 3.3442
#  - Ground-thruth (100-th perc.) = 3.4803
#  - Edit distance (median) = 5.0
# Epoch 27/50
# 100/100 [==============================] - 16s 156ms/step - loss: 0.2515
#  - Oracle (80-th perc.) = 3.2203
#  - Ground-thruth (80-th perc.) = 3.3126
#  - Ground-thruth (95-th perc.) = 3.3771
#  - Ground-thruth (100-th perc.) = 3.3811
#  - Edit distance (median) = 5.0
# Epoch 28/50
# 100/100 [==============================] - 15s 147ms/step - loss: 0.2523
#  - Oracle (80-th perc.) = 3.2338
#  - Ground-thruth (80-th perc.) = 3.314
#  - Ground-thruth (95-th perc.) = 3.3713
#  - Ground-thruth (100-th perc.) = 3.4809
#  - Edit distance (median) = 6.0
# Epoch 29/50
# 100/100 [==============================] - 14s 142ms/step - loss: 0.2507
#  - Oracle (80-th perc.) = 3.2097
#  - Ground-thruth (80-th perc.) = 3.3232
#  - Ground-thruth (95-th perc.) = 3.3447
#  - Ground-thruth (100-th perc.) = 3.4045
#  - Edit distance (median) = 6.0
# Epoch 30/50
# 100/100 [==============================] - 13s 132ms/step - loss: 0.2514
#  - Oracle (80-th perc.) = 3.2174
#  - Ground-thruth (80-th perc.) = 3.2978
#  - Ground-thruth (95-th perc.) = 3.3297
#  - Ground-thruth (100-th perc.) = 3.4122
#  - Edit distance (median) = 6.0
# Epoch 31/50
# 100/100 [==============================] - 12s 123ms/step - loss: 0.2532
#  - Oracle (80-th perc.) = 3.2337
#  - Ground-thruth (80-th perc.) = 3.3041
#  - Ground-thruth (95-th perc.) = 3.3517
#  - Ground-thruth (100-th perc.) = 3.4009
#  - Edit distance (median) = 6.0
# Epoch 32/50
# 100/100 [==============================] - 13s 126ms/step - loss: 0.2505
#  - Oracle (80-th perc.) = 3.2127
#  - Ground-thruth (80-th perc.) = 3.3241
#  - Ground-thruth (95-th perc.) = 3.355
#  - Ground-thruth (100-th perc.) = 3.3921
#  - Edit distance (median) = 4.0
# Epoch 33/50
# 100/100 [==============================] - 12s 121ms/step - loss: 0.2507
#  - Oracle (80-th perc.) = 3.2167
#  - Ground-thruth (80-th perc.) = 3.3224
#  - Ground-thruth (95-th perc.) = 3.344
#  - Ground-thruth (100-th perc.) = 3.4122
#  - Edit distance (median) = 4.0
# Epoch 34/50
# 100/100 [==============================] - 11s 113ms/step - loss: 0.2529
#  - Oracle (80-th perc.) = 3.2162
#  - Ground-thruth (80-th perc.) = 3.3038
#  - Ground-thruth (95-th perc.) = 3.3297
#  - Ground-thruth (100-th perc.) = 3.3771
#  - Edit distance (median) = 5.0
# Epoch 35/50
# 100/100 [==============================] - 11s 113ms/step - loss: 0.2524
#  - Oracle (80-th perc.) = 3.2227
#  - Ground-thruth (80-th perc.) = 3.3123
#  - Ground-thruth (95-th perc.) = 3.3297
#  - Ground-thruth (100-th perc.) = 3.371
#  - Edit distance (median) = 5.0
# Epoch 36/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.2501
#  - Oracle (80-th perc.) = 3.2167
#  - Ground-thruth (80-th perc.) = 3.3099
#  - Ground-thruth (95-th perc.) = 3.3366
#  - Ground-thruth (100-th perc.) = 3.3808
#  - Edit distance (median) = 7.0
# Epoch 37/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.2516
#  - Oracle (80-th perc.) = 3.2435
#  - Ground-thruth (80-th perc.) = 3.2976
#  - Ground-thruth (95-th perc.) = 3.3157
#  - Ground-thruth (100-th perc.) = 3.3297
#  - Edit distance (median) = 6.0
# Epoch 38/50
# 100/100 [==============================] - 8s 81ms/step - loss: 0.2526
#  - Oracle (80-th perc.) = 3.2128
#  - Ground-thruth (80-th perc.) = 3.3059
#  - Ground-thruth (95-th perc.) = 3.3304
#  - Ground-thruth (100-th perc.) = 3.3845
#  - Edit distance (median) = 4.0
# Epoch 39/50
# 100/100 [==============================] - 8s 77ms/step - loss: 0.2517
#  - Oracle (80-th perc.) = 3.2103
#  - Ground-thruth (80-th perc.) = 3.3123
#  - Ground-thruth (95-th perc.) = 3.3311
#  - Ground-thruth (100-th perc.) = 3.4182
#  - Edit distance (median) = 5.0
# Epoch 40/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2527
#  - Oracle (80-th perc.) = 3.2432
#  - Ground-thruth (80-th perc.) = 3.3123
#  - Ground-thruth (95-th perc.) = 3.3556
#  - Ground-thruth (100-th perc.) = 3.3771
#  - Edit distance (median) = 5.0
# Epoch 41/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.2507
#  - Oracle (80-th perc.) = 3.2148
#  - Ground-thruth (80-th perc.) = 3.3123
#  - Ground-thruth (95-th perc.) = 3.3368
#  - Ground-thruth (100-th perc.) = 3.4186
#  - Edit distance (median) = 4.0
# Epoch 42/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2505
#  - Oracle (80-th perc.) = 3.2227
#  - Ground-thruth (80-th perc.) = 3.3141
#  - Ground-thruth (95-th perc.) = 3.3408
#  - Ground-thruth (100-th perc.) = 3.3893
#  - Edit distance (median) = 5.0
# Epoch 43/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2514
#  - Oracle (80-th perc.) = 3.2086
#  - Ground-thruth (80-th perc.) = 3.3147
#  - Ground-thruth (95-th perc.) = 3.3493
#  - Ground-thruth (100-th perc.) = 3.4122
#  - Edit distance (median) = 3.0
# Epoch 44/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2518
#  - Oracle (80-th perc.) = 3.2152
#  - Ground-thruth (80-th perc.) = 3.28
#  - Ground-thruth (95-th perc.) = 3.3299
#  - Ground-thruth (100-th perc.) = 3.3894
#  - Edit distance (median) = 7.0
# Epoch 45/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2500
#  - Oracle (80-th perc.) = 3.2156
#  - Ground-thruth (80-th perc.) = 3.2848
#  - Ground-thruth (95-th perc.) = 3.3297
#  - Ground-thruth (100-th perc.) = 3.4045
#  - Edit distance (median) = 3.5
# Epoch 46/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.2508
#  - Oracle (80-th perc.) = 3.2453
#  - Ground-thruth (80-th perc.) = 3.2788
#  - Ground-thruth (95-th perc.) = 3.3124
#  - Ground-thruth (100-th perc.) = 3.4104
#  - Edit distance (median) = 6.0
# Epoch 47/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2520
#  - Oracle (80-th perc.) = 3.2283
#  - Ground-thruth (80-th perc.) = 3.3001
#  - Ground-thruth (95-th perc.) = 3.3377
#  - Ground-thruth (100-th perc.) = 3.4527
#  - Edit distance (median) = 5.5
# Epoch 48/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2514
#  - Oracle (80-th perc.) = 3.21
#  - Ground-thruth (80-th perc.) = 3.2964
#  - Ground-thruth (95-th perc.) = 3.329
#  - Ground-thruth (100-th perc.) = 3.376
#  - Edit distance (median) = 4.0
# Epoch 49/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2493
#  - Oracle (80-th perc.) = 3.2199
#  - Ground-thruth (80-th perc.) = 3.2978
#  - Ground-thruth (95-th perc.) = 3.3405
#  - Ground-thruth (100-th perc.) = 3.3771
#  - Edit distance (median) = 6.0
# Epoch 50/50
# 100/100 [==============================] - 7s 74ms/step - loss: 0.2517
#  - Oracle (80-th perc.) = 3.2247
#  - Ground-thruth (80-th perc.) = 3.3126
#  - Ground-thruth (95-th perc.) = 3.329
#  - Ground-thruth (100-th perc.) = 3.3549
#  - Edit distance (median) = 4.5
#  - Oracle (80-th perc.) = -0.6325
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 203.0
# Epoch 1/50
# 100/100 [==============================] - 9s 95ms/step - loss: 7.9743
#  - Oracle (80-th perc.) = 3.3962
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 81.0
# Epoch 2/50
# 100/100 [==============================] - 8s 85ms/step - loss: 2.2249
#  - Oracle (80-th perc.) = 3.2979
#  - Ground-thruth (80-th perc.) = 2.994
#  - Ground-thruth (95-th perc.) = 3.0188
#  - Ground-thruth (100-th perc.) = 3.0991
#  - Edit distance (median) = 15.0
# Epoch 3/50
# 100/100 [==============================] - 10s 102ms/step - loss: 0.3018
#  - Oracle (80-th perc.) = 3.2317
#  - Ground-thruth (80-th perc.) = 3.269
#  - Ground-thruth (95-th perc.) = 3.3053
#  - Ground-thruth (100-th perc.) = 3.3298
#  - Edit distance (median) = 5.0
# Epoch 4/50
# 100/100 [==============================] - 11s 110ms/step - loss: 0.2753
#  - Oracle (80-th perc.) = 3.2052
#  - Ground-thruth (80-th perc.) = 3.2704
#  - Ground-thruth (95-th perc.) = 3.3013
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 5.0
# Epoch 5/50
# 100/100 [==============================] - 11s 112ms/step - loss: 0.2739
#  - Oracle (80-th perc.) = 3.2209
#  - Ground-thruth (80-th perc.) = 3.2919
#  - Ground-thruth (95-th perc.) = 3.3265
#  - Ground-thruth (100-th perc.) = 3.3421
#  - Edit distance (median) = 4.0
# Epoch 6/50
# 100/100 [==============================] - 12s 118ms/step - loss: 0.2733
#  - Oracle (80-th perc.) = 3.2657
#  - Ground-thruth (80-th perc.) = 3.271
#  - Ground-thruth (95-th perc.) = 3.3129
#  - Ground-thruth (100-th perc.) = 3.3478
#  - Edit distance (median) = 6.5
# Epoch 7/50
# 100/100 [==============================] - 13s 127ms/step - loss: 0.2696
#  - Oracle (80-th perc.) = 3.2261
#  - Ground-thruth (80-th perc.) = 3.3047
#  - Ground-thruth (95-th perc.) = 3.3425
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 4.0
# Epoch 8/50
# 100/100 [==============================] - 14s 140ms/step - loss: 0.2695
#  - Oracle (80-th perc.) = 3.2408
#  - Ground-thruth (80-th perc.) = 3.2788
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 5.0
# Epoch 9/50
# 100/100 [==============================] - 15s 146ms/step - loss: 0.2682
#  - Oracle (80-th perc.) = 3.2452
#  - Ground-thruth (80-th perc.) = 3.2848
#  - Ground-thruth (95-th perc.) = 3.3268
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 4.0
# Epoch 10/50
# 100/100 [==============================] - 14s 142ms/step - loss: 0.2667
#  - Oracle (80-th perc.) = 3.2252
#  - Ground-thruth (80-th perc.) = 3.2843
#  - Ground-thruth (95-th perc.) = 3.3279
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 5.0
# Epoch 11/50
# 100/100 [==============================] - 13s 135ms/step - loss: 0.2656
#  - Oracle (80-th perc.) = 3.2403
#  - Ground-thruth (80-th perc.) = 3.2974
#  - Ground-thruth (95-th perc.) = 3.3265
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 5.0
# Epoch 12/50
# 100/100 [==============================] - 12s 117ms/step - loss: 0.2646
#  - Oracle (80-th perc.) = 3.2062
#  - Ground-thruth (80-th perc.) = 3.2709
#  - Ground-thruth (95-th perc.) = 3.3101
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 3.0
# Epoch 13/50
# 100/100 [==============================] - 12s 121ms/step - loss: 0.2656
#  - Oracle (80-th perc.) = 3.2513
#  - Ground-thruth (80-th perc.) = 3.2715
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3478
#  - Edit distance (median) = 4.0
# Epoch 14/50
# 100/100 [==============================] - 12s 117ms/step - loss: 0.2632
#  - Oracle (80-th perc.) = 3.2469
#  - Ground-thruth (80-th perc.) = 3.2728
#  - Ground-thruth (95-th perc.) = 3.3052
#  - Ground-thruth (100-th perc.) = 3.3471
#  - Edit distance (median) = 5.0
# Epoch 15/50
# 100/100 [==============================] - 12s 117ms/step - loss: 0.2624
#  - Oracle (80-th perc.) = 3.2103
#  - Ground-thruth (80-th perc.) = 3.2711
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 4.5
# Epoch 16/50
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2643
#  - Oracle (80-th perc.) = 3.1975
#  - Ground-thruth (80-th perc.) = 3.2775
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3376
#  - Edit distance (median) = 1.5
# Epoch 17/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.2645
#  - Oracle (80-th perc.) = 3.2926
#  - Ground-thruth (80-th perc.) = 3.2578
#  - Ground-thruth (95-th perc.) = 3.2987
#  - Ground-thruth (100-th perc.) = 3.3071
#  - Edit distance (median) = 4.0
# Epoch 18/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.2633
#  - Oracle (80-th perc.) = 3.2001
#  - Ground-thruth (80-th perc.) = 3.3047
#  - Ground-thruth (95-th perc.) = 3.3278
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 2.0
# Epoch 19/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2626
#  - Oracle (80-th perc.) = 3.2063
#  - Ground-thruth (80-th perc.) = 3.2953
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 4.0
# Epoch 20/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.2618
#  - Oracle (80-th perc.) = 3.2035
#  - Ground-thruth (80-th perc.) = 3.2732
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3318
#  - Edit distance (median) = 4.0
# Epoch 21/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.2594
#  - Oracle (80-th perc.) = 3.2779
#  - Ground-thruth (80-th perc.) = 3.2623
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 5.0
# Epoch 22/50
# 100/100 [==============================] - 9s 90ms/step - loss: 0.2557
#  - Oracle (80-th perc.) = 3.2282
#  - Ground-thruth (80-th perc.) = 3.2855
#  - Ground-thruth (95-th perc.) = 3.3229
#  - Ground-thruth (100-th perc.) = 3.3425
#  - Edit distance (median) = 4.0
# Epoch 23/50
# 100/100 [==============================] - 8s 76ms/step - loss: 0.2568
#  - Oracle (80-th perc.) = 3.2337
#  - Ground-thruth (80-th perc.) = 3.2881
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 4.5
# Epoch 24/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2562
#  - Oracle (80-th perc.) = 3.2214
#  - Ground-thruth (80-th perc.) = 3.2919
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3318
#  - Edit distance (median) = 4.5
# Epoch 25/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.2567
#  - Oracle (80-th perc.) = 3.2059
#  - Ground-thruth (80-th perc.) = 3.2798
#  - Ground-thruth (95-th perc.) = 3.3266
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 3.0
# Epoch 26/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2566
#  - Oracle (80-th perc.) = 3.2063
#  - Ground-thruth (80-th perc.) = 3.2802
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3263
#  - Edit distance (median) = 4.5
# Epoch 27/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.2540
#  - Oracle (80-th perc.) = 3.213
#  - Ground-thruth (80-th perc.) = 3.2975
#  - Ground-thruth (95-th perc.) = 3.3229
#  - Ground-thruth (100-th perc.) = 3.3621
#  - Edit distance (median) = 4.0
# Epoch 28/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2544
#  - Oracle (80-th perc.) = 3.2272
#  - Ground-thruth (80-th perc.) = 3.2996
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 4.0
# Epoch 29/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2525
#  - Oracle (80-th perc.) = 3.2168
#  - Ground-thruth (80-th perc.) = 3.2996
#  - Ground-thruth (95-th perc.) = 3.3266
#  - Ground-thruth (100-th perc.) = 3.3451
#  - Edit distance (median) = 5.0
# Epoch 30/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2514
#  - Oracle (80-th perc.) = 3.2165
#  - Ground-thruth (80-th perc.) = 3.3145
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3442
#  - Edit distance (median) = 6.0
# Epoch 31/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2530
#  - Oracle (80-th perc.) = 3.2168
#  - Ground-thruth (80-th perc.) = 3.2858
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3318
#  - Edit distance (median) = 8.0
# Epoch 32/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2525
#  - Oracle (80-th perc.) = 3.206
#  - Ground-thruth (80-th perc.) = 3.2976
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 4.5
# Epoch 33/50
# 100/100 [==============================] - 7s 72ms/step - loss: 0.2512
#  - Oracle (80-th perc.) = 3.2036
#  - Ground-thruth (80-th perc.) = 3.2968
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 4.0
# Epoch 34/50
# 100/100 [==============================] - 8s 84ms/step - loss: 0.2499
#  - Oracle (80-th perc.) = 3.2113
#  - Ground-thruth (80-th perc.) = 3.2711
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 6.0
# Epoch 35/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.2490
#  - Oracle (80-th perc.) = 3.2023
#  - Ground-thruth (80-th perc.) = 3.3042
#  - Ground-thruth (95-th perc.) = 3.3265
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 5.0
# Epoch 36/50
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2505
#  - Oracle (80-th perc.) = 3.2079
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3318
#  - Edit distance (median) = 3.0
# Epoch 37/50
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2484
#  - Oracle (80-th perc.) = 3.218
#  - Ground-thruth (80-th perc.) = 3.2996
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 4.5
# Epoch 38/50
# 100/100 [==============================] - 11s 115ms/step - loss: 0.2489
#  - Oracle (80-th perc.) = 3.2071
#  - Ground-thruth (80-th perc.) = 3.2922
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3771
#  - Edit distance (median) = 13.5
# Epoch 39/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.2471
#  - Oracle (80-th perc.) = 3.2135
#  - Ground-thruth (80-th perc.) = 3.2824
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 5.5
# Epoch 40/50
# 100/100 [==============================] - 13s 128ms/step - loss: 0.2481
#  - Oracle (80-th perc.) = 3.2115
#  - Ground-thruth (80-th perc.) = 3.2876
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3318
#  - Edit distance (median) = 4.5
# Epoch 41/50
# 100/100 [==============================] - 15s 149ms/step - loss: 0.2496
#  - Oracle (80-th perc.) = 3.204
#  - Ground-thruth (80-th perc.) = 3.2934
#  - Ground-thruth (95-th perc.) = 3.3229
#  - Ground-thruth (100-th perc.) = 3.3263
#  - Edit distance (median) = 4.0
# Epoch 42/50
# 100/100 [==============================] - 15s 147ms/step - loss: 0.2475
#  - Oracle (80-th perc.) = 3.2148
#  - Ground-thruth (80-th perc.) = 3.3071
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 4.0
# Epoch 43/50
# 100/100 [==============================] - 13s 133ms/step - loss: 0.2491
#  - Oracle (80-th perc.) = 3.2235
#  - Ground-thruth (80-th perc.) = 3.2831
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.3329
#  - Edit distance (median) = 6.0
# Epoch 44/50
# 100/100 [==============================] - 13s 129ms/step - loss: 0.2513
#  - Oracle (80-th perc.) = 3.2101
#  - Ground-thruth (80-th perc.) = 3.2723
#  - Ground-thruth (95-th perc.) = 3.3243
#  - Ground-thruth (100-th perc.) = 3.3366
#  - Edit distance (median) = 4.5
# Epoch 45/50
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2489
#  - Oracle (80-th perc.) = 3.2091
#  - Ground-thruth (80-th perc.) = 3.2835
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3944
#  - Edit distance (median) = 5.0
# Epoch 46/50
# 100/100 [==============================] - 12s 116ms/step - loss: 0.2499
#  - Oracle (80-th perc.) = 3.199
#  - Ground-thruth (80-th perc.) = 3.2919
#  - Ground-thruth (95-th perc.) = 3.323
#  - Ground-thruth (100-th perc.) = 3.38
#  - Edit distance (median) = 4.0
# Epoch 47/50
# 100/100 [==============================] - 11s 113ms/step - loss: 0.2489
#  - Oracle (80-th perc.) = 3.2162
#  - Ground-thruth (80-th perc.) = 3.2812
#  - Ground-thruth (95-th perc.) = 3.3228
#  - Ground-thruth (100-th perc.) = 3.3279
#  - Edit distance (median) = 6.0
# Epoch 48/50
# 100/100 [==============================] - 9s 90ms/step - loss: 0.2476
#  - Oracle (80-th perc.) = 3.2244
#  - Ground-thruth (80-th perc.) = 3.289
#  - Ground-thruth (95-th perc.) = 3.3243
#  - Ground-thruth (100-th perc.) = 3.3442
#  - Edit distance (median) = 5.5
# Epoch 49/50
# 100/100 [==============================] - 10s 96ms/step - loss: 0.2467
#  - Oracle (80-th perc.) = 3.221
#  - Ground-thruth (80-th perc.) = 3.2731
#  - Ground-thruth (95-th perc.) = 3.3264
#  - Ground-thruth (100-th perc.) = 3.38
#  - Edit distance (median) = 6.0
# Epoch 50/50
# 100/100 [==============================] - 9s 91ms/step - loss: 0.2457
#  - Oracle (80-th perc.) = 3.2164
#  - Ground-thruth (80-th perc.) = 3.2855
#  - Ground-thruth (95-th perc.) = 3.3263
#  - Ground-thruth (100-th perc.) = 3.3318
#  - Edit distance (median) = 6.0
#  - Oracle (80-th perc.) = -0.3775
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 203.0
# Epoch 1/50
# 100/100 [==============================] - 13s 126ms/step - loss: 8.0525
#  - Oracle (80-th perc.) = 3.4365
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 85.0
# Epoch 2/50
# 100/100 [==============================] - 10s 103ms/step - loss: 1.9909
#  - Oracle (80-th perc.) = 3.2337
#  - Ground-thruth (80-th perc.) = 3.2713
#  - Ground-thruth (95-th perc.) = 3.2936
#  - Ground-thruth (100-th perc.) = 3.311
#  - Edit distance (median) = 4.0
# Epoch 3/50
# 100/100 [==============================] - 10s 97ms/step - loss: 0.2878
#  - Oracle (80-th perc.) = 3.2878
#  - Ground-thruth (80-th perc.) = 3.2603
#  - Ground-thruth (95-th perc.) = 3.2684
#  - Ground-thruth (100-th perc.) = 3.2879
#  - Edit distance (median) = 3.5
# Epoch 4/50
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2894
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.2876
#  - Edit distance (median) = 1.0
# Epoch 5/50
# 100/100 [==============================] - 8s 84ms/step - loss: 0.2905
#  - Oracle (80-th perc.) = 3.3427
#  - Ground-thruth (80-th perc.) = 3.2538
#  - Ground-thruth (95-th perc.) = 3.3105
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 3.0
# Epoch 6/50
# 100/100 [==============================] - 8s 78ms/step - loss: 0.2895
#  - Oracle (80-th perc.) = 3.3016
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2618
#  - Ground-thruth (100-th perc.) = 3.3105
#  - Edit distance (median) = 3.0
# Epoch 7/50
# 100/100 [==============================] - 7s 75ms/step - loss: 0.2876
#  - Oracle (80-th perc.) = 3.2952
#  - Ground-thruth (80-th perc.) = 3.2499
#  - Ground-thruth (95-th perc.) = 3.2697
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 2.0
# Epoch 8/50
# 100/100 [==============================] - 7s 72ms/step - loss: 0.2858
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 1.5
# Epoch 9/50
# 100/100 [==============================] - 7s 72ms/step - loss: 0.2848
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.318
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 1.0
# Epoch 10/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2844
#  - Oracle (80-th perc.) = 3.3013
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2658
#  - Ground-thruth (100-th perc.) = 3.3204
#  - Edit distance (median) = 3.0
# Epoch 11/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2835
#  - Oracle (80-th perc.) = 3.2046
#  - Ground-thruth (80-th perc.) = 3.2589
#  - Ground-thruth (95-th perc.) = 3.2731
#  - Ground-thruth (100-th perc.) = 3.2945
#  - Edit distance (median) = 2.0
# Epoch 12/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.2832
#  - Oracle (80-th perc.) = 3.2443
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 2.0
# Epoch 13/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2824
#  - Oracle (80-th perc.) = 3.2072
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.274
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 1.5
# Epoch 14/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2826
#  - Oracle (80-th perc.) = 3.2027
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.274
#  - Ground-thruth (100-th perc.) = 3.3568
#  - Edit distance (median) = 1.0
# Epoch 15/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2820
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2731
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 2.0
# Epoch 16/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2814
#  - Oracle (80-th perc.) = 3.2288
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 3.0
# Epoch 17/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2827
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.2834
#  - Edit distance (median) = 1.5
# Epoch 18/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2814
#  - Oracle (80-th perc.) = 3.2458
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2616
#  - Ground-thruth (100-th perc.) = 3.2716
#  - Edit distance (median) = 4.0
# Epoch 19/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.2800
#  - Oracle (80-th perc.) = 3.213
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.2834
#  - Edit distance (median) = 1.0
# Epoch 20/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2799
#  - Oracle (80-th perc.) = 3.2154
#  - Ground-thruth (80-th perc.) = 3.2487
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 3.0
# Epoch 21/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2800
#  - Oracle (80-th perc.) = 3.2076
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 2.0
# Epoch 22/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2803
#  - Oracle (80-th perc.) = 3.209
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2706
#  - Ground-thruth (100-th perc.) = 3.3502
#  - Edit distance (median) = 2.0
# Epoch 23/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2794
#  - Oracle (80-th perc.) = 3.2268
#  - Ground-thruth (80-th perc.) = 3.2487
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.2705
#  - Edit distance (median) = 3.5
# Epoch 24/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2780
#  - Oracle (80-th perc.) = 3.249
#  - Ground-thruth (80-th perc.) = 3.2503
#  - Ground-thruth (95-th perc.) = 3.2541
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 3.0
# Epoch 25/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2787
#  - Oracle (80-th perc.) = 3.2123
#  - Ground-thruth (80-th perc.) = 3.2548
#  - Ground-thruth (95-th perc.) = 3.2627
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 2.0
# Epoch 26/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2776
#  - Oracle (80-th perc.) = 3.2115
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 3.0
# Epoch 27/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2797
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2527
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.2873
#  - Edit distance (median) = 2.0
# Epoch 28/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.2774
#  - Oracle (80-th perc.) = 3.2106
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2731
#  - Ground-thruth (100-th perc.) = 3.3204
#  - Edit distance (median) = 3.0
# Epoch 29/50
# 100/100 [==============================] - 7s 72ms/step - loss: 0.2768
#  - Oracle (80-th perc.) = 3.2068
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.274
#  - Ground-thruth (100-th perc.) = 3.3204
#  - Edit distance (median) = 3.0
# Epoch 30/50
# 100/100 [==============================] - 8s 80ms/step - loss: 0.2766
#  - Oracle (80-th perc.) = 3.2112
#  - Ground-thruth (80-th perc.) = 3.2499
#  - Ground-thruth (95-th perc.) = 3.2661
#  - Ground-thruth (100-th perc.) = 3.3204
#  - Edit distance (median) = 3.0
# Epoch 31/50
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2766
#  - Oracle (80-th perc.) = 3.2208
#  - Ground-thruth (80-th perc.) = 3.2491
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.3204
#  - Edit distance (median) = 4.0
# Epoch 32/50
# 100/100 [==============================] - 9s 86ms/step - loss: 0.2770
#  - Oracle (80-th perc.) = 3.2063
#  - Ground-thruth (80-th perc.) = 3.2586
#  - Ground-thruth (95-th perc.) = 3.2664
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 2.0
# Epoch 33/50
# 100/100 [==============================] - 9s 94ms/step - loss: 0.2780
#  - Oracle (80-th perc.) = 3.1992
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2751
#  - Ground-thruth (100-th perc.) = 3.2834
#  - Edit distance (median) = 2.0
# Epoch 34/50
# 100/100 [==============================] - 9s 89ms/step - loss: 0.2767
#  - Oracle (80-th perc.) = 3.2072
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2705
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 3.0
# Epoch 35/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.2778
#  - Oracle (80-th perc.) = 3.2133
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.2926
#  - Edit distance (median) = 4.0
# Epoch 36/50
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2779
#  - Oracle (80-th perc.) = 3.2135
#  - Ground-thruth (80-th perc.) = 3.2502
#  - Ground-thruth (95-th perc.) = 3.2616
#  - Ground-thruth (100-th perc.) = 3.2625
#  - Edit distance (median) = 4.0
# Epoch 37/50
# 100/100 [==============================] - 12s 117ms/step - loss: 0.2763
#  - Oracle (80-th perc.) = 3.2131
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.274
#  - Edit distance (median) = 3.0
# Epoch 38/50
# 100/100 [==============================] - 12s 118ms/step - loss: 0.2770
#  - Oracle (80-th perc.) = 3.2029
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2616
#  - Ground-thruth (100-th perc.) = 3.2876
#  - Edit distance (median) = 2.0
# Epoch 39/50
# 100/100 [==============================] - 12s 125ms/step - loss: 0.2773
#  - Oracle (80-th perc.) = 3.2267
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2538
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 3.0
# Epoch 40/50
# 100/100 [==============================] - 14s 137ms/step - loss: 0.2765
#  - Oracle (80-th perc.) = 3.2389
#  - Ground-thruth (80-th perc.) = 3.2585
#  - Ground-thruth (95-th perc.) = 3.2801
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 2.0
# Epoch 41/50
# 100/100 [==============================] - 14s 143ms/step - loss: 0.2769
#  - Oracle (80-th perc.) = 3.2067
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2876
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 3.0
# Epoch 42/50
# 100/100 [==============================] - 15s 146ms/step - loss: 0.2762
#  - Oracle (80-th perc.) = 3.225
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 2.5
# Epoch 43/50
# 100/100 [==============================] - 15s 150ms/step - loss: 0.2772
#  - Oracle (80-th perc.) = 3.213
#  - Ground-thruth (80-th perc.) = 3.259
#  - Ground-thruth (95-th perc.) = 3.2742
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 2.5
# Epoch 44/50
# 100/100 [==============================] - 14s 139ms/step - loss: 0.2772
#  - Oracle (80-th perc.) = 3.2475
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2746
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 3.5
# Epoch 45/50
# 100/100 [==============================] - 15s 147ms/step - loss: 0.2770
#  - Oracle (80-th perc.) = 3.203
#  - Ground-thruth (80-th perc.) = 3.2616
#  - Ground-thruth (95-th perc.) = 3.2882
#  - Ground-thruth (100-th perc.) = 3.3122
#  - Edit distance (median) = 2.0
# Epoch 46/50
# 100/100 [==============================] - 15s 150ms/step - loss: 0.2769
#  - Oracle (80-th perc.) = 3.2171
#  - Ground-thruth (80-th perc.) = 3.2484
#  - Ground-thruth (95-th perc.) = 3.2996
#  - Ground-thruth (100-th perc.) = 3.3204
#  - Edit distance (median) = 4.0
# Epoch 47/50
# 100/100 [==============================] - 14s 142ms/step - loss: 0.2762
#  - Oracle (80-th perc.) = 3.2106
#  - Ground-thruth (80-th perc.) = 3.2499
#  - Ground-thruth (95-th perc.) = 3.2791
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 4.5
# Epoch 48/50
# 100/100 [==============================] - 14s 141ms/step - loss: 0.2749
#  - Oracle (80-th perc.) = 3.2044
#  - Ground-thruth (80-th perc.) = 3.2544
#  - Ground-thruth (95-th perc.) = 3.2674
#  - Ground-thruth (100-th perc.) = 3.2996
#  - Edit distance (median) = 3.0
# Epoch 49/50
# 100/100 [==============================] - 14s 140ms/step - loss: 0.2754
#  - Oracle (80-th perc.) = 3.2294
#  - Ground-thruth (80-th perc.) = 3.2539
#  - Ground-thruth (95-th perc.) = 3.2775
#  - Ground-thruth (100-th perc.) = 3.3033
#  - Edit distance (median) = 4.0
# Epoch 50/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2753
#  - Oracle (80-th perc.) = 3.2089
#  - Ground-thruth (80-th perc.) = 3.257
#  - Ground-thruth (95-th perc.) = 3.2625
#  - Ground-thruth (100-th perc.) = 3.2876
#  - Edit distance (median) = 3.5
#  - Oracle (80-th perc.) = -1.7711
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 205.0
# Epoch 1/50
# 100/100 [==============================] - 17s 170ms/step - loss: 9.2820
#  - Oracle (80-th perc.) = 2.0201
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 67.5
# Epoch 2/50
# 100/100 [==============================] - 12s 122ms/step - loss: 4.1704
#  - Oracle (80-th perc.) = 3.1195
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 29.0
# Epoch 3/50
# 100/100 [==============================] - 11s 113ms/step - loss: 0.4856
#  - Oracle (80-th perc.) = 3.1942
#  - Ground-thruth (80-th perc.) = 3.3192
#  - Ground-thruth (95-th perc.) = 3.3462
#  - Ground-thruth (100-th perc.) = 3.3562
#  - Edit distance (median) = 4.0
# Epoch 4/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2613
#  - Oracle (80-th perc.) = 3.1938
#  - Ground-thruth (80-th perc.) = 3.3423
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4058
#  - Edit distance (median) = 2.0
# Epoch 5/50
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2612
#  - Oracle (80-th perc.) = 3.1833
#  - Ground-thruth (80-th perc.) = 3.3285
#  - Ground-thruth (95-th perc.) = 3.3421
#  - Ground-thruth (100-th perc.) = 3.3843
#  - Edit distance (median) = 1.0
# Epoch 6/50
# 100/100 [==============================] - 9s 89ms/step - loss: 0.2611
#  - Oracle (80-th perc.) = 3.1988
#  - Ground-thruth (80-th perc.) = 3.3234
#  - Ground-thruth (95-th perc.) = 3.3476
#  - Ground-thruth (100-th perc.) = 3.3668
#  - Edit distance (median) = 3.0
# Epoch 7/50
# 100/100 [==============================] - 8s 80ms/step - loss: 0.2609
#  - Oracle (80-th perc.) = 3.181
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3421
#  - Ground-thruth (100-th perc.) = 3.3649
#  - Edit distance (median) = 1.0
# Epoch 8/50
# 100/100 [==============================] - 8s 82ms/step - loss: 0.2601
#  - Oracle (80-th perc.) = 3.1879
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3562
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 2.0
# Epoch 9/50
# 100/100 [==============================] - 7s 70ms/step - loss: 0.2600
#  - Oracle (80-th perc.) = 3.1957
#  - Ground-thruth (80-th perc.) = 3.3266
#  - Ground-thruth (95-th perc.) = 3.3565
#  - Ground-thruth (100-th perc.) = 3.3937
#  - Edit distance (median) = 2.0
# Epoch 10/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2600
#  - Oracle (80-th perc.) = 3.1983
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3562
#  - Ground-thruth (100-th perc.) = 3.395
#  - Edit distance (median) = 2.0
# Epoch 11/50
# 100/100 [==============================] - 6s 65ms/step - loss: 0.2589
#  - Oracle (80-th perc.) = 3.1933
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4027
#  - Edit distance (median) = 2.0
# Epoch 12/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2581
#  - Oracle (80-th perc.) = 3.2019
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3476
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 3.0
# Epoch 13/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2579
#  - Oracle (80-th perc.) = 3.1933
#  - Ground-thruth (80-th perc.) = 3.3387
#  - Ground-thruth (95-th perc.) = 3.3502
#  - Ground-thruth (100-th perc.) = 3.3881
#  - Edit distance (median) = 3.0
# Epoch 14/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2577
#  - Oracle (80-th perc.) = 3.1973
#  - Ground-thruth (80-th perc.) = 3.35
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4058
#  - Edit distance (median) = 3.0
# Epoch 15/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.2571
#  - Oracle (80-th perc.) = 3.1944
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4076
#  - Edit distance (median) = 3.0
# Epoch 16/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2576
#  - Oracle (80-th perc.) = 3.193
#  - Ground-thruth (80-th perc.) = 3.3235
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4058
#  - Edit distance (median) = 3.0
# Epoch 17/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.2561
#  - Oracle (80-th perc.) = 3.194
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3881
#  - Ground-thruth (100-th perc.) = 3.4027
#  - Edit distance (median) = 2.5
# Epoch 18/50
# 100/100 [==============================] - 7s 65ms/step - loss: 0.2556
#  - Oracle (80-th perc.) = 3.1933
#  - Ground-thruth (80-th perc.) = 3.3228
#  - Ground-thruth (95-th perc.) = 3.3766
# ...
#  - Ground-thruth (80-th perc.) = 3.3391
#  - Ground-thruth (95-th perc.) = 3.4119
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 8.5
# Epoch 43/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.2386
#  - Oracle (80-th perc.) = 3.2071
#  - Ground-thruth (80-th perc.) = 3.3173
#  - Ground-thruth (95-th perc.) = 3.4148
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 10.0
# Epoch 44/50
# 100/100 [==============================] - 7s 70ms/step - loss: 0.2410
#  - Oracle (80-th perc.) = 3.2177
#  - Ground-thruth (80-th perc.) = 3.3229
#  - Ground-thruth (95-th perc.) = 3.4119
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 10.0
# Epoch 45/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.2406
#  - Oracle (80-th perc.) = 3.2166
#  - Ground-thruth (80-th perc.) = 3.3403
#  - Ground-thruth (95-th perc.) = 3.4294
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 9.5
# Epoch 46/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2399
#  - Oracle (80-th perc.) = 3.2169
#  - Ground-thruth (80-th perc.) = 3.3229
#  - Ground-thruth (95-th perc.) = 3.3786
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 12.5
# Epoch 47/50
# 100/100 [==============================] - 17s 165ms/step - loss: 0.2387
#  - Oracle (80-th perc.) = 3.2121
#  - Ground-thruth (80-th perc.) = 3.3181
#  - Ground-thruth (95-th perc.) = 3.4123
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 14.0
# Epoch 48/50
# 100/100 [==============================] - 16s 158ms/step - loss: 0.2379
#  - Oracle (80-th perc.) = 3.2112
#  - Ground-thruth (80-th perc.) = 3.3229
#  - Ground-thruth (95-th perc.) = 3.3994
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 9.0
# Epoch 49/50
# 100/100 [==============================] - 16s 164ms/step - loss: 0.2393
#  - Oracle (80-th perc.) = 3.2143
#  - Ground-thruth (80-th perc.) = 3.318
#  - Ground-thruth (95-th perc.) = 3.3972
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 13.0
# Epoch 50/50
# 100/100 [==============================] - 15s 149ms/step - loss: 0.2373
#  - Oracle (80-th perc.) = 3.2163
#  - Ground-thruth (80-th perc.) = 3.3433
#  - Ground-thruth (95-th perc.) = 3.4294
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 9.5
#  - Oracle (80-th perc.) = -1.95
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 203.0
# Epoch 1/50
# 100/100 [==============================] - 13s 132ms/step - loss: 8.0378
#  - Oracle (80-th perc.) = 2.619
#  - Ground-thruth (80-th perc.) = 2.894
#  - Ground-thruth (95-th perc.) = 2.894
#  - Ground-thruth (100-th perc.) = 2.894
#  - Edit distance (median) = 70.0
# Epoch 2/50
# 100/100 [==============================] - 8s 78ms/step - loss: 1.9894
#  - Oracle (80-th perc.) = 3.2099
#  - Ground-thruth (80-th perc.) = 3.1685
#  - Ground-thruth (95-th perc.) = 3.2267
#  - Ground-thruth (100-th perc.) = 3.2766
#  - Edit distance (median) = 12.0
# Epoch 3/50
# 100/100 [==============================] - 7s 72ms/step - loss: 0.2790
#  - Oracle (80-th perc.) = 3.2224
#  - Ground-thruth (80-th perc.) = 3.3582
#  - Ground-thruth (95-th perc.) = 3.4119
#  - Ground-thruth (100-th perc.) = 3.459
#  - Edit distance (median) = 7.0
# Epoch 4/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.2731
#  - Oracle (80-th perc.) = 3.2196
#  - Ground-thruth (80-th perc.) = 3.3401
#  - Ground-thruth (95-th perc.) = 3.3891
#  - Ground-thruth (100-th perc.) = 3.4356
#  - Edit distance (median) = 7.0
# Epoch 5/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2708
#  - Oracle (80-th perc.) = 3.2213
#  - Ground-thruth (80-th perc.) = 3.3631
#  - Ground-thruth (95-th perc.) = 3.4147
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 7.0
# Epoch 6/50
# 100/100 [==============================] - 7s 69ms/step - loss: 0.2680
#  - Oracle (80-th perc.) = 3.2356
#  - Ground-thruth (80-th perc.) = 3.3432
#  - Ground-thruth (95-th perc.) = 3.3996
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 8.0
# Epoch 7/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2645
#  - Oracle (80-th perc.) = 3.2261
#  - Ground-thruth (80-th perc.) = 3.3479
#  - Ground-thruth (95-th perc.) = 3.3867
#  - Ground-thruth (100-th perc.) = 3.4122
#  - Edit distance (median) = 6.5
# Epoch 8/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.2641
#  - Oracle (80-th perc.) = 3.2242
#  - Ground-thruth (80-th perc.) = 3.3799
#  - Ground-thruth (95-th perc.) = 3.3999
#  - Ground-thruth (100-th perc.) = 3.4335
#  - Edit distance (median) = 6.0
# Epoch 9/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2626
#  - Oracle (80-th perc.) = 3.2067
#  - Ground-thruth (80-th perc.) = 3.3625
#  - Ground-thruth (95-th perc.) = 3.4123
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 4.0
# Epoch 10/50
# 100/100 [==============================] - 7s 68ms/step - loss: 0.2596
#  - Oracle (80-th perc.) = 3.2151
#  - Ground-thruth (80-th perc.) = 3.3706
#  - Ground-thruth (95-th perc.) = 3.4154
#  - Ground-thruth (100-th perc.) = 3.4335
#  - Edit distance (median) = 8.0
# Epoch 11/50
# 100/100 [==============================] - 7s 75ms/step - loss: 0.2595
#  - Oracle (80-th perc.) = 3.2123
#  - Ground-thruth (80-th perc.) = 3.3799
#  - Ground-thruth (95-th perc.) = 3.4335
#  - Ground-thruth (100-th perc.) = 3.4499
#  - Edit distance (median) = 6.0
# Epoch 12/50
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2569
#  - Oracle (80-th perc.) = 3.2085
#  - Ground-thruth (80-th perc.) = 3.378
#  - Ground-thruth (95-th perc.) = 3.3938
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 5.0
# Epoch 13/50
# 100/100 [==============================] - 8s 82ms/step - loss: 0.2548
#  - Oracle (80-th perc.) = 3.22
#  - Ground-thruth (80-th perc.) = 3.3751
#  - Ground-thruth (95-th perc.) = 3.4122
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 7.0
# Epoch 14/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.2553
#  - Oracle (80-th perc.) = 3.2177
#  - Ground-thruth (80-th perc.) = 3.3591
#  - Ground-thruth (95-th perc.) = 3.3914
#  - Ground-thruth (100-th perc.) = 3.4335
#  - Edit distance (median) = 8.5
# Epoch 15/50
# 100/100 [==============================] - 9s 88ms/step - loss: 0.2552
#  - Oracle (80-th perc.) = 3.2101
#  - Ground-thruth (80-th perc.) = 3.3799
#  - Ground-thruth (95-th perc.) = 3.4148
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 5.0
# Epoch 16/50
# 100/100 [==============================] - 9s 92ms/step - loss: 0.2534
#  - Oracle (80-th perc.) = 3.2118
#  - Ground-thruth (80-th perc.) = 3.3423
#  - Ground-thruth (95-th perc.) = 3.4129
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 6.0
# Epoch 17/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.2531
#  - Oracle (80-th perc.) = 3.22
#  - Ground-thruth (80-th perc.) = 3.3689
#  - Ground-thruth (95-th perc.) = 3.3982
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 6.5
# Epoch 18/50
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2518
#  - Oracle (80-th perc.) = 3.2116
#  - Ground-thruth (80-th perc.) = 3.3602
#  - Ground-thruth (95-th perc.) = 3.381
#  - Ground-thruth (100-th perc.) = 3.4703
#  - Edit distance (median) = 6.0
# Epoch 19/50
# 100/100 [==============================] - 10s 105ms/step - loss: 0.2510
#  - Oracle (80-th perc.) = 3.2149
#  - Ground-thruth (80-th perc.) = 3.3432
#  - Ground-thruth (95-th perc.) = 3.3886
#  - Ground-thruth (100-th perc.) = 3.4335
#  - Edit distance (median) = 9.0
# Epoch 20/50
# 100/100 [==============================] - 12s 124ms/step - loss: 0.2526
#  - Oracle (80-th perc.) = 3.2117
#  - Ground-thruth (80-th perc.) = 3.3687
#  - Ground-thruth (95-th perc.) = 3.4086
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 5.0
# Epoch 21/50
# 100/100 [==============================] - 13s 130ms/step - loss: 0.2505
#  - Oracle (80-th perc.) = 3.2115
#  - Ground-thruth (80-th perc.) = 3.361
#  - Ground-thruth (95-th perc.) = 3.4003
#  - Ground-thruth (100-th perc.) = 3.426
#  - Edit distance (median) = 7.0
# Epoch 22/50
# 100/100 [==============================] - 14s 139ms/step - loss: 0.2521
#  - Oracle (80-th perc.) = 3.212
#  - Ground-thruth (80-th perc.) = 3.3495
#  - Ground-thruth (95-th perc.) = 3.3781
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 8.0
# Epoch 23/50
# 100/100 [==============================] - 15s 145ms/step - loss: 0.2508
#  - Oracle (80-th perc.) = 3.2128
#  - Ground-thruth (80-th perc.) = 3.3702
#  - Ground-thruth (95-th perc.) = 3.3808
#  - Ground-thruth (100-th perc.) = 3.4148
#  - Edit distance (median) = 7.0
# Epoch 24/50
# 100/100 [==============================] - 15s 146ms/step - loss: 0.2506
#  - Oracle (80-th perc.) = 3.2159
#  - Ground-thruth (80-th perc.) = 3.3591
#  - Ground-thruth (95-th perc.) = 3.4156
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 7.0
# Epoch 25/50
# 100/100 [==============================] - 16s 155ms/step - loss: 0.2490
#  - Oracle (80-th perc.) = 3.2173
#  - Ground-thruth (80-th perc.) = 3.3446
#  - Ground-thruth (95-th perc.) = 3.3762
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 8.5
# Epoch 26/50
# 100/100 [==============================] - 15s 149ms/step - loss: 0.2494
#  - Oracle (80-th perc.) = 3.2151
#  - Ground-thruth (80-th perc.) = 3.3615
#  - Ground-thruth (95-th perc.) = 3.4134
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 6.0
# Epoch 27/50
# 100/100 [==============================] - 15s 155ms/step - loss: 0.2498
#  - Oracle (80-th perc.) = 3.2131
#  - Ground-thruth (80-th perc.) = 3.3712
#  - Ground-thruth (95-th perc.) = 3.4091
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 7.0
# Epoch 28/50
# 100/100 [==============================] - 16s 159ms/step - loss: 0.2510
#  - Oracle (80-th perc.) = 3.2104
#  - Ground-thruth (80-th perc.) = 3.3632
#  - Ground-thruth (95-th perc.) = 3.4003
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 7.0
# Epoch 29/50
# 100/100 [==============================] - 16s 155ms/step - loss: 0.2495
#  - Oracle (80-th perc.) = 3.2169
#  - Ground-thruth (80-th perc.) = 3.3327
#  - Ground-thruth (95-th perc.) = 3.392
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 8.5
# Epoch 30/50
# 100/100 [==============================] - 14s 144ms/step - loss: 0.2514
#  - Oracle (80-th perc.) = 3.208
#  - Ground-thruth (80-th perc.) = 3.3445
#  - Ground-thruth (95-th perc.) = 3.378
#  - Ground-thruth (100-th perc.) = 3.3928
#  - Edit distance (median) = 8.0
# Epoch 31/50
# 100/100 [==============================] - 13s 131ms/step - loss: 0.2503
#  - Oracle (80-th perc.) = 3.2134
#  - Ground-thruth (80-th perc.) = 3.3466
#  - Ground-thruth (95-th perc.) = 3.3791
#  - Ground-thruth (100-th perc.) = 3.4277
#  - Edit distance (median) = 7.0
# Epoch 32/50
# 100/100 [==============================] - 14s 143ms/step - loss: 0.2492
#  - Oracle (80-th perc.) = 3.2124
#  - Ground-thruth (80-th perc.) = 3.352
#  - Ground-thruth (95-th perc.) = 3.378
#  - Ground-thruth (100-th perc.) = 3.3999
#  - Edit distance (median) = 8.0
# Epoch 33/50
# 100/100 [==============================] - 14s 144ms/step - loss: 0.2488
#  - Oracle (80-th perc.) = 3.2163
#  - Ground-thruth (80-th perc.) = 3.3418
#  - Ground-thruth (95-th perc.) = 3.381
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 7.0
# Epoch 34/50
# 100/100 [==============================] - 13s 133ms/step - loss: 0.2495
#  - Oracle (80-th perc.) = 3.2181
#  - Ground-thruth (80-th perc.) = 3.3579
#  - Ground-thruth (95-th perc.) = 3.4002
#  - Ground-thruth (100-th perc.) = 3.4335
#  - Edit distance (median) = 6.0
# Epoch 35/50
# 100/100 [==============================] - 13s 128ms/step - loss: 0.2501
#  - Oracle (80-th perc.) = 3.2121
#  - Ground-thruth (80-th perc.) = 3.3453
#  - Ground-thruth (95-th perc.) = 3.3799
#  - Ground-thruth (100-th perc.) = 3.4122
#  - Edit distance (median) = 7.0
# Epoch 36/50
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2494
#  - Oracle (80-th perc.) = 3.2099
#  - Ground-thruth (80-th perc.) = 3.3446
#  - Ground-thruth (95-th perc.) = 3.3975
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 7.0
# Epoch 37/50
# 100/100 [==============================] - 11s 114ms/step - loss: 0.2497
#  - Oracle (80-th perc.) = 3.2085
#  - Ground-thruth (80-th perc.) = 3.3332
#  - Ground-thruth (95-th perc.) = 3.3859
#  - Ground-thruth (100-th perc.) = 3.4148
#  - Edit distance (median) = 7.5
# Epoch 38/50
# 100/100 [==============================] - 12s 121ms/step - loss: 0.2491
#  - Oracle (80-th perc.) = 3.2125
#  - Ground-thruth (80-th perc.) = 3.3392
#  - Ground-thruth (95-th perc.) = 3.3587
#  - Ground-thruth (100-th perc.) = 3.4279
#  - Edit distance (median) = 9.0
# Epoch 39/50
# 100/100 [==============================] - 11s 115ms/step - loss: 0.2482
#  - Oracle (80-th perc.) = 3.2099
#  - Ground-thruth (80-th perc.) = 3.3566
#  - Ground-thruth (95-th perc.) = 3.4148
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 7.0
# Epoch 40/50
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2484
#  - Oracle (80-th perc.) = 3.2138
#  - Ground-thruth (80-th perc.) = 3.3547
#  - Ground-thruth (95-th perc.) = 3.4036
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 7.0
# Epoch 41/50
# 100/100 [==============================] - 10s 97ms/step - loss: 0.2482
#  - Oracle (80-th perc.) = 3.2094
#  - Ground-thruth (80-th perc.) = 3.3565
#  - Ground-thruth (95-th perc.) = 3.4086
#  - Ground-thruth (100-th perc.) = 3.4335
#  - Edit distance (median) = 8.0
# Epoch 42/50
# 100/100 [==============================] - 10s 98ms/step - loss: 0.2506
#  - Oracle (80-th perc.) = 3.2187
#  - Ground-thruth (80-th perc.) = 3.3315
#  - Ground-thruth (95-th perc.) = 3.378
#  - Ground-thruth (100-th perc.) = 3.4122
#  - Edit distance (median) = 10.0
# Epoch 43/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2478
#  - Oracle (80-th perc.) = 3.2124
#  - Ground-thruth (80-th perc.) = 3.3466
#  - Ground-thruth (95-th perc.) = 3.4035
#  - Ground-thruth (100-th perc.) = 3.4335
#  - Edit distance (median) = 8.0
# Epoch 44/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2482
#  - Oracle (80-th perc.) = 3.2099
#  - Ground-thruth (80-th perc.) = 3.3447
#  - Ground-thruth (95-th perc.) = 3.3797
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 8.0
# Epoch 45/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2491
#  - Oracle (80-th perc.) = 3.2176
#  - Ground-thruth (80-th perc.) = 3.3563
#  - Ground-thruth (95-th perc.) = 3.395
#  - Ground-thruth (100-th perc.) = 3.4096
#  - Edit distance (median) = 7.0
# Epoch 46/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2479
#  - Oracle (80-th perc.) = 3.2105
#  - Ground-thruth (80-th perc.) = 3.3387
#  - Ground-thruth (95-th perc.) = 3.3786
#  - Ground-thruth (100-th perc.) = 3.4304
#  - Edit distance (median) = 8.0
# Epoch 47/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2487
#  - Oracle (80-th perc.) = 3.2099
#  - Ground-thruth (80-th perc.) = 3.3414
#  - Ground-thruth (95-th perc.) = 3.3706
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 8.0
# Epoch 48/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2479
#  - Oracle (80-th perc.) = 3.2073
#  - Ground-thruth (80-th perc.) = 3.331
#  - Ground-thruth (95-th perc.) = 3.3711
#  - Ground-thruth (100-th perc.) = 3.3999
#  - Edit distance (median) = 8.5
# Epoch 49/50
# 100/100 [==============================] - 7s 66ms/step - loss: 0.2487
#  - Oracle (80-th perc.) = 3.2126
#  - Ground-thruth (80-th perc.) = 3.3522
#  - Ground-thruth (95-th perc.) = 3.3813
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 10.0
# Epoch 50/50
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2478
#  - Oracle (80-th perc.) = 3.2136
#  - Ground-thruth (80-th perc.) = 3.3526
#  - Ground-thruth (95-th perc.) = 3.3913
#  - Ground-thruth (100-th perc.) = 3.4294
#  - Edit distance (median) = 9.0

# %%
run_experimental_den_opt(0, repeat_start=0, repeats=1, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.50, vae_log_p_margin=1000.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
run_experimental_den_opt(1, repeat_start=0, repeats=1, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.50, vae_log_p_margin=1000.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
run_experimental_den_opt(2, repeat_start=0, repeats=1, fitness_loss_mode='log_sf', target_val=3.15, similarity_margin=0.50, vae_log_p_margin=1000.0, decoded_pwm_eps=0.0001, fitness_weight=0.05)
